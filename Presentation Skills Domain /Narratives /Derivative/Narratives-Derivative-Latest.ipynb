# %%
import nltk
import codecs
#import pronto
import itertools


from nltk.tokenize import PunktSentenceTokenizer,sent_tokenize, word_tokenize
from nltk.corpus import stopwords, wordnet

from nltk.stem import WordNetLemmatizer, PorterStemmer
import signal, ctypes
from pronto import Ontology
from pronto import *
import re
import pandas as pd
from pandas import DataFrame
import math
from difflib import SequenceMatcher
import sys
import collections
from collections import Counter
import statistics 
import ast
#aggregates=pd.read_excel("Videos Cleaned Aggregates For Narratives .xlsx",sheet_name ="Sheet1")
#aggregates=pd.read_excel("Videos Cleaned Aggregates For Narratives-with duration .xlsx",sheet_name ="Sheet1")

#aggregates=pd.read_excel("Videos Cleaned Aggregates For Narratives2 .xlsx",sheet_name ="Sheet1") 
aggregates=pd.read_excel("Videos Cleaned Aggregates For Narratives3-delete first and last seg .xlsx",sheet_name ="Sheet1")  
print('With duration')
print()

for i in aggregates:
    print(i)
    print()

videoId=list(aggregates['VideoID'])

startTime=list(aggregates['Start'])
endTime=list(aggregates['End'])
# this is added here but not in the aggregation file in the aggregation folder
duration=list(aggregates['Duration'])
##################################################################
focusTopic=list(aggregates['Focus Topic'])+list(aggregates['Unnamed: 5'])+list(aggregates['Unnamed: 6'])+list(aggregates['Unnamed: 7'])

fC1=list(aggregates['Focus Concept'])
w1=list(aggregates['Focus Concept Weight'])
fC2=list(aggregates['Unnamed: 10'])
w2=list(aggregates['Unnamed: 11'])
fC3=list(aggregates['Unnamed: 12'])
w3=list(aggregates['Unnamed: 13'])
fC4=list(aggregates['Unnamed: 14'])
w4=list(aggregates['Unnamed: 15'])
fC5=list(aggregates['Unnamed: 16'])
w5=list(aggregates['Unnamed: 17'])

oC1=list(aggregates['Unnamed: 19'])
wOC1=list(aggregates['Unnamed: 20'])
oC2=list(aggregates['Unnamed: 21'])
wOC2=list(aggregates['Unnamed: 22'])
oC3=list(aggregates['Unnamed: 23'])
wOC3=list(aggregates['Unnamed: 24'])
oC4=list(aggregates['Unnamed: 25'])
wOC4=list(aggregates['Unnamed: 26'])
oC5=list(aggregates['Unnamed: 27'])
wOC5=list(aggregates['Unnamed: 28'])
oC6=list(aggregates['Unnamed: 29'])
wOC6=list(aggregates['Unnamed: 30'])
oC7=list(aggregates['Unnamed: 31'])
wOC7=list(aggregates['Unnamed: 32'])
oC8=list(aggregates['Unnamed: 33'])
wOC8=list(aggregates['Unnamed: 34'])
oC9=list(aggregates['Unnamed: 35'])
wOC9=list(aggregates['Unnamed: 36'])
oC10=list(aggregates['Unnamed: 37'])
wOC10=list(aggregates['Unnamed: 38'])
oC11=list(aggregates['Unnamed: 39'])
wOC11=list(aggregates['Unnamed: 40'])
oC12=list(aggregates['Unnamed: 41'])
wOC12=list(aggregates['Unnamed: 42'])
oC13=list(aggregates['Unnamed: 43'])
wOC13=list(aggregates['Unnamed: 44'])
oC14=list(aggregates['Unnamed: 45'])
wOC14=list(aggregates['Unnamed: 46'])
oC15=list(aggregates['Unnamed: 47'])
wOC15=list(aggregates['Unnamed: 48'])
oC16=list(aggregates['Unnamed: 49'])
wOC16=list(aggregates['Unnamed: 50'])
#oC17=list(aggregates['Unnamed: 51'])
#wOC17=list(aggregates['Unnamed: 52'])
#oC18=list(aggregates['Unnamed: 53'])
#wOC18=list(aggregates['Unnamed: 54'])






segCharacterisation=[]
for i in range(len(videoId)):
    segCharacterisation.append([videoId[i],startTime[i],endTime[i],int(duration[i]),[fC1[i],w1[i],fC2[i],w2[i],fC3[i],w3[i],fC4[i],
    w4[i],fC5[i],w5[i]],[oC1[i],wOC1[i],oC2[i],wOC2[i],oC3[i],wOC3[i],oC4[i],wOC4[i],oC5[i],wOC5[i],oC6[i],wOC6[i],
    oC7[i],wOC7[i],oC8[i],wOC8[i],oC9[i],wOC9[i],oC10[i],wOC10[i],oC11[i],wOC11[i],oC12[i],wOC12[i],
    oC13[i],wOC13[i],oC14[i],wOC14[i],oC15[i],wOC15[i],oC16[i],wOC16[i]]]) #oC17[i],wOC17[i],oC18[i],wOC18[i]]])

# I want to find the segments with oneFC. I think they will be good to start with in generating their narratives
# This could help in deciding which narratives to use for the evaluation

segWithOneFC=[]
segWithTwoFC=[]
segWithMoreFC=[]
otherCon=[]
for i in  segCharacterisation  :
    
    c=0
    j=0
    if i[4]:
        while j <= len(i[4])-2:
            if str(i[4][j]) != 'nan':
                c+=1
            j+=2
        
    if c==1:
        conc=[]
        otherCon=[]
        j=0
        while j <= len(i[4])-2:
            if str(i[4][j]) != 'nan':
                conc.append([i[4][j],i[4][j+1]])
            j+=2
        j=0
        if i[5]:
            while j <= len(i[5])-2:
                
                if str(i[5][j]) != 'nan':
                    otherCon.append([i[5][j],i[5][j+1]])
                j+=2
        segWithOneFC.append([i[0],i[1],i[2],i[3],conc,otherCon])
        conc=[]
        otherCon=[]
    if c==2:
        conc=[]
        otherCon=[]
        j=0
        while j <= len(i[4])-2:
            if str(i[4][j]) != 'nan':
                conc.append([i[4][j],i[4][j+1]])
            j+=2
        j=0
        if i[5]:
            while j <= len(i[5])-2:
                
                if str(i[5][j]) != 'nan':
                    otherCon.append([i[5][j],i[5][j+1]])
                j+=2
        segWithTwoFC.append([i[0],i[1],i[2],i[3],conc,otherCon])
        conc=[]
        otherCon=[]
    if c>=3:
        conc=[]
        otherCon=[]
        j=0
        while j <= len(i[4])-2:
            if str(i[4][j]) != 'nan':
                conc.append([i[4][j],i[4][j+1]])
            j+=2
        j=0
        if i[5]:
            while j <= len(i[5])-2:
                
                if str(i[5][j]) != 'nan':
                    otherCon.append([i[5][j],i[5][j+1]])
                j+=2
        segWithMoreFC.append([i[0],i[1],i[2],i[3],conc,otherCon])
        conc=[]
        otherCon=[]


print('# of segments with one FC= ',len(segWithOneFC))  
print()
print('# of segments with Two FC= ',len(segWithTwoFC))   
print()
print('# of segments with More FC= ',len(segWithMoreFC))   
print()
if  segWithOneFC:
    print('Seg with one FC')
    print('*******************************************************')
    print()
    for i in segWithOneFC:
        print(i)
        print()
if segWithTwoFC:
    print('Seg with Two FC')
    print('*******************************************************')
    print()
    for i in segWithTwoFC:
        print(i)
        print()
if segWithMoreFC:
    print('Seg with More than 3 FC')
    print('*******************************************************')
    for i in segWithMoreFC:
        print(i)
        print()
# Out:
# With duration
#
# VideoID
#
# Start
#
# End
#
# Duration
#
# Focus Topic
#
# Unnamed: 5
#
# Unnamed: 6
#
# Unnamed: 7
#
# Focus Concept
#
# Focus Concept Weight
#
# Unnamed: 10
#
# Unnamed: 11
#
# Unnamed: 12
#
# Unnamed: 13
#
# Unnamed: 14
#
# Unnamed: 15
#
# Unnamed: 16
#
# Unnamed: 17
#
# Other concepts
#
# Unnamed: 19
#
# Unnamed: 20
#
# Unnamed: 21
#
# Unnamed: 22
#
# Unnamed: 23
#
# Unnamed: 24
#
# Unnamed: 25
#
# Unnamed: 26
#
# Unnamed: 27
#
# Unnamed: 28
#
# Unnamed: 29
#
# Unnamed: 30
#
# Unnamed: 31
#
# Unnamed: 32
#
# Unnamed: 33
#
# Unnamed: 34
#
# Unnamed: 35
#
# Unnamed: 36
#
# Unnamed: 37
#
# Unnamed: 38
#
# Unnamed: 39
#
# Unnamed: 40
#
# Unnamed: 41
#
# Unnamed: 42
#
# Unnamed: 43
#
# Unnamed: 44
#
# Unnamed: 45
#
# Unnamed: 46
#
# Unnamed: 47
#
# Unnamed: 48
#
# Unnamed: 49
#
# Unnamed: 50
#
# Unnamed: 51
#
# Unnamed: 52
#
# Unnamed: 53
#
# Unnamed: 54
#
# # of segments with one FC=  141
#
# # of segments with Two FC=  64
#
# # of segments with More FC=  38
#
# ...

# %%
from numpy import nan
conceptsPath=pd.read_excel("Presentation Skills Ontology as Concepts PAths.xlsx",sheet_name ="concept Path") 
cleanedParents2=[]

con1=list(conceptsPath['Concept'])

con2=list(conceptsPath['Concept Path'])

con3=list(conceptsPath['Unnamed: 2'])

con4=list(conceptsPath['Unnamed: 3'])

con5=list(conceptsPath['Unnamed: 4'])

con6=list(conceptsPath['Unnamed: 5'])

con7=list(conceptsPath['Unnamed: 6'])

for i in range(0,len(con1)):
    
    cleanedParents2.append([con1[i],con2[i],con3[i],con4[i],con5[i],con6[i],con7[i]])

cleanedP=[]
for i in cleanedParents2:
    cleanedP.append([item for item in i if not(pd.isnull(item)) == True])
cleanedParents2=cleanedP
for i in cleanedParents2:
    print(i)
    print()
# Out:
# ['Accent', 'Paralanguage', 'NonVerbalCommunication', 'Delivery']
#
# ['Acknowledgement', 'ClosingComponentOpeningComponent', 'StructureComponent', 'Structure']
#
# ['AcquireKnowledge', 'ContentPreparation', 'Preparation', 'Delivery']
#
# ['Adaptability', 'PresentationAttribute']
#
# ['Aim', 'ContentIntroduction', 'OpeningComponent', 'StructureComponent', 'Structure']
#
# ['Analogy', 'RhetoricalDevice', 'VerbalCommunication', 'Delivery']
#
# ['Analysis', 'BodyComponent', 'StructureComponent', 'Structure']
#
# ['Animation', 'MovingImage', 'Illustration', 'VisualAidArtefact', 'VisualAid']
#
# ['Animations', 'MovingImage', 'Illustration', 'VisualAidArtefact', 'VisualAid']
#
# ['Anticlimax', 'RhetoricalDevice', 'VerbalCommunication', 'Delivery']
#
# ['Antithesis', 'RhetoricalDevice', 'VerbalCommunication', 'Delivery']
#
# ['Anxiousness', 'SpeakerEmotion', 'Delivery']
#
# ['Approach', 'BodyComponent', 'StructureComponent', 'Structure']
#
# ['Appropriateness', 'PresentationAttribute']
#
# ...

# %%
# Remove nan values within the concepts in segCharacterisation and save the result into segCharacterisation1
segCharacterisation1=[]
tempCon1=[]
tempCon2=[]

for i in segCharacterisation  : 
    for j in i[4]:
        if str(j) != 'nan':
            tempCon1.append(j)
    for j in i[5]:
        if str(j) != 'nan':
            tempCon2.append(j)
    segCharacterisation1.append([i[0],i[1],i[2],i[3],tempCon1,tempCon2]) 
    tempCon1=[]
    tempCon2=[]
print()
print('# of segments  ',len(segCharacterisation1))
print()
for i in  segCharacterisation1:
    
    print(i)
    print()
    print('________________________')
# Out:
# # of segments   247
#
# ['MnIPpUiTcRc', 0.14, 0.41, 27, ['Organization', 1.0, 'Impact', 1.0, 'Memorable', 1.0, 'Audience', 2.0], []]
#
# ________________________
# ['MnIPpUiTcRc', 1.05, 1.23, 18, ['Audience', 1.0], []]
#
# ________________________
# ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]
#
# ________________________
# ['MnIPpUiTcRc', 3.36, 4.0, 24, ['Summary', 1.0, 'MainPoint', 1.0, 'Beginning', 1.0, 'Middle', 1.0, 'End', 1.0], []]
#
# ________________________
# ['MnIPpUiTcRc', 4.0, 4.55, 55, ['Audience', 3.0], ['Story', 2.0, 'Information', 1.0, 'Memorable', 1.0, 'Attention', 1.0, 'Delivery', 1.0, 'Comfortable', 1.0]]
#
# ________________________
# ...

# %%
# Remove segments with duration <20 seconds
segCharacterisation2=[]
for i in  segCharacterisation1:
    if i[3] >=20:
        segCharacterisation2.append(i)
print('# of segments left after removing the segments with duration <20 sec ',len(segCharacterisation2))
print()
for i in segCharacterisation2:
    print(i)
    print()
    print('________________________')
# Out:
# # of segments left after removing the segments with duration <20 sec  226
#
# ['MnIPpUiTcRc', 0.14, 0.41, 27, ['Organization', 1.0, 'Impact', 1.0, 'Memorable', 1.0, 'Audience', 2.0], []]
#
# ________________________
# ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]
#
# ________________________
# ['MnIPpUiTcRc', 3.36, 4.0, 24, ['Summary', 1.0, 'MainPoint', 1.0, 'Beginning', 1.0, 'Middle', 1.0, 'End', 1.0], []]
#
# ________________________
# ['MnIPpUiTcRc', 4.0, 4.55, 55, ['Audience', 3.0], ['Story', 2.0, 'Information', 1.0, 'Memorable', 1.0, 'Attention', 1.0, 'Delivery', 1.0, 'Comfortable', 1.0]]
#
# ________________________
# ['MnIPpUiTcRc', 4.56, 6.19, 83, ['Confidence', 5.0], ['Audience', 3.0, 'Comfortable', 1.0, 'Figure', 1.0, 'Enthusiasm', 2.0, 'Practice', 3.0]]
#
# ...

# %%
# Derivative after correcting the understanding

ontConcWithSuitablePath=[]
conceptPathChecking=[]
xx=[]
# 1. extract from the ontology the concepts with path length >=3. Two levels away from the topic
for c in cleanedParents2:
    if  len(c) >=3:
        ontConcWithSuitablePath.append(c)
        
# 2. Retrive all the concepts that has path >=3

print(' number of all segments = ',len(segCharacterisation2))
print()
for i in segCharacterisation2:
    if i[4]:
        if len(i[4])==2:
            xx=[x for x in ontConcWithSuitablePath if x[0] ==i[4][0]]
            if xx:
                if xx not in conceptPathChecking:
                    conceptPathChecking.append(xx[0])
            
        
        elif len(i[4])==4: # other wise it is not suitable to introduce a specific concept
            for j in range(0,len(i[4]),2):
                xx=[x for x in ontConcWithSuitablePath if x[0] ==i[4][j]]
                if xx:
                    if xx not in conceptPathChecking:
                        conceptPathChecking.append(xx[0])

# 3. check the parent of the concept we want to learn. if the concept path=3, then check direct parent only. Else, check parent except the last one in the paty (topic)
print('number of segments with path >=3 ',len(conceptPathChecking))
print()

conceptDerivative=[]
concFullDeriv=[]
processedCon=[]
conceptSeg=[]
for i in conceptPathChecking:
    if i[0] not in processedCon:
        processedCon.append(i[0])
        #print(i)
        #print()

        for j in segCharacterisation2:
            if len(j[4])==2:

                if j[4][0] in i[1:-1]:
                    if j not in conceptDerivative:
                        conceptDerivative.append([j[4][0],j])
                if j[4][0]== i[0]:
                    if j not in conceptSeg:
                        conceptSeg.append([j[4][0],j])
               
            elif len(j[4])>2:
                for k in range(0,len(j[4]),2):
                    if j[4][k] in i[1:-1]:
                        if j not in conceptDerivative:
                            conceptDerivative.append([j[4][k],j])
                    if j[4][k]== i[0]:
                        if j not in conceptSeg:
                            conceptSeg.append([j[4][k],j])
                            
        if conceptDerivative:
            
            concFullDeriv.append([i[0],conceptDerivative,conceptSeg])
            conceptDerivative=[]
        conceptSeg=[]
            
                
for i in   concFullDeriv:
    print(i[0])
    print()
    for j in i[1]:
        print(j)
        print()
    print()
    for j in i[2]:
        print(j)
        print()
    print('______________________________________________')
    print()
# Out:
#  number of all segments =  226
#
# number of segments with path >=3  175
#
# Graph
#
# ['Figure', ['Hp7Id3Yb9XQ', 16.56, 17.39, 43, ['Figure', 2.0, 'Slide', 2.0], []]]
#
# ['Figure', ['Hp7Id3Yb9XQ', 21.2, 23.07, 107, ['Slide', 3.0, 'Figure', 3.0], ['Image', 1.0, 'Animation', 1.0]]]
#
# ['Figure', ['Yl_FJAOcFgQ', 4.28, 5.02, 33, ['Figure', 1.0], []]]
#
#
# ['Graph', ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]]
#
# ['Graph', ['bgFNTuRYtKE', 5.1, 5.35, 25, ['Graph', 1.0, 'Highlight', 1.0], []]]
#
# ______________________________________________
#
# Memorable
#
# ['Impact', ['MnIPpUiTcRc', 0.14, 0.41, 27, ['Organization', 1.0, 'Impact', 1.0, 'Memorable', 1.0, 'Audience', 2.0], []]]
#
# ...

# %%
# Filter concept derivative narratives based on conditions
concSeg=[]
concSeg2=[]
multiConcSeg=[]
singleConcSeg=[]
concCharc=[]
length=[]
processed=[]
processedSeg=[]
def collectSegWithinSameVideo(segments, seg):
    group=[]
    process=[]
    group.append(seg)
    process.append(seg)
    for i in segments:
        if seg[1][0]==i[1][0] and seg!=i:
            
            group.append(i)
            
            process.append(i)
    return group,process
        
for i in   concFullDeriv:
    concSeg=[]
    concSeg2=[]
    if i[0] not in processed:
        processed.append(i[0])
    

        #print(i[0])
        #print()#
        
        #concSeg.append(i[0])
        
        # group the parent segments based on their video
        
        seg=i[1]
        #print('seg= ',seg)
        #print()
        #print('len(seg = )',len(seg))
        #print()
        segProcessed=[]
        c=0
        multi=[]
        pro=[]
        processedSeg=[]
        multiConcSeg=[]
        singleConcSeg=[]
        if len(seg)>=3:
           
            for j in seg:
                if j not in processedSeg:
                    processedSeg.append(j)
                    if j != seg[-1]:
                        multi,pro=collectSegWithinSameVideo(seg[1:], j)
                        
                        if len(pro) >1:
                            for p in pro:
                                processedSeg.append(p)

                        if len(multi)>1:
                            if multi not in multiConcSeg:

                                multiConcSeg.append(multi)
                            

                        else:
                            if j not in singleConcSeg:
                                singleConcSeg.append(j)
                            
                    else:
                        #print('j is the last element ',j)
                        #print()
                        #print('singleConcSeg ',singleConcSeg)
                        #print()
                        if j not in singleConcSeg:
                            #print('add j ')
                            singleConcSeg.append(j)
                            #print(singleConcSeg)
                        

                    #if multiConcSeg:
                    #    if [multiConcSeg,singleConcSeg] not in concSeg:
                    #        concSeg.append([multiConcSeg,singleConcSeg])
                    #else:
                    #    if singleConcSeg not in concSeg:
                    #        concSeg.append(singleConcSeg)

                    #multiConcSeg=[]
                    #singleConcSeg=[]
        elif len(seg)==2:
            if seg[0][1][0]==seg[1][1][0]:
                if seg[0] not in multiConcSeg:
                    multiConcSeg.append(seg[0])
                if seg[1]  not in  multiConcSeg:
                    multiConcSeg.append(seg[1])
            else:
                if seg[0] not in singleConcSeg: 
                    singleConcSeg.append(seg[0])
                if seg[1] not in singleConcSeg:
                    singleConcSeg.append(seg[1])
        elif len(seg)==1:
            if seg[0] not in singleConcSeg:
                singleConcSeg.append(seg[0]) 
        
        if multiConcSeg:
            if [multiConcSeg,singleConcSeg] not in concSeg:
                concSeg.append([multiConcSeg,singleConcSeg])
        else:
            if singleConcSeg not in concSeg:
                concSeg.append(singleConcSeg)
            
            
        multiConcSeg=[]
        singleConcSeg=[]
        
        # group the concept segments based on their video
        if len(i)==3:
            seg2=i[2]
            #print('seg= ',seg)
            #print()
            #print('len(seg = )',len(seg))
            #print()
            segProcessed=[]
            c=0
            multi=[]
            pro=[]
            processedSeg=[]
            multiConcSeg=[]
            singleConcSeg=[]
            if len(seg)>=3:

                for j in seg2:
                    if j not in processedSeg:
                        processedSeg.append(j)
                        if j != seg2[-1]:
                            multi,pro=collectSegWithinSameVideo(seg2[1:], j)

                            if len(pro) >1:
                                for p in pro:
                                    processedSeg.append(p)

                            if len(multi)>1:
                                
                                
                                if multi not in multiConcSeg:

                                    multiConcSeg.append(multi)


                            else:
                                if j not in singleConcSeg:
                                    singleConcSeg.append(j)

                        else:
                            #print('j is the last element ',j)
                            #print()
                            #print('singleConcSeg ',singleConcSeg)
                            #print()
                            if j not in singleConcSeg:
                                #print('add j ')
                                singleConcSeg.append(j)
                                #print(singleConcSeg)


                        #if multiConcSeg:
                        #    if [multiConcSeg,singleConcSeg] not in concSeg:
                        #        concSeg.append([multiConcSeg,singleConcSeg])
                        #else:
                        #    if singleConcSeg not in concSeg:
                        #        concSeg.append(singleConcSeg)

                        #multiConcSeg=[]
                        #singleConcSeg=[]
            elif len(seg)==2:
                if seg[0][1][0]==seg[1][1][0]:
                    multiConcSeg.append(seg[0])
                    multiConcSeg.append(seg[1])
                else:
                    singleConcSeg.append(seg[0])
                    singleConcSeg.append(seg[1])
            elif len(seg)==1:
                singleConcSeg.append(seg[0]) 

            if multiConcSeg:
                if [multiConcSeg,singleConcSeg] not in concSeg2:
                    concSeg2.append([multiConcSeg,singleConcSeg])
            else:
                if singleConcSeg not in concSeg2:
                    concSeg2.append(singleConcSeg)


            multiConcSeg=[]
            singleConcSeg=[]



        if concSeg != concSeg2:
            if [i[0],concSeg,concSeg2] not in concCharc:
                print('[i[0],concSeg,concSeg2] not in concCharc ',[i[0],concSeg,concSeg2])
                print()

                concCharc.append([i[0],concSeg,concSeg2]) 
                print('concCharc ',concCharc)
                print()
        else:
            
            if [i[0],concSeg] not in concCharc:
                print('[i[0],concSeg] not in concCharc ',[i[0],concSeg])
                print()

                concCharc.append([i[0],concSeg]) 
                print('concCharc ',concCharc)
                print()
    concSeg=[]
    concSeg2=[]
                    
#to calculate the duration of the segments to use it in the conditional narratives

length=[]
length1=[]
cleanedNarrCharac=[]
temp=[]
temp2=[]
for i in concCharc:
    for j in i:
        print(j)
        print()
    print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^')
for i in concCharc:
    #print(i[0])
    for j in i[1]:
        print('*********************************************')
        print('j of i[1] ',j)
        print()
    
        #temp.append(i[0])
    
        if  type(j[0][0])==list:
            print('_______ For each j in i[1] _____________________')
            print()
            for x in j:
                while type(x[0][0])==list:
                    x1=x[0]
                    x=x1
                if type(x[0])==list:
                    for x1 in x:
                        print('x1 ',x1)
                        print()
                        if x1 not in temp:
                            temp.append(x1)
                else:
                    print('x  ',x)
                    print()
                    
                    if x not in temp:
                        temp.append(x)
        else:
            if type(j[0])==list:
                for x1 in j:
                    print('x1 of j ',x1)
                    print()
                    
                    if x1 not in temp:
                        temp.append(x1)
            else:
                print('j  ',j)
                print()
                if j not in temp:
                    temp.append(j)
                
            
    if len(i)==3:               
        for j in i[2]:
            temp2=[]
            print('j of i[2]= ',j)
            print()
            if  type(j[0][0])==list:
                print('_______ For each j in i[2] _____________________')
                print()
                for x in j:
                    print('x of j  = ',x)
                    print()
                    if x:
                        while type(x[0][0])==list:
                            x1=x[0]
                            x=x1
                        if type(x[0])==list:
                            for x1 in x:
                                print('x1 ',x1)
                                print()
                                if x1 not in temp2:
                                    temp2.append(x1)

                        else:
                            print('x  ',x)
                            print()
                            if x not in temp2:
                                temp2.append(x)

            else:
                if type(j[0])==list:
                    for x1 in j:
                        print('x1 of j ',x1)
                        print()
                        if x1 not in temp2:

                            temp2.append(x1)

                else:
                    print('j  ',j)
                    print()
                    if j not in temp2:
                        temp2.append(j)

    if temp2:   
        if [i[0],temp,temp2] not in  cleanedNarrCharac:  
            cleanedNarrCharac.append([i[0],temp,temp2])
    else:
        if [i[0],temp] not in  cleanedNarrCharac:  
            cleanedNarrCharac.append([i[0],temp])
    temp=[]
    temp2=[]
    #print('___________________________________________________')
# Out:
# [i[0],concSeg,concSeg2] not in concCharc  ['Graph', [[[[['Figure', ['Hp7Id3Yb9XQ', 16.56, 17.39, 43, ['Figure', 2.0, 'Slide', 2.0], []]], ['Figure', ['Hp7Id3Yb9XQ', 21.2, 23.07, 107, ['Slide', 3.0, 'Figure', 3.0], ['Image', 1.0, 'Animation', 1.0]]]]], [['Figure', ['Yl_FJAOcFgQ', 4.28, 5.02, 33, ['Figure', 1.0], []]]]]], [[['Graph', ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]], ['Graph', ['bgFNTuRYtKE', 5.1, 5.35, 25, ['Graph', 1.0, 'Highlight', 1.0], []]]]]]
#
# ...

# %%
for i in cleanedNarrCharac:
    print(i[0])
    print()
    for j in i[1]:
        print(j)
        print()
    if len(i)==3:
        for j in i[2]:
            print(j)
            print()
            
    print('_____________________________________')
# Out:
# Graph
#
# ['Figure', ['Hp7Id3Yb9XQ', 16.56, 17.39, 43, ['Figure', 2.0, 'Slide', 2.0], []]]
#
# ['Figure', ['Hp7Id3Yb9XQ', 21.2, 23.07, 107, ['Slide', 3.0, 'Figure', 3.0], ['Image', 1.0, 'Animation', 1.0]]]
#
# ['Figure', ['Yl_FJAOcFgQ', 4.28, 5.02, 33, ['Figure', 1.0], []]]
#
# ['Graph', ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]]
#
# ['Graph', ['bgFNTuRYtKE', 5.1, 5.35, 25, ['Graph', 1.0, 'Highlight', 1.0], []]]
#
# _____________________________________
# Memorable
#
# ['Impact', ['MnIPpUiTcRc', 0.14, 0.41, 27, ['Organization', 1.0, 'Impact', 1.0, 'Memorable', 1.0, 'Audience', 2.0], []]]
#
# ['Impact', ['i5mYphUoOCs', 0.04, 1.09, 65, ['Stand', 2.0, 'Communication', 2.0, 'Impact', 1.0], []]]
#
# ...

# %%
# Add the condition
#concept='Highlight'
segMin=2
segMax=6
durMin=120
durMax=300
maximumSeg=0
duration=0
numbOfSeg=0
narrative=[]
temp=[]
temp2=[]
#for i in cleanedNarrCharac:
#    for j in i:
#        print(j)
#        print()
#to get the name of all the concepts we have narratives about
conceptsList=[]
for i in cleanedNarrCharac:
    conceptsList.append(i[0])
narrative=[]
processedConcepts=[]
for i in cleanedNarrCharac:
    maximumSeg=0
    duration=0
    numbOfSeg=0
    
    temp=[]
    temp2=[]
    if i[0] not in processedConcepts:
        #print('i[0]= ',i[0])
        processedConcepts.append(i[0])
        # Group the parent segments if they are from the same video. It is best to watch them first
        
        #temp.append(concept)
        
        if len(i)==3:
            if len(i[2]) >=int(segMax/2):
                maximumSeg=int(segMax/2)
            else:
                
                maximumSeg=segMax-len(i[2])
        else:
            maximumSeg=segMax
        #print('maximumSeg ',maximumSeg)
        for j in i[1]:
            #print('j= ',j)
            #print()
            if (duration+j[1][3]) <= durMax and (numbOfSeg+1) <=maximumSeg:
                #print('the conditions are met and temp = ',temp)
                temp.append(j)
                #print('the conditions are met and temp = ',temp)
                #print()
                duration+=j[1][3]
                numbOfSeg+=1
            
            if  len(i[1]) ==numbOfSeg or numbOfSeg == maximumSeg : 
                if len(i)==3:
                    #print('we will start with i[2]')

                    for j2 in i[2]:


                        if (duration+j2[1][3]) <= durMax and (numbOfSeg+1) <=segMax:
                            #print('the conditions are met and temp = ',temp)
                            temp2.append(j2)
                            #print('the conditions are met and temp = ',temp)
                            #print()
                            duration+=j2[1][3]
                            numbOfSeg+=1
                    #else:
                    #    narrative.append(temp2)
                    #    temp2=[]

        
            
            
        if [i[0],temp,temp2] not in narrative:
            #print([i[0],temp,temp2],' not in ',narrative)
            narrative.append([i[0],temp,temp2])
            temp=[]
            temp2=[]
            #print('narrative after ',narrative)
            #print()
print('# of derivative narratives = ',len(narrative))
narrative2=[]
for i in narrative:
    
    for c in cleanedParents2:
        if c[0]==i[0]:
            topic=c[-1]
    narrative2.append([topic,i])
        
    print(i[0])
    for j in i[1]:
        print(j)
        print()
    for j in i[2]:
        print(j)
        print()
# Out:
# # of derivative narratives =  22
# Graph
# ['Figure', ['Hp7Id3Yb9XQ', 16.56, 17.39, 43, ['Figure', 2.0, 'Slide', 2.0], []]]
#
# ['Figure', ['Hp7Id3Yb9XQ', 21.2, 23.07, 107, ['Slide', 3.0, 'Figure', 3.0], ['Image', 1.0, 'Animation', 1.0]]]
#
# ['Figure', ['Yl_FJAOcFgQ', 4.28, 5.02, 33, ['Figure', 1.0], []]]
#
# ['Graph', ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]]
#
# Memorable
# ['Impact', ['MnIPpUiTcRc', 0.14, 0.41, 27, ['Organization', 1.0, 'Impact', 1.0, 'Memorable', 1.0, 'Audience', 2.0], []]]
#
# ['Impact', ['i5mYphUoOCs', 0.04, 1.09, 65, ['Stand', 2.0, 'Communication', 2.0, 'Impact', 1.0], []]]
#
# ['Impact', ['1VCaJ4dSHak', 0.07, 0.44, 37, ['Gesture', 2.0, 'Audience', 1.0, 'Impact', 1.0], []]]
#
# ...

# %%
length=[]
c=0
for i in narrative2:
    c=0
    print('topoic ',i[0])# topic
    print('concept i[1][0] ',i[1][0])
    print('Parent concept i[1][1][0][0] ',i[1][1][0][0])
    for j in i[1][1]:
        if c==0:
            print('You will watch an episode')
            c+=1
        else:
            print('you have watched and now will watch again')
            c+=1
        
        for k in j:
            print('k ',k)
            print
    print('***********************')
    if len(i[1][2])>=1:
        c=0
        print('i[1][2][0][0] ',i[1][2][0][0])
        print('About the concept i[1][1][0][0] ',i[1][1][0][0])
        for j in i[1][2]:
            if c==0:
                print('You will watch an episode')
                c+=1
            else:
                print('you have watched and now will watch again')
                c+=1
        
            
            for k2 in j:
                print('k2 ',k2)
                print
    else:
        print('len(i[1][2]) ',len(i[1][2]) ,'   len(i[1][1]) ',len(i[1][1]))
        print(i[1][2])
        print('no concept segments')
    
    print('_________________________________')
print('length= ',length)
# Out:
# topoic  VisualAid
# concept i[1][0]  Graph
# Parent concept i[1][1][0][0]  Figure
# You will watch an episode
# k  Figure
# k  ['Hp7Id3Yb9XQ', 16.56, 17.39, 43, ['Figure', 2.0, 'Slide', 2.0], []]
# you have watched and now will watch again
# k  Figure
# k  ['Hp7Id3Yb9XQ', 21.2, 23.07, 107, ['Slide', 3.0, 'Figure', 3.0], ['Image', 1.0, 'Animation', 1.0]]
# you have watched and now will watch again
# k  Figure
# k  ['Yl_FJAOcFgQ', 4.28, 5.02, 33, ['Figure', 1.0], []]
# ***********************
# i[1][2][0][0]  Graph
# About the concept i[1][1][0][0]  Figure
# You will watch an episode
# k2  Graph
# k2  ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]
# _________________________________
# topoic  PresentationAttribute
# concept i[1][0]  Memorable
# Parent concept i[1][1][0][0]  Impact
# ...

# %%
narrative3=[]
temp=[]
temp2=[]
temp3=[]
listUnwanted=['V8eLdbKXGzk','i68a6M5FFBc&t','Yl_FJAOcFgQ']
for i in narrative2:
   
    
    for j in i[1][1]:
        
        if j[1][0] not in listUnwanted:
            temp2.append(j)
        
    if i[1][2]:
        for j2 in i[1][2]:
            
            if j2[1][0] not in listUnwanted:
                temp3.append(j2)
    
    #print('i[0]= ',i[0])
    #print('i[1][0] ',i[1][0])
    #print('temp2 ',temp2)
    #print()
    #print('temp3= ',temp3)
    #print()
    temp=[i[1][0],temp2,temp3]
    narrative3.append([i[0],temp])
    temp2=[]
    temp3=[]
for i in  narrative3:
    print('i[0] ',i[0])
    print('i[1][0] ',i[1][0])
    print()
    for j in i[1][1]:
        print('j ',j)
        print()
    if i[1][2]:
        for j2 in i[1][2]:
            print('j2= ',j2)
            print()
    else:
        print('i[1][2] is empty ',i[1][2])
    
    
    print('_________________________')
narrative2=narrative3
# Out:
# i[0]  VisualAid
# i[1][0]  Graph
#
# j  ['Figure', ['Hp7Id3Yb9XQ', 16.56, 17.39, 43, ['Figure', 2.0, 'Slide', 2.0], []]]
#
# j  ['Figure', ['Hp7Id3Yb9XQ', 21.2, 23.07, 107, ['Slide', 3.0, 'Figure', 3.0], ['Image', 1.0, 'Animation', 1.0]]]
#
# j2=  ['Graph', ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]]
#
# _________________________
# i[0]  PresentationAttribute
# i[1][0]  Memorable
#
# j  ['Impact', ['MnIPpUiTcRc', 0.14, 0.41, 27, ['Organization', 1.0, 'Impact', 1.0, 'Memorable', 1.0, 'Audience', 2.0], []]]
#
# j  ['Impact', ['i5mYphUoOCs', 0.04, 1.09, 65, ['Stand', 2.0, 'Communication', 2.0, 'Impact', 1.0], []]]
#
# j  ['Impact', ['1VCaJ4dSHak', 0.07, 0.44, 37, ['Gesture', 2.0, 'Audience', 1.0, 'Impact', 1.0], []]]
#
# ...

# %%
narrative3=[]
temp=[]
temp2=[]
seg_alreadyTaken=[]
for i in  narrative2:
    print('i[0] ',i[0])
    print('i[1][0] ',i[1][0])
    print()
    for j in i[1][1]:
        print('j ',j)
        print()
        if j[1] not in seg_alreadyTaken:
            seg_alreadyTaken.append(j[1])
            temp.append(j)
    
            
    if i[1][2]:
        for j in i[1][2]:
            print('j= ',j)
            print()
            if j[1] not in seg_alreadyTaken:
                seg_alreadyTaken.append(j[1])
                temp2.append(j)
    narrative3.append([i[0],[i[1][0],temp,temp2]])
    temp=[]
    temp2=[]
    seg_alreadyTaken=[]
print('*********************************************************************')
for i in narrative3:
    print('i[0] ',i[0])
    print('i[1][0] ',i[1][0])
    print()
    for j in i[1][1]:
        print('j ',j)
        print()
        
            
    if i[1][2]:
        for j2 in i[1][2]:
            print('j2= ',j2)
            print()
    print('*****************************************')
            
narrative2=narrative3
# Out:
# i[0]  VisualAid
# i[1][0]  Graph
#
# j  ['Figure', ['Hp7Id3Yb9XQ', 16.56, 17.39, 43, ['Figure', 2.0, 'Slide', 2.0], []]]
#
# j  ['Figure', ['Hp7Id3Yb9XQ', 21.2, 23.07, 107, ['Slide', 3.0, 'Figure', 3.0], ['Image', 1.0, 'Animation', 1.0]]]
#
# j=  ['Graph', ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]]
#
# i[0]  PresentationAttribute
# i[1][0]  Memorable
#
# j  ['Impact', ['MnIPpUiTcRc', 0.14, 0.41, 27, ['Organization', 1.0, 'Impact', 1.0, 'Memorable', 1.0, 'Audience', 2.0], []]]
#
# j  ['Impact', ['i5mYphUoOCs', 0.04, 1.09, 65, ['Stand', 2.0, 'Communication', 2.0, 'Impact', 1.0], []]]
#
# j  ['Impact', ['1VCaJ4dSHak', 0.07, 0.44, 37, ['Gesture', 2.0, 'Audience', 1.0, 'Impact', 1.0], []]]
#
# j=  ['Memorable', ['Hp7Id3Yb9XQ', 18.13, 19.33, 79, ['Slide', 2.0, 'Memorable', 1.0], []]]
# ...

# %%
# write the result to excel sheet
import xlsxwriter
workbook = xlsxwriter.Workbook('Derivative Narratives2.xlsx')# save the puncutaed transcript to file with the same video ID
worksheet = workbook.add_worksheet('Derivative')
row=1
col=0
worksheet.write('A1', 'Focus Topic')
worksheet.write('B1', 'Focus Concept')
worksheet.write('C1', 'Video Topic Intro')
worksheet.write('D1', 'Narrative Intro')
worksheet.write('E1', 'Concept')
worksheet.write('F1','VideoID' )
worksheet.write('G1','Start Time' )
worksheet.write('H1','End Time' )
worksheet.write('I1', 'Duration')
worksheet.write('J1', 'Concepts within the segment')

concIntro=''
videoClosing=''
videoOpen=''
segOpening=''
counter=0
for i in narrative2:
    col=0
    counter=0
    tempCol=0
    
    worksheet.write(row,col,str(i[0]).upper())#topic
    worksheet.write(row,col+1,str(i[1][0]).upper())#concept
    videoOpen='This video is about the topic '+str(i[0]).upper()+' which relates to presentation skills.'
    
    worksheet.write(row,col+2,videoOpen)
    
    
    
    
    ## video Intro
    if len(i[1][1])>1:
        concIntro='From the topic '+str(i[0]).upper()+' ,you will learn about '+str(i[1][0] ).upper()+'. '+ str(i[1][0] ).upper()+ ' is an example of ' +str(i[1][1][0][0] ).upper()+'. '+ 'Hence, this video will present several video episodes that mention '+ str(i[1][1][0][0] ).upper()+'. '
        partOfvideoClosing=', this video presented you with several video episodes that mention ' 
    elif len(i[1][1])==1:
        concIntro='From the topic '+str(i[0]).upper()+' ,you will learn about '+str(i[1][0] ).upper()+'. '+ str(i[1][0] ).upper()+ ' is an example of ' +str(i[1][1][0][0] ).upper()+'. '+ 'Hence, this video will present a video episode that mentions '+ str(i[1][1][0][0] ).upper()+'. '
        partOfvideoClosing=', this video presented you with a video episode that mentions ' 
    worksheet.write(row,col+3,concIntro) 
    # opening seg / closing seg and opena another one
    row+=1
    tempCol=col+3 
    
   
    
    if len(i[1][1])>=1: 
        
        for j in i[1][1]:
             
            for k in j:
                
                
                
                if type(k)!=list:
                    cc=k #save the name of the concepts
                    #worksheet.write(row,tempCol,k)
                    #tempCol+=1
                if type(k)==list:
                    if counter==0:
                        segOpening='You will now watch a video episode that mentions ' + str(i[1][1][0][0] ).upper()+'. It is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                        counter+=1
                    else:
                        #segOpening='You have watched a video episode that mentions ' + str(i[1][1][0][0] ).capitalize()+'.  Now you will watch another video episode that mentions ' + str(i[1][1][0][0] )+'. '
                        segOpening='Now you will watch another video episode that mentions '+str(i[1][1][0][0] ).upper()+'. It is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                    worksheet.write(row,tempCol,segOpening)
                    tempCol+=1 
                    
                    worksheet.write(row,tempCol,str(cc).upper())
                    tempCol+=1 
                    
                    for k1 in k[0:4]:
                        worksheet.write(row,tempCol,k1)
                        tempCol+=1
                        
                    for m in k[4]:
                        worksheet.write(row,tempCol,m)# the parent concept name


                        tempCol+=1
                        

            row+=1
            col=1
            tempCol=col+2
    #row+=1
    #col=1
    tempCol=2
            
                
        
    counter=0
 
    if len(i[1][2])>1:
        
        videoClosing='To learn about ' +str(i[1][0] ).upper()+partOfvideoClosing +str(i[1][1][0][0] ).upper()+'. '+ str(i[1][0] ).upper()+' is an example of ' +str(i[1][1][0][0] ).upper()+'. '+ 'You can now watch several video episodes that mention '+ str(i[1][2][0][0] ).upper()+'.'
    elif len(i[1][2])==1:
        videoClosing='To learn about ' +str(i[1][0] ).upper()+partOfvideoClosing +str(i[1][1][0][0] ).upper()+'. '+ str(i[1][0] ).upper()+' is an example of ' +str(i[1][1][0][0] ).upper()+'. '+ 'You can now watch a video episode that mentions '+ str(i[1][2][0][0] ).upper()+'.'
    
    elif len(i[1][2])==0:
        videoClosing='To learn about ' +str(i[1][0] ).upper()+partOfvideoClosing+str(i[1][1][0][0] ).upper()+'. '+ str(i[1][0] ).upper()+' is an example of ' +str(i[1][1][0][0] ).upper()+'. '
    
    worksheet.write(row,tempCol,videoClosing)
    tempCol+=1
  
    
    #tempCol=col+1
    if len(i[1][2])>1:
       
        for j in i[1][2]:
            
            for k in j:

                
                if type(k)!=list:
                    cc=k
                    
                if type(k)==list:
                    if counter==0:
                        segOpening='You will now watch a video episode that mentions ' + str(i[1][2][0][0] ).upper()+'. It is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                        counter+=1
                    else:
                        segOpening='Now you will watch another video episode that mentions' + str(i[1][2][0][0] ).upper()+'. It is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                        counter+=1
                    worksheet.write(row,tempCol,segOpening)
                    tempCol+=1
                    worksheet.write(row,tempCol,str(cc).upper())
                    tempCol+=1 
                    for k1 in k[0:4]:
                        worksheet.write(row,tempCol,k1)
                        tempCol+=1
                        
                    for m in k[4]:
                        worksheet.write(row,tempCol,m)# the parent concept name


                        tempCol+=1

            row+=1
            col=1
            tempCol=3

    elif len(i[1][2])==1:
        
        for j in i[1][2]:
            for k in j:

                if type(k)!=list:
                    cc=k
                    
                if type(k)==list:
                    segOpening='You will now watch a video episode that mentions ' + str(i[1][2][0][0] ).upper()+'. It is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                    worksheet.write(row,tempCol,segOpening)
                    tempCol+=1
                    worksheet.write(row,tempCol,str(cc).upper())
                    tempCol+=1
                    for k1 in k[0:4]:
                        
                        worksheet.write(row,tempCol,k1)
                        tempCol+=1
                        
                    for m in k[4]:
                        worksheet.write(row,tempCol,m)# the parent concept name


                        tempCol+=1

            row+=1
            col=1
            tempCol=2
   
        
    row+=1
    col=1
    tempCol=1
workbook.close()

# %%
import statistics
length=[]
for i in narrative2:
    print('i[0] ',i[0])
    print()
    print('i[1][0]= ',i[1][0])
    print()
    
    for j in i[1][1]:
        print(j)
        print()
    if i[1][2]:
        print('second part')
        print()
        for j in i[1][2]:
            print(j)
            print()
uniqueDurationOFNarrative=[]
allNarrativesDur=[]
durationOfNarratives=0
numberOfNarratives=0
for i in narrative2:
    numberOfNarratives+=1

    print(i[0])
    print()
    if len(i[1])==2:
        print('length is 2')
        print()
        print('i[1][0]= ',i[1][0])
        for j in i[1][1]:
            print('j of i[1][1] ',j)
            if j[1][3] not in uniqueDurationOFNarrative:
                uniqueDurationOFNarrative.append(j[1][3])
            durationOfNarratives+=j[1][3]
            print()

    elif len(i[1])==3:
        print('length is 3')
        print()
        print('i[1][0]= ',i[1][0])
        for j in i[1][1]:
            print('j of i[1][1] ',j)
            print()
            if j[1][3] not in uniqueDurationOFNarrative:
                uniqueDurationOFNarrative.append(j[1][3])
            durationOfNarratives+=j[1][3]
        for j in i[1][2]:
            print('j of i[1][2] ',j)
            print()
            if j[1][3] not in uniqueDurationOFNarrative:
                uniqueDurationOFNarrative.append(j[1][3])
            durationOfNarratives+=j[1][3]
    allNarrativesDur.append([i[0],i[1][0],durationOfNarratives])
    durationOfNarratives=0
        
    
    
    print('___________________________________')
print('uniqueDurationOFNarrative = ',uniqueDurationOFNarrative)
sumDur=0
for i in uniqueDurationOFNarrative:
    sumDur+=i
print('AvgDuration of a segment  = ',round((sumDur/len(uniqueDurationOFNarrative)),2))
print()
print('Number of narratives= ',numberOfNarratives)
print()

durationOfAllNarratives=0
listOfNarrDuration=[]
listOfNarrAbove3Duration=[]
numOfNarrativeAbove3Min=0
numOfNarrativeBelow3Min=0
numOfNarrativeAbove2Min=0
numOfNarrativeBelow2Min=0

durOfNarrativeAbove3Min=0
for i in allNarrativesDur:
    print(i)
    durationOfAllNarratives+=i[2]
    listOfNarrDuration.append(i[2])
    if i[2]>=180:
        numOfNarrativeAbove3Min+=1
        durOfNarrativeAbove3Min+=i[2]
        listOfNarrAbove3Duration.append(i[2])
    if i[2]>=120:
        numOfNarrativeAbove2Min+=1
    if i[2]<180:
        numOfNarrativeBelow3Min+=1
    if i[2]<120:
        numOfNarrativeBelow2Min+=1
        
    print()
print('duration of all Derivatives = ',durationOfAllNarratives)
print()        
print('Average of narrative duration = ', round((durationOfAllNarratives/len(allNarrativesDur)),0))
print('Minimum narrative duration = ',min(listOfNarrDuration))
print('maximum of narrative duration= ',max(listOfNarrDuration))
print()
print('STDV of narrative duration= ',round(statistics.stdev(listOfNarrDuration),0))
print()
print('# of narratives above 3 minutes = ',numOfNarrativeAbove3Min)
print()
print('duration of narratives above 3 minutes = ',durOfNarrativeAbove3Min)
print()
print('Average of narratives above 3 duration = ', round((durOfNarrativeAbove3Min/numOfNarrativeAbove3Min),0))
print('Minimum narratives above 3 duration = ',min(listOfNarrAbove3Duration))
print('maximum of narratives above 3 duration= ',max(listOfNarrAbove3Duration))
print()
print('STDV of narrative duration= ',round(statistics.stdev(listOfNarrAbove3Duration),0))
print()
print('number of narratives per evaluater= ',round(numOfNarrativeAbove3Min/5,0))
print()
print('# of narratives below 3 minutes = ',numOfNarrativeBelow3Min)
print()
print('# of narratives above 2 minutes = ',numOfNarrativeAbove2Min)
print()
print('# of narratives below 2 minutes = ',numOfNarrativeBelow2Min)
print()
# Out:
# i[0]  VisualAid
#
# i[1][0]=  Graph
#
# ['Figure', ['Hp7Id3Yb9XQ', 16.56, 17.39, 43, ['Figure', 2.0, 'Slide', 2.0], []]]
#
# ['Figure', ['Hp7Id3Yb9XQ', 21.2, 23.07, 107, ['Slide', 3.0, 'Figure', 3.0], ['Image', 1.0, 'Animation', 1.0]]]
#
# second part
#
# ['Graph', ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]]
#
# i[0]  PresentationAttribute
#
# i[1][0]=  Memorable
#
# ['Impact', ['MnIPpUiTcRc', 0.14, 0.41, 27, ['Organization', 1.0, 'Impact', 1.0, 'Memorable', 1.0, 'Audience', 2.0], []]]
#
# ['Impact', ['i5mYphUoOCs', 0.04, 1.09, 65, ['Stand', 2.0, 'Communication', 2.0, 'Impact', 1.0], []]]
#
# ['Impact', ['1VCaJ4dSHak', 0.07, 0.44, 37, ['Gesture', 2.0, 'Audience', 1.0, 'Impact', 1.0], []]]
#
# second part
#
# ...

# %%
import os
import codecs
from bs4 import BeautifulSoup as Soup
def inSecTime(t):
    intPart=int(t)
    floatPart=int(round(float(t)-int(t),2)*100)

    inSec=(intPart*60)+floatPart
    return inSec

videoIDs=[['MnIPpUiTcRc','HOW TO Give a Great Presentation - 7 Presentation Skills and Tips to Leave an Impression'],
          ['yoD8RMq2OkU','The 3 Magic Ingredients of Amazing Presentations  Phil WAKNELL  TEDxSaclay'],
          ['dEDcc0aCjaA','How to Do a Presentation - 5 Steps to a Killer Opener'],
          ['Q5WT2vweFRY','PRESENTING AND PUBLIC SPEAKING TIPS - HOW TO IMPROVE SKILLS & CONFIDENCE'],
          ['ADJAcyTq1us','Soft Skills - Presentation Skills'],
          ['V8eLdbKXGzk','Good Presentation VS Bad Presentation '],
          ['wp4ho9raVjA','Presentation Skills Tips & Tricks'],
          ['d812a7qG9Kw','How to Practice a Speech or Presentation'],
          ['hMk5s1y486I','Presentation Skills 7 Presentation Structures Used by the Best TED Talks'],
          ['bgFNTuRYtKE','40 Phrases For Presenting In English - Business English'],
          ['XA1o5rvy8r4','Present with CONFIDENCE with THESE 3 PowerPoint Tips'], 
          ['fzIxD1jXn44','Presentations in English - How to Give a Presentation - Business English'],  
          ['UOceysteIjo','08 Simple tips to develop  great Presentation Skills - Public speaking tips  Body language'] , 
          ['bt8YFCveNpY','Presentation skills - How to improve your presentations'], 
          ['HRaPmO6TlaM','Oral Presentation Skills'],  
          ['QT5vlkGM810','Business Presentation Tips - The Top 8 Business Presentation Skills'],  
          ['XyRjKCT_wrk','5 TIPS FOR DELIVERING GREAT ZOOM PRESENTATION'], 
          ['5utoLhjUuAI','Delivering a good presentation - identify the good techniques'], 
          ['Jv18JGOk06o','How to Deliver a Great Presentation Project Management'],  
          ['TmbQFWBvTtY','Body Language for Presentations'], 
          ['x9E8yaFCX0Y','5 Tips For Delivering A Great Presentation - How To Speak In Front Of Others - Public Speaking Tips'], 
          ['FOCpMAww28',"TED's secret to great public speaking | Chris Anderson"], 
          ['i5mYphUoOCs','Public Speaking For Beginners'],  
          ['TQiln3CjtvM','5 QUICK Ways to Improve Your PowerPoint Design'],  
          ['Iwpi1Lm6dFo','How to avoid death By PowerPoint  David JP Phillips  TEDxStockholmSalon'],  
          ['PgOD1j2DhNg','MANAGEMENT CONSULTING PRESENTATION - How consulting firms create slide presentations (Ex-McKinsey)'],  
          ['Hp7Id3Yb9XQ','Susan McConnell (Stanford) Designing effective scientific presentations'],  
          ['1VCaJ4dSHak','The 4 Public Speaking Gestures And How To Use Them'],  
          ['h6sm47j-Am4','How to Use Humor in a Speech Opening'],  
          ['i68a6M5FFBc&t','How to Give an Awesome (PowerPoint) Presentation (Whiteboard Animation Explainer Video).'],  
          ['Yl_FJAOcFgQ','How to open and close presentations Presentation lesson from Mark Powell'],  
          ['RHX-xnP_G5s','Make a Presentation Like Steve Jobs'], 
          ['7MWaeOHDBOg','The five secrets of speaking with confidence']]

concIntro=''
videoClosing=''
videoOpen=''
segOpening=''
counter=0
no=1
videoTitle=[]
openingList=[]
moreEpisodes1_2=False

for i in narrative2:
    print('___________________________________________________________________________')
    col=0
    counter=0
    tempCol=0
    
    videoTitle=[]
    openingList=[]
    
    temp="""
        <html>
        <body>
        more words y y y 
          <tr>
              <th> </th>
          </tr>
          
          

       </body>
       </html>


    """
    moreEpisodes1=False
    moreEpisodes1_2=False
    
    if len(i[1][1])>1 and i[1][2]:
        moreEpisodes1_2=True
        moreEpisodes1=True
        
    elif len(i[1][1])>1 and not i[1][2] :
        moreEpisodes1_2=False
        moreEpisodes1=True
    elif len(i[1][1])==1 and not i[1][2] :
        moreEpisodes1_2=False
        moreEpisodes1=False
        
    '''   
    if len(i[1][2])>1:
        moreEpisodes2=True
        
    else:
        moreEpisodes2=False
    ''' 
    for j in i[1][1]:
        #print(j)
        parentCon=str(j[0]).upper()
        #print()
        
    topic=''
    if i[0]=='PresentationAttribute':
        topic='Presentation Attribute'.upper()
    else:
        topic=str(i[0]).upper()
    videoInto_1='<center><h1> Learning about Presentation Skills:</h1></center><br />'
    videoInto_1_2='<center><h1> Learning '+str(i[1][0]).upper() + ' from ' +topic+'</h1></center><br />' 
    
    if moreEpisodes1_2==True and moreEpisodes1==True:
        
        videoInto_1_3=str(i[1][0] ).upper()+ '  is part of  '+ str(i[1][1][0][0] ).upper()+'. You are given a collection of video segments about ' +parentCon+' and '+str(i[1][0] ).upper()+ ' related to ' +topic+'.<br /><br />' 
    elif moreEpisodes1_2==False and moreEpisodes1==True:
        videoInto_1_3=str(i[1][0] ).upper()+ '  is part of  '+ str(i[1][1][0][0] ).upper()+'. You are given a  collection of video segments about ' +parentCon+ ' related to ' +topic+'.<br /><br />' 

    elif   moreEpisodes1_2==False and moreEpisodes1==False:  
        videoInto_1_3=str(i[1][0] ).upper()+ '  is part of  '+ str(i[1][1][0][0] ).upper()+'. You are given a of video segments about ' +parentCon+ ' related to ' +topic+'.<br /><br />' 

        
    video_meta_1='These video segments have been extracted automatically from popular YouTube videos related to presentation skills.<br /><br />'
    video_meta_2='Each segment will start from a time point in the video and will stop when the corresponding concepts are covered.<br /><br />' 
    video_meta_3='You can re-watch the segment or watch other parts of the video, if you wish so.<br /><br />'
    
    #videoOpen='This video is about the topic '+str(i[0]).upper()+' which relates to presentation skills.'
    
   
    
    # to write the closing of the video, I need to check do I have segemtns about the subconcept as well to write several
    # other wise, I will check the length of i[1][1] which are the segments about the super class to decide to write several or a video episode
    if len(i[1][2])>=1 and len(i[1][1])>1:
        video_closing='<h2>You watched several video segments about ('+str(i[1][1][0][0] ).upper()+') and ('+str(i[1][0] ).upper()+ ') related to '+topic+'.</h2><br/><br/>'
    
    elif not i[1][2] and len(i[1][1])>1:
        video_closing='<h2>You watched several video segments about ('+str(i[1][1][0][0] ).upper()+') related to '+topic+'.</h2><br/><br/>'

        
    elif len(i[1][1])==1: 
        video_closing='<h2>You watched a video segment about ('+str(i[1][1][0][0] ).upper()+ ') related to '+topic+'.</h2><br/><br/>'
        
    meta_closing_1='The video segments were automatically extracted from popular YouTube videos on presentation skills, using algorithms for segmentation, characterisation and linking based on a theory for concept learning.<br/><br/> '    
    meta_closing_2='We hope you found the collection of video segments helpful. <br/><br/>'
        
    
    # opening seg / closing seg and opena another one
   
    
   
    
    if len(i[1][1])>=1: 
        
        for j in i[1][1]:
             
            for k in j:
                
                
                
                if type(k)!=list:
                    cc=k #save the name of the concepts
                   
                if type(k)==list:
                    if counter==0:
                        segOpening='The next video segment mentions '+str(i[1][1][0][0] ).upper()+' ( related to '+topic+' ).'+' The segment is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                        counter+=1
                    else:
                        #segOpening='You have watched a video episode that mentions ' + str(i[1][1][0][0] ).capitalize()+'.  Now you will watch another video episode that mentions ' + str(i[1][1][0][0] )+'. '
                        segOpening='The next video segment mentions '+str(i[1][1][0][0] ).upper()+' ( related to '+topic+' ).'+' The segment is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
            openingList.append(segOpening)
                    
                   
                    
            for v in videoIDs:
                
                if v[0]==j[1][0]:
                    st=inSecTime(j[1][1])
                    en=inSecTime(j[1][2])
                    videoTitle.append(str(v[1])+'.mp4#t='+str(st)+','+str(en))
                    print('video= ',str(v[1])+'.mp4#t='+str(st)+','+str(en))
                    print()

            
            
                
        
    counter=0
 
       
    
    #tempCol=col+1
    if len(i[1][2])>1:
       
        for j in i[1][2]:
            
            for k in j:

                
                if type(k)!=list:
                    cc=k
                    
                if type(k)==list:
                    
                    segOpening='The next video segment mentions '+str(i[1][2][0][0] ).upper()+' ( related to '+topic+' ).'+' The segment is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                        
                    
            openingList.append(segOpening)
                    
            for v in videoIDs:
                
                if v[0]==j[1][0]:
                    st=inSecTime(j[1][1])
                    en=inSecTime(j[1][2])
                    videoTitle.append(str(v[1])+'.mp4#t='+str(st)+','+str(en))
                    print('video= ',str(v[1])+'.mp4#t='+str(st)+','+str(en))
                    print()

                        


    elif len(i[1][2])==1:
        
        for j in i[1][2]:
            for k in j:

                if type(k)!=list:
                    cc=k
                    
                if type(k)==list:
                    segOpening='The next video segment mentions '+str(i[1][2][0][0] ).upper()+' ( related to '+topic+' ).'+' The segment is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
            openingList.append(segOpening)
                    
            for v in videoIDs:
                
                
                if v[0]==j[1][0]:
                    st=inSecTime(j[1][1])
                    en=inSecTime(j[1][2])
                    videoTitle.append(str(v[1])+'.mp4#t='+str(st)+','+str(en))
                    print('video= ',str(v[1])+'.mp4#t='+str(st)+','+str(en))
                    print()
                    
    additionalText=''
    print('len(openingList) ',len(openingList),'   len(videoTitle) ',len(videoTitle))
    print()
    for s in range(0,len(openingList)):
        additionalText+='<p>'
        #additionalText+='/n'
        additionalText+='<br />'
        additionalText+=str(openingList[s])
        #additionalText+='/n'
        additionalText+='<br />'
        additionalText+='</p>'
        additionalText+='<br />'
        #additionalText+='/n'
        #additionalText+='<p>'
        #additionalText+='/n'
        additionalText+="<video  width='400' height='200' class='demoVideo' controls>"
        #additionalText+='/n'
        additionalText+="<source src= '"+str(videoTitle[s])+"' type='video/mp4'>"
        #additionalText+='/n'
        additionalText+="</video>" 
        additionalText+='<br />'
        additionalText+='<br />'
        #additionalText+='/n'
        #additionalText+='</p>'
        #additionalText+='/n'
    #additionalText+='"""'
    print('additional text')
    
    print(additionalText)
    print()
    
    #videoClose='You have watched a video to learn about using the two topics ' +i[2][0][0]+', '+i[2][0][1]+' relevant to presentation skills.'
    elements = temp.split("more words y y y ")
    fileName='DerivativeNarrativeWebPage'+str(no)+'.html'
    no+=1
    newFile=elements[0]+videoInto_1 +videoInto_1_2+videoInto_1_3+video_meta_1+video_meta_2+video_meta_3+ additionalText +video_closing+meta_closing_1+meta_closing_2+elements[1]
    f = open(fileName, 'w')
    
    
    f.write(newFile)

    f.close()
# Out:
# ___________________________________________________________________________
# video=  Susan McConnell (Stanford) Designing effective scientific presentations.mp4#t=1016,1059
#
# video=  Susan McConnell (Stanford) Designing effective scientific presentations.mp4#t=1280,1387
#
# video=  HOW TO Give a Great Presentation - 7 Presentation Skills and Tips to Leave an Impression.mp4#t=109,216
#
# len(openingList)  3    len(videoTitle)  3
#
# additional text
# ...

# %%
##### 
listOfHighQualityConcepts=['Distraction','Smile','Interest','Colour','Chart','HandGesture','Color','Highlight','Image',
                           'Influence','Graph','Message','PowerPoint','Memorable']
for i in narrative2:
    numOfSeg=0
    segDurGre30=0
    segDurLes30=0
    mention=[]
    
    if i[1][0] in listOfHighQualityConcepts:
        print('i[0] ',i[0])
        print()
        print('i[1][0] ',i[1][0])
        print()
    
        numOfSeg+=len(i[1][1])
        for j in i[1][1]:
            if j[1][3]>=30:
                segDurGre30+=1
            else:
                segDurLes30+=1
            for m in range(0,len(j[1][4])) :
                if j[0] ==j[1][4][m]:
                    mention.append([j[0],j[1][4][m+1]])

            print(j)
            print()
        if i[1][2]:
            numOfSeg+=len(i[1][2])
            for j in i[1][2]:
                if j[1][3]>=30:
                    segDurGre30+=1
                else:
                    segDurLes30+=1
                for m in range(0,len(j[1][4])) :
                    if j[0] ==j[1][4][m]:
                        mention.append([j[0],j[1][4][m+1]])
                print(j)
                print()
        print('Number of seg= ',numOfSeg)
        print()
        print('number of seg with duration >=30 ',segDurGre30)
        print()
        print('number of seg with duration <30 ',segDurLes30)
        print()
        print('Mentioned concepts')
        print()
        for m in mention:
            print(m)
            print()

        print('______________________________________')
# Out:
# i[0]  VisualAid
#
# i[1][0]  Graph
#
# ['Figure', ['Hp7Id3Yb9XQ', 16.56, 17.39, 43, ['Figure', 2.0, 'Slide', 2.0], []]]
#
# ['Figure', ['Hp7Id3Yb9XQ', 21.2, 23.07, 107, ['Slide', 3.0, 'Figure', 3.0], ['Image', 1.0, 'Animation', 1.0]]]
#
# ['Graph', ['MnIPpUiTcRc', 1.49, 3.36, 107, ['Graph', 4.0], ['Visuals', 1.0, 'Chart', 3.0, 'Infographics', 1.0, 'Impact', 2.0, 'Memorable', 2.0, 'Video', 1.0, 'Structure', 1.0, 'Information', 1.0, 'Delivery', 1.0, 'Audience', 1.0, 'Image', 1.0, 'Picture', 1.0]]]
#
# Number of seg=  3
#
# number of seg with duration >=30  3
#
# number of seg with duration <30  0
#
# Mentioned concepts
#
# ['Figure', 2.0]
#
# ['Figure', 3.0]
#
# ['Graph', 4.0]
#
# ______________________________________
# i[0]  PresentationAttribute
#
# i[1][0]  Memorable
#
# ['Impact', ['MnIPpUiTcRc', 0.14, 0.41, 27, ['Organization', 1.0, 'Impact', 1.0, 'Memorable', 1.0, 'Audience', 2.0], []]]
#
# ...

# %%
# add filter to select narratives with duration >= 3minutes only

import os
import codecs
from bs4 import BeautifulSoup as Soup
def inSecTime(t):
    intPart=int(t)
    floatPart=int(round(float(t)-int(t),2)*100)

    inSec=(intPart*60)+floatPart
    return inSec

videoIDs=[['MnIPpUiTcRc','HOW TO Give a Great Presentation - 7 Presentation Skills and Tips to Leave an Impression'],
          ['yoD8RMq2OkU','The 3 Magic Ingredients of Amazing Presentations  Phil WAKNELL  TEDxSaclay'],
          ['dEDcc0aCjaA','How to Do a Presentation - 5 Steps to a Killer Opener'],
          ['Q5WT2vweFRY','PRESENTING AND PUBLIC SPEAKING TIPS - HOW TO IMPROVE SKILLS & CONFIDENCE'],
          ['ADJAcyTq1us','Soft Skills - Presentation Skills'],
          ['V8eLdbKXGzk','Good Presentation VS Bad Presentation *'],
          ['wp4ho9raVjA','Presentation Skills Tips & Tricks'],
          ['d812a7qG9Kw','How to Practice a Speech or Presentation'],
          ['hMk5s1y486I','Presentation Skills 7 Presentation Structures Used by the Best TED Talks'],
          ['bgFNTuRYtKE','40 Phrases For Presenting In English - Business English'],
          ['XA1o5rvy8r4','Present with CONFIDENCE with THESE 3 PowerPoint Tips'], 
          ['fzIxD1jXn44','Presentations in English - How to Give a Presentation - Business English'],  
          ['UOceysteIjo','08 Simple tips to develop  great Presentation Skills - Public speaking tips  Body language'] , 
          ['bt8YFCveNpY','Presentation skills - How to improve your presentations'], 
          ['HRaPmO6TlaM','Oral Presentation Skills'],  
          ['QT5vlkGM810','Business Presentation Tips - The Top 8 Business Presentation Skills'],  
          ['XyRjKCT_wrk','5 TIPS FOR DELIVERING GREAT ZOOM PRESENTATION'], 
          ['5utoLhjUuAI','Delivering a good presentation - identify the good techniques'], 
          ['Jv18JGOk06o','How to Deliver a Great Presentation Project Management'],  
          ['TmbQFWBvTtY','Body Language for Presentations'], 
          ['x9E8yaFCX0Y','5 Tips For Delivering A Great Presentation - How To Speak In Front Of Others - Public Speaking Tips'], 
          ['FOCpMAww28',"TED's secret to great public speaking | Chris Anderson"], 
          ['i5mYphUoOCs','Public Speaking For Beginners'],  
          ['TQiln3CjtvM','5 QUICK Ways to Improve Your PowerPoint Design'],  
          ['Iwpi1Lm6dFo','How to avoid death By PowerPoint  David JP Phillips  TEDxStockholmSalon'],  
          ['PgOD1j2DhNg','MANAGEMENT CONSULTING PRESENTATION - How consulting firms create slide presentations (Ex-McKinsey)'],  
          ['Hp7Id3Yb9XQ','Susan McConnell (Stanford) Designing effective scientific presentations'],  
          ['1VCaJ4dSHak','The 4 Public Speaking Gestures And How To Use Them'],  
          ['h6sm47j-Am4','How to Use Humor in a Speech Opening'],  
          ['i68a6M5FFBc&t','How to Give an Awesome (PowerPoint) Presentation (Whiteboard Animation Explainer Video).'],  
          ['Yl_FJAOcFgQ','How to open and close presentations: Presentation lesson from Mark Powell'],  
          ['RHX-xnP_G5s','Make a Presentation Like Steve Jobs'], 
          ['7MWaeOHDBOg','The five secrets of speaking with confidence']]
'''
videoIDs=[['MnIPpUiTcRc','https://www.youtube.com/watch?v=MnIPpUiTcRc'],
          ['yoD8RMq2OkU','https://www.youtube.com/watch?v=yoD8RMq2OkU'],
          ['dEDcc0aCjaA','https://www.youtube.com/watch?v=dEDcc0aCjaA'],
          ['Q5WT2vweFRY','https://www.youtube.com/watch?v=Q5WT2vweFRY'],
          ['ADJAcyTq1us','https://www.youtube.com/watch?v=ADJAcyTq1us'],
          ['V8eLdbKXGzk','https://www.youtube.com/watch?v=V8eLdbKXGzk'],
          ['wp4ho9raVjA','https://www.youtube.com/watch?v=wp4ho9raVjA'],
          ['d812a7qG9Kw','https://www.youtube.com/watch?v=d812a7qG9Kw'],
          ['hMk5s1y486I','https://www.youtube.com/watch?v=hMk5s1y486I'],
          ['bgFNTuRYtKE','https://www.youtube.com/watch?v=bgFNTuRYtKE'],
          ['XA1o5rvy8r4','https://www.youtube.com/watch?v=XA1o5rvy8r4'], 
          ['fzIxD1jXn44','https://www.youtube.com/watch?v=fzIxD1jXn44'],  
          ['UOceysteIjo','https://www.youtube.com/watch?v=UOceysteIjo'] , 
          ['bt8YFCveNpY','https://www.youtube.com/watch?v=bt8YFCveNpY'], 
          ['HRaPmO6TlaM','https://www.youtube.com/watch?v=HRaPmO6TlaM'],  
          ['QT5vlkGM810','https://www.youtube.com/watch?v=QT5vlkGM810'],  
          ['XyRjKCT_wrk','https://www.youtube.com/watch?v=XyRjKCT_wrk'], 
          ['5utoLhjUuAI','https://www.youtube.com/watch?v=5utoLhjUuAI'], 
          ['Jv18JGOk06o','https://www.youtube.com/watch?v=Jv18JGOk06o'],  
          ['TmbQFWBvTtY','https://www.youtube.com/watch?v=TmbQFWBvTtY'], 
          ['x9E8yaFCX0Y','https://www.youtube.com/watch?v=x9E8yaFCX0Y'], 
          ['FOCpMAww28',"https://www.youtube.com/watch?v=-FOCpMAww28"], 
          ['i5mYphUoOCs','https://www.youtube.com/watch?v=i5mYphUoOCs'],  
          ['TQiln3CjtvM','https://www.youtube.com/watch?v=TQiln3CjtvM'],  
          ['Iwpi1Lm6dFo','https://www.youtube.com/watch?v=Iwpi1Lm6dFo'],  
          ['PgOD1j2DhNg','https://www.youtube.com/watch?v=PgOD1j2DhNg'],  
          ['Hp7Id3Yb9XQ','https://www.youtube.com/watch?v=Hp7Id3Yb9XQ'],  
          ['1VCaJ4dSHak','https://www.youtube.com/watch?v=1VCaJ4dSHak'],  
          ['h6sm47j-Am4','https://www.youtube.com/watch?v=h6sm47j-Am4'],  
          ['i68a6M5FFBc&t','https://www.youtube.com/watch?v=i68a6M5FFBc'],  
          ['Yl_FJAOcFgQ','https://www.youtube.com/watch?v=Yl_FJAOcFgQ'],  
          ['RHX-xnP_G5s','https://www.youtube.com/watch?v=RHX-xnP_G5s'], 
          ['7MWaeOHDBOg','https://www.youtube.com/watch?v=7MWaeOHDBOg']]

'''


concIntro=''
videoClosing=''
videoOpen=''
segOpening=''
counter=0
no=1
videoTitle=[]
openingList=[]
moreEpisodes1_2=False

for i in narrative2:
    print('___________________________________________________________________________')
    for a in allNarrativesDur:
        if a[2]>=180 and a[1]==i[1][0] :# a[0]==i[0]   and   :
            col=0
            counter=0
            tempCol=0

            videoTitle=[]
            openingList=[]
            print('i[1][0] ',i[1][0])
            print()

            temp="""
                <html>
                <body>
                more words y y y 
                  <tr>
                      <th> </th>
                  </tr>



               </body>
               </html>


            """
            moreEpisodes1=False
            moreEpisodes1_2=False

            if len(i[1][1])>1 and i[1][2]:
                moreEpisodes1_2=True
                moreEpisodes1=True

            elif len(i[1][1])>1 and not i[1][2] :
                moreEpisodes1_2=False
                moreEpisodes1=True
            elif len(i[1][1])==1 and not i[1][2] :
                moreEpisodes1_2=False
                moreEpisodes1=False

            '''   
            if len(i[1][2])>1:
                moreEpisodes2=True

            else:
                moreEpisodes2=False
            ''' 
            #for j in i[1][1]:
                #print(j)
            parentCon=str(i[1][1][0][0] ).upper()
                #print()
            print('parentCon ',parentCon)
            print()

            topic=''
            if i[0]=='PresentationAttribute':
                topic='Presentation Attribute'.upper()
            else:
                topic=str(i[0]).upper()
            videoInto_1='<center><h1> Learning about Presentation Skills:</h1></center><br />'
            videoInto_1_2='<center><h1> Learning '+str(i[1][0]).upper() + ' from ' +topic+'</h1></center><br />' 

            if moreEpisodes1_2==True and moreEpisodes1==True:

                videoInto_1_3=str(i[1][0] ).upper()+ '  is part of  '+ str(i[1][1][0][0] ).upper()+'. You are given a collection of video segments about ' +parentCon+' and '+str(i[1][0] ).upper()+ ' related to ' +topic+'.<br /><br />' 
            elif moreEpisodes1_2==False and moreEpisodes1==True:
                videoInto_1_3=str(i[1][0] ).upper()+ '  is part of  '+ str(i[1][1][0][0]).upper()+'. You are given a  collection of video segments about ' +parentCon+ ' related to ' +topic+'.<br /><br />' 

            elif   moreEpisodes1_2==False and moreEpisodes1==False:  
                videoInto_1_3=str(i[1][0] ).upper()+ '  is part of  '+ str(i[1][1][0][0] ).upper()+'. You are given a of video segments about ' +parentCon+ ' related to ' +topic+'.<br /><br />' 


            video_meta_1='These video segments have been extracted automatically from popular YouTube videos related to presentation skills.<br /><br />'
            video_meta_2='Each segment will start from a time point in the video and will stop when the corresponding concepts are covered.<br /><br />' 
            video_meta_3='You can re-watch the segment or watch other parts of the video, if you wish so.<br /><br />'

            #videoOpen='This video is about the topic '+str(i[0]).upper()+' which relates to presentation skills.'



            # to write the closing of the video, I need to check do I have segemtns about the subconcept as well to write several
            # other wise, I will check the length of i[1][1] which are the segments about the super class to decide to write several or a video episode
            if len(i[1][2])>=1 and len(i[1][1])>1:
                video_closing='<h2>You watched several video segments about ('+str(i[1][1][0][0] ).upper()+') and ('+str(i[1][0] ).upper()+ ') related to '+topic+'.</h2><br/><br/>'

            elif not i[1][2] and len(i[1][1])>1:
                video_closing='<h2>You watched several video segments about ('+str(i[1][1][0][0] ).upper()+') related to '+topic+'.</h2><br/><br/>'


            elif len(i[1][1])==1: 
                video_closing='<h2>You watched a video segment about ('+str(i[1][1][0][0] ).upper()+ ') related to '+topic+'.</h2><br/><br/>'

            meta_closing_1='The video segments were automatically extracted from popular YouTube videos on presentation skills, using algorithms for segmentation, characterisation and linking based on a theory for concept learning.<br/><br/> '    
            meta_closing_2='We hope you found the collection of video segments helpful. <br/><br/>'


            # opening seg / closing seg and opena another one




            #if len(i[1][1])>=1: 

            for j in i[1][1]:

                for k in j:



                    if type(k)!=list:
                        cc=k #save the name of the concepts

                    if type(k)==list:
                        if counter==0:
                            segOpening='The next video segment mentions '+str(i[1][1][0][0] ).upper()+' ( related to '+topic+' ).'+' The segment is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                            counter+=1
                        else:
                            #segOpening='You have watched a video episode that mentions ' + str(i[1][1][0][0] ).capitalize()+'.  Now you will watch another video episode that mentions ' + str(i[1][1][0][0] )+'. '
                            segOpening='The next video segment mentions '+str(i[1][1][0][0] ).upper()+' ( related to '+topic+' ).'+' The segment is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                openingList.append(segOpening)



                for v in videoIDs:
                    if v[0]==j[1][0]:
                        st=inSecTime(j[1][1])
                        en=inSecTime(j[1][2])
                        videoTitle.append(str(v[1])+'.mp4#t='+str(st)+','+str(en))
                        print('video= ',str(v[1])+'.mp4#t='+str(st)+','+str(en))
                        print()





            counter=0



            #tempCol=col+1
            #if len(i[1][2])>1:

            for j in i[1][2]:

                for k in j:


                    if type(k)!=list:
                        cc=k

                    if type(k)==list:

                        segOpening='The next video segment mentions '+str(i[1][2][0][0] ).upper()+' ( related to '+topic+' ).'+' The segment is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'


                openingList.append(segOpening)

                for v in videoIDs:
                    if v[0]==j[1][0]:
                        st=inSecTime(j[1][1])
                        en=inSecTime(j[1][2])
                        videoTitle.append(str(v[1])+'.mp4#t='+str(st)+','+str(en))
                        print('video= ',str(v[1])+'.mp4#t='+str(st)+','+str(en))
                        print()



            '''
            elif len(i[1][2])==1:

                for j in i[1][2]:
                    for k in j:

                        if type(k)!=list:
                            cc=k

                        if type(k)==list:
                            segOpening='The next video segment mentions '+str(i[1][2][0][0] ).upper()+' ( related to '+topic+' ).'+' The segment is taken from a YouTube video with ID= '+ str(k[0])+' , and starts at '+str(k[1])+' with a duration of '+str(k[3])+' seconds.'
                    openingList.append(segOpening)

                    for v in videoIDs:
                        if v[0]==j[1][0]:
                            st=inSecTime(j[1][1])
                            en=inSecTime(j[1][2])
                            videoTitle.append(str(v[1])+'.mp4#t='+str(st)+','+str(en))
                            print('video= ',str(v[1])+'.mp4#t='+str(st)+','+str(en))
                            print()
            '''

            additionalText=''
            print('len(openingList) ',len(openingList),'   len(videoTitle) ',len(videoTitle))
            print()
            for s in range(0,len(openingList)):
                additionalText+='<p>'
                #additionalText+='/n'
                additionalText+='<br />'
                additionalText+=str(openingList[s])
                #additionalText+='/n'
                additionalText+='<br />'
                additionalText+='</p>'
                additionalText+='<br />'
                #additionalText+='/n'
                #additionalText+='<p>'
                #additionalText+='/n'
                additionalText+="<video  width='400' height='200' class='demoVideo' controls>"
                #additionalText+='/n'
                
                additionalText+="<source src= '"+str(videoTitle[s])+"' type='video/mp4'>"
                
                #additionalText+='/n'
                additionalText+="</video>" 
                additionalText+='<br />'
                additionalText+='<br />'
                #additionalText+='/n'
                #additionalText+='</p>'
                #additionalText+='/n'
            #additionalText+='"""'
            print('additional text')

            print(additionalText)
            print()

            #videoClose='You have watched a video to learn about using the two topics ' +i[2][0][0]+', '+i[2][0][1]+' relevant to presentation skills.'
            elements = temp.split("more words y y y ")
            fileName='DerivativeNarrativeWebPage-Trial2_'+str(no)+'.html'
            no+=1
            newFile=elements[0]+videoInto_1 +videoInto_1_2+videoInto_1_3+video_meta_1+video_meta_2+video_meta_3+ additionalText +video_closing+meta_closing_1+meta_closing_2+elements[1]
            f = open(fileName, 'w')


            f.write(newFile)

            f.close()
# Out:
# ___________________________________________________________________________
# i[1][0]  Graph
#
# parentCon  FIGURE
#
# video=  Susan McConnell (Stanford) Designing effective scientific presentations.mp4#t=1016,1059
#
# video=  Susan McConnell (Stanford) Designing effective scientific presentations.mp4#t=1280,1387
#
# video=  HOW TO Give a Great Presentation - 7 Presentation Skills and Tips to Leave an Impression.mp4#t=109,216
#
# len(openingList)  3    len(videoTitle)  3
#
# additional text
# ...
