# %%
import xlrd
from nltk.tokenize import PunktSentenceTokenizer,sent_tokenize, word_tokenize
#### 1.  Create the segments from each video
import pandas as pd
import xlsxwriter
import os

#### The characterisation work
################################################################################
import nltk
import codecs
import pronto
import itertools
#import owlready
#from owlready import *

from nltk.corpus import stopwords, wordnet
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer, PorterStemmer
import signal, ctypes
from pronto import Ontology
from pronto import *
import re

from pandas import DataFrame
import math
from difflib import SequenceMatcher
import sys
import collections
from collections import Counter
import statistics 
from nltk.wsd import lesk
from nltk.corpus import wordnet as wn
lemmatizer = WordNetLemmatizer()

###############################################################################
videosExcelFile='PresentationSkill Videos With views 100K and more-usingyoutube library.xlsx'    
xls1= pd.ExcelFile(videosExcelFile)
#xls2= pd.ExcelFile('JavaProgrammingDomainSegments3MinutesEach.xlsx')

workbook = xlsxwriter.Workbook('Pres Videos To 6 sentences using Full Stop as Delimiter.xlsx')

# Get the sheets from both excel workbooks
presentationSheetNames=xls1.sheet_names
#javaSheetNames=xls2.sheet_names

# calculate howmany videos I can create by joining segmnet from both domain.I need 5 segments from each domain to create 30 minutes video
# no of segments from presentation domain is less than from Jave, so I will use it to claculate # videos to avoid out of range issue

noOfVideos=len(presentationSheetNames)
print('# of videos = ',noOfVideos)
#print(sheetNames)

### Get the segments with thier metadata for the first video
allArtificialVideos=[]
artificialVideo=[]
videoMetaData=[]
artificialVideoWithoutTime=[]
allArtificialVideosWithoutTime=[]
counterOfDomainVideo=0
df_idP=[]
df_topicP=[]
df_textP=[]
df_timeP=[]
df_Video=[]
for i in  range(noOfVideos):       
    presentationSheetIteration = pd.read_excel(videosExcelFile, sheet_name=presentationSheetNames[i])
    
       
    ####### Get the presentation segment
    df_idP=presentationSheetIteration['VideoId'].tolist()
    
            
    df_Video.append([presentationSheetIteration['VideoId'].tolist()[0],
                     presentationSheetIteration['Transcript Time'].tolist(),
                     presentationSheetIteration['Transcript Text'].tolist()])
    
    
    #df_topicP.append(presentationSheetIteration['Topic'])
    

for i in df_Video:
    print(i[1])
    print()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Main\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Main\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Main\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# # of videos =  33
# [0.01, 0.04, 0.05, 0.07, 0.08, 0.09, 0.12, 0.14, 0.17, 0.18, 0.2, 0.22, 0.23, 0.25, 0.27, 0.28, 0.3, 0.32, 0.34, 0.35, 0.38, 0.4, 0.41, 0.43, 0.45, 0.47, 0.49, 0.5, 0.52, 0.53, 0.54, 0.56, 0.58, 0.59, 1.01, 1.03, 1.05, 1.06, 1.08, 1.1, 1.11, 1.13, 1.15, 1.17, 1.19, 1.2, 1.21, 1.23, 1.25, 1.26, 1.28, 1.3, 1.33, 1.34, 1.36, 1.37, 1.39, 1.4, 1.42, 1.44, 1.46, 1.48, 1.49, 1.51, 1.53, 1.55, 1.56, 1.58, 2.0, 2.02, 2.04, 2.06, 2.08, 2.1, 2.12, 2.13, 2.14, 2.17, 2.18, 2.2, 2.22, 2.24, 2.26, 2.27, 2.29, 2.31, 2.33, 2.35, 2.36, 2.38, 2.4, 2.41, 2.43, 2.44, 2.46, 2.48, 
    videoSegemnts=[]

    for i in range(start,len(videoTime)):
            #print(videoTime[i],'    ',videoTime.index(videoTime[i]),'    ',videoTranscript[i].split())
            #print()




            newLine=videoTranscript[i].split()# for each text line in the transcript, split it into list of words
            #print('newLine = ',newLine)
            #print()
            segText.append(videoTranscript[i])
            #print('segText = ',segText)

            #numberOfword=len(newLine)# count ho mqany word per line
            #print('start = ',start)
            for j in range(0, len(newLine)):

                if newLine[j][-1]!='.':
                    #print('text =',newLine[j][-1])
                    if videoTime[i] not in segTime:
                        segTime.append(videoTime[i])
                        wordsCollected.append(newLine[j])

                else:
                    #print('segTime = ',segTime)
                    #print()
                    if segTime:
                        segment.append([segTime[0],segTime[-1],segText])
                        videoSegemnts.append([segTime[0],segTime[-1],segText])
                        #print('segment= ',segment)
                        #print()
                    segment=[]
                    segText=[]
                    segTime=[]
                    strat=videoTime[i]
                    #break

    segm= videoSegemnts[-1] 
    segment=[]
    #print(videoTime.index(segm[1]))
    temptimeList=[]
    tempText=[]
    if segm[1] != videoTime[-1]:
        start=videoTime.index(segm[1])
        for i in range(start,len(videoTime)):
            temptimeList.append(videoTime[i])
            tempText.append(videoTranscript[videoTime.index(videoTime[i])])
    if len(temptimeList)>1:

        videoSegemnts.append([temptimeList[0],temptimeList[-1],tempText])
        
        
    elif len(temptimeList)==1:
        videoSegemnts.append([temptimeList[0],tempText])
        
    allVideosSeg.append([v[0],videoSegemnts])
    videoSegemnts=[]

# %%
print('# of videos = ',len(allVideosSeg))
print()
for i in allVideosSeg:
    for j in i[1]:
        print(j)
        print()
    print('********* END of Video ***************')
    print()
# Out:
# # of videos =  33
#
# [0.01, 0.14, ["Pay practitioner today, I'm going to be", 'teaching you with the help of my friend,', 'Dana Blouin, the top seven tip for a', 'great presentation,', 'Dana blue and a an entrepreneur', 'currently living in Bangkok, Thailand,', 'where he is a co and CEO of a', "company called mango lab. Anyways here's"]]
#
# [0.14, 0.17, ['some of his tip. We all have to give']]
#
# [0.17, 0.34, ['presentation at different point in our', 'life that might be for school or work or', "an organization that you weren't", 'involved with no matter where We give', 'the presentation, or to who we want to', 'make sure that it ha the impact on the', 'Audience and that it memorable, these', 'are seven tip that are going to ensure', 'that you nail the presentation, and leave', 'a lasting impression on your audience.']]
#
# [0.35, 0.35, ['Number one know your audience. The first']]
#
# [0.35, 0.41, ['step in preparing for any presentation', 'should be to get a better idea of who', 'your audience. is. Knowing your audience.']]
#
# [0.41, 0.41, []]
#
# [0.43, 1.01, ['will allow you to understand the type of', 'content they are going to be expecting', 'with regard to depth and technical', 'detail, you want to give the', 'same presentation to a group of high', 'school student who are interested in', 'entrepreneurship, that you went to a', 'roomful of startup, founder and CEOs,', 'because their expectation and level of', 'understanding will be on completely', 'different level dig up a much a you', 'can about who your audience. is. what']]
#
# [1.01, 1.05, ['industry they work in and what', 'position they generally hold. This']]
#
# [1.05, 1.11, ['allows you to really tailor the content', 'and delivery of the presentation, in a', 'way that will really make it stand out', 'and be too many time.']]
#
# [1.13, 1.23, ['People give killer presentation at one', 'venue to a group made up of their core', 'audience and then bomb on the same', 'presentation to a different group', 'because they make the change', 'they needed to better address the new', 'audience just because you kill it in one', 'audience. mean the same exact']]
#
# [1.25, 1.48, ['content will replicate the reaction with', 'all Audience Number two use structure', 'to build on idea If you stand up and', 'give a presentation, and all the point', 'you want to make are just tossed around', 'randomly and they make any sense,', 'not too many People are going to enjoy', 'your presentation and If they remember', 'it, it, likely that it not For the', 'reason that you want them to, however, if', 'you structure your presentation in a way', 'that each idea each section build on', 'the one before it, you help your audience.']]
#
# [1.49, 1.51, ['connect with the content and create', 'logical link between the concept. This']]
#
# [1.51, 2.0, ['is a great way to make more complex', 'idea easier for the Audience to', 'understand and remember', 'number three use visuals another great', 'tool to cement. Those idea in the mind']]
#
# [2.0, 2.02, ['of your audience. is. to use visuals like']]
#
# [2.02, 2.06, ['chart graph and infographics to', 'illustrate and communicate a concept. a']]
#
# [2.06, 2.1, ['many a 65 percent of People are', 'considered to be visual learner. So if']]
#
# [2.1, 2.27, ['you take this approach in your', 'presentation you are going to ignore the', 'vast majority of the population using an', 'image, regardless of If it, a picture', 'graph or chart can be a much more potent', 'conveyor of information and ha a much', 'more powerful impact on the Audience a', 'single image can convey so much', 'information just like the old saying', 'that a picture worth a thousand word.']]
#
# [2.29, 2.35, ['It really is think of the impact This', 'can have when explaining data or result', 'in a presentation, If you had to stand', 'there in front of your audience. and go']]
#
# [2.35, 2.43, ['through every data point verbally, it can', 'get bad quickly and This is much more', 'common of an occurrence than you might', 'think But if you able to visualize', 'that data for your audience. with a graph']]
#
# [2.43, 2.56, ['or chart you instantly make it much more', 'understandable and memorable, showing', 'someone 200 percent growth with a graph', 'is much more exciting than explaining it', 'while looking at the raw data,', 'for example, If I took away the screen of', 'This video and all you saw wa black, it', 'be near a exciting number. Four']]
#
# [2.56, 3.21, ['repetition is your friend having a bit', 'of structure in your presentation go a', 'long way in keeping the Audience engaged', 'because they can follow the information', 'from step to step But even more than', 'just structuring the flow of the', 'presentation, you also want to build in', 'repetition This encourages people to', 'remember the key point of the', 'presentation, and help it stick which', 'again make it and you more memorable a', 'classic way to go about repetition is', 'something Dana learned early on when he', 'started his public speaking career.']]
#
# [3.23, 3.26, ['Another speaker at a big regional tech', 'event came up to him after a talk and', 'complimented Dana on is. delivery in the']]
#
# [3.26, 3.36, ['depth of the material but asked why he', 'use more repetition Dana wa a', 'bit stumped, because he never really', 'thought about that before the Other', 'speaker suggested that Dana start', 'telling the Audience what it is. he']]
#
# [3.36, 3.44, ['wanted to tell them just to give them a', 'brief rundown of the key point after', 'that move right into the body of the', 'presentation, and tell them exactly what', 'wa highlighted at the beginning. But']]
#
# [3.44, 3.53, ['obviously, with more detail and extra', 'element that you add in to make the', 'presentation, stick then in the', 'presentation, by telling them what you', 'just told them, reminding them of the key', 'point and a brief summary for final', 'repetition. Using this technique help to']]
#
# [3.55, 3.58, ['reinforce the main point of the', 'presentation, at least three time at the', 'beginning. middle and end. The key is to']]
#
# [4.0, 4.0, []]
#
# [4.0, 4.08, ['find a way to do this, that it feel', 'natural and not overly scholastic, and', 'that take practice which talk', 'about later. On tip Number five have a']]
#
# [4.08, 4.2, ['story to tell', 'the difference between an average', 'presentation that People zone out of and', 'a great presentation, that keep them', 'engaged is how you convey the', 'information to the Audience', 'a great way to convey the information or', 'key point of your presentation is. to']]
#
# [4.2, 4.23, ['use a story', 'using a story preferably an interesting', 'one. You get your point across and you']]
#
# [4.25, 4.29, ['creating a moment in the presentation,', 'that is. memorable and easier for the']]
#
# [4.29, 4.31, ['Audience to recall later. also,']]
#
# [4.31, 4.35, ['hopefully going to be something that', 'catch their attention pulling them in', 'to what you were saying. One of the key']]
#
# [4.35, 4.4, ['here, though, is that it ha to be a story', 'you can tell with commitment, and it ha', 'to be true always be honest with your', 'audience. because because If you not']]
#
# [4.42, 4.45, ['they will know and you will have lost', 'all credibility, tip Number six. Be']]
#
# [4.45, 4.53, ['relatable being relatable is actually', 'one of the most important factor of', 'your delivery you want to be someone', 'that your audience. can relate to, But']]
#
# [4.53, 4.55, ['they would feel comfortable with talking', 'to. Even when giving a talk a an expert']]
#
# [4.56, 5.06, ['on a topic, you want the Audience to feel', 'the relation it help them mentally,', 'engage with your content and remember', 'you and your talk', 'most people do feel comfortable going', 'up and talking to. a stern authority']]
#
# [5.06, 5.09, ['figure and no one want to listen to', 'someone with no confidence. So there a']]
#
# [5.09, 5.16, ['fine balance, you need a strike and', 'here, how the most important thing you', 'can do to come across a more relatable', 'is to be authentic, be yourself. Another']]
#
# [5.16, 5.21, ['great way to accomplish this is to work', 'on coming across a relaxed which can be', 'difficult. If you not used to']]
#
# [5.23, 5.33, ['presenting, but This go a long way to', 'helping people, see you a relatable the', 'final way you can be a more relatable is', 'to be enthusiastic about your', 'presentation your enthusiasm will', 'transfer to your audience. and now that']]
#
# [5.33, 5.42, ['you have enthusiasm in common you will', 'begin to see is more relatable If you', 'get all three of these technique', "mastered, you will be we'll On your way to", 'making it to your audience. relate to, you']]
#
# [5.42, 5.44, ['tip Number seven build your confidence.']]
#
# [5.46, 5.49, ['with practice this might be the last tip,', 'but it is. by far the most important one']]
#
# [5.49, 5.51, ['out of these seven confidence. and what']]
#
# [5.51, 5.54, ['you do is by far the most important', 'element of your presentation having', 'confidence. add an authority to']]
#
# [5.56, 6.0, ['everything you say during your', 'presentation But you not going to', 'develop the confidence. you need If you']]
#
# [6.0, 6.02, ['do practice and practice a lot.']]
#
# [6.04, 6.05, ['Whatever Dana give a talk or', 'presentation he practice he say for', 'hour. They want to make sure he']]
#
# [6.08, 6.11, ['ha the timing down that he know every', 'slide, so he have to read off', 'them. He know what the next slide is, So']]
#
# [6.13, 6.18, ['he can smoothly transition between them', 'So that he will sound natural and', 'authentic, and can explain the concept.']]
#
# [6.19, 6.19, ['and tell the story with confidence. and']]
#
# [6.19, 6.35, ['This all come with practice when you', 'are practicing a presentation, it not', 'enough to sit in front of your computer', 'and go through it you have to practice', 'it in front of Other people Invite some', 'friend over and have them give some', 'feedback on your presentation and make', 'improvement based on their feedback No', 'one get it right the first time. But']]
#
# [6.35, 6.37, ['practice will', 'get you towards perfect. With these seven']]
#
# [6.37, 6.42, ['tip you should be able to put together', 'and deliver a masterful presentation', 'that will wow your audience. and make']]
#
# [6.42, 6.51, ['sure that they remember you and your', 'topic, If you guy, like this', 'collaboration, be sure to check out', 'Dana YouTube channel and subscribe, he', 'ha ton of video on entrepreneurship,', '  and self. I hope you guy,']]
#
# [6.51, 6.58, ['  and self. I hope you guy,', '  like this video and learn something and', '  if you did, click the like button or if', "  you have n't already the subscribe button", '  thanks so much guy']]
#
# ********* END of Video ***************
#
# [0.0, 0.07, ['Transcriber : eric vautier Reviewer : Helene Vernet', 'Most people who come to speak at TED are here because they ’ ve succeeded .']]
#
# [0.13, 0.13, ['I ’ m here because I haven ’ t .']]
#
# [0.17, 0.23, ['For the last ten year', 'I ’ ve been helping conference speaker business leader entrepreneur', 'to prepare and deliver powerful presentation .']]
#
# [0.27, 0.3, ['And in those same ten year TED ha shown', 'that presentation can and should be both enjoyable and effective .']]
#
# [0.37, 0.47, ['But ten year on', 'despite TED and despite my best effort at school conference and company', 'most presentation still do this to their audience .']]
#
# [0.53, 0.55, ['So have I failed ?', "No ! I just have n't succeeded yet ."]]
#
# [0.59, 1.04, ['And to succeed in making all presentation resonate with their audience', 'I need your help .']]
#
# [1.06, 1.06, ['That ’ s why I ’ m here .']]
#
# [1.08, 1.09, ['So I ’ d like to share with you', 'the three magic ingredient of powerful presentation .']]
#
# [1.15, 1.15, ['OK let ’ s just pause there for a moment .']]
#
# [1.18, 1.18, ['I ’ ve told you what I ’ m going to say .']]
#
# [1.21, 1.31, ['The question you should be asking is :', " So what ? What ’ s in it for me ? Why should I care ? ''", 'And that is a really important question', 'because the first magic ingredient is in fact the audience .']]
#
# [1.36, 1.36, ['The audience is the magic ingredient in every presentation .']]
#
# [1.39, 1.39, ['This is not my talk it ’ s yours .']]
#
# [1.42, 1.45, ['Every presentation should be made to measure', 'for a specific audience in a specific context .']]
#
# [1.49, 1.58, ['So why should you care about the magic ingredient of great presentation ?', "Well it 's very important right ?", 'It ’ s really important to understand that we all have to listen to presentation .']]
#
# [2.03, 2.18, ['Wouldn ’ t it be great if they weren ’ t all so boring ?', 'But we don ’ t just listen to presentation', 'we also have to give presentations right ?', 'How many of you ever have to give presentation ?', 'I think if we ’ re honest we all do .']]
#
# [2.21, 2.32, ['Sooner or later at school or at work', 'and also in interview', 'we all have to present with or without slide', 'and it ’ s how well we present', 'that will make a huge difference to how well we succeed .']]
#
# [2.36, 2.36, ['That ’ s why you should care .']]
#
# [2.39, 2.39, ['So that ’ s the first magic ingredient : the audience .']]
#
# [2.42, 2.42, ['Always make it special for them .']]
#
# [2.46, 2.46, ['The second magic ingredient is the speaker .']]
#
# [2.5, 2.52, ['Now you ’ re probably looking at me and thinking :', '“ Well Phil not very magical . ”']]
#
# [2.52, 3.02, ['Thanks by the way !', 'But it ’ s really important that you put something of yourself in there', 'something only you can say .']]
#
# [3.05, 3.14, ['This doesn ’ t mean you tell them what you had for breakfast', 'but it doe mean that if someone else', 'could give the exact same presentation in your place', 'then you didn ’ t put anything personal into it .']]
#
# [3.16, 3.2, ['And that matter because when you share', 'we care .']]
#
# [3.21, 3.21, ['So show why you care why it ’ s important to you .']]
#
# [3.25, 3.25, ['Tell u example and story from your experience .']]
#
# [3.29, 3.29, ['And that will make it more personal and more memorable .']]
#
# [3.33, 3.36, ['So those are the first two magic ingredient :', 'the audience and the speaker .']]
#
# [3.38, 3.41, ['I know it doesn ’ t sound very magical', 'but you ’ d be amazed how many presentation have neither of them .']]
#
# [3.46, 3.46, ['So the third magic ingredient is transformation .']]
#
# [3.5, 3.56, ['Now most presentation aim only to inform their audience', 'and it doesn ’ t work very well .']]
#
# [3.58, 4.05, ['Let me take out my magic wand because I ’ m going to do a disappearing trick', 'because like this guy', 'we forget most of what we hear very quickly indeed .']]
#
# [4.11, 4.15, ['But good presentation are not about information', 'they are about transformation .']]
#
# [4.17, 4.22, ['They are about changing something in what your audience belief', 'in what they feel in what they do .']]
#
# [4.25, 4.28, ['Imagine you are making a pitch', 'for raising fund for a project or a start .']]
#
# [4.32, 4.36, ['After your pitch the audience know everything they need to know', 'but they don ’ t fund you .']]
#
# [4.38, 4.39, ['Did you succeed ?', 'No .']]
#
# [4.41, 4.53, ['Now imagine that after your pitch your audience doe give you the fund', 'because they feel confident and trusting', 'and they believe that your project will be successful', 'and that it is a good investment .']]
#
# [4.55, 4.55, ['All of that is not information it ’ s transformation .']]
#
# [5.0, 5.05, ['So it ’ s easy for me to say “ Don ’ t inform transform ! ”', 'but how ?', 'Well every magician need a magic wand and here is yours .']]
#
# [5.1, 5.1, ["It ’ s called the  Audience Transformation Roadmap . ''"]]
#
# [5.1, 5.26, ['This is a really simple but amazingly powerful technique', 'to understand what your transformational objective are', 'and then to brainstorm', 'what you can say show and do to transform your audience .']]
#
# [5.3, 5.3, ['So here ’ s how it work .']]
#
# [5.33, 5.37, ['To understand how to take your audience on a transformational journey', 'you first need to work out where they are starting from .']]
#
# [5.4, 5.57, ['So we ask ourselves four simple question :', 'What doe my audience know before my presentation ?', 'What do they know about the subject ?', 'What do they believe ?', 'And what do they feel ?', 'Now the difference between the two', 'is believing is something you think and feeling is an emotion .']]
#
# [6.0, 6.04, ['So for example I believe it ’ s time for dinner', 'I feel hungry .']]
#
# [6.06, 6.07, ['See the difference ?', 'Right .']]
#
# [6.08, 6.16, ['So what do they know believe and feel and lastly what do they do ?', 'Now this could be nothing maybe they do nothing relevant', 'or maybe they do something that you need to change .']]
#
# [6.21, 6.23, ['So once you ’ ve worked out where they are before', 'you can then take them to where you want them to go afterwards .']]
#
# [6.26, 6.26, ['And we ask the same four question but in the reverse order .']]
#
# [6.31, 6.31, ['So now we know what they do before .']]
#
# [6.32, 6.52, ['What do we want them to do after the presentation ?', 'What do they need to feel ?', 'What should they believe differently to feel and do those thing ?', 'And lastly what do they need to know ?', 'And when you follow this process', 'you realize very quickly that the real transformation', 'are not in what they know it ’ s in what they believe and feel and do .']]
#
# [6.56, 6.56, ['That ’ s what make the difference .']]
#
# [6.59, 7.1, ['Once we ’ ve understood where they are and where we need to take them', 'then we can fill in the Transformation Column', 'with all of the idea on what we can say in our presentation', 'to make those transformation in our audience .']]
#
# [7.13, 7.13, ['And that give u the content of the presentation .']]
#
# [7.17, 7.3, ['Clear so far ?', 'Maybe we should take an example so let ’ s take one !', 'Let ’ s assume that I am going to make a presentation', "and I 'd like to explain the three magic ingredient of a great presentation", 'and I ’ d like to make my audience want to use the Audience Transformation Roadmap .']]
#
# [7.35, 7.43, ['So what doe my audience know before the presentation ?', 'Well they know that most presentation aren ’ t exactly successful', 'and they know TED is the exception that prof that rule .']]
#
# [7.47, 7.48, ['What do they believe ?', 'Probably like most people they believe presentation are for sharing information .']]
#
# [7.53, 7.53, ['It might be wrong but that doesn ’ t stop them believing it .']]
#
# [7.57, 8.05, ['What do they feel about presentation ?', 'Probably bored but also resigned to a really ineffective way of presenting', 'because that ’ s just what everyone doe .']]
#
# [8.08, 8.15, ['And lastly what do they do ?', 'Well when it ’ s their turn to present', 'they generally will pack thing full of information', 'and they won ’ t personalize it to their audience .']]
#
# [8.18, 8.27, ['So what do I want them to do after my presentation ?', 'Well afterwards I ’ m going to want them', 'to aim to transform their audience every time they present', 'to change something in their audience .']]
#
# [8.29, 8.29, ['I ’ m going to need them to personalize their presentation every time .']]
#
# [8.34, 8.38, ['And also I ’ d like them to use the Audience Transformation Roadmap', 'because I know it will help them to succeed .']]
#
# [8.42, 8.45, ['What do they need to feel to do those thing ?', 'Well If they still feel bored or resigned they ’ re not going to do very much .']]
#
# [8.49, 8.55, ['So they need to feel curious about this new technique', 'they need to feel motivated to try it', 'and optimistic that it can work for them .']]
#
# [8.58, 9.03, ['What do they need to believe to feel those thing ?', 'They ’ ll need to believe that the Roadmap', 'can actually help them to succeed in their presentation .']]
#
# [9.06, 9.1, ['Lastly what do they need to know to believe feel and do those thing ?', 'Well they ’ ll need to know the three magic ingredient that ’ s pretty basic .']]
#
# [9.14, 9.17, ["They 'll need to know presentation are bad at information", 'but great at transformation .']]
#
# [9.19, 9.19, ['And they ’ ll need to know how to use the Audience Transformation Roadmap .']]
#
# [9.24, 9.24, ['OK now we ’ ve worked out where they were and where I want to take them .']]
#
# [9.29, 9.29, ['What can I do now ? I fill in the Transformation Column .']]
#
# [9.32, 9.38, ['So what can I say or show or do to make those transformation ?', 'Now usually I ’ m using a flip and some sticky note here .']]
#
# [9.43, 9.43, ['So I ’ m going to use virtual sticky note .']]
#
# [9.45, 9.45, ['Let ’ s start at the top .']]
#
# [9.47, 9.53, ['We need to make sure they know the three magic ingredient', 'so I ’ m going to need to talk at some point about the audience', 'about the speaker and the transformation .']]
#
# [9.56, 9.59, ['They need to know presentation are bad at information', 'so maybe I should tell them that we forget most of what we hear very quickly .']]
#
# [10.03, 10.03, ['And perhaps I can find a visual way to show that a well .']]
#
# [10.08, 10.12, ['What next ? They need to know how to use the Roadmap so I ’ d better show it to them', 'and I guess I could make it even clearer by going through an example .']]
#
# [10.16, 10.17, ['They need to believe', 'that the Roadmap can help them to succeed in their presentation .']]
#
# [10.21, 10.3, ['So I ’ ll need to show how easy it is', 'to take all of these sticky note off of the Transformation Column', 'and arrange them in a suitable order', 'to create the storyline for their presentation .']]
#
# [10.32, 10.32, ['It really is a short .']]
#
# [10.34, 10.34, ['OK now I need to make them curious .']]
#
# [10.36, 10.4, ['Now to make them curious I ’ m going to need to make them care', 'and to make them care I need to show that I care .']]
#
# [10.43, 10.48, ['So I probably need to explain that most presentation really don ’ t succeed', 'and that I care about fixing that .']]
#
# [10.51, 10.53, ['And then to make them care', 'I ’ m going to need to find out how relevant it is to them .']]
#
# [10.57, 11.01, ['Perhaps I could ask them how many of them actually need to present', 'and of course I know the answer is pretty much everybody .']]
#
# [11.04, 11.04, ['I need to make them motivated and optimistic .']]
#
# [11.06, 11.1, ['Well I can make them optimistic by explaining how easy this is to use', 'but also how powerful it is .']]
#
# [11.12, 11.18, ['And to motivate them to try it', 'I ’ m going to need to explain that successful presentation', 'can really make a difference to how well they succeed in life .']]
#
# [11.24, 11.27, ['Lastly to make them do these thing I ’ ll need a call to action', 'which focus on what I want them to do afterwards .']]
#
# [11.31, 11.36, ['So there we have it !', 'That ’ s a very accelerated version of the brainstorming', 'but it doesn ’ t need to take long .']]
#
# [11.38, 11.42, ['What we have now is just enough relevant idea', 'on how we can transform our audience .']]
#
# [11.45, 11.5, ['So what happens next ?', 'Well this is where I ’ m going to take my magic wand out again', 'because this is where the presentation magic happens .']]
#
# [11.52, 12.09, ['This is where you can take all the sticky note off of the Transformation Column', 'prepare a suitably magical story line', 'and then arrange all of these idea back into that story line', 'and hey presto there is my presentation !', 'Now you might recognize this one because ...']]
#
# [12.12, 12.12, ['this is the presentation you have been watching for the last ten minute .']]
#
# [12.17, 12.17, ['And this is where we are now .']]
#
# [12.2, 12.25, ['Isn ’ t that magic ?', 'So now you know what happens next !', 'Next I need to explain how simple this can be and how powerful .']]
#
# [12.29, 12.29, ['And it ’ s so simple that it doesn ’ t take an expert .']]
#
# [12.32, 12.39, ['Thousands of people have already used this technique', 'to prepare and deliver fantastic presentation of all kind', 'from TED talk to the boardroom .']]
#
# [12.42, 12.55, ['But more than presentation they ’ ve used it also for email', 'for proposal for preparing interview for preparing conference …', 'Basically it work in any situation', 'where you need to change what people believe feel and do .']]
#
# [12.59, 12.59, ['You really don ’ t need a magic wand .']]
#
# [13.02, 13.02, ['This is all the magic you need .']]
#
# [13.1, 13.1, ['Thank you .']]
#
# [13.14, 13.14, ['Thank you . So now I need to give you a call to action and here it is .']]
#
# [13.14, 13.14, []]
#
# [13.2, 13.26, ['Remember those three magic ingredient of every great presentation :', 'the audience the speaker', 'and the transformation you want to create in your audience .']]
#
# [13.3, 13.34, ['Try using the Audience Transformation Roadmap for your next presentation', 'and you ’ ll be amazed at how well your idea resonate with your audience .']]
#
# [13.4, 13.4, ['And lastly please remember I need your help .']]
#
# [13.44, 13.44, ["I ca n't cure the world of bad presentation on my own ."]]
#
# [13.51, 13.57, ['But together we really can make a difference !', 'So by all mean share this with anyone you know', 'who need a dose of presentation magic .']]
#
# [14.0, 14.02, ['It could be your colleague your teacher your bos', 'but you all know someone .']]
#
# [14.04, 14.08, ['And most of all every time you get to present', 'focus not on informing but on transforming your audience .']]
#
# [14.12, 14.21, ['That ’ s where the magic happens', 'and if you can succeed in changing', 'what your audience belief feel and doe', 'there truly is no limit to what you can achieve .']]
#
# [14.26, 14.26, ['Thank you .']]
#
# ********* END of Video ***************
#
# [0.01, 0.01, ["Hi I 'm Jason Teteak ."]]
#
# [0.02, 0.11, ['I help people overcome their fear of public speaking and deliver amazing presentation', "and today I 'm going to show you how to captivate your audience within the first 5 minute of", 'your presentation .']]
#
# [0.13, 0.13, ["Here 's how I 'm going to do it . ''"]]
#
# [0.13, 0.14, ["I 'm going to show you 5 step to deliver a killer opener . ''"]]
#
# [0.14, 0.38, ["If you 're watching this you probably already know that delivering great presentation is", 'critical to advance your career but did you know that research say that most adult will', "stop listening to your presentation within the first 10 minute if they are n't convinced", "there 's something in it for them ?", "The problem is that most people do n't know about the skill they need to hook their audience", 'give a great presentation and overcome their fear of doing it .']]
#
# [0.43, 0.44, ['What am I going to do ?', 'Hi Jim .']]
#
# [0.45, 0.46, ["How 's it going ?", "I 'm freaking out about this big presentation I have to give tomorrow ."]]
#
# [0.5, 0.53, ['Well did you write out your opener and practice it three time ?', 'No .']]
#
# [0.54, 0.56, ['No ?', 'Why not ?', "I 'm terrified and I do n't even know where to start ."]]
#
# [1.0, 1.0, ["Trust me I 've been in that situation before and it 's not fun ."]]
#
# [1.03, 1.09, ["So to help you out I 'm going to show you my 5 step formula to deliver a killer presentation", 'opener every time .']]
#
# [1.1, 1.1, ["Let 's start off with step number one which is Give a Confident Introduction . ''"]]
#
# [1.1, 1.15, ['One of the biggest mistake people make when they start their presentation is showing nervousness .']]
#
# [1.21, 1.21, ["Here 's the key : It 's not whether you 're nervous it 's whether you show it ."]]
#
# [1.25, 1.25, ['The first thing you need to do is stand STILL .']]
#
# [1.28, 1.28, ["Do n't move ."]]
#
# [1.29, 1.29, ["Do n't pace and keep your hand at your side ."]]
#
# [1.33, 1.38, ['This is the most calm and confident stance on the planet and it handle the number 1', 'need of your audience which is to feel safe .']]
#
# [1.41, 1.41, ["Now you can introduce yourself and say Hi my name is Jason Teteak . ''"]]
#
# [1.41, 1.46, ['When you do this bring your inflection down at the end to show confidence .']]
#
# [1.51, 1.53, ["Instead of : Hi my name is Jason Teteak ? ''", "Say : Hi my name is Jason Teteak . ''"]]
#
# [1.53, 1.58, ['See the difference ?', 'Now we move on to step 2 which is Give Your Credentials .']]
#
# [2.03, 2.08, ['This is where many presenter make the mistake of simply giving their title and year of', 'experience .']]
#
# [2.09, 2.13, ["They say something like I 'm a presentation skill coach and I 've been doing it for 20", "year . ''"]]
#
# [2.13, 2.22, ["Yet your audience want to know : What can you do for me ? ''", "They need to know who you are why you 're the best person to deliver this presentation", 'and what you have to offer them .']]
#
# [2.24, 2.3, ['For example I might say I help people overcome their fear of public speaking and deliver', "amazing presentation . ''"]]
#
# [2.3, 2.35, ['What would that look like for you ?', 'To figure this out you need a short elevator speech .']]
#
# [2.38, 2.42, ['It look like this : You know how some people have this problem ?', "Well I offer this solution . ''"]]
#
# [2.42, 2.45, ['The solution you offer is how you help people .']]
#
# [2.48, 2.55, ['For me it wa : You know how some people have a fear of public speaking and a have', 'hard time getting their message across in a presentation ?', "Well I help them overcome their fear of public speaking and deliver amazing presentation . ''"]]
#
# [2.55, 3.05, ["What 's your credential statement ?", "You 'll be amazed at the effect this ha on your audience ."]]
#
# [3.07, 3.07, ["Step 3 is to Deliver Your Hook . ''"]]
#
# [3.07, 3.16, ["My hook for this video presentation might look something like this I 'm going to show", "you how to captivate your audience within the first 5 minute of your presentation . ''"]]
#
# [3.16, 3.21, ["When you do this you have to get your audience to feel '' something ."]]
#
# [3.25, 3.27, ['How do you get them to feel ?', 'You have 3 choice .']]
#
# [3.28, 3.28, ['You can get them to feel more happy more successful or more free .']]
#
# [3.33, 3.33, ['Look at my hook .']]
#
# [3.35, 3.4, ["I said I 'm going to show you how to captivate your audience within the first 5 minute of", "your presentation . ''"]]
#
# [3.4, 3.54, ["When you captivate your audience within the first 5 minute of your presentation you 'll", "feel happier because they are listening to you you 'll feel more successful because you", "look like an expert and you 'll feel more freedom when you spend le time worrying", 'about your presentation the night before .']]
#
# [3.57, 3.57, ["Here 's the practical for you ."]]
#
# [3.58, 3.58, ["For your presentation write down the word I 'm going to show you. '' then fill in the"]]
#
# [3.58, 4.08, ["rest with something that 's going to create more happiness success or freedom for your", 'audience .']]
#
# [4.09, 4.09, ["Here 's the rule ."]]
#
# [4.1, 4.14, ["You ca n't tell them WHAT they 're going to get until you 've told them WHY they would", 'want it .']]
#
# [4.15, 4.2, ["Your hook ha to be something that get them to BELIEVE that they want what you 're going", 'to give them .']]
#
# [4.22, 4.27, ['Take a moment right now and write down WHY your presentation will make your audience', 'more happy successful or free in their life .']]
#
# [4.31, 4.31, ["And now we move on to step number 4 which is to Introduce Your Agenda . ''"]]
#
# [4.31, 4.41, ['I recommend you use a PowerPoint for this step and the slide should look something', 'like this .']]
#
# [4.44, 4.48, ['The purpose of this step is to show your audience the takeaway for your presentation the', "thing they get to take away '' and use tomorrow after listening to your presentation ."]]
#
# [4.54, 4.54, ["Do n't read the slide ."]]
#
# [4.55, 4.55, ["They 're adult ."]]
#
# [4.56, 4.56, ['They can read .']]
#
# [4.57, 5.01, ['Instead just give them a moment to read it themselves and introduce your agenda by summarizing', "what you 'll be doing ."]]
#
# [5.03, 5.08, ["You do this by mentioning the number of takeaway you 'll be giving them and paraphrasing the", 'goal of your presentation .']]
#
# [5.09, 5.11, ["Here 's what it look like :", "I 'm going to show you 5 step to deliver a killer opener . ''"]]
#
# [5.11, 5.19, ['What would this look like for you ?', 'The last step is Step 5 Give a Credible Statement .']]
#
# [5.23, 5.23, ['You can do this by giving relevant or compelling data to your audience to support your message .']]
#
# [5.27, 5.51, ['Remember how I did this at the beginning of this video ?', 'I said You probably already know that delivering great presentation is critical to advance', 'your career but did you know that research say that most adult will stop listening', "to your presentation within the first 10 minute if they are n't convinced there 's something", "in it for them ? ''", 'When you do this within the first 2 minute of your presentation your audience start', 'to trust you .']]
#
# [5.53, 5.58, ["Without bragging your listener start to think oooh this guy know what he 's talking", "about ''", 'Done .']]
#
# [5.59, 6.03, ['When I put those 5 step together it sound like this :', "Hi I 'm Jason Teteak ."]]
#
# [6.05, 6.14, ['I help people overcome their fear of public speaking and deliver amazing presentation', "and today I 'm going to show you how to captivate your audience within the first 5 minute of", 'your presentation .']]
#
# [6.16, 6.16, ["Here 's how I 'm going to do it . ''"]]
#
# [6.16, 6.17, ["I 'm going to show you 5 step to deliver a killer opener . ''"]]
#
# [6.17, 6.4, ['You probably already know that delivering great presentation is critical to advance', 'your career but did you know that research say that most adult will stop listening', "to your presentation within the first 10 minute if they are n't convinced there 's something", "in it for them ? ''", 'Wow !', 'Do you see how powerful that is ?', 'Those are the 5 step to deliver a killer presentation opener whenever you do a presentation .']]
#
# [6.46, 6.46, ['I know this is a lot of information for you to take in .']]
#
# [6.49, 6.53, ['For that reason I put together some free video training for everyone who stayed to', 'the end of this video .']]
#
# [6.55, 6.59, ["You 'll not only learn how to give a killer opener but the exact skill and specific", 'technique you need to nail your entire presentation .']]
#
# [7.03, 7.08, ['To get your free training all you need to do is click the button right here or the', 'link below in the description .']]
#
# [7.1, 7.1, ['So go on get your free training and click that link below .']]
#
# [7.15, 7.19, ['I hope you enjoyed this video and if you did let me know by leaving a comment hitting', 'the thumb up button and subscribing to my channel .']]
#
# [7.23, 7.28, ['This is Jason Teteak from ruletheroom.com and you just learned the 5 step to deliver', 'a killer opener every time you give a presentation .']]
#
# ********* END of Video ***************
#
# [0.0, 0.07, ['We ve worked in the live event and', 'production industry for over 40 year', 'and have worked with hundred of', 'presenter all over the world. In this']]
#
# [0.07, 0.16, ['video we are going to share with you our', 'top 10 tip guaranteed to make you a', 'better presenter. So let s get started,']]
#
# [0.16, 0.19, ['number one focus on the audience. Your']]
#
# [0.19, 0.26, ['presentation is not about you, it s about', 'the audience. What benefit will the']]
#
# [0.26, 0.26, ['audience. get from listening to you What']]
#
# [0.29, 0.42, ['do you want them to think feel and do a', 'a result of listening to you once you', 'have these clear objective in Your mind,', 'you are on Your way to delivering a', 'winning presentation. Number two']]
#
# [0.42, 0.49, ['delete all excess text from your slide', 'load of bullet point. On your slide']]
#
# [0.49, 0.52, ['are a complete waste of time. Nobody']]
#
# [0.52, 0.55, ['actually read them. The brain is a self']]
#
# [0.55, 0.58, ['organizing mechanism. If you use slide']]
#
# [0.58, 1.03, ['like these, you re sending a signal', 'directly to the audience. to start']]
#
# [1.03, 1.03, ['daydreaming. Your slide are not your']]
#
# [1.05, 1.08, ['speaker, note, use powerful image and', 'picture. They are much more effective in']]
#
# [1.11, 1.14, ['getting your message across number. Three.']]
#
# [1.18, 1.18, ['Keep it simple. Le really is more get']]
#
# [1.18, 1.26, ['used to cutting out material, including', 'your presentation. only what really']]
#
# [1.26, 1.31, ['matter this is a difficult process, but', 'think back to point. one. What do you want']]
#
# [1.31, 1.44, ['The audience to think feel and do If', 'Your content doe nt, match your answer', 'to these question? Cut it out', 'use the same language that you d use', 'while explaining your presentation. to a']]
#
# [1.44, 1.48, ['friend in the local pub over a pint and', 'try to use simple. wording to to make']]
#
# [1.48, 1.52, ['Your content clear and easy to', 'understand.']]
#
# [1.55, 1.55, ['Rule of Three. can be really effective.']]
#
# [1.55, 1.55, []]
#
# [1.59, 2.04, ['rehearse the biggest single difference a', 'presenter. can make to their performance']]
#
# [2.07, 2.12, ['is to stand up in front of the bathroom', 'mirror', 'amra her.']]
#
# [2.13, 2.18, ['If you are serious about success, then', 'you need to get serious about rehearsing', 'and If you do nt, prepare them. prepare to']]
#
# [2.18, 2.33, ['fail number five is especially important', 'if you re speaking at an event or away', 'from your usual place of work, make', 'friend with the crew and the people at', 'the venue. The crew can play a huge part']]
#
# [2.33, 2.46, ['in Your success, and If you are rude and', 'arrogant they ll enjoy watching you fail', 'get there early', 'make friend with them learn their name', 'and ask them for help and advice. Ask']]
#
# [2.46, 2.49, ['politely for a sound check.']]
#
# [2.51, 3.0, ['Ask to view your PowerPoint slide On', 'The big screen you can see where I m', 'going with this this preparation will', 'ease your nerve and raise your', 'confidence before your presentation.']]
#
# [3.02, 3.02, ['start number. six. Now this is a much']]
#
# [3.02, 3.16, ['debated point, but we always say: dress to', 'impress if you are in any doubt about', 'What to wear be smart, smart, hair, smart,', 'shoe, smart dress sense. Do nt fall into']]
#
# [3.16, 3.22, ['the trap of getting up on stage looking', 'casual because you ll only look scruffy.']]
#
# [3.24, 3.31, ['If it s smart, casual dress, wear always', 'go the smarter side of casual better for', 'people to say: wow. She look smart, rather']]
#
# [3.31, 3.34, ['than God she could have made an effort.']]
#
# [3.37, 3.39, ['Number seven', 'make friend with yourself and be', 'comfortable.']]
#
# [3.42, 3.48, ['Do nt create a Pasha version of the real', 'you, someone who us big word and try', 'to disguise a regional accent. You are']]
#
# [3.48, 3.48, ['unique. You are special! Nobody is quite']]
#
# [3.52, 3.58, ['like you So stick to the real you, be', 'authentic and the audience. will believe']]
#
# [3.58, 4.01, ['in you number eight stand still. Everyone']]
#
# [4.01, 4.11, ['feel a rush of adrenaline a They stand', 'up ready to speak in front of an', 'audience a adrenaline flow through the', 'body. Your body. will get ready for fight']]
#
# [4.14, 4.14, []]
#
# [4.14, 4.16, ['or flight. The lactic acid build up in']]
#
# [4.16, 4.21, ['Your muscle tissue and you will feel an', 'overwhelming need to move. This is What']]
#
# [4.21, 4.25, ['we call we', 'moving. An advanced stage of weaving is']]
#
# [4.26, 4.29, ['prowling from one. end of the stage to']]
#
# [4.29, 4.37, ['the other, lock out your hip, and imagine', 'that your foot are stuck to the floor.']]
#
# [4.39, 4.39, ['You still. have plenty of room to move.']]
#
# [4.39, 4.39, []]
#
# [4.42, 4.44, ['around', 'number 9. Tell a story.']]
#
# [4.44, 4.44, []]
#
# [4.47, 4.52, ['Forget the corporate spiel and all those', 'text slide that Nobody will read Tell', 'the audience. a story. engage in a']]
#
# [4.52, 4.52, []]
#
# [4.52, 4.55, ['conversation with the audience. and then']]
#
# [4.55, 5.0, ['and only then talk about target and', 'measurable goal. I guarantee you that']]
#
# [5.0, 5.03, ['the audience. will remember a story. that']]
#
# [5.03, 5.03, []]
#
# [5.03, 5.12, ['relates to Your key message, rather than', 'a barrage load of slide The final point', 'that will make you an even better', 'presenter. is be enthusiastic. Nothing']]
#
# [5.13, 5.13, []]
#
# [5.13, 5.26, ['absolutely nothing succeeds like', 'enthusiasm, it s infectious', 'once The audience can spot that you have', 'a passion for Your subject. They ll']]
#
# [5.26, 5.36, ['immediately begin to warn to you and', 'will ignore any imperfection or', 'omission in Your presentation so get', 'passionate, get excited and get', 'enthusiastic. We hope you find these tip']]
#
# [5.36, 5.51, ['passionate, get excited and get', 'enthusiastic. We hope you find these tip', 'helpful the next time that you have to', 'present in front of an audience Please', 'do get in touch with? U, if you have any', 'question or would like to have a chat,', 'we d love to hear from you?']]
#
# ********* END of Video ***************
#
# [0.0, 0.05, ['Hello, everybody welcome to this video on', 'tutorial point today we will talk in', 'detail about presentation, skill. Well, I']]
#
# [0.05, 0.07, ['would like you to imagine a situation.']]
#
# [0.09, 0.15, ['Have you at any point in your school, in', 'your college or at your workplace ever', 'faced a situation. like this, where, in']]
#
# [0.15, 0.47, ['your teacher or your bos at work, ha', 'asked you to give a good presentation on', 'a particular topic in front of a group', 'of people? Well, what are the feeling', 'that you go to? Do you feel challenged', 'anxious nervous or you feel like hiding', 'under your bed and never coming out', 'again? Well, if you go through such', 'feeling, this is a video tutorial I', 'would really urge you to watch out for', 'because today we are going to talk in', 'detail about how to give a good', 'presentation and an effective', 'presentation. Well, let s get started.']]
#
# [0.49, 0.49, []]
#
# [0.51, 1.21, ['Let s see what is there on the agenda', 'today? We will talk about what is a', 'presentation what are the step of a', 'good presentation', 'anatomy of a successful presentation and', 'that s the crux of our module today,', 'adding your own flavor in your', 'presentation how to structure your', 'presentation and what is the checklist', 'for a successful presentation Well, this,', 'is what is in store for u today and I m', 'very excited to teach you because this', 'is one of my personal favorite topic. So']]
#
# [1.21, 1.24, ['let s get started. well, if you Have to']]
#
# [1.24, 1.43, ['define what is a presentation what Do', 'you exactly mean by the word', 'presentation? Let s look at that Well, a', 'lot of people? actually have a nightmare', 'when it come to giving a presentation', 'in a room full of people? it is not an', 'easy task, I must say when I started.']]
#
# [1.46, 1.46, ['training a couple of year back. I']]
#
# [1.46, 1.58, ['actually felt another breakdown because', 'of the fact that I had to give a', 'presentation in front of a room of', 'people? I felt dizzy a Well, a nervous', 'and my hand started to sweat. Well, this,']]
#
# [1.58, 2.11, ['is a phenomenon which happens with most', 'of the people They get a nightmare about', 'giving a presentation you Have a fear of', 'phobia, and that is something which we', 'will challenge today in our', 'datian. Well, we Have to define what']]
#
# [2.13, 2.24, ['exactly is a presentation let s look at', 'that it is a process of presenting the', 'content of a topic through an audience', 'which is consisting of one or more', 'people. It utilizes some kind of a visual']]
#
# [2.26, 2.26, ['aid.']]
#
# [2.3, 2.36, ['It is generally a PowerPoint file', 'containing all the slide for a given', 'content or a speech. Well, it is a slide']]
#
# [2.36, 2.39, ['form of a PowerPoint presentation. you']]
#
# [2.39, 2.5, ['need to put together thing on a slide', 'in term of a PowerPoint and place it in', 'front of an audience That is exactly', 'what we mean by the term presentation.']]
#
# [2.54, 2.57, ['let s look at what are the step of', 'giving a good order, an effective', 'presentation. there are certain step']]
#
# [3.0, 3.04, ['which will help? U let s look at that', 'the fourth is a strategy. Secondly, a good']]
#
# [3.04, 3.16, ['structure of a presentation presentation', 'skill wherein big presentation actually', 'happens and the fourth handling', 'question of the participant well', 'friend. Today we are going to discus in']]
#
# [3.18, 3.25, ['detail about all of these four step,', 'which will in turn, help u to make an', 'effective presentation. when the first']]
#
# [3.25, 3.31, ['step of actually giving our presentation,', 'is formulating a strategy. Now, whenever']]
#
# [3.31, 3.38, ['your teacher at school, or your bos at', 'work, ha given You this entire project', 'of making a presentation the first thing', 'friend. you need to Do is make a']]
#
# [3.41, 3.41, ['strategy. What is expected out of you Why']]
#
# [3.43, 3.52, ['are you making the presentation the', 'need of the presentation need to be', 'clear, so you need to ask yourself', 'certain question ridge. You need to']]
#
# [3.52, 3.54, ['know the purpose of the communication.']]
#
# [3.56, 4.0, ['What exactly are we trying to show to', 'people? with the help? of this', 'presentation, your communication. need to']]
#
# [4.0, 4.04, ['be clear, you should know the audience', 'and their expectation. You should tailor']]
#
# [4.04, 4.15, ['your presentation according to the', 'audience Well, a presentation is not', 'about you it is about the audience', 'completely about the audience You need', 'to understand what their expectation.']]
#
# [4.18, 4.25, ['from this particular presentation is', 'what are their like? Their dislike, what', 'part of the society they are coming from', 'and what kind', 'language they speak. When you know Your']]
#
# [4.25, 4.3, ['audience You will be able to completely', 'tailor make according to their', 'requirement. You need to be concrete,']]
#
# [4.31, 4.39, ['specific, practical and relevant, meaning', 'your presentation should not be out of', 'the box, which ha, to be whatever is the', 'requirement. You need to make your']]
#
# [4.41, 4.47, ['presentation around that, and your', 'presentation need to be brief and to', 'the point. It should not be too elaborate']]
#
# [4.47, 4.49, ['and it should not be over. You']]
#
# [4.49, 5.13, ['need to make It relevant, to the audience', 'be clear, about your objective, whether', 'your objective, of the presentation is to', 'motivate people to persuade people to', 'inform them about something or draw the', 'distance teach them about something You', 'need to be clear, and rather, I would say', 'be crystal clear on what is the purpose', 'of your presentation and accordingly, you', 'need to make your presentation research.']]
#
# [5.16, 5.16, ['Your topic thoroughly. A presentation can']]
#
# [5.16, 5.19, ['be a complete disaster.']]
#
# [5.22, 5.28, ['If you Do not have researched your topic', 'completely You need to know in and out', 'about that topic. because you need to be']]
#
# [5.28, 5.3, ['prepared completely and thoroughly. on']]
#
# [5.3, 5.32, ['that topic. this my friend. is the first']]
#
# [5.32, 5.32, []]
#
# [5.32, 5.37, ['step of giving a good presentation know', 'Your strategy or formulate your strategy.']]
#
# [5.4, 5.43, ['moving on to the second step, which is', 'developing of flexible and a flowing', 'structure. Now, once you know What is the']]
#
# [5.45, 5.58, ['purpose of your presentation you need to', 'make a structure around that, particular', 'presentation let s look at this, step', 'after knowing what you Have to say you', 'need to organize all the material in a', 'very structured manner. You need to']]
#
# [5.58, 5.58, ['research. Your topic get all the data, but']]
#
# [6.0, 6.05, ['with all this data, you can not give a', 'presentation you need to edit it. You']]
#
# [6.05, 6.07, ['need to make It very very polished. Hence']]
#
# [6.07, 6.13, ['you need to make It crystal clear do nt', 'assume that information will speak. by']]
#
# [6.13, 6.17, ['itself? You are the presenter and you', 'need to speak. on that particular topic a']]
#
# [6.17, 6.25, ['presentation will not talk by itself?', 'Audience might interpret the information', 'in different way. Everybody ha a']]
#
# ...
#
# [3.23, 3.31, ['how often you think They able to', 'answer the question correctly:', 'twenty percent', '33 percent. The answer is ninety']]
#
# [3.31, 3.41, ['percent of the time,', 'statistically, just amazing and it,', 'prof the power of team. I want to say']]
#
# [3.41, 3.45, ['a few thing, about winning. Did you know.']]
#
# [3.45, 3.45, []]
#
# [3.48, 4.25, ['that in all the major golf tournament', 'over the last 25 year,', 'the margin of victory ha been le than', 'three stroke in Formula one motor', 'racing so far this season, the average', 'time difference between first and second', 'place ha been just over seven and a', 'half second and Remember last summer,', 'olympics in the 100 meter', 'butterfly the American swimmer, worn by', 'one hundredth of a second', 'one hundredth it wa so close that the', 'Serbian team, who won silver even filed a', 'protest. The']]
#
# [4.28, 4.3, ['these day in business a in sport. The']]
#
# [4.3, 4.36, ['difference between winning and losing is', 'practically zero, but not quite in every', 'case. The winner ha that vital edge. The']]
#
# [4.42, 4.42, []]
#
# [4.42, 4.51, ['figure going to show you this', 'afternoon demonstrate that we too have', 'that marginal but vital edge. From your']]
#
# [4.51, 5.02, ['audience point of view, the end of your', 'talk might be even more important than', 'the beginning. These are the word they']]
#
# [5.02, 5.04, ['will be left with after you stop. If']]
#
# [5.04, 5.1, ['you ever been to a firework display,', 'you know. that the biggest brightest']]
#
# [5.1, 5.13, ['firework are usually saved. For the end']]
#
# [5.13, 5.21, ['this doe mean you have to finish', 'with a bang, but you do want to leave a', 'lasting impression', 'watch. These presenter clinch the']]
#
# [5.22, 5.25, ['clothes, to summarise. Whenever we have']]
#
# [5.25, 5.41, ['offered bonus to incentivize our staff', 'in sale, HR and manufacturing division,', 'productivity ha increased in some case', 'quite dramatically, but a we saw In R & D.']]
#
# [5.47, 5.49, ['Introducing pay by performance ha had', 'precisely the opposite effect.']]
#
# [5.52, 5.59, ['Incentivized research unit were, on', 'average only half a productive, a those', 'working without added incentive. What']]
#
# [5.59, 6.08, ['are we to make of this Well, quite simply,', 'it seems bonus really do make you work', 'harder when your job. is pretty routine,']]
#
# [6.08, 6.11, ['but when your job. is creative incentive.']]
#
# [6.11, 6.11, []]
#
# [6.15, 6.26, ['Just stress you out and actually make', 'you le creative not all Clearly we all', 'need to go away and think of a fresh', 'initiative for motivating our most', 'mission. Employee thanks a lot']]
#
# [6.29, 6.32, ['a you know. it a tradition in Asia. To']]
#
# [6.32, 6.32, []]
#
# [6.32, 6.39, ['quote word of wisdom So I going to be', 'totally predictable and do the same.']]
#
# [6.41, 6.45, ['An ancient philosopher once said a man,', 'who chase two rabbit catch. Neither']]
#
# [6.45, 6.5, ['in our research been chasing too many', 'rabbit for far too long. it, time, to']]
#
# [6.5, 6.5, ['stop. to prioritize. If one thing,']]
#
# [6.52, 6.52, []]
#
# [6.52, 6.55, ['we now. need to do in a word it This']]
#
# [6.55, 6.55, ['focus. Thank you very much']]
#
# [6.59, 7.06, ['at the preparation stage, a lot of', 'presenter like to create their clothes.']]
#
# [7.08, 7.08, ['first, so They know. where going']]
#
# [7.08, 7.13, ['and then work backwards finishing up', 'with an attention opening. But']]
#
# [7.13, 7.22, ['whichever way you plan your talk, make', 'sure you always give priority to the', 'first and last three minute.']]
#
# ********* END of Video ***************
#
# [0.07, 0.09, ['Anyone who ha watched a Steve Jobs', 'keynote will tell you. He is one of the']]
#
# [0.09, 0.27, ['most extraordinary speaker in corporate', 'America who doe the best job of that,', 'while most presenter simply convey', 'information Jobs inspires carmine', 'gallo and today walk you through', 'several key technique. That Steve Jobs']]
#
# [0.27, 0.31, ['us to electrify his audience', 'element you can adopt in your very next', 'presentation. Welcome to Macworld 2008.']]
#
# [0.33, 0.33, []]
#
# [0.39, 0.48, ['got some some great stuff for you,', 'clearly something in the air', 'today with those word job open,', 'Macworld, 2008 setting the theme for his', 'presentation. and hinting at a major']]
#
# [0.51, 1.02, ['announcement of the day,', 'the launch of the ultra MacBook Air,', 'whether a new notebook Or the', 'iPhone Jobs unveils a single headline', 'that set the theme today. Apple is going']]
#
# [1.02, 1.16, ['to reinvent the phone once you identify', 'a theme make sure clear and', 'consistent throughout the presentation.']]
#
# [1.17, 1.17, ['Think of a staff meeting, a a', 'presentation. so, say a sale']]
#
# [1.19, 1.25, ['manager introducing a new software tool', 'to help your team generate track and', 'share sale lead. You might kick off']]
#
# [1.25, 1.28, ['your meeting, this way', 'good morning. Thanks for coming. I know']]
#
# [1.28, 1.28, []]
#
# [1.28, 1.31, ['you be really excited about this', 'today. We make it easier for you, to make']]
#
# [1.33, 1.35, ['your quota. the headline easier to']]
#
# [1.35, 1.38, ['make quota. it memorable and it set']]
#
# [1.38, 1.45, ['the direction for the rest of your', 'meeting, it give your audience a reason', 'to listen. So got four thing:']]
#
# [1.45, 1.57, ['like to talk about with you today', 'get started', 'Steve Jobs always provides an outline', 'for his presentation. and then verbally']]
#
# [1.57, 2.02, ['open and close each section with a', 'clear transition in between an', 'example. So time, capsule a perfect']]
#
# [2.04, 2.12, ['companion to leopard and That the', 'first thing I wanted to share with you', 'this morning.']]
#
# [2.17, 2.3, ['the point is: make it easy for your', 'listener to follow your story, your', 'outline will serve a guide post along', 'the way', 'you also notice that, during his', 'presentation. Jobs us word like']]
#
# [2.32, 2.35, ['extraordinary amazing and cool. He is']]
#
# [2.35, 2.44, ['passionate, enthusiastic and it show', 'incredible unbelievable amazing awesome', 'extraordinary year forever.']]
#
# [2.47, 2.52, ['You know your audience want to be wowed', 'not put to sleep too many people fall', 'into this presentation mode. If stiff is']]
#
# [2.52, 3.03, ['formal, it lack pizzazz, we your', 'listener are giving you permission to', 'have fun and to be excited about your', 'company, your product or your service. If']]
#
# [3.03, 3.07, ['you not passionate about it we not', 'going to be remember. Job selling']]
#
# [3.07, 3.15, ['hardware selling an experience. If']]
#
# [3.15, 3.24, ['you offer number and statistic make', 'them meaningful, we have sold four', 'million iPhones to date. divided']]
#
# [3.24, 3.28, ['four million by two hundred day.']]
#
# [3.3, 3.53, ['20000 iPhones every day on average', 'number, mean much unless', 'placed in context manager connect the', 'dot for your listener Recently I', 'worked with a company, that launched a 12', 'gigabyte memory card 12 gigabyte that', 'number mean much to most people', 'So we put into context we said', 'enough memory to listen. to your music,']]
#
# [3.53, 3.59, ['while traveling to the moon and back now,', '12 gig mean something to me. Make']]
#
# [3.59, 4.06, ['number meaningful, one of the most', 'effective element of a Steve Jobs', 'presentation. is that, they are easy on']]
#
# [4.08, 4.1, ['the eye. His presentation are visual']]
#
# [4.1, 4.22, ['and simple,', 'while most speaker fill their slide', 'with mind, data and text and', 'shard', 'chomp doe, just the opposite. He us']]
#
# [4.22, 4.28, ['very little text and usually one maybe', 'two image per slide. You see you want']]
#
# [4.28, 4.33, ['to paint a picture for your audience', 'without overwhelming them. Inspiring']]
#
# [4.33, 4.38, ['presentation are short on bullet point', 'and big on visuals. If you really want']]
#
# [4.38, 4.42, ['your presentation. to pop treat it like a']]
#
# [4.42, 4.55, ['show when ad and flow theme and', 'transition Jobs includes video clip', 'demonstration and guest, he also ha a', 'knack for dramatic flair and it very', 'effective for example. when introducing']]
#
# [4.55, 5.15, ['the MacBook Air, Jobs drew cheer by', 'opening a manila interoffice envelope', 'and holding the laptop out for everyone', 'to see This is the new MacBook Air, and', 'you can get a feel for how thin it is:', 'What is the one memorable moment of your', 'presentation. identified ahead of time,']]
#
# [5.18, 5.23, ['then build up to it it will help from', 'our friend. Everything will work today']]
#
# [5.23, 5.28, ['and finally, rehearse rehearse and', 'rehearse some more. Let me show You how']]
#
# [5.28, 5.35, ['easy that, is now, Steve Jobs make it', 'look easy because he spends hour', 'rehearsing. He can not pull off an']]
#
# [5.38, 5.45, ['intricate presentation with video clip', 'and demonstration and outside speaker', 'without practice. The result, a']]
#
# [5.45, 5.45, ['presentation. that is perfectly']]
#
# [5.48, 5.49, ['synchronized and look yes. Effortless']]
#
# [5.49, 6.0, ['now The average businessperson doe not', 'have the resource to create a Steve', 'Jobs extravaganza, but you do have time', 'to rehearse The greatest presenter. Do']]
#
# [6.0, 6.04, ['it, and so, should you', 'oh and one more. thing at the end of most']]
#
# [6.04, 6.04, ['presentation. Jobs add to the drama by']]
#
# [6.09, 6.11, ['saying and one more. thing one last thing:']]
#
# [6.11, 6.18, ['If it add a new product or a feature,', 'sometimes just introduces a band. This']]
#
# [6.18, 6.25, ['not only heightens the excitement, it', 'also leaf your audience feeling', 'been given an added bonus. The']]
#
# [6.25, 6.37, ['point is: Steve Jobs approach, each', 'present,', 'a an event: a production with a strong', 'opening product demonstration in the', 'middle and a strong conclusion, and yes,', 'even an encore that one more thing. I']]
#
# [6.37, 6.46, ['wish you, a dazzling presentation for', 'more information, go to be Netcom.']]
#
# ********* END of Video ***************
#
# [0.03, 0.09, ['Presentation or talking to your bos in', 'the elevator, there are five secret to', 'being a confident speaker. First,']]
#
# [0.09, 0.13, ['your stance. Second, your sound third']]
#
# [0.13, 0.17, ['smile, fourth silence and fit your site.']]
#
# [0.25, 0.25, ['First, your stance. when you']]
#
# [0.25, 0.28, ['you need to have a nice firm stance. your']]
#
# [0.28, 0.35, ['foot should be about hip apart, not', 'too wide and not too close. We want to']]
#
# [0.35, 1.32, ['have our foot firmly planted on the', 'ground, no crossing of the leg,', 'no swaying back and forth no dancing', 'backwards and forward no pacing', 'side', 'and by all mean no popping of the hip', 'Once we have that firm, stable stance, we', 'need to then stand up nice and tall to', 'have a length in our torso, but our', 'shoulder relaxed to increase the', 'distance between our shoulder and our', 'ear and to imagine the top of our head', 'ha a string going Right to the ceiling', 'making? U stand taller than usual? What', 'do we do with our arm? The question', 'every new speaker ha keep them in a', 'neutral position at your side do', 'clasp in front or behind do do this', 'defensive move and when at your', 'side then you can use them freely to', 'gesture and add impact to your speech. If']]
#
# [1.32, 1.52, ['standing behind a lectern be', 'careful not to grasp onto the lectern', 'for dear life,', 'this can cause you to bend over,', 'impacting your posture negatively', 'prevent you from doing any gesture and', 'you might tap on it or make other', 'distracting noise. So if you do need to']]
#
# [1.52, 1.58, ['use the lectern for your note, make sure', 'that you are not touching it and that', 'you are gesturing. talked about']]
#
# [1.58, 2.0, ['your stance. now, talk about your']]
#
# [2.0, 2.02, ['sound when you are giving a speech. that']]
#
# [2.02, 2.46, ['great stance is the basis for phenomenal', 'projection,', 'it will allow you to speak from your', 'diaphragm and fill the room with sound', 'make sure that you really lower those', 'shoulder, because when We get nervous', 'which most of U are when We speak we', 'tend to make those shoulder, go higher', 'and higher and higher towards our ear', 'our voice get higher and higher and', 'faster and faster and it help', 'our presentation relax those shoulder,', 'lower that voice and make sure that you', 'speak in a slow, understandable case when', 'We working with sound also think', 'about having variation. Add interest to']]
#
# [2.46, 2.49, ['your speech. with sound use up high tone']]
#
# [2.49, 2.55, ['in a low tone, speak slow, and really', 'really fast yeah. These will Add a']]
#
# [2.55, 3.01, ['dynamic nature to your speech. making you']]
#
# [3.01, 3.04, ['look very confident. We talked about']]
#
# [3.04, 3.25, ['stance, and your sound now, we have to', 'talk about your smile, this is an', 'extension of your sound because people', 'who are smiling sound, more pleasant,', 'great to listen to you might', 'think that you look cheesy and silly', 'smiling through a speech. but you will']]
#
# [3.25, 3.25, ['not. You will look friendly.']]
#
# [3.28, 3.28, []]
#
# [3.3, 3.3, ['You will look confident. and you will']]
#
# [3.3, 3.33, ['look at ease a a speaker. even if you']]
#
# [3.33, 3.37, ['really nervous on the inside, no one ha', 'to know put on a big smile. When you give']]
#
# [3.37, 3.4, ['a speech. So long a it is appropriate to']]
#
# [3.4, 3.43, ['your topic now into the fourth s,', 'silence. How is silence. something that a']]
#
# [3.47, 3.47, []]
#
# [3.47, 3.52, ['confident speaker. doe in our culture we']]
#
# [3.52, 3.58, ['like to fill every single moment with', 'sound We do like to pause between', 'sentence. We add word like, and So the']]
#
# [4.03, 4.06, ['entire speech is one long run. We']]
# [4.06, 4.14, ['should prevent that and when We lose our', 'train of thought or need to think of', 'What we want to say next,', 'we often fill that time with um. Ah, like']]
#
# [4.14, 4.25, ['you know other mouth sound, This doe', 'make a slip, professional prepared or', 'polished use silence. It is your best']]
#
# [4.25, 4.25, ['friend. Lastly, your sight, what I mean by']]
#
# [4.29, 4.41, ['sight, is what about when you looking', 'out at the audience, making eye contact', 'is an important part of being a great', 'confident. speaker you need to hold that']]
#
# [4.45, 4.55, ['eye contact Just like you would, in a', 'one conversation to establish', 'rapport with your audience, You might', 'feel that it s, too long five to seven.']]
#
# [4.57, 4.57, ['Second in a speech. but that s, exactly']]
#
# [4.57, 5.02, ['what you should do it will decrease the', 'distance If you will between the speaker.']]
#
# [5.05, 5.16, ['and audience, make sure that you do', 'scan back and forth without making any', 'lasting contact on member of your', 'audience, also make sure you do do The', 'hunt and peck. what I call it']]
#
# [5.16, 5.22, ['where you look at two people over and', 'over, and ignore the rest of the crowd.']]
#
# [5.24, 5.43, ['Maybe those people are smiling and', 'nodding, but you need to make an effort', 'to establish eye contact with all part', 'of the room by all mean ignore the', 'advice you might have received at some', 'point where someone said if you', 'nervous all you need to do is Just stare', 'at the back wall of the room and it', 'be the easiest speech you ever gave well.']]
#
# [5.46, 5.51, ['also be the worst speech, because', 'no one in your audience, will be involved', 'and engaged because you be making?', 'I contact with him. We have talked about']]
#
# [5.51, 6.03, ['today, the 5 is they are stance, sound,', 'smile, silence and sight. if you apply']]
#
# [6.03, 6.09, ['these principle, you will be a confident', 'speaker. The next time you are giving a']]
#
# [6.13, 6.15, ['formal speech or your elevator speech.']]
#
# [6.15, 6.19, ['formal speech or your elevator speech.', 'Mr. Toastmaster.']]
#
# ********* END of Video ***************

# %%
worksheet = workbook.add_worksheet('sheet2')
worksheet.write('A1', 'SegmentId')
worksheet.write('B1', 'StartTime')
worksheet.write('C1', 'EndTime')
worksheet.write('D1', 'Transcript')
row=1
col=0

for i in allVideosSeg:
    col=0
    count=1
    
    
    # start,end and transcript are saved as second element in i=1
    for j in i[1]:
        worksheet.write(row,col,str(i[0])+str(count))
        
        worksheet.write(row,col+1,j[0]) # write the start time
        worksheet.write(row,col+2,j[1]) # write the end time
        tempCol=col+3
        
        if j[2]:
            for k in j[2]:
                
                worksheet.write(row,tempCol,k)
               
                row+=1
        else:
            worksheet.write(row,tempCol,'')
            row+=1
        count+=1
    
      
workbook.close()
