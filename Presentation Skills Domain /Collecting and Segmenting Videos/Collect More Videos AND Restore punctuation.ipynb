# %%
! pip install youtube-search-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: youtube-search-python in c:\users\main\appdata\roaming\python\python39\site-packages (1.6.6)
# Requirement already satisfied: httpx>=0.14.2 in c:\users\main\appdata\roaming\python\python39\site-packages (from youtube-search-python) (0.23.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\main\appdata\roaming\python\python39\site-packages (from httpx>=0.14.2->youtube-search-python) (1.5.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\main\appdata\roaming\python\python39\site-packages (from httpx>=0.14.2->youtube-search-python) (0.16.3)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (1.2.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.14.2->youtube-search-python) (2022.9.14)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\main\appdata\roaming\python\python39\site-packages (from httpcore<0.17.0,>=0.15.0->httpx>=0.14.2->youtube-search-python) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\programdata\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx>=0.14.2->youtube-search-python) (3.5.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from rfc3986[idna2008]<2,>=1.3->httpx>=0.14.2->youtube-search-python) (3.3)

# %%
from youtubesearchpython import VideosSearch

videosSearch = VideosSearch('Presentation skill', limit = 20)

print(videosSearch.result()['result'])
# Out:
# [{'type': 'video', 'id': 'MnIPpUiTcRc', 'title': 'HOW TO Give a Great Presentation - 7 Presentation Skills and Tips to Leave an Impression', 'publishedTime': '6 years ago', 'duration': '7:04', 'viewCount': {'text': '2,223,382 views', 'short': '2.2M views'}, 'thumbnails': [{'url': 'https://i.ytimg.com/vi/MnIPpUiTcRc/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDAbWr4ObXJaPlKdwNUWIn0XOBT0w', 'width': 360, 'height': 202}, {'url': 'https://i.ytimg.com/vi/MnIPpUiTcRc/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCasP68RyGYn5L3oZCapL97ayjXTA', 'width': 720, 'height': 404}], 'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/MnIPpUiTcRc/mqdefault_6s.webp?du=3000&sqp=CKLHlJ8G&rs=AOn4CLCzlas7FeKgB3gKhEyQ5lJEiOnfAA', 'width': 320, 'height': 180}, 'descriptionSnippet': [{'text': 'Learn the best tips and tricks to give a great '}, {'text': 'presentation', 'bold': True}, {'text': ". If you've ever given a "}, {'text': 'presentation', 'bold': True}, {'text': ' before, you might know where you\xa0...'}], 'channel': {'name': 'Practical Psychology', 'id': 'UCir93b_ftqInEaDpsWYbo_g', 'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AL5GRJUyNes6gWjmEReE4RmAi93hGqx7vqX2o0miLYft_g=s68-c-k-c0x00ffffff-no-rj', 'width': 68, 'height': 68}], 'link': 'https://www.youtube.com/channel/UCir93b_ftqInEaDpsWYbo_g'}, 'accessibility': {'title': 'HOW TO Give a Great Presentation - 7 Presentation Skills and Tips to Leave an Impression by Practical Psychology 6 years ago 7 minutes, 4 seconds 2,223,382 views', 'duration': '7 minutes, 4 seconds'}, 'link': 'https://www.youtube.com/watch?v=MnIPpUiTcRc', 'shelfTitle': None}, {'type': 'video', 'id': 'dEDcc0aCjaA', 'title': 'How to Do a Presentation - 5 Steps to a Killer Opener', 'publishedTime': '9 years ago', 'duration': '7:34', 'viewCount': {'text': '7,737,825 views', 'short': '7.7M views'}, 'thumbnails': [{'url': 'https://i.ytimg.com/vi/dEDcc0aCjaA/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA2Qu6CYTyQ8rvB6ULYjsMKsHy_Ng', 'width': 360, 'height': 202}, {'url': 'https://i.ytimg.com/vi/dEDcc0aCjaA/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAo1lFmbmVvYAI-LdsBGz-0vxkP0w', 'width': 720, 'height': 404}], 'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/dEDcc0aCjaA/mqdefault_6s.webp?du=3000&sqp=CMC7lJ8G&rs=AOn4CLCZvnSw52CtV5kTL30zOWSS6ItYXg', 'width': 320, 'height': 180}, 'descriptionSnippet': [{'text': 'Watch public speaking and '}, {'text': 'presentation skills', 'bold': True}, {'text': ' expert Jason Teteak give a presentation modeling exact techniques for how to do\xa0...'}], 'channel': {'name': 'Rule The Room', 'id': 'UCSkn1qgZCvy8GA165KwanrQ', 'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AL5GRJWt3jnwocjSXaUwcJYHczyaKaiKalqym0OcuZFl5g=s68-c-k-c0x00ffffff-no-rj', 'width': 68, 'height': 68}], 'link': 'https://www.youtube.com/channel/UCSkn1qgZCvy8GA165KwanrQ'}, 'accessibility': {'title': 'How to Do a Presentation - 5 Steps to a Killer Opener by Rule The Room 9 years ago 7 minutes, 34 seconds 7,737,825 views', 'duration': '7 minutes, 34 seconds'}, 'link': 'https://www.youtube.com/watch?v=dEDcc0aCjaA', 'shelfTitle': None}, {'type': 'video', 'id': 'yoD8RMq2OkU', 'title': 'The 3 Magic Ingredients of Amazing Presentations | Phil WAKNELL | TEDxSaclay', 'publishedTime': '3 years ago', 'duration': '14:35', 'viewCount': {'text': '608,046 views', 'short': '608K views'}, 'thumbnails': [{'url': 'https://i.ytimg.com/vi/yoD8RMq2OkU/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC0_yEfhoKPZ8xvHpHHJt46ym-o6A', 'width': 360, 'height': 202}, {'url': 'https://i.ytimg.com/vi/yoD8RMq2OkU/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBU4x7gkkLWBFp2p9ijEH9jAm2mmw', 'width': 720, 'height': 404}], 'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/yoD8RMq2OkU/mqdefault_6s.webp?du=3000&sqp=CI_AlJ8G&rs=AOn4CLC4aobPGegleoVo1i2zzs84Eo9p1Q', 'width': 320, 'height': 180}, 'descr ...

# %%
! pip install punctuator
# Out:
# Requirement already satisfied: punctuator in c:\users\main\anaconda3\lib\site-packages (0.9.6)
# Requirement already satisfied: theano>=1.0.4 in c:\users\main\anaconda3\lib\site-packages (from punctuator) (1.0.5)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\main\anaconda3\lib\site-packages (from punctuator) (1.19.5)
# Requirement already satisfied: nltk>=3.4.5 in c:\users\main\appdata\roaming\python\python37\site-packages (from punctuator) (3.5)
# Requirement already satisfied: gdown>=3.8.3 in c:\users\main\anaconda3\lib\site-packages (from punctuator) (4.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\main\anaconda3\lib\site-packages (from gdown>=3.8.3->punctuator) (4.8.2)
# Requirement already satisfied: tqdm in c:\users\main\anaconda3\lib\site-packages (from gdown>=3.8.3->punctuator) (4.42.1)
# Requirement already satisfied: filelock in c:\users\main\anaconda3\lib\site-packages (from gdown>=3.8.3->punctuator) (3.0.12)
# Requirement already satisfied: six in c:\users\main\anaconda3\lib\site-packages (from gdown>=3.8.3->punctuator) (1.15.0)
# Requirement already satisfied: requests[socks] in c:\users\main\anaconda3\lib\site-packages (from gdown>=3.8.3->punctuator) (2.25.1)
# Requirement already satisfied: regex in c:\users\main\appdata\roaming\python\python37\site-packages (from nltk>=3.4.5->punctuator) (2020.6.8)
# Requirement already satisfied: joblib in c:\users\main\anaconda3\lib\site-packages (from nltk>=3.4.5->punctuator) (0.14.1)
# Requirement already satisfied: click in c:\users\main\anaconda3\lib\site-packages (from nltk>=3.4.5->punctuator) (7.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\main\anaconda3\lib\site-packages (from theano>=1.0.4->punctuator) (1.4.1)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\main\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.8.3->punctuator) (1.9.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\main\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.8.3->punctuator) (2019.11.28)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\main\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.8.3->punctuator) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\main\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.8.3->punctuator) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\main\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.8.3->punctuator) (1.25.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\main\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.8.3->punctuator) (1.7.1)
# WARNING: Ignoring invalid distribution -umpy (c:\users\main\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\main\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\main\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\main\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\main\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\main\anaconda3\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the 'c:\users\main\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np # linear algebra
import pandas as pd 
import re
import sys
punctuatedLine=[]
textfileList=[]
df = pd.read_csv("textfileInExcel.csv")# save the transcript of the video in excel file to process it easily
#df2=pd.read_csv("videoText.csv")

# %%
for i in df['Transcript Text']:
    print(i.split())
# Out:
# ['presentation', 'or', 'talking', 'to', 'your', 'bos', 'in']
# ['the', 'elevator', 'there', 'are', 'five', 'secret', 'to']
# ['being', 'a', 'confident', 'speaker', 'first', 'there', "'s"]
# ['your', 'stance', 'second', 'your', 'sound', 'third']
# ['smile', 'fourth', 'silence', 'and', 'fit', 'your', 'site']
# ['first', 'your', 'stance', 'when', 'you', "'re", 'speaking']
# ['you', 'need', 'to', 'have', 'a', 'nice', 'firm', 'stance', 'your']
# ['foot', 'should', 'be', 'about', 'hip', 'apart', 'not']
# ['too', 'wide', 'and', 'not', 'too', 'close', 'we', 'want', 'to']
# ['have', 'our', 'foot', 'firmly', 'planted', 'on', 'the']
# ['ground', 'no', 'crossing', 'of', 'the', 'leg']
# ['no', 'swaying', 'back', 'and', 'forth', 'no', 'dancing']
# ['backwards', 'and', 'forward', 'no', 'pacing']
# ['side']
# ['and', 'by', 'all', 'mean', 'no', 'popping', 'of', 'the', 'hip']
# ['once', 'we', 'have', 'that', 'firm', 'stable', 'stance', 'we']
# ['need', 'to', 'then', 'stand', 'up', 'nice', 'and', 'tall', 'to']
# ['have', 'a', 'length', 'in', 'our', 'torso', 'but', 'our']
# ['shoulder', 'relaxed', 'to', 'increase', 'the']
# ['distance', 'between', 'our', 'shoulder', 'and', 'our']
# ['ear', 'and', 'to', 'imagine', 'the', 'top', 'of', 'our', 'head']
# ['ha', 'a', 'string', 'going', 'right', 'to', 'the', 'ceiling']
# ['making', 'u', 'stand', 'taller', 'than', 'usual', 'what']
# ['do', 'we', 'do', 'with', 'our', 'arm', 'the', 'question']
# ['every', 'new', 'speaker', 'ha', 'keep', 'them', 'in', 'a']
# ['neutral', 'position', 'at', 'your', 'side', 'do', "n't"]
# ['clasp', 'in', 'front', 'or', 'behind', 'do', "n't", 'do', 'this']
# ['defensive', 'move', 'and', 'when', 'they', "'re", 'at', 'your']
# ['side', 'then', 'you', 'can', 'use', 'them', 'freely', 'to']
# ['gesture', 'and', 'add', 'impact', 'to', 'your', 'speech', 'if']
# ['you', "'re", 'standing', 'behind', 'a', 'lectern', 'be']
# ['careful', 'not', 'to', 'grasp', 'onto', 'the', 'lectern']
# ['for', 'dear', 'life']
# ['this', 'can', 'cause', 'you', 'to', 'bend', 'over']
# ['impacting', 'your', 'posture', 'negatively', 'it', "'ll"]
# ['prevent', 'you', 'from', 'doing', 'any', 'gesture', 'and']
# ['you', 'might', 'tap', 'on', 'it', 'or', 'make', 'other']
# ['distracting', 'noise', 'so', 'if', 'you', 'do', 'need', 'to']
# ['use', 'the', 'lectern', 'for', 'your', 'note', 'make', 'sure']
# ['that', 'you', 'are', 'not', 'touching', 'it', 'and', 'that']
# ['you', 'are', 'gesturing', 'we', "'ve", 'talked', 'about']
# ['your', 'stance', 'now', 'let', "'s", 'talk', 'about', 'your']
# ['sound', 'when', 'you', 'are', 'giving', 'a', 'speech', 'that']
# ['great', 'stance', 'is', 'the', 'basis', 'for', 'phenomenal']
# ['projection']
# ['it', 'will', 'allow', 'you', 'to', 'speak', 'from', 'your']
# ['diaphragm', 'and', 'fill', 'the', 'room', 'with', 'sound']
# ['make', 'sure', 'that', 'you', 'really', 'lower', 'those']
# ['shoulder', 'because', 'when', 'we', 'get', 'nervous']
# ['which', 'most', 'of', 'u', 'are', 'when', 'we', 'speak', 'we']
# ['tend', 'to', 'make', 'those', 'shoulder', 'go', 'higher']
# ['and', 'higher', 'and', 'higher', 'towards', 'our', 'ear']
# ['our', 'voice', 'get', 'higher', 'and', 'higher', 'and']
# ['faster', 'and', 'faster', 'and', 'it', 'doe', "n't", 'help']
# ['our', 'presentation', 'relax', 'those', 'shoulder']
# ['lower', 'that', 'voice', 'and', 'make', 'sure', 'that', 'you']
# ['speak', 'in', 'a', 'slow', 'understandable', 'case', 'when']
# ['we', "'re", 'working', 'with', 'sound', 'also', 'think']
# ['about', 'having', 'variation', 'add', 'interest', 'to']
# ['your', 'speech', 'with', 'sound', 'use', 'up', 'high', 'tone']
# ['in', 'a', 'low', 'tone', 'speak', 'slow', 'and', 'really']
# ['really', 'fast', 'yeah', 'these', 'will', 'add', 'a']
# ['dynamic', 'nature', 'to', 'your', 'speech', 'making', 'you']
# ['look', 'very', 'confident', 'we', 'talked', 'about']
# ['stance', 'and', 'your', 'sound', 'now', 'we', 'have', 'to']
# ['talk', 'about', 'your', 'smile', 'this', 'is', 'an']
# ['extension', 'of', 'your', 'sound', 'because', 'people']
# ['who', 'are', 'smiling', 'sound', 'more', 'pleasant']
# ['they', "'re", 'great', 'to', 'listen', 'to', 'you', 'might']
# ['think', 'that', 'you', 'look', 'cheesy', 'and', 'silly']
# ['smiling', 'through', 'a', 'speech', 'but', 'you', 'will']
# ['not', 'you', 'will', 'look', 'friendly']
# ['you', 'will', 'look', 'confident', 'and', 'you', 'will']
# ['look', 'at', 'ease', 'a', 'a', 'speaker', 'even', 'if', 'you', "'re"]
# ['really', 'nervous', 'on', 'the', 'inside', 'no', 'one', 'ha']
# ['to', 'know', 'put', 'on', 'a', 'big', 'smile', 'when', 'you', 'give']
# ['a', 'speech', 'so', 'long', 'a', 'it', 'is', 'appropriate', 'to']
# ['your', 'topic', 'now', 'into', 'the', 'fourth', 's']
# ['silence', 'how', 'is', 'silence', 'something', 'that', 'a']
# ['confident', 'speaker', 'doe', 'in', 'our', 'culture', 'we']
# ['like', 'to', 'fill', 'every', 'single', 'moment', 'with']
# ['sound', 'we', 'do', "n't", 'like', 'to', 'pause', 'between']
# ['sentence', 'we', 'add', 'word', 'like', 'and', 'so', 'the']
# ['entire', 'speech', 'is', 'one', 'long', 'run', 'we']
# ['should', 'prevent', 'that', 'and', 'when', 'we', 'lose', 'our']
# ['train', 'of', 'thought', 'or', 'need', 'to', 'think', 'of']
# ['what', 'we', 'want', 'to', 'say', 'next']
# ['we', 'often', 'fill', 'that', 'time', 'with', 'um', 'ah', 'like']
# ['you', 'know', 'other', 'mouth', 'sound', 'this', 'doe', "n't"]
# ['make', 'a', 'slip', 'professional', 'prepared', 'or']
# ['polished', 'use', 'silence', 'it', 'is', 'your', 'best']
# ['friend', 'lastly', 'your', 'sight', 'what', 'I', 'mean', 'by']
# ['sight', 'is', 'what', 'about', 'when', 'you', "'re", 'looking']
# ['out', 'at', 'the', 'audience', 'making', 'eye', 'contact']
# ['is', 'an', 'important', 'part', 'of', 'being', 'a', 'great']
# ['confident', 'speaker', 'you', 'need', 'to', 'hold', 'that']
# ['eye', 'contact', 'just', 'like', 'you', 'would', 'in', 'a']
# ['one', 'conversation', 'to', 'establish']
# ['rapport', 'with', 'your', 'audience', 'you', 'might']
# ['feel', 'that', 'it', "'s", 'too', 'long', 'five', 'to', 'seven']
# ['second', 'in', 'a', 'speech', 'but', 'that', "'s", 'exactly']
# ['what', 'you', 'should', 'do', 'it', 'will', 'decrease', 'the']
# ['distance', 'if', 'you', 'will', 'between', 'the', 'speaker']
# ['and', 'audience', 'make', 'sure', 'that', 'you', 'do', "n't"]
# ['scan', 'back', 'and', 'forth', 'without', 'making', 'any']
# ['lasting', 'contact', 'on', 'member', 'of', 'your']
# ['audience', 'also', 'make', 'sure', 'you', 'do', "n't", 'do', 'the']
# ['hunt', 'and', 'peck', 'that', "'s", 'what', 'I', 'call', 'it']
# ['where', 'you', 'look', 'at', 'two', 'people', 'over', 'and']
# ['over', 'and', 'ignore', 'the', 'rest', 'of', 'the', 'crowd']
# ['maybe', 'those', 'people', 'are', 'smiling', 'and']
# ['nodding', 'but', 'you', 'need', 'to', 'make', 'an', 'effort']
# ['to', 'establish', 'eye', 'contact', 'with', 'all', 'part']
# ['of', 'the', 'room', 'by', 'all', 'mean', 'ignore', 'the']
# ['advice', 'you', 'might', 'have', 'received', 'at', 'some']
# ['point', 'where', 'someone', 'said', 'if', 'you', "'re"]
# ['nervous', 'all', 'you', 'need', 'to', 'do', 'is', 'just', 'stare']
# ['at', 'the', 'back', 'wall', 'of', 'the', 'room', 'and', 'it', "'ll"]
# ['be', 'the', 'easiest', 'speech', 'you', 'ever', 'gave', 'well']
# ['it', "'ll", 'also', 'be', 'the', 'worst', 'speech', 'because']
# ['no', 'one', 'in', 'your', 'audience', 'will', 'be', 'involved']
# ['and', 'engaged', 'because', 'you', 'wo', "n't", 'be', 'making']
# ['I', 'contact', 'with', 'him', 'we', 'have', 'talked', 'about']
# ['today', 'the', '5', 'is', 'they', 'are', 'stance', 'sound']
# ['smile', 'silence', 'and', 'sight', 'if', 'you', 'apply']
# ['these', 'principle', 'you', 'will', 'be', 'a', 'confident']
# ['speaker', 'the', 'next', 'time', 'you', 'are', 'giving', 'a']
# ['formal', 'speech', 'or', 'your', 'elevator', 'speech']
# ['mr.', 'Toastmaster']

# %%
import string

# %%
fp=open('textfile.txt',"r")# file contains the punctuated transcript generated from the punctuation tool
textWithPunc=[]

textWithPunc=[x.split() for x in fp][0]
print(textWithPunc)
print()
print(len(textWithPunc))
fp.close()
# Out:
# ['Presentation', 'or', 'talking', 'to', 'your', 'bos', 'in', 'the', 'elevator,', 'there', 'are', 'five', 'secret', 'to', 'being', 'a', 'confident', 'speaker.', 'First,', "there's", 'your', 'stance.', 'Second,', 'your', 'sound', 'third', 'smile,', 'fourth', 'silence', 'and', 'fit', 'your', 'site.', 'First,', 'your', 'stance', 'when', "you're", 'speaking,', 'you', 'need', 'to', 'have', 'a', 'nice', 'firm', 'stance.', 'Your', 'foot', 'should', 'be', 'about', 'hip', 'apart,', 'not', 'too', 'wide', 'and', 'not', 'too', 'close.', 'We', 'want', 'to', 'have', 'our', 'foot', 'firmly', 'planted', 'on', 'the', 'ground,', 'no', 'crossing', 'of', 'the', 'leg,', 'no', 'swaying', 'back', 'and', 'forth', 'no', 'dancing', 'backwards', 'and', 'forward', 'no', 'pacing', 'side', 'and', 'by', 'all', 'mean', 'no', 'popping', 'of', 'the', 'hip.', 'Once', 'we', 'have', 'that', 'firm,', 'stable', 'stance,', 'we', 'need', 'to', 'then', 'stand', 'up', 'nice', 'and', 'tall', 'to', 'have', 'a', 'length', 'in', 'our', 'torso,', 'but', 'our', 'shoulder', 'relaxed', 'to', 'increase', 'the', 'distance', 'between', 'our', 'shoulder', 'and', 'our', 'ear', 'and', 'to', 'imagine', 'the', 'top', 'of', 'our', 'head', 'ha', 'a', 'string', 'going', 'Right', 'to', 'the', 'ceiling', 'making?', 'U', 'stand', 'taller', 'than', 'usual?', 'What', 'do', 'we', 'do', 'with', 'our', 'arm?', 'The', 'question', 'every', 'new', 'speaker', 'ha', 'keep', 'them', 'in', 'a', 'neutral', 'position', 'at', 'your', 'side,', "don't", 'clasp', 'in', 'front', 'or', 'behind', "don't", 'do', 'this', 'defensive', 'move', 'and', 'when', "they're", 'at', 'your', 'side,', 'then', 'you', 'can', 'use', 'them', 'freely', 'to', 'gesture', 'and', 'add', 'impact', 'to', 'your', 'speech.', 'If', "you're", 'standing', 'behind', 'a', 'lectern', 'be', 'careful', 'not', 'to', 'grasp', 'onto', 'the', 'lectern', 'for', 'dear', 'life,', 'this', 'can', 'cause', 'you', 'to', 'bend', 'over,', 'impacting', 'your', 'posture', 'negatively', "it'll,", 'prevent', 'you', 'from', 'doing', 'any', 'gesture', 'and', 'you', 'might', 'tap', 'on', 'it', 'or', 'make', 'other', 'distracting', 'noise.', 'So', 'if', 'you', 'do', 'need', 'to', 'use', 'the', 'lectern', 'for', 'your', 'note,', 'make', 'sure', 'that', 'you', 'are', 'not', 'touching', 'it', 'and', 'that', 'you', 'are', 'gesturing.', "We'Ve", 'talked', 'about', 'your', 'stance', 'now,', "let's", 'talk', 'about', 'your', 'sound', 'when', 'you', 'are', 'giving', 'a', 'speech', 'that', 'great', 'stance', 'is', 'the', 'basis', 'for', 'phenomenal', 'projection,', 'it', 'will', 'allow', 'you', 'to', 'speak', 'from', 'your', 'diaphragm', 'and', 'fill', 'the', 'room', 'with', 'sound.', 'Make', 'sure', 'that', 'you', 'really', 'lower', 'those', 'shoulder,', 'because', 'when', 'we', 'get', 'nervous', 'which', 'most', 'of', 'u', 'are', 'when', 'we', 'speak,', 'we', 'tend', 'to', 'make', 'those', 'shoulder:', 'go', 'higher', 'and', 'higher', 'and', 'higher', 'towards', 'our', 'ear.', 'Our', 'voice', 'get', 'higher', 'and', 'higher', 'and', 'faster', 'and', 'faster,', 'and', 'it', "doen't", 'help', 'our', 'presentation', 'relax', 'those', 'shoulder', 'lower', 'that', 'voice', 'and', 'make', 'sure', 'that', 'you', 'speak', 'in', 'a', 'slow,', 'understandable', 'case', 'when', "we're", 'working', 'with', 'sound,', 'also', 'think', 'about', 'having', 'variation.', 'Add', 'interest', 'to', 'your', 'speech', 'with', 'sound', 'use', 'up', 'high', 'tone', 'in', 'a', 'low', 'tone,', 'speak', 'slow', 'and', 'really', 'really', 'fast', 'yeah.', 'These', 'will', 'add', 'a', 'dynamic', 'nature', 'to', 'your', 'speech,', 'making', 'you', 'look', 'very', 'confident.', 'We', 'talked', 'about', 'stance', 'and', 'your', 'sound.', 'Now', 'we', 'have', 'to', 'talk', 'about', 'your', 'smile.', 'This', 'is', 'an', 'extension', 'of', 'your', 'sound', 'because', 'people', 'who', 'are', 'smiling', 'sound,', 'more', 'pleasant,', "they're", 'great', 'to', 'listen', 'to', 'you', 'might', 'think', 'that', 'yo ...
#
# 911

# %%
newTextWithPunc=[]
textWithPunc1=[]
tempWordCollection=[]
start=0

index=0

#compare word by word between the transcript and the punctuated text

for i in df['Transcript Text']:
    newLine=i.split()# for each text line in the transcript, split it into list of words
    
    numberOfword=len(newLine)# count ho mqany word per line
    print('newline= ',newLine,'  ','# of words= ',numberOfword,' Start=',start,' END= ',(start+numberOfword)-1,'  ','index= ')
    print()
    for k in newLine:# loop through the line in transcript based on the number of its words
        
        #One of the easiest ways to remove punctuation from a string in Python is to use the str.translate() method. 
        #The translate method typically takes a translation table, which we’ll do using the .maketrans() method.
        #The .maketrans() method here takes three arguments, the first two of which are empty strings, 
        #and the third is the list of punctuation we want to remove. This tells the function to replace all punctuation 
        #with None.
        
        k1=k.translate(str.maketrans('', '', string.punctuation))# the word from transcript is with no punctuation
        #print('range= ',(start+numberOfword))
        
        if (start+numberOfword)<=len(textWithPunc):# it keep comparing words as long as the punctuated text did not ends.
            for w in range(index,(start+numberOfword)): # loop through th punctuated text, strating from the position of 
                #the last word checked previously and end with the last word in the text line we are processing
                
                w1=textWithPunc[w].translate(str.maketrans('', '', string.punctuation))# Remove the punctuation from the puntucated 
                #text as well
                
                if str(w1).lower()==str(k1).lower():# comaprison is case sensetive, so both words should be in lower case
                    
                    tempWordCollection.append(str(w1).lower())# keep track of the words we have selected for the transcript
                    
                    newTextWithPunc.append(textWithPunc[w]) # save the same text from transcript but with punctuation
                    index=textWithPunc.index(textWithPunc[w]) # save the index of the punctuated word in the punctuated text
                    break
        elif (start+numberOfword)>len(textWithPunc):
            print('#of words exceeds*************')
            print('index= ',index)
            temporaryIndex=index
            for w in range(index,len(textWithPunc)):
                print('w= ',textWithPunc[w])
                w1=textWithPunc[w].translate(str.maketrans('', '', string.punctuation))
                print('w1= ',str(w1).lower(),'   ','k1= ',str(k1).lower())
                #print()
                if str(w1).lower()==str(k1).lower():
                    #print('w= ',textWithPunc[w])
                    #if str(w1).lower() not in tempWordCollection:
                    tempWordCollection.append(str(w1).lower())
                    #if textWithPunc[index] not in newTextWithPunc:
                    newTextWithPunc.append(textWithPunc[index])
                    index=(textWithPunc.index(textWithPunc[index]))
                    break
            #index=temporaryIndex

            
    textWithPunc1.append(newTextWithPunc)
    print(newTextWithPunc)
    print()
    print('***********')
    newTextWithPunc=[]
    tempWordCollection=[]
    start+=numberOfword
# Out:
# newline=  ['presentation', 'or', 'talking', 'to', 'your', 'bos', 'in']    # of words=  7  Start= 0  END=  6    index=
#
# ['Presentation', 'or', 'talking', 'to', 'your', 'bos', 'in']
#
# ***********
# newline=  ['the', 'elevator', 'there', 'are', 'five', 'secret', 'to']    # of words=  7  Start= 7  END=  13    index=
#
# ['the', 'elevator,', 'there', 'are', 'five', 'secret', 'to']
#
# ***********
# newline=  ['being', 'a', 'confident', 'speaker', 'first', 'there', "'s"]    # of words=  7  Start= 14  END=  20    index=
#
# ['being', 'a', 'confident', 'speaker.', 'First,']
#
# ***********
# newline=  ['your', 'stance', 'second', 'your', 'sound', 'third']    # of words=  6  Start= 21  END=  26    index=
#
# ['your', 'stance.', 'Second,', 'your', 'sound', 'third']
#
# ***********
# newline=  ['smile', 'fourth', 'silence', 'and', 'fit', 'your', 'site']    # of words=  7  Start= 27  END=  33    index=
#
# ['smile,', 'fourth', 'silence', 'and', 'fit', 'your', 'site.']
#
# ***********
# newline=  ['first', 'your', 'stance', 'when', 'you', "'re", 'speaking']    # of words=  7  Start= 34  END=  40    index=
#
# ['First,', 'your', 'stance.', 'when', 'you']
#
# ***********
# newline=  ['you', 'need', 'to', 'have', 'a', 'nice', 'firm', 'stance', 'your']    # of words=  9  Start= 41  END=  49    index=
#
# ['you', 'need', 'to', 'have', 'a', 'nice', 'firm', 'stance.', 'your']
#
# ***********
# newline=  ['foot', 'should', 'be', 'about', 'hip', 'apart', 'not']    # of words=  7  Start= 50  END=  56    index=
#
# ['foot', 'should', 'be', 'about', 'hip', 'apart,', 'not']
#
# ***********
# newline=  ['too', 'wide', 'and', 'not', 'too', 'close', 'we', 'want', 'to']    # of words=  9  Start= 57  END=  65    index=
#
# ['too', 'wide', 'and', 'not', 'too', 'close.', 'We', 'want', 'to']
#
# ***********
# newline=  ['have', 'our', 'foot', 'firmly', 'planted', 'on', 'the']    # of words=  7  Start= 66  END=  72    index=
#
# ['have', 'our', 'foot', 'firmly', 'planted', 'on', 'the']
#
# ***********
# newline=  ['ground', 'no', 'crossing', 'of', 'the', 'leg']    # of words=  6  Start= 73  END=  78    index=
#
# ['ground,', 'no', 'crossing', 'of', 'the', 'leg,']
#
# ***********
# newline=  ['no', 'swaying', 'back', 'and', 'forth', 'no', 'dancing']    # of words=  7  Start= 79  END=  85    index=
#
# ['no', 'swaying', 'back', 'and', 'forth', 'no', 'dancing']
#
# ***********
# newline=  ['backwards', 'and', 'forward', 'no', 'pacing']    # of words=  5  Start= 86  END=  90    index=
#
# ['backwards', 'and', 'forward', 'no', 'pacing']
#
# ***********
# newline=  ['side']    # of words=  1  Start= 91  END=  91    index=
#
# ['side']
#
# ***********
# newline=  ['and', 'by', 'all', 'mean', 'no', 'popping', 'of', 'the', 'hip']    # of words=  9  Start= 92  END=  100    index=
#
# ['and', 'by', 'all', 'mean', 'no', 'popping', 'of', 'the', 'hip']
#
# ***********
# newline=  ['once', 'we', 'have', 'that', 'firm', 'stable', 'stance', 'we']    # of words=  8  Start= 101  END=  108    index=
#
# ['Once', 'we', 'have', 'that', 'firm,', 'stable', 'stance,', 'we']
#
# ***********
# newline=  ['need', 'to', 'then', 'stand', 'up', 'nice', 'and', 'tall', 'to']    # of words=  9  Start= 109  END=  117    index=
#
# ['need', 'to', 'then', 'stand', 'up', 'nice', 'and', 'tall', 'to']
#
# ***********
# newline=  ['have', 'a', 'length', 'in', 'our', 'torso', 'but', 'our']    # of words=  8  Start= 118  END=  125    index=
#
# ['have', 'a', 'length', 'in', 'our', 'torso,', 'but', 'our']
#
# ***********
# newline=  ['shoulder', 'relaxed', 'to', 'increase', 'the']    # of words=  5  Start= 126  END=  130    index=
#
# ['shoulder', 'relaxed', 'to', 'increase', 'the']
#
# ***********
# newline=  ['distance', 'between', 'our', 'shoulder', 'and', 'our']    # of words=  6  Start= 131  END=  136    index=
#
# ['distance', 'between', 'our', 'shoulder', 'and', 'our']
#
# ***********
# newline=  ['ear', 'and', 'to', 'imagine', 'the', 'top', 'of', 'our', 'head']    # of words=  9  Start= 137  END=  145    index=
#
# ['ear', 'and', 'to', 'imagine', 'the', 'top', 'of', 'our', 'head']
#
# ***********
# newline=  ['ha', 'a', 'string', 'going', 'right', 'to', 'the', 'ceiling']    # of words=  8  Start= 146  END=  153    index=
#
# ['ha', 'a', 'string', 'going', 'Right', 'to', 'the', 'ceiling']
#
# ***********
# newline=  ['making', 'u', 'stand', 'taller', 'than', 'usual', 'what']    # of words=  7  Start= 154  END=  160    index=
#
# ['making?', 'U', 'stand', 'taller', 'than', 'usual?', 'What']
#
# ***********
# newline=  ['do', 'we', 'do', 'with', 'our', 'arm', 'the', 'question']    # of words=  8  Start= 161  END=  168    index=
#
# ['do', 'we', 'do', 'with', 'our', 'arm?', 'The', 'question']
#
# ***********
# newline=  ['every', 'new', 'speaker', 'ha', 'keep', 'them', 'in', 'a']    # of words=  8  Start= 169  END=  176    index=
#
# ['every', 'new', 'speaker', 'ha', 'keep', 'them', 'in', 'a']
#
# ***********
# newline=  ['neutral', 'position', 'at', 'your', 'side', 'do', "n't"]    # of words=  7  Start= 177  END=  183    index=
#
# ['neutral', 'position', 'at', 'your', 'side', 'do']
#
# ***********
# newline=  ['clasp', 'in', 'front', 'or', 'behind', 'do', "n't", 'do', 'this']    # of words=  9  Start= 184  END=  192    index=
#
# ['clasp', 'in', 'front', 'or', 'behind', 'do', 'do', 'this']
#
# ***********
# newline=  ['defensive', 'move', 'and', 'when', 'they', "'re", 'at', 'your']    # of words=  8  Start= 193  END=  200    index=
#
# ['defensive', 'move', 'and', 'when', 'at', 'your']
#
# ***********
# newline=  ['side', 'then', 'you', 'can', 'use', 'them', 'freely', 'to']    # of words=  8  Start= 201  END=  208    index=
#
# ['side', 'then', 'you', 'can', 'use', 'them', 'freely', 'to']
#
# ***********
# newline=  ['gesture', 'and', 'add', 'impact', 'to', 'your', 'speech', 'if']    # of words=  8  Start= 209  END=  216    index=
#
# ['gesture', 'and', 'add', 'impact', 'to', 'your', 'speech.', 'If']
#
# ***********
# newline=  ['you', "'re", 'standing', 'behind', 'a', 'lectern', 'be']    # of words=  7  Start= 217  END=  223    index=
#
# ['standing', 'behind', 'a', 'lectern', 'be']
#
# ***********
# newline=  ['careful', 'not', 'to', 'grasp', 'onto', 'the', 'lectern']    # of words=  7  Start= 224  END=  230    index=
#
# ['careful', 'not', 'to', 'grasp', 'onto', 'the', 'lectern']
#
# ***********
# newline=  ['for', 'dear', 'life']    # of words=  3  Start= 231  END=  233    index=
#
# ['for', 'dear', 'life,']
#
# ***********
# newline=  ['this', 'can', 'cause', 'you', 'to', 'bend', 'over']    # of words=  7  Start= 234  END=  240    index=
#
# ['this', 'can', 'cause', 'you', 'to', 'bend', 'over,']
#
# ***********
# newline=  ['impacting', 'your', 'posture', 'negatively', 'it', "'ll"]    # of words=  6  Start= 241  END=  246    index=
#
# ['impacting', 'your', 'posture', 'negatively']
#
# ***********
# newline=  ['prevent', 'you', 'from', 'doing', 'any', 'gesture', 'and']    # of words=  7  Start= 247  END=  253    index=
#
# ['prevent', 'you', 'from', 'doing', 'any', 'gesture', 'and']
#
# ***********
# newline=  ['you', 'might', 'tap', 'on', 'it', 'or', 'make', 'other']    # of words=  8  Start= 254  END=  261    index=
#
# ['you', 'might', 'tap', 'on', 'it', 'or', 'make', 'other']
#
# ***********
# newline=  ['distracting', 'noise', 'so', 'if', 'you', 'do', 'need', 'to']    # of words=  8  Start= 262  END=  269    index=
#
# ['distracting', 'noise.', 'So', 'if', 'you', 'do', 'need', 'to']
#
# ***********
# newline=  ['use', 'the', 'lectern', 'for', 'your', 'note', 'make', 'sure']    # of words=  8  Start= 270  END=  277    index=
#
# ['use', 'the', 'lectern', 'for', 'your', 'note,', 'make', 'sure']
#
# ***********
# newline=  ['that', 'you', 'are', 'not', 'touching', 'it', 'and', 'that']    # of words=  8  Start= 278  END=  285    index=
#
# ['that', 'you', 'are', 'not', 'touching', 'it', 'and', 'that']
#
# ***********
# newline=  ['you', 'are', 'gesturing', 'we', "'ve", 'talked', 'about']    # of words=  7  Start= 286  END=  292    index=
#
# ['you', 'are', 'gesturing.', 'talked', 'about']
#
# ***********
# newline=  ['your', 'stance', 'now', 'let', "'s", 'talk', 'about', 'your']    # of words=  8  Start= 293  END=  300    index=
#
# ['your', 'stance.', 'now,', 'talk', 'about', 'your']
#
# ***********
# newline=  ['sound', 'when', 'you', 'are', 'giving', 'a', 'speech', 'that']    # of words=  8  Start= 301  END=  308    index=
#
# ['sound', 'when', 'you', 'are', 'giving', 'a', 'speech.', 'that']
#
# ***********
# newline=  ['great', 'stance', 'is', 'the', 'basis', 'for', 'phenomenal']    # of words=  7  Start= 309  END=  315    index=
#
# ['great', 'stance', 'is', 'the', 'basis', 'for', 'phenomenal']
#
# ***********
# newline=  ['projection']    # of words=  1  Start= 316  END=  316    index=
#
# ['projection,']
#
# ***********
# newline=  ['it', 'will', 'allow', 'you', 'to', 'speak', 'from', 'your']    # of words=  8  Start= 317  END=  324    index=
#
# ['it', 'will', 'allow', 'you', 'to', 'speak', 'from', 'your']
#
# ***********
# newline=  ['diaphragm', 'and', 'fill', 'the', 'room', 'with', 'sound']    # of words=  7  Start= 325  END=  331    index=
#
# ['diaphragm', 'and', 'fill', 'the', 'room', 'with', 'sound']
#
# ***********
# newline=  ['make', 'sure', 'that', 'you', 'really', 'lower', 'those']    # of words=  7  Start= 332  END=  338    index=
#
# ['make', 'sure', 'that', 'you', 'really', 'lower', 'those']
#
# ***********
# newline=  ['shoulder', 'because', 'when', 'we', 'get', 'nervous']    # of words=  6  Start= 339  END=  344    index=
#
# ['shoulder,', 'because', 'when', 'We', 'get', 'nervous']
#
# ***********
# newline=  ['which', 'most', 'of', 'u', 'are', 'when', 'we', 'speak', 'we']    # of words=  9  Start= 345  END=  353    index=
#
# ['which', 'most', 'of', 'U', 'are', 'when', 'We', 'speak', 'we']
#
# ***********
# newline=  ['tend', 'to', 'make', 'those', 'shoulder', 'go', 'higher']    # of words=  7  Start= 354  END=  360    index=
#
# ['tend', 'to', 'make', 'those', 'shoulder,', 'go', 'higher']
#
# ***********
# newline=  ['and', 'higher', 'and', 'higher', 'towards', 'our', 'ear']    # of words=  7  Start= 361  END=  367    index=
#
# ['and', 'higher', 'and', 'higher', 'towards', 'our', 'ear']
#
# ***********
# newline=  ['our', 'voice', 'get', 'higher', 'and', 'higher', 'and']    # of words=  7  Start= 368  END=  374    index=
#
# ['our', 'voice', 'get', 'higher', 'and', 'higher', 'and']
#
# ***********
# newline=  ['faster', 'and', 'faster', 'and', 'it', 'doe', "n't", 'help']    # of words=  8  Start= 375  END=  382    index=
#
# ['faster', 'and', 'faster', 'and', 'it', 'help']
#
# ***********
# newline=  ['our', 'presentation', 'relax', 'those', 'shoulder']    # of words=  5  Start= 383  END=  387    index=
#
# ['our', 'presentation', 'relax', 'those', 'shoulder,']
#
# ***********
# newline=  ['lower', 'that', 'voice', 'and', 'make', 'sure', 'that', 'you']    # of words=  8  Start= 388  END=  395    index=
#
# ['lower', 'that', 'voice', 'and', 'make', 'sure', 'that', 'you']
#
# ***********
# newline=  ['speak', 'in', 'a', 'slow', 'understandable', 'case', 'when']    # of words=  7  Start= 396  END=  402    index=
#
# ['speak', 'in', 'a', 'slow,', 'understandable', 'case', 'when']
#
# ***********
# newline=  ['we', "'re", 'working', 'with', 'sound', 'also', 'think']    # of words=  7  Start= 403  END=  409    index=
#
# ['We', 'working', 'with', 'sound', 'also', 'think']
#
# ***********
# newline=  ['about', 'having', 'variation', 'add', 'interest', 'to']    # of words=  6  Start= 410  END=  415    index=
#
# ['about', 'having', 'variation.', 'Add', 'interest', 'to']
#
# ***********
# newline=  ['your', 'speech', 'with', 'sound', 'use', 'up', 'high', 'tone']    # of words=  8  Start= 416  END=  423    index=
#
# ['your', 'speech.', 'with', 'sound', 'use', 'up', 'high', 'tone']
#
# ***********
# newline=  ['in', 'a', 'low', 'tone', 'speak', 'slow', 'and', 'really']    # of words=  8  Start= 424  END=  431    index=
#
# ['in', 'a', 'low', 'tone,', 'speak', 'slow,', 'and', 'really']
#
# ***********
# newline=  ['really', 'fast', 'yeah', 'these', 'will', 'add', 'a']    # of words=  7  Start= 432  END=  438    index=
#
# ['really', 'fast', 'yeah.', 'These', 'will', 'Add', 'a']
#
# ***********
# newline=  ['dynamic', 'nature', 'to', 'your', 'speech', 'making', 'you']    # of words=  7  Start= 439  END=  445    index=
#
# ['dynamic', 'nature', 'to', 'your', 'speech.', 'making', 'you']
#
# ***********
# newline=  ['look', 'very', 'confident', 'we', 'talked', 'about']    # of words=  6  Start= 446  END=  451    index=
#
# ['look', 'very', 'confident.', 'We', 'talked', 'about']
#
# ***********
# newline=  ['stance', 'and', 'your', 'sound', 'now', 'we', 'have', 'to']    # of words=  8  Start= 452  END=  459    index=
#
# ['stance,', 'and', 'your', 'sound', 'now,', 'we', 'have', 'to']
#
# ***********
# newline=  ['talk', 'about', 'your', 'smile', 'this', 'is', 'an']    # of words=  7  Start= 460  END=  466    index=
#
# ['talk', 'about', 'your', 'smile,', 'this', 'is', 'an']
#
# ***********
# newline=  ['extension', 'of', 'your', 'sound', 'because', 'people']    # of words=  6  Start= 467  END=  472    index=
#
# ['extension', 'of', 'your', 'sound', 'because', 'people']
#
# ***********
# newline=  ['who', 'are', 'smiling', 'sound', 'more', 'pleasant']    # of words=  6  Start= 473  END=  478    index=
#
# ['who', 'are', 'smiling', 'sound,', 'more', 'pleasant,']
#
# ***********
# newline=  ['they', "'re", 'great', 'to', 'listen', 'to', 'you', 'might']    # of words=  8  Start= 479  END=  486    index=
#
# ['great', 'to', 'listen', 'to', 'you', 'might']
#
# ***********
# newline=  ['think', 'that', 'you', 'look', 'cheesy', 'and', 'silly']    # of words=  7  Start= 487  END=  493    index=
#
# ['think', 'that', 'you', 'look', 'cheesy', 'and', 'silly']
#
# ***********
# newline=  ['smiling', 'through', 'a', 'speech', 'but', 'you', 'will']    # of words=  7  Start= 494  END=  500    index=
#
# ['smiling', 'through', 'a', 'speech.', 'but', 'you', 'will']
#
# ***********
# newline=  ['not', 'you', 'will', 'look', 'friendly']    # of words=  5  Start= 501  END=  505    index=
#
# ['not.', 'You', 'will', 'look', 'friendly.']
#
# ***********
# newline=  ['you', 'will', 'look', 'confident', 'and', 'you', 'will']    # of words=  7  Start= 506  END=  512    index=
#
# ['You', 'will', 'look', 'confident.', 'and', 'you', 'will']
#
# ***********
# newline=  ['look', 'at', 'ease', 'a', 'a', 'speaker', 'even', 'if', 'you', "'re"]    # of words=  10  Start= 513  END=  522    index=
#
# ['look', 'at', 'ease', 'a', 'a', 'speaker.', 'even', 'if', 'you']
#
# ***********
# newline=  ['really', 'nervous', 'on', 'the', 'inside', 'no', 'one', 'ha']    # of words=  8  Start= 523  END=  530    index=
#
# ['really', 'nervous', 'on', 'the', 'inside,', 'no', 'one', 'ha']
#
# ***********
# newline=  ['to', 'know', 'put', 'on', 'a', 'big', 'smile', 'when', 'you', 'give']    # of words=  10  Start= 531  END=  540    index=
#
# ['to', 'know', 'put', 'on', 'a', 'big', 'smile.', 'When', 'you', 'give']
#
# ***********
# newline=  ['a', 'speech', 'so', 'long', 'a', 'it', 'is', 'appropriate', 'to']    # of words=  9  Start= 541  END=  549    index=
#
# ['a', 'speech.', 'So', 'long', 'a', 'it', 'is', 'appropriate', 'to']
#
# ***********
# newline=  ['your', 'topic', 'now', 'into', 'the', 'fourth', 's']    # of words=  7  Start= 550  END=  556    index=
#
# ['your', 'topic', 'now', 'into', 'the', 'fourth', 's,']
#
# ***********
# newline=  ['silence', 'how', 'is', 'silence', 'something', 'that', 'a']    # of words=  7  Start= 557  END=  563    index=
#
# ['silence.', 'How', 'is', 'silence.', 'something', 'that', 'a']
#
# ***********
# newline=  ['confident', 'speaker', 'doe', 'in', 'our', 'culture', 'we']    # of words=  7  Start= 564  END=  570    index=
#
# ['confident', 'speaker.', 'doe', 'in', 'our', 'culture', 'we']
#
# ***********
# newline=  ['like', 'to', 'fill', 'every', 'single', 'moment', 'with']    # of words=  7  Start= 571  END=  577    index=
#
# ['like', 'to', 'fill', 'every', 'single', 'moment', 'with']
#
# ***********
# newline=  ['sound', 'we', 'do', "n't", 'like', 'to', 'pause', 'between']    # of words=  8  Start= 578  END=  585    index=
#
# ['sound', 'We', 'do', 'like', 'to', 'pause', 'between']
#
# ***********
# newline=  ['sentence', 'we', 'add', 'word', 'like', 'and', 'so', 'the']    # of words=  8  Start= 586  END=  593    index=
#
# ['sentence.', 'We', 'add', 'word', 'like,', 'and', 'So', 'the']
#
# ***********
# newline=  ['entire', 'speech', 'is', 'one', 'long', 'run', 'we']    # of words=  7  Start= 594  END=  600    index=
#
# ['entire', 'speech', 'is', 'one', 'long', 'run.', 'We']
#
# ***********
# newline=  ['should', 'prevent', 'that', 'and', 'when', 'we', 'lose', 'our']    # of words=  8  Start= 601  END=  608    index=
#
# ['should', 'prevent', 'that', 'and', 'when', 'We', 'lose', 'our']
#
# ***********
# newline=  ['train', 'of', 'thought', 'or', 'need', 'to', 'think', 'of']    # of words=  8  Start= 609  END=  616    index=
#
# ['train', 'of', 'thought', 'or', 'need', 'to', 'think', 'of']
#
# ***********
# newline=  ['what', 'we', 'want', 'to', 'say', 'next']    # of words=  6  Start= 617  END=  622    index=
#
# ['What', 'we', 'want', 'to', 'say', 'next,']
#
# ***********
# newline=  ['we', 'often', 'fill', 'that', 'time', 'with', 'um', 'ah', 'like']    # of words=  9  Start= 623  END=  631    index=
#
# ['we', 'often', 'fill', 'that', 'time', 'with', 'um.', 'Ah,', 'like']
#
# ***********
# newline=  ['you', 'know', 'other', 'mouth', 'sound', 'this', 'doe', "n't"]    # of words=  8  Start= 632  END=  639    index=
#
# ['you', 'know', 'other', 'mouth', 'sound,', 'This', 'doe']
#
# ***********
# newline=  ['make', 'a', 'slip', 'professional', 'prepared', 'or']    # of words=  6  Start= 640  END=  645    index=
#
# ['make', 'a', 'slip,', 'professional', 'prepared', 'or']
#
# ***********
# newline=  ['polished', 'use', 'silence', 'it', 'is', 'your', 'best']    # of words=  7  Start= 646  END=  652    index=
#
# ['polished', 'use', 'silence.', 'It', 'is', 'your', 'best']
#
# ***********
# newline=  ['friend', 'lastly', 'your', 'sight', 'what', 'I', 'mean', 'by']    # of words=  8  Start= 653  END=  660    index=
#
# ['friend.', 'Lastly,', 'your', 'sight,', 'what', 'I', 'mean', 'by']
#
# ***********
# newline=  ['sight', 'is', 'what', 'about', 'when', 'you', "'re", 'looking']    # of words=  8  Start= 661  END=  668    index=
#
# ['sight,', 'is', 'what', 'about', 'when', 'you', 'looking']
#
# ***********
# newline=  ['out', 'at', 'the', 'audience', 'making', 'eye', 'contact']    # of words=  7  Start= 669  END=  675    index=
#
# ['out', 'at', 'the', 'audience,', 'making', 'eye', 'contact']
#
# ***********
# newline=  ['is', 'an', 'important', 'part', 'of', 'being', 'a', 'great']    # of words=  8  Start= 676  END=  683    index=
#
# ['is', 'an', 'important', 'part', 'of', 'being', 'a', 'great']
#
# ***********
# newline=  ['confident', 'speaker', 'you', 'need', 'to', 'hold', 'that']    # of words=  7  Start= 684  END=  690    index=
#
# ['confident.', 'speaker', 'you', 'need', 'to', 'hold', 'that']
#
# ***********
# newline=  ['eye', 'contact', 'just', 'like', 'you', 'would', 'in', 'a']    # of words=  8  Start= 691  END=  698    index=
#
# ['eye', 'contact', 'Just', 'like', 'you', 'would,', 'in', 'a']
#
# ***********
# newline=  ['one', 'conversation', 'to', 'establish']    # of words=  4  Start= 699  END=  702    index=
#
# ['one', 'conversation', 'to', 'establish']
#
# ***********
# newline=  ['rapport', 'with', 'your', 'audience', 'you', 'might']    # of words=  6  Start= 703  END=  708    index=
#
# ['rapport', 'with', 'your', 'audience,', 'You', 'might']
#
# ***********
# newline=  ['feel', 'that', 'it', "'s", 'too', 'long', 'five', 'to', 'seven']    # of words=  9  Start= 709  END=  717    index=
#
# ['feel', 'that', 'it', 's,', 'too', 'long', 'five', 'to', 'seven.']
#
# ***********
# newline=  ['second', 'in', 'a', 'speech', 'but', 'that', "'s", 'exactly']    # of words=  8  Start= 718  END=  725    index=
#
# ['Second', 'in', 'a', 'speech.', 'but', 'that', 's,', 'exactly']
#
# ***********
# newline=  ['what', 'you', 'should', 'do', 'it', 'will', 'decrease', 'the']    # of words=  8  Start= 726  END=  733    index=
#
# ['what', 'you', 'should', 'do', 'it', 'will', 'decrease', 'the']
#
# ***********
# newline=  ['distance', 'if', 'you', 'will', 'between', 'the', 'speaker']    # of words=  7  Start= 734  END=  740    index=
#
# ['distance', 'If', 'you', 'will', 'between', 'the', 'speaker.']
#
# ***********
# newline=  ['and', 'audience', 'make', 'sure', 'that', 'you', 'do', "n't"]    # of words=  8  Start= 741  END=  748    index=
#
# ['and', 'audience,', 'make', 'sure', 'that', 'you', 'do']
#
# ***********
# newline=  ['scan', 'back', 'and', 'forth', 'without', 'making', 'any']    # of words=  7  Start= 749  END=  755    index=
#
# ['scan', 'back', 'and', 'forth', 'without', 'making', 'any']
#
# ***********
# newline=  ['lasting', 'contact', 'on', 'member', 'of', 'your']    # of words=  6  Start= 756  END=  761    index=
#
# ['lasting', 'contact', 'on', 'member', 'of', 'your']
#
# ***********
# newline=  ['audience', 'also', 'make', 'sure', 'you', 'do', "n't", 'do', 'the']    # of words=  9  Start= 762  END=  770    index=
#
# ['audience,', 'also', 'make', 'sure', 'you', 'do', 'do', 'The']
#
# ***********
# newline=  ['hunt', 'and', 'peck', 'that', "'s", 'what', 'I', 'call', 'it']    # of words=  9  Start= 771  END=  779    index=
#
# ['hunt', 'and', 'peck.', 'what', 'I', 'call', 'it']
#
# ***********
# newline=  ['where', 'you', 'look', 'at', 'two', 'people', 'over', 'and']    # of words=  8  Start= 780  END=  787    index=
#
# ['where', 'you', 'look', 'at', 'two', 'people', 'over', 'and']
#
# ***********
# newline=  ['over', 'and', 'ignore', 'the', 'rest', 'of', 'the', 'crowd']    # of words=  8  Start= 788  END=  795    index=
# ['over,', 'and', 'ignore', 'the', 'rest', 'of', 'the', 'crowd.']
#
# ***********
# newline=  ['maybe', 'those', 'people', 'are', 'smiling', 'and']    # of words=  6  Start= 796  END=  801    index=
#
# ['Maybe', 'those', 'people', 'are', 'smiling', 'and']
#
# ***********
# newline=  ['nodding', 'but', 'you', 'need', 'to', 'make', 'an', 'effort']    # of words=  8  Start= 802  END=  809    index=
#
# ['nodding,', 'but', 'you', 'need', 'to', 'make', 'an', 'effort']
#
# ***********
# newline=  ['to', 'establish', 'eye', 'contact', 'with', 'all', 'part']    # of words=  7  Start= 810  END=  816    index=
#
# ['to', 'establish', 'eye', 'contact', 'with', 'all', 'part']
#
# ***********
# newline=  ['of', 'the', 'room', 'by', 'all', 'mean', 'ignore', 'the']    # of words=  8  Start= 817  END=  824    index=
#
# ['of', 'the', 'room', 'by', 'all', 'mean', 'ignore', 'the']
#
# ***********
# newline=  ['advice', 'you', 'might', 'have', 'received', 'at', 'some']    # of words=  7  Start= 825  END=  831    index=
#
# ['advice', 'you', 'might', 'have', 'received', 'at', 'some']
#
# ***********
# newline=  ['point', 'where', 'someone', 'said', 'if', 'you', "'re"]    # of words=  7  Start= 832  END=  838    index=
#
# ['point', 'where', 'someone', 'said', 'if', 'you']
#
# ***********
# newline=  ['nervous', 'all', 'you', 'need', 'to', 'do', 'is', 'just', 'stare']    # of words=  9  Start= 839  END=  847    index=
#
# ['nervous', 'all', 'you', 'need', 'to', 'do', 'is', 'Just', 'stare']
#
# ***********
# newline=  ['at', 'the', 'back', 'wall', 'of', 'the', 'room', 'and', 'it', "'ll"]    # of words=  10  Start= 848  END=  857    index=
#
# ['at', 'the', 'back', 'wall', 'of', 'the', 'room', 'and', 'it']
#
# ***********
# newline=  ['be', 'the', 'easiest', 'speech', 'you', 'ever', 'gave', 'well']    # of words=  8  Start= 858  END=  865    index=
#
# ['be', 'the', 'easiest', 'speech', 'you', 'ever', 'gave', 'well.']
#
# ***********
# newline=  ['it', "'ll", 'also', 'be', 'the', 'worst', 'speech', 'because']    # of words=  8  Start= 866  END=  873    index=
#
# ['also', 'be', 'the', 'worst', 'speech,', 'because']
#
# ***********
# newline=  ['no', 'one', 'in', 'your', 'audience', 'will', 'be', 'involved']    # of words=  8  Start= 874  END=  881    index=
#
# ['no', 'one', 'in', 'your', 'audience,', 'will', 'be', 'involved']
#
# ***********
# newline=  ['and', 'engaged', 'because', 'you', 'wo', "n't", 'be', 'making']    # of words=  8  Start= 882  END=  889    index=
#
# ['and', 'engaged', 'because', 'you', 'be', 'making?']
#
# ***********
# newline=  ['I', 'contact', 'with', 'him', 'we', 'have', 'talked', 'about']    # of words=  8  Start= 890  END=  897    index=
#
# ['I', 'contact', 'with', 'him.', 'We', 'have', 'talked', 'about']
#
# ***********
# newline=  ['today', 'the', '5', 'is', 'they', 'are', 'stance', 'sound']    # of words=  8  Start= 898  END=  905    index=
#
# ['today,', 'the', '5', 'is', 'they', 'are', 'stance.', 'sound']
#
# ***********
# newline=  ['smile', 'silence', 'and', 'sight', 'if', 'you', 'apply']    # of words=  7  Start= 906  END=  912    index=
#
# #of words exceeds*************
# index=  24
# w=  sound
# w1=  sound     k1=  smile
# w=  third
# w1=  third     k1=  smile
# w=  smile,
# w1=  smile     k1=  smile
# #of words exceeds*************
# index=  24
# w=  sound
# w1=  sound     k1=  silence
# w=  third
# w1=  third     k1=  silence
# w=  smile,
# w1=  smile     k1=  silence
# w=  fourth
# w1=  fourth     k1=  silence
# w=  silence
# w1=  silence     k1=  silence
# #of words exceeds*************
# index=  24
# w=  sound
# w1=  sound     k1=  and
# w=  third
# w1=  third     k1=  and
# w=  smile,
# w1=  smile     k1=  and
# w=  fourth
# w1=  fourth     k1=  and
# w=  silence
# w1=  silence     k1=  and
# w=  and
# w1=  and     k1=  and
# #of words exceeds*************
# index=  24
# w=  sound
# w1=  sound     k1=  sight
# w=  third
# w1=  third     k1=  sight
# w=  smile,
# w1=  smile     k1=  sight
# w=  fourth
# w1=  fourth     k1=  sight
# w=  silence
# w1=  silence     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  fit
# w1=  fit     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  site.
# w1=  site     k1=  sight
# w=  First,
# w1=  first     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  stance
# w1=  stance     k1=  sight
# w=  when
# w1=  when     k1=  sight
# w=  you're
# w1=  youre     k1=  sight
# w=  speaking,
# w1=  speaking     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  need
# w1=  need     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  have
# w1=  have     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  nice
# w1=  nice     k1=  sight
# w=  firm
# w1=  firm     k1=  sight
# w=  stance.
# w1=  stance     k1=  sight
# w=  Your
# w1=  your     k1=  sight
# w=  foot
# w1=  foot     k1=  sight
# w=  should
# w1=  should     k1=  sight
# w=  be
# w1=  be     k1=  sight
# w=  about
# w1=  about     k1=  sight
# w=  hip
# w1=  hip     k1=  sight
# w=  apart,
# w1=  apart     k1=  sight
# w=  not
# w1=  not     k1=  sight
# w=  too
# w1=  too     k1=  sight
# w=  wide
# w1=  wide     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  not
# w1=  not     k1=  sight
# w=  too
# w1=  too     k1=  sight
# w=  close.
# w1=  close     k1=  sight
# w=  We
# w1=  we     k1=  sight
# w=  want
# w1=  want     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  have
# w1=  have     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  foot
# w1=  foot     k1=  sight
# w=  firmly
# w1=  firmly     k1=  sight
# w=  planted
# w1=  planted     k1=  sight
# w=  on
# w1=  on     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  ground,
# w1=  ground     k1=  sight
# w=  no
# w1=  no     k1=  sight
# w=  crossing
# w1=  crossing     k1=  sight
# w=  of
# w1=  of     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  leg,
# w1=  leg     k1=  sight
# w=  no
# w1=  no     k1=  sight
# w=  swaying
# w1=  swaying     k1=  sight
# w=  back
# w1=  back     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  forth
# w1=  forth     k1=  sight
# w=  no
# w1=  no     k1=  sight
# w=  dancing
# w1=  dancing     k1=  sight
# w=  backwards
# w1=  backwards     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  forward
# w1=  forward     k1=  sight
# w=  no
# w1=  no     k1=  sight
# w=  pacing
# w1=  pacing     k1=  sight
# w=  side
# w1=  side     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  by
# w1=  by     k1=  sight
# w=  all
# w1=  all     k1=  sight
# w=  mean
# w1=  mean     k1=  sight
# w=  no
# w1=  no     k1=  sight
# w=  popping
# w1=  popping     k1=  sight
# w=  of
# w1=  of     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  hip.
# w1=  hip     k1=  sight
# w=  Once
# w1=  once     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  have
# w1=  have     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  firm,
# w1=  firm     k1=  sight
# w=  stable
# w1=  stable     k1=  sight
# w=  stance,
# w1=  stance     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  need
# w1=  need     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  then
# w1=  then     k1=  sight
# w=  stand
# w1=  stand     k1=  sight
# w=  up
# w1=  up     k1=  sight
# w=  nice
# w1=  nice     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  tall
# w1=  tall     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  have
# w1=  have     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  length
# w1=  length     k1=  sight
# w=  in
# w1=  in     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  torso,
# w1=  torso     k1=  sight
# w=  but
# w1=  but     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  shoulder
# w1=  shoulder     k1=  sight
# w=  relaxed
# w1=  relaxed     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  increase
# w1=  increase     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  distance
# w1=  distance     k1=  sight
# w=  between
# w1=  between     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  shoulder
# w1=  shoulder     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  ear
# w1=  ear     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  imagine
# w1=  imagine     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  top
# w1=  top     k1=  sight
# w=  of
# w1=  of     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  head
# w1=  head     k1=  sight
# w=  ha
# w1=  ha     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  string
# w1=  string     k1=  sight
# w=  going
# w1=  going     k1=  sight
# w=  Right
# w1=  right     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  ceiling
# w1=  ceiling     k1=  sight
# w=  making?
# w1=  making     k1=  sight
# w=  U
# w1=  u     k1=  sight
# w=  stand
# w1=  stand     k1=  sight
# w=  taller
# w1=  taller     k1=  sight
# w=  than
# w1=  than     k1=  sight
# w=  usual?
# w1=  usual     k1=  sight
# w=  What
# w1=  what     k1=  sight
# w=  do
# w1=  do     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  do
# w1=  do     k1=  sight
# w=  with
# w1=  with     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  arm?
# w1=  arm     k1=  sight
# w=  The
# w1=  the     k1=  sight
# w=  question
# w1=  question     k1=  sight
# w=  every
# w1=  every     k1=  sight
# w=  new
# w1=  new     k1=  sight
# w=  speaker
# w1=  speaker     k1=  sight
# w=  ha
# w1=  ha     k1=  sight
# w=  keep
# w1=  keep     k1=  sight
# w=  them
# w1=  them     k1=  sight
# w=  in
# w1=  in     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  neutral
# w1=  neutral     k1=  sight
# w=  position
# w1=  position     k1=  sight
# w=  at
# w1=  at     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  side,
# w1=  side     k1=  sight
# w=  don't
# w1=  dont     k1=  sight
# w=  clasp
# w1=  clasp     k1=  sight
# w=  in
# w1=  in     k1=  sight
# w=  front
# w1=  front     k1=  sight
# w=  or
# w1=  or     k1=  sight
# w=  behind
# w1=  behind     k1=  sight
# w=  don't
# w1=  dont     k1=  sight
# w=  do
# w1=  do     k1=  sight
# w=  this
# w1=  this     k1=  sight
# w=  defensive
# w1=  defensive     k1=  sight
# w=  move
# w1=  move     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  when
# w1=  when     k1=  sight
# w=  they're
# w1=  theyre     k1=  sight
# w=  at
# w1=  at     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  side,
# w1=  side     k1=  sight
# w=  then
# w1=  then     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  can
# w1=  can     k1=  sight
# w=  use
# w1=  use     k1=  sight
# w=  them
# w1=  them     k1=  sight
# w=  freely
# w1=  freely     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  gesture
# w1=  gesture     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  add
# w1=  add     k1=  sight
# w=  impact
# w1=  impact     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  speech.
# w1=  speech     k1=  sight
# w=  If
# w1=  if     k1=  sight
# w=  you're
# w1=  youre     k1=  sight
# w=  standing
# w1=  standing     k1=  sight
# w=  behind
# w1=  behind     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  lectern
# w1=  lectern     k1=  sight
# w=  be
# w1=  be     k1=  sight
# w=  careful
# w1=  careful     k1=  sight
# w=  not
# w1=  not     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  grasp
# w1=  grasp     k1=  sight
# w=  onto
# w1=  onto     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  lectern
# w1=  lectern     k1=  sight
# w=  for
# w1=  for     k1=  sight
# w=  dear
# w1=  dear     k1=  sight
# w=  life,
# w1=  life     k1=  sight
# w=  this
# w1=  this     k1=  sight
# w=  can
# w1=  can     k1=  sight
# w=  cause
# w1=  cause     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  bend
# w1=  bend     k1=  sight
# w=  over,
# w1=  over     k1=  sight
# w=  impacting
# w1=  impacting     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  posture
# w1=  posture     k1=  sight
# w=  negatively
# w1=  negatively     k1=  sight
# w=  it'll,
# w1=  itll     k1=  sight
# w=  prevent
# w1=  prevent     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  from
# w1=  from     k1=  sight
# w=  doing
# w1=  doing     k1=  sight
# w=  any
# w1=  any     k1=  sight
# w=  gesture
# w1=  gesture     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  might
# w1=  might     k1=  sight
# w=  tap
# w1=  tap     k1=  sight
# w=  on
# w1=  on     k1=  sight
# w=  it
# w1=  it     k1=  sight
# w=  or
# w1=  or     k1=  sight
# w=  make
# w1=  make     k1=  sight
# w=  other
# w1=  other     k1=  sight
# w=  distracting
# w1=  distracting     k1=  sight
# w=  noise.
# w1=  noise     k1=  sight
# w=  So
# w1=  so     k1=  sight
# w=  if
# w1=  if     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  do
# w1=  do     k1=  sight
# w=  need
# w1=  need     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  use
# w1=  use     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  lectern
# w1=  lectern     k1=  sight
# w=  for
# w1=  for     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  note,
# w1=  note     k1=  sight
# w=  make
# w1=  make     k1=  sight
# w=  sure
# w1=  sure     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  are
# w1=  are     k1=  sight
# w=  not
# w1=  not     k1=  sight
# w=  touching
# w1=  touching     k1=  sight
# w=  it
# w1=  it     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  are
# w1=  are     k1=  sight
# w=  gesturing.
# w1=  gesturing     k1=  sight
# w=  We'Ve
# w1=  weve     k1=  sight
# w=  talked
# w1=  talked     k1=  sight
# w=  about
# w1=  about     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  stance
# w1=  stance     k1=  sight
# w=  now,
# w1=  now     k1=  sight
# w=  let's
# w1=  lets     k1=  sight
# w=  talk
# w1=  talk     k1=  sight
# w=  about
# w1=  about     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  sound
# w1=  sound     k1=  sight
# w=  when
# w1=  when     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  are
# w1=  are     k1=  sight
# w=  giving
# w1=  giving     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  speech
# w1=  speech     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  great
# w1=  great     k1=  sight
# w=  stance
# w1=  stance     k1=  sight
# w=  is
# w1=  is     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  basis
# w1=  basis     k1=  sight
# w=  for
# w1=  for     k1=  sight
# w=  phenomenal
# w1=  phenomenal     k1=  sight
# w=  projection,
# w1=  projection     k1=  sight
# w=  it
# w1=  it     k1=  sight
# w=  will
# w1=  will     k1=  sight
# w=  allow
# w1=  allow     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  speak
# w1=  speak     k1=  sight
# w=  from
# w1=  from     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  diaphragm
# w1=  diaphragm     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  fill
# w1=  fill     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  room
# w1=  room     k1=  sight
# w=  with
# w1=  with     k1=  sight
# w=  sound.
# w1=  sound     k1=  sight
# w=  Make
# w1=  make     k1=  sight
# w=  sure
# w1=  sure     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  really
# w1=  really     k1=  sight
# w=  lower
# w1=  lower     k1=  sight
# w=  those
# w1=  those     k1=  sight
# w=  shoulder,
# w1=  shoulder     k1=  sight
# w=  because
# w1=  because     k1=  sight
# w=  when
# w1=  when     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  get
# w1=  get     k1=  sight
# w=  nervous
# w1=  nervous     k1=  sight
# w=  which
# w1=  which     k1=  sight
# w=  most
# w1=  most     k1=  sight
# w=  of
# w1=  of     k1=  sight
# w=  u
# w1=  u     k1=  sight
# w=  are
# w1=  are     k1=  sight
# w=  when
# w1=  when     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  speak,
# w1=  speak     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  tend
# w1=  tend     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  make
# w1=  make     k1=  sight
# w=  those
# w1=  those     k1=  sight
# w=  shoulder:
# w1=  shoulder     k1=  sight
# w=  go
# w1=  go     k1=  sight
# w=  higher
# w1=  higher     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  higher
# w1=  higher     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  higher
# w1=  higher     k1=  sight
# w=  towards
# w1=  towards     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  ear.
# w1=  ear     k1=  sight
# w=  Our
# w1=  our     k1=  sight
# w=  voice
# w1=  voice     k1=  sight
# w=  get
# w1=  get     k1=  sight
# w=  higher
# w1=  higher     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  higher
# w1=  higher     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  faster
# w1=  faster     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  faster,
# w1=  faster     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  it
# w1=  it     k1=  sight
# w=  doen't
# w1=  doent     k1=  sight
# w=  help
# w1=  help     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  presentation
# w1=  presentation     k1=  sight
# w=  relax
# w1=  relax     k1=  sight
# w=  those
# w1=  those     k1=  sight
# w=  shoulder
# w1=  shoulder     k1=  sight
# w=  lower
# w1=  lower     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  voice
# w1=  voice     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  make
# w1=  make     k1=  sight
# w=  sure
# w1=  sure     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  speak
# w1=  speak     k1=  sight
# w=  in
# w1=  in     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  slow,
# w1=  slow     k1=  sight
# w=  understandable
# w1=  understandable     k1=  sight
# w=  case
# w1=  case     k1=  sight
# w=  when
# w1=  when     k1=  sight
# w=  we're
# w1=  were     k1=  sight
# w=  working
# w1=  working     k1=  sight
# w=  with
# w1=  with     k1=  sight
# w=  sound,
# w1=  sound     k1=  sight
# w=  also
# w1=  also     k1=  sight
# w=  think
# w1=  think     k1=  sight
# w=  about
# w1=  about     k1=  sight
# w=  having
# w1=  having     k1=  sight
# w=  variation.
# w1=  variation     k1=  sight
# w=  Add
# w1=  add     k1=  sight
# w=  interest
# w1=  interest     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  speech
# w1=  speech     k1=  sight
# w=  with
# w1=  with     k1=  sight
# w=  sound
# w1=  sound     k1=  sight
# w=  use
# w1=  use     k1=  sight
# w=  up
# w1=  up     k1=  sight
# w=  high
# w1=  high     k1=  sight
# w=  tone
# w1=  tone     k1=  sight
# w=  in
# w1=  in     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  low
# w1=  low     k1=  sight
# w=  tone,
# w1=  tone     k1=  sight
# w=  speak
# w1=  speak     k1=  sight
# w=  slow
# w1=  slow     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  really
# w1=  really     k1=  sight
# w=  really
# w1=  really     k1=  sight
# w=  fast
# w1=  fast     k1=  sight
# w=  yeah.
# w1=  yeah     k1=  sight
# w=  These
# w1=  these     k1=  sight
# w=  will
# w1=  will     k1=  sight
# w=  add
# w1=  add     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  dynamic
# w1=  dynamic     k1=  sight
# w=  nature
# w1=  nature     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  speech,
# w1=  speech     k1=  sight
# w=  making
# w1=  making     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  look
# w1=  look     k1=  sight
# w=  very
# w1=  very     k1=  sight
# w=  confident.
# w1=  confident     k1=  sight
# w=  We
# w1=  we     k1=  sight
# w=  talked
# w1=  talked     k1=  sight
# w=  about
# w1=  about     k1=  sight
# w=  stance
# w1=  stance     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  sound.
# w1=  sound     k1=  sight
# w=  Now
# w1=  now     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  have
# w1=  have     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  talk
# w1=  talk     k1=  sight
# w=  about
# w1=  about     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  smile.
# w1=  smile     k1=  sight
# w=  This
# w1=  this     k1=  sight
# w=  is
# w1=  is     k1=  sight
# w=  an
# w1=  an     k1=  sight
# w=  extension
# w1=  extension     k1=  sight
# w=  of
# w1=  of     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  sound
# w1=  sound     k1=  sight
# w=  because
# w1=  because     k1=  sight
# w=  people
# w1=  people     k1=  sight
# w=  who
# w1=  who     k1=  sight
# w=  are
# w1=  are     k1=  sight
# w=  smiling
# w1=  smiling     k1=  sight
# w=  sound,
# w1=  sound     k1=  sight
# w=  more
# w1=  more     k1=  sight
# w=  pleasant,
# w1=  pleasant     k1=  sight
# w=  they're
# w1=  theyre     k1=  sight
# w=  great
# w1=  great     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  listen
# w1=  listen     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  might
# w1=  might     k1=  sight
# w=  think
# w1=  think     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  look
# w1=  look     k1=  sight
# w=  cheesy
# w1=  cheesy     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  silly
# w1=  silly     k1=  sight
# w=  smiling
# w1=  smiling     k1=  sight
# w=  through
# w1=  through     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  speech,
# w1=  speech     k1=  sight
# w=  but
# w1=  but     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  will
# w1=  will     k1=  sight
# w=  not.
# w1=  not     k1=  sight
# w=  You
# w1=  you     k1=  sight
# w=  will
# w1=  will     k1=  sight
# w=  look
# w1=  look     k1=  sight
# w=  friendly.
# w1=  friendly     k1=  sight
# w=  You
# w1=  you     k1=  sight
# w=  will
# w1=  will     k1=  sight
# w=  look
# w1=  look     k1=  sight
# w=  confident
# w1=  confident     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  will
# w1=  will     k1=  sight
# w=  look
# w1=  look     k1=  sight
# w=  at
# w1=  at     k1=  sight
# w=  ease
# w1=  ease     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  speaker
# w1=  speaker     k1=  sight
# w=  even
# w1=  even     k1=  sight
# w=  if
# w1=  if     k1=  sight
# w=  you're
# w1=  youre     k1=  sight
# w=  really
# w1=  really     k1=  sight
# w=  nervous
# w1=  nervous     k1=  sight
# w=  on
# w1=  on     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  inside,
# w1=  inside     k1=  sight
# w=  no
# w1=  no     k1=  sight
# w=  one
# w1=  one     k1=  sight
# w=  ha
# w1=  ha     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  know
# w1=  know     k1=  sight
# w=  put
# w1=  put     k1=  sight
# w=  on
# w1=  on     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  big
# w1=  big     k1=  sight
# w=  smile.
# w1=  smile     k1=  sight
# w=  When
# w1=  when     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  give
# w1=  give     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  speech
# w1=  speech     k1=  sight
# w=  so
# w1=  so     k1=  sight
# w=  long
# w1=  long     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  it
# w1=  it     k1=  sight
# w=  is
# w1=  is     k1=  sight
# w=  appropriate
# w1=  appropriate     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  topic
# w1=  topic     k1=  sight
# w=  now
# w1=  now     k1=  sight
# w=  into
# w1=  into     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  fourth
# w1=  fourth     k1=  sight
# w=  s,
# w1=  s     k1=  sight
# w=  silence.
# w1=  silence     k1=  sight
# w=  How
# w1=  how     k1=  sight
# w=  is
# w1=  is     k1=  sight
# w=  silence
# w1=  silence     k1=  sight
# w=  something
# w1=  something     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  confident
# w1=  confident     k1=  sight
# w=  speaker
# w1=  speaker     k1=  sight
# w=  doe
# w1=  doe     k1=  sight
# w=  in
# w1=  in     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  culture
# w1=  culture     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  like
# w1=  like     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  fill
# w1=  fill     k1=  sight
# w=  every
# w1=  every     k1=  sight
# w=  single
# w1=  single     k1=  sight
# w=  moment
# w1=  moment     k1=  sight
# w=  with
# w1=  with     k1=  sight
# w=  sound?
# w1=  sound     k1=  sight
# w=  We
# w1=  we     k1=  sight
# w=  don't
# w1=  dont     k1=  sight
# w=  like
# w1=  like     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  pause
# w1=  pause     k1=  sight
# w=  between
# w1=  between     k1=  sight
# w=  sentence.
# w1=  sentence     k1=  sight
# w=  We
# w1=  we     k1=  sight
# w=  add
# w1=  add     k1=  sight
# w=  word
# w1=  word     k1=  sight
# w=  like,
# w1=  like     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  so
# w1=  so     k1=  sight
# w=  the
# w1=  the     k1=  sight
# w=  entire
# w1=  entire     k1=  sight
# w=  speech
# w1=  speech     k1=  sight
# w=  is
# w1=  is     k1=  sight
# w=  one
# w1=  one     k1=  sight
# w=  long
# w1=  long     k1=  sight
# w=  run.
# w1=  run     k1=  sight
# w=  We
# w1=  we     k1=  sight
# w=  should
# w1=  should     k1=  sight
# w=  prevent
# w1=  prevent     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  and
# w1=  and     k1=  sight
# w=  when
# w1=  when     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  lose
# w1=  lose     k1=  sight
# w=  our
# w1=  our     k1=  sight
# w=  train
# w1=  train     k1=  sight
# w=  of
# w1=  of     k1=  sight
# w=  thought
# w1=  thought     k1=  sight
# w=  or
# w1=  or     k1=  sight
# w=  need
# w1=  need     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  think
# w1=  think     k1=  sight
# w=  of
# w1=  of     k1=  sight
# w=  what
# w1=  what     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  want
# w1=  want     k1=  sight
# w=  to
# w1=  to     k1=  sight
# w=  say
# w1=  say     k1=  sight
# w=  next,
# w1=  next     k1=  sight
# w=  we
# w1=  we     k1=  sight
# w=  often
# w1=  often     k1=  sight
# w=  fill
# w1=  fill     k1=  sight
# w=  that
# w1=  that     k1=  sight
# w=  time
# w1=  time     k1=  sight
# w=  with
# w1=  with     k1=  sight
# w=  um.
# w1=  um     k1=  sight
# w=  Ah,
# w1=  ah     k1=  sight
# w=  like
# w1=  like     k1=  sight
# w=  you
# w1=  you     k1=  sight
# w=  know,
# w1=  know     k1=  sight
# w=  other
# w1=  other     k1=  sight
# w=  mouth
# w1=  mouth     k1=  sight
# w=  sound,
# w1=  sound     k1=  sight
# w=  this
# w1=  this     k1=  sight
# w=  doen't
# w1=  doent     k1=  sight
# w=  make
# w1=  make     k1=  sight
# w=  a
# w1=  a     k1=  sight
# w=  slip,
# w1=  slip     k1=  sight
# w=  professional
# w1=  professional     k1=  sight
# w=  prepared
# w1=  prepared     k1=  sight
# w=  or
# w1=  or     k1=  sight
# w=  polished
# w1=  polished     k1=  sight
# w=  use
# w1=  use     k1=  sight
# w=  silence.
# w1=  silence     k1=  sight
# w=  It
# w1=  it     k1=  sight
# w=  is
# w1=  is     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  best
# w1=  best     k1=  sight
# w=  friend.
# w1=  friend     k1=  sight
# w=  Lastly,
# w1=  lastly     k1=  sight
# w=  your
# w1=  your     k1=  sight
# w=  sight,
# w1=  sight     k1=  sight
# #of words exceeds*************
# index=  24
# w=  sound
# w1=  sound     k1=  if
# w=  third
# w1=  third     k1=  if
# w=  smile,
# w1=  smile     k1=  if
# w=  fourth
# w1=  fourth     k1=  if
# w=  silence
# w1=  silence     k1=  if
# w=  and
# w1=  and     k1=  if
# w=  fit
# w1=  fit     k1=  if
# w=  your
# w1=  your     k1=  if
# w=  site.
# w1=  site     k1=  if
# w=  First,
# w1=  first     k1=  if
# w=  your
# w1=  your     k1=  if
# w=  stance
# w1=  stance     k1=  if
# w=  when
# w1=  when     k1=  if
# w=  you're
# w1=  youre     k1=  if
# w=  speaking,
# w1=  speaking     k1=  if
# w=  you
# w1=  you     k1=  if
# w=  need
# w1=  need     k1=  if
# w=  to
# w1=  to     k1=  if
# w=  have
# w1=  have     k1=  if
# w=  a
# w1=  a     k1=  if
# w=  nice
# w1=  nice     k1=  if
# w=  firm
# w1=  firm     k1=  if
# w=  stance.
# w1=  stance     k1=  if
# w=  Your
# w1=  your     k1=  if
# w=  foot
# w1=  foot     k1=  if
# w=  should
# w1=  should     k1=  if
# w=  be
# w1=  be     k1=  if
# w=  about
# w1=  about     k1=  if
# w=  hip
# w1=  hip     k1=  if
# w=  apart,
# w1=  apart     k1=  if
# w=  not
# w1=  not     k1=  if
# w=  too
# w1=  too     k1=  if
# w=  wide
# w1=  wide     k1=  if
# w=  and
# w1=  and     k1=  if
# w=  not
# w1=  not     k1=  if
# w=  too
# w1=  too     k1=  if
# w=  close.
# w1=  close     k1=  if
# w=  We
# w1=  we     k1=  if
# w=  want
# w1=  want     k1=  if
# w=  to
# w1=  to     k1=  if
# w=  have
# w1=  have     k1=  if
# w=  our
# w1=  our     k1=  if
# w=  foot
# w1=  foot     k1=  if
# w=  firmly
# w1=  firmly     k1=  if
# w=  planted
# w1=  planted     k1=  if
# w=  on
# w1=  on     k1=  if
# w=  the
# w1=  the     k1=  if
# w=  ground,
# w1=  ground     k1=  if
# w=  no
# w1=  no     k1=  if
# w=  crossing
# w1=  crossing     k1=  if
# w=  of
# w1=  of     k1=  if
# w=  the
# w1=  the     k1=  if
# w=  leg,
# w1=  leg     k1=  if
# w=  no
# w1=  no     k1=  if
# w=  swaying
# w1=  swaying     k1=  if
# w=  back
# ...
# w=  one
# w1=  one     k1=  toastmaster
# w=  ha
# w1=  ha     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  know
# w1=  know     k1=  toastmaster
# w=  put
# w1=  put     k1=  toastmaster
# w=  on
# w1=  on     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  big
# w1=  big     k1=  toastmaster
# w=  smile.
# w1=  smile     k1=  toastmaster
# w=  When
# w1=  when     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  give
# w1=  give     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  speech
# w1=  speech     k1=  toastmaster
# w=  so
# w1=  so     k1=  toastmaster
# w=  long
# w1=  long     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  it
# w1=  it     k1=  toastmaster
# w=  is
# w1=  is     k1=  toastmaster
# w=  appropriate
# w1=  appropriate     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  your
# w1=  your     k1=  toastmaster
# w=  topic
# w1=  topic     k1=  toastmaster
# w=  now
# w1=  now     k1=  toastmaster
# w=  into
# w1=  into     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  fourth
# w1=  fourth     k1=  toastmaster
# w=  s,
# w1=  s     k1=  toastmaster
# w=  silence.
# w1=  silence     k1=  toastmaster
# w=  How
# w1=  how     k1=  toastmaster
# w=  is
# w1=  is     k1=  toastmaster
# w=  silence
# w1=  silence     k1=  toastmaster
# w=  something
# w1=  something     k1=  toastmaster
# w=  that
# w1=  that     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  confident
# w1=  confident     k1=  toastmaster
# w=  speaker
# w1=  speaker     k1=  toastmaster
# w=  doe
# w1=  doe     k1=  toastmaster
# w=  in
# w1=  in     k1=  toastmaster
# w=  our
# w1=  our     k1=  toastmaster
# w=  culture
# w1=  culture     k1=  toastmaster
# w=  we
# w1=  we     k1=  toastmaster
# w=  like
# w1=  like     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  fill
# w1=  fill     k1=  toastmaster
# w=  every
# w1=  every     k1=  toastmaster
# w=  single
# w1=  single     k1=  toastmaster
# w=  moment
# w1=  moment     k1=  toastmaster
# w=  with
# w1=  with     k1=  toastmaster
# w=  sound?
# w1=  sound     k1=  toastmaster
# w=  We
# w1=  we     k1=  toastmaster
# w=  don't
# w1=  dont     k1=  toastmaster
# w=  like
# w1=  like     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  pause
# w1=  pause     k1=  toastmaster
# w=  between
# w1=  between     k1=  toastmaster
# w=  sentence.
# w1=  sentence     k1=  toastmaster
# w=  We
# w1=  we     k1=  toastmaster
# w=  add
# w1=  add     k1=  toastmaster
# w=  word
# w1=  word     k1=  toastmaster
# w=  like,
# w1=  like     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  so
# w1=  so     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  entire
# w1=  entire     k1=  toastmaster
# w=  speech
# w1=  speech     k1=  toastmaster
# w=  is
# w1=  is     k1=  toastmaster
# w=  one
# w1=  one     k1=  toastmaster
# w=  long
# w1=  long     k1=  toastmaster
# w=  run.
# w1=  run     k1=  toastmaster
# w=  We
# w1=  we     k1=  toastmaster
# w=  should
# w1=  should     k1=  toastmaster
# w=  prevent
# w1=  prevent     k1=  toastmaster
# w=  that
# w1=  that     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  when
# w1=  when     k1=  toastmaster
# w=  we
# w1=  we     k1=  toastmaster
# w=  lose
# w1=  lose     k1=  toastmaster
# w=  our
# w1=  our     k1=  toastmaster
# w=  train
# w1=  train     k1=  toastmaster
# w=  of
# w1=  of     k1=  toastmaster
# w=  thought
# w1=  thought     k1=  toastmaster
# w=  or
# w1=  or     k1=  toastmaster
# w=  need
# w1=  need     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  think
# w1=  think     k1=  toastmaster
# w=  of
# w1=  of     k1=  toastmaster
# w=  what
# w1=  what     k1=  toastmaster
# w=  we
# w1=  we     k1=  toastmaster
# w=  want
# w1=  want     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  say
# w1=  say     k1=  toastmaster
# w=  next,
# w1=  next     k1=  toastmaster
# w=  we
# w1=  we     k1=  toastmaster
# w=  often
# w1=  often     k1=  toastmaster
# w=  fill
# w1=  fill     k1=  toastmaster
# w=  that
# w1=  that     k1=  toastmaster
# w=  time
# w1=  time     k1=  toastmaster
# w=  with
# w1=  with     k1=  toastmaster
# w=  um.
# w1=  um     k1=  toastmaster
# w=  Ah,
# w1=  ah     k1=  toastmaster
# w=  like
# w1=  like     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  know,
# w1=  know     k1=  toastmaster
# w=  other
# w1=  other     k1=  toastmaster
# w=  mouth
# w1=  mouth     k1=  toastmaster
# w=  sound,
# w1=  sound     k1=  toastmaster
# w=  this
# w1=  this     k1=  toastmaster
# w=  doen't
# w1=  doent     k1=  toastmaster
# w=  make
# w1=  make     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  slip,
# w1=  slip     k1=  toastmaster
# w=  professional
# w1=  professional     k1=  toastmaster
# w=  prepared
# w1=  prepared     k1=  toastmaster
# w=  or
# w1=  or     k1=  toastmaster
# w=  polished
# w1=  polished     k1=  toastmaster
# w=  use
# w1=  use     k1=  toastmaster
# w=  silence.
# w1=  silence     k1=  toastmaster
# w=  It
# w1=  it     k1=  toastmaster
# w=  is
# w1=  is     k1=  toastmaster
# w=  your
# w1=  your     k1=  toastmaster
# w=  best
# w1=  best     k1=  toastmaster
# w=  friend.
# w1=  friend     k1=  toastmaster
# w=  Lastly,
# w1=  lastly     k1=  toastmaster
# w=  your
# w1=  your     k1=  toastmaster
# w=  sight,
# w1=  sight     k1=  toastmaster
# w=  what
# w1=  what     k1=  toastmaster
# w=  I
# w1=  i     k1=  toastmaster
# w=  mean
# w1=  mean     k1=  toastmaster
# w=  by
# w1=  by     k1=  toastmaster
# w=  sight
# w1=  sight     k1=  toastmaster
# w=  is
# w1=  is     k1=  toastmaster
# w=  what
# w1=  what     k1=  toastmaster
# w=  about
# w1=  about     k1=  toastmaster
# w=  when
# w1=  when     k1=  toastmaster
# w=  you're,
# w1=  youre     k1=  toastmaster
# w=  looking
# w1=  looking     k1=  toastmaster
# w=  out
# w1=  out     k1=  toastmaster
# w=  at
# w1=  at     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  audience,
# w1=  audience     k1=  toastmaster
# w=  making
# w1=  making     k1=  toastmaster
# w=  eye
# w1=  eye     k1=  toastmaster
# w=  contact
# w1=  contact     k1=  toastmaster
# w=  is
# w1=  is     k1=  toastmaster
# w=  an
# w1=  an     k1=  toastmaster
# w=  important
# w1=  important     k1=  toastmaster
# w=  part
# w1=  part     k1=  toastmaster
# w=  of
# w1=  of     k1=  toastmaster
# w=  being
# w1=  being     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  great
# w1=  great     k1=  toastmaster
# w=  confident
# w1=  confident     k1=  toastmaster
# w=  speaker.
# w1=  speaker     k1=  toastmaster
# w=  You
# w1=  you     k1=  toastmaster
# w=  need
# w1=  need     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  hold
# w1=  hold     k1=  toastmaster
# w=  that
# w1=  that     k1=  toastmaster
# w=  eye
# w1=  eye     k1=  toastmaster
# w=  contact.
# w1=  contact     k1=  toastmaster
# w=  Just
# w1=  just     k1=  toastmaster
# w=  like
# w1=  like     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  would,
# w1=  would     k1=  toastmaster
# w=  in
# w1=  in     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  one
# w1=  one     k1=  toastmaster
# w=  conversation
# w1=  conversation     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  establish
# w1=  establish     k1=  toastmaster
# w=  rapport
# w1=  rapport     k1=  toastmaster
# w=  with
# w1=  with     k1=  toastmaster
# w=  your
# w1=  your     k1=  toastmaster
# w=  audience.
# w1=  audience     k1=  toastmaster
# w=  You
# w1=  you     k1=  toastmaster
# w=  might
# w1=  might     k1=  toastmaster
# w=  feel
# w1=  feel     k1=  toastmaster
# w=  that
# w1=  that     k1=  toastmaster
# w=  it's
# w1=  its     k1=  toastmaster
# w=  too
# w1=  too     k1=  toastmaster
# w=  long
# w1=  long     k1=  toastmaster
# w=  five
# w1=  five     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  seven.
# w1=  seven     k1=  toastmaster
# w=  Second
# w1=  second     k1=  toastmaster
# w=  in
# w1=  in     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  speech,
# w1=  speech     k1=  toastmaster
# w=  but
# w1=  but     k1=  toastmaster
# w=  that's
# w1=  thats     k1=  toastmaster
# w=  exactly
# w1=  exactly     k1=  toastmaster
# w=  what
# w1=  what     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  should
# w1=  should     k1=  toastmaster
# w=  do.
# w1=  do     k1=  toastmaster
# w=  It
# w1=  it     k1=  toastmaster
# w=  will
# w1=  will     k1=  toastmaster
# w=  decrease
# w1=  decrease     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  distance.
# w1=  distance     k1=  toastmaster
# w=  If
# w1=  if     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  will,
# w1=  will     k1=  toastmaster
# w=  between
# w1=  between     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  speaker
# w1=  speaker     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  audience,
# w1=  audience     k1=  toastmaster
# w=  make
# w1=  make     k1=  toastmaster
# w=  sure
# w1=  sure     k1=  toastmaster
# w=  that
# w1=  that     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  don't
# w1=  dont     k1=  toastmaster
# w=  scan
# w1=  scan     k1=  toastmaster
# w=  back
# w1=  back     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  forth
# w1=  forth     k1=  toastmaster
# w=  without
# w1=  without     k1=  toastmaster
# w=  making
# w1=  making     k1=  toastmaster
# w=  any
# w1=  any     k1=  toastmaster
# w=  lasting
# w1=  lasting     k1=  toastmaster
# w=  contact
# w1=  contact     k1=  toastmaster
# w=  on
# w1=  on     k1=  toastmaster
# w=  member
# w1=  member     k1=  toastmaster
# w=  of
# w1=  of     k1=  toastmaster
# w=  your
# w1=  your     k1=  toastmaster
# w=  audience
# w1=  audience     k1=  toastmaster
# w=  also
# w1=  also     k1=  toastmaster
# w=  make
# w1=  make     k1=  toastmaster
# w=  sure
# w1=  sure     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  don't
# w1=  dont     k1=  toastmaster
# w=  do
# w1=  do     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  hunt
# w1=  hunt     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  peck.
# w1=  peck     k1=  toastmaster
# w=  That'S
# w1=  thats     k1=  toastmaster
# w=  what
# w1=  what     k1=  toastmaster
# w=  I
# w1=  i     k1=  toastmaster
# w=  call
# w1=  call     k1=  toastmaster
# w=  it
# w1=  it     k1=  toastmaster
# w=  where
# w1=  where     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  look
# w1=  look     k1=  toastmaster
# w=  at
# w1=  at     k1=  toastmaster
# w=  two
# w1=  two     k1=  toastmaster
# w=  people
# w1=  people     k1=  toastmaster
# w=  over
# w1=  over     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  over
# w1=  over     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  ignore
# w1=  ignore     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  rest
# w1=  rest     k1=  toastmaster
# w=  of
# w1=  of     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  crowd.
# w1=  crowd     k1=  toastmaster
# w=  Maybe
# w1=  maybe     k1=  toastmaster
# w=  those
# w1=  those     k1=  toastmaster
# w=  people
# w1=  people     k1=  toastmaster
# w=  are
# w1=  are     k1=  toastmaster
# w=  smiling
# w1=  smiling     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  nodding,
# w1=  nodding     k1=  toastmaster
# w=  but
# w1=  but     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  need
# w1=  need     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  make
# w1=  make     k1=  toastmaster
# w=  an
# w1=  an     k1=  toastmaster
# w=  effort
# w1=  effort     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  establish
# w1=  establish     k1=  toastmaster
# w=  eye
# w1=  eye     k1=  toastmaster
# w=  contact
# w1=  contact     k1=  toastmaster
# w=  with
# w1=  with     k1=  toastmaster
# w=  all
# w1=  all     k1=  toastmaster
# w=  part
# w1=  part     k1=  toastmaster
# w=  of
# w1=  of     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  room
# w1=  room     k1=  toastmaster
# w=  by
# w1=  by     k1=  toastmaster
# w=  all
# w1=  all     k1=  toastmaster
# w=  mean
# w1=  mean     k1=  toastmaster
# w=  ignore
# w1=  ignore     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  advice
# w1=  advice     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  might
# w1=  might     k1=  toastmaster
# w=  have
# w1=  have     k1=  toastmaster
# w=  received
# w1=  received     k1=  toastmaster
# w=  at
# w1=  at     k1=  toastmaster
# w=  some
# w1=  some     k1=  toastmaster
# w=  point
# w1=  point     k1=  toastmaster
# w=  where
# w1=  where     k1=  toastmaster
# w=  someone
# w1=  someone     k1=  toastmaster
# w=  said
# w1=  said     k1=  toastmaster
# w=  if
# w1=  if     k1=  toastmaster
# w=  you're
# w1=  youre     k1=  toastmaster
# w=  nervous,
# w1=  nervous     k1=  toastmaster
# w=  all
# w1=  all     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  need
# w1=  need     k1=  toastmaster
# w=  to
# w1=  to     k1=  toastmaster
# w=  do
# w1=  do     k1=  toastmaster
# w=  is
# w1=  is     k1=  toastmaster
# w=  Just
# w1=  just     k1=  toastmaster
# w=  stare
# w1=  stare     k1=  toastmaster
# w=  at
# w1=  at     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  back
# w1=  back     k1=  toastmaster
# w=  wall
# w1=  wall     k1=  toastmaster
# w=  of
# w1=  of     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  room
# w1=  room     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  it'll
# w1=  itll     k1=  toastmaster
# w=  be
# w1=  be     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  easiest
# w1=  easiest     k1=  toastmaster
# w=  speech
# w1=  speech     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  ever
# w1=  ever     k1=  toastmaster
# w=  gave
# w1=  gave     k1=  toastmaster
# w=  well.
# w1=  well     k1=  toastmaster
# w=  It'Ll
# w1=  itll     k1=  toastmaster
# w=  also
# w1=  also     k1=  toastmaster
# w=  be
# w1=  be     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  worst
# w1=  worst     k1=  toastmaster
# w=  speech,
# w1=  speech     k1=  toastmaster
# w=  because
# w1=  because     k1=  toastmaster
# w=  no
# w1=  no     k1=  toastmaster
# w=  one
# w1=  one     k1=  toastmaster
# w=  in
# w1=  in     k1=  toastmaster
# w=  your
# w1=  your     k1=  toastmaster
# w=  audience
# w1=  audience     k1=  toastmaster
# w=  will
# w1=  will     k1=  toastmaster
# w=  be
# w1=  be     k1=  toastmaster
# w=  involved
# w1=  involved     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  engaged
# w1=  engaged     k1=  toastmaster
# w=  because
# w1=  because     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  won't
# w1=  wont     k1=  toastmaster
# w=  be
# w1=  be     k1=  toastmaster
# w=  making
# w1=  making     k1=  toastmaster
# w=  I
# w1=  i     k1=  toastmaster
# w=  contact
# w1=  contact     k1=  toastmaster
# w=  with
# w1=  with     k1=  toastmaster
# w=  him.
# w1=  him     k1=  toastmaster
# w=  We
# w1=  we     k1=  toastmaster
# w=  have
# w1=  have     k1=  toastmaster
# w=  talked
# w1=  talked     k1=  toastmaster
# w=  about
# w1=  about     k1=  toastmaster
# w=  today,
# w1=  today     k1=  toastmaster
# w=  the
# w1=  the     k1=  toastmaster
# w=  5
# w1=  5     k1=  toastmaster
# w=  is
# w1=  is     k1=  toastmaster
# w=  they
# w1=  they     k1=  toastmaster
# w=  are
# w1=  are     k1=  toastmaster
# w=  stance,
# w1=  stance     k1=  toastmaster
# w=  sound,
# w1=  sound     k1=  toastmaster
# w=  smile,
# w1=  smile     k1=  toastmaster
# w=  silence
# w1=  silence     k1=  toastmaster
# w=  and
# w1=  and     k1=  toastmaster
# w=  sight.
# w1=  sight     k1=  toastmaster
# w=  If
# w1=  if     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  apply
# w1=  apply     k1=  toastmaster
# w=  these
# w1=  these     k1=  toastmaster
# w=  principle,
# w1=  principle     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  will
# w1=  will     k1=  toastmaster
# w=  be
# w1=  be     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  confident
# w1=  confident     k1=  toastmaster
# w=  speaker.
# w1=  speaker     k1=  toastmaster
# w=  The
# w1=  the     k1=  toastmaster
# w=  next
# w1=  next     k1=  toastmaster
# w=  time
# w1=  time     k1=  toastmaster
# w=  you
# w1=  you     k1=  toastmaster
# w=  are
# w1=  are     k1=  toastmaster
# w=  giving
# w1=  giving     k1=  toastmaster
# w=  a
# w1=  a     k1=  toastmaster
# w=  formal
# w1=  formal     k1=  toastmaster
# w=  speech
# w1=  speech     k1=  toastmaster
# w=  or
# w1=  or     k1=  toastmaster
# w=  your
# w1=  your     k1=  toastmaster
# w=  elevator
# w1=  elevator     k1=  toastmaster
# w=  speech.
# w1=  speech     k1=  toastmaster
# w=  Mr.
# w1=  mr     k1=  toastmaster
# w=  Toastmaster
# w1=  toastmaster     k1=  toastmaster
# ['sound', 'sound']
#
# ***********

# %%
for i in textWithPunc1:
    print(i)
# Out:
# ['Presentation', 'or', 'talking', 'to', 'your', 'bos', 'in']
# ['the', 'elevator,', 'there', 'are', 'five', 'secret', 'to']
# ['being', 'a', 'confident', 'speaker.', 'First,']
# ['your', 'stance.', 'Second,', 'your', 'sound', 'third']
# ['smile,', 'fourth', 'silence', 'and', 'fit', 'your', 'site.']
# ['First,', 'your', 'stance.', 'when', 'you']
# ['you', 'need', 'to', 'have', 'a', 'nice', 'firm', 'stance.', 'your']
# ['foot', 'should', 'be', 'about', 'hip', 'apart,', 'not']
# ['too', 'wide', 'and', 'not', 'too', 'close.', 'We', 'want', 'to']
# ['have', 'our', 'foot', 'firmly', 'planted', 'on', 'the']
# ['ground,', 'no', 'crossing', 'of', 'the', 'leg,']
# ['no', 'swaying', 'back', 'and', 'forth', 'no', 'dancing']
# ['backwards', 'and', 'forward', 'no', 'pacing']
# ['side']
# ['and', 'by', 'all', 'mean', 'no', 'popping', 'of', 'the', 'hip']
# ['Once', 'we', 'have', 'that', 'firm,', 'stable', 'stance,', 'we']
# ['need', 'to', 'then', 'stand', 'up', 'nice', 'and', 'tall', 'to']
# ['have', 'a', 'length', 'in', 'our', 'torso,', 'but', 'our']
# ['shoulder', 'relaxed', 'to', 'increase', 'the']
# ['distance', 'between', 'our', 'shoulder', 'and', 'our']
# ['ear', 'and', 'to', 'imagine', 'the', 'top', 'of', 'our', 'head']
# ['ha', 'a', 'string', 'going', 'Right', 'to', 'the', 'ceiling']
# ['making?', 'U', 'stand', 'taller', 'than', 'usual?', 'What']
# ['do', 'we', 'do', 'with', 'our', 'arm?', 'The', 'question']
# ['every', 'new', 'speaker', 'ha', 'keep', 'them', 'in', 'a']
# ['neutral', 'position', 'at', 'your', 'side', 'do']
# ['clasp', 'in', 'front', 'or', 'behind', 'do', 'do', 'this']
# ['defensive', 'move', 'and', 'when', 'at', 'your']
# ['side', 'then', 'you', 'can', 'use', 'them', 'freely', 'to']
# ['gesture', 'and', 'add', 'impact', 'to', 'your', 'speech.', 'If']
# ['standing', 'behind', 'a', 'lectern', 'be']
# ['careful', 'not', 'to', 'grasp', 'onto', 'the', 'lectern']
# ['for', 'dear', 'life,']
# ['this', 'can', 'cause', 'you', 'to', 'bend', 'over,']
# ['impacting', 'your', 'posture', 'negatively']
# ['prevent', 'you', 'from', 'doing', 'any', 'gesture', 'and']
# ['you', 'might', 'tap', 'on', 'it', 'or', 'make', 'other']
# ['distracting', 'noise.', 'So', 'if', 'you', 'do', 'need', 'to']
# ['use', 'the', 'lectern', 'for', 'your', 'note,', 'make', 'sure']
# ['that', 'you', 'are', 'not', 'touching', 'it', 'and', 'that']
# ['you', 'are', 'gesturing.', 'talked', 'about']
# ['your', 'stance.', 'now,', 'talk', 'about', 'your']
# ['sound', 'when', 'you', 'are', 'giving', 'a', 'speech.', 'that']
# ['great', 'stance', 'is', 'the', 'basis', 'for', 'phenomenal']
# ['projection,']
# ['it', 'will', 'allow', 'you', 'to', 'speak', 'from', 'your']
# ['diaphragm', 'and', 'fill', 'the', 'room', 'with', 'sound']
# ['make', 'sure', 'that', 'you', 'really', 'lower', 'those']
# ['shoulder,', 'because', 'when', 'We', 'get', 'nervous']
# ['which', 'most', 'of', 'U', 'are', 'when', 'We', 'speak', 'we']
# ['tend', 'to', 'make', 'those', 'shoulder,', 'go', 'higher']
# ['and', 'higher', 'and', 'higher', 'towards', 'our', 'ear']
# ['our', 'voice', 'get', 'higher', 'and', 'higher', 'and']
# ['faster', 'and', 'faster', 'and', 'it', 'help']
# ['our', 'presentation', 'relax', 'those', 'shoulder,']
# ['lower', 'that', 'voice', 'and', 'make', 'sure', 'that', 'you']
# ['speak', 'in', 'a', 'slow,', 'understandable', 'case', 'when']
# ['We', 'working', 'with', 'sound', 'also', 'think']
# ['about', 'having', 'variation.', 'Add', 'interest', 'to']
# ['your', 'speech.', 'with', 'sound', 'use', 'up', 'high', 'tone']
# ['in', 'a', 'low', 'tone,', 'speak', 'slow,', 'and', 'really']
# ['really', 'fast', 'yeah.', 'These', 'will', 'Add', 'a']
# ['dynamic', 'nature', 'to', 'your', 'speech.', 'making', 'you']
# ['look', 'very', 'confident.', 'We', 'talked', 'about']
# ['stance,', 'and', 'your', 'sound', 'now,', 'we', 'have', 'to']
# ['talk', 'about', 'your', 'smile,', 'this', 'is', 'an']
# ['extension', 'of', 'your', 'sound', 'because', 'people']
# ['who', 'are', 'smiling', 'sound,', 'more', 'pleasant,']
# ['great', 'to', 'listen', 'to', 'you', 'might']
# ['think', 'that', 'you', 'look', 'cheesy', 'and', 'silly']
# ['smiling', 'through', 'a', 'speech.', 'but', 'you', 'will']
# ['not.', 'You', 'will', 'look', 'friendly.']
# ['You', 'will', 'look', 'confident.', 'and', 'you', 'will']
# ['look', 'at', 'ease', 'a', 'a', 'speaker.', 'even', 'if', 'you']
# ['really', 'nervous', 'on', 'the', 'inside,', 'no', 'one', 'ha']
# ['to', 'know', 'put', 'on', 'a', 'big', 'smile.', 'When', 'you', 'give']
# ['a', 'speech.', 'So', 'long', 'a', 'it', 'is', 'appropriate', 'to']
# ['your', 'topic', 'now', 'into', 'the', 'fourth', 's,']
# ['silence.', 'How', 'is', 'silence.', 'something', 'that', 'a']
# ['confident', 'speaker.', 'doe', 'in', 'our', 'culture', 'we']
# ['like', 'to', 'fill', 'every', 'single', 'moment', 'with']
# ['sound', 'We', 'do', 'like', 'to', 'pause', 'between']
# ['sentence.', 'We', 'add', 'word', 'like,', 'and', 'So', 'the']
# ['entire', 'speech', 'is', 'one', 'long', 'run.', 'We']
# ['should', 'prevent', 'that', 'and', 'when', 'We', 'lose', 'our']
# ['train', 'of', 'thought', 'or', 'need', 'to', 'think', 'of']
# ['What', 'we', 'want', 'to', 'say', 'next,']
# ['we', 'often', 'fill', 'that', 'time', 'with', 'um.', 'Ah,', 'like']
# ['you', 'know', 'other', 'mouth', 'sound,', 'This', 'doe']
# ['make', 'a', 'slip,', 'professional', 'prepared', 'or']
# ['polished', 'use', 'silence.', 'It', 'is', 'your', 'best']
# ['friend.', 'Lastly,', 'your', 'sight,', 'what', 'I', 'mean', 'by']
# ['sight,', 'is', 'what', 'about', 'when', 'you', 'looking']
# ['out', 'at', 'the', 'audience,', 'making', 'eye', 'contact']
# ['is', 'an', 'important', 'part', 'of', 'being', 'a', 'great']
# ['confident.', 'speaker', 'you', 'need', 'to', 'hold', 'that']
# ['eye', 'contact', 'Just', 'like', 'you', 'would,', 'in', 'a']
# ['one', 'conversation', 'to', 'establish']
# ['rapport', 'with', 'your', 'audience,', 'You', 'might']
# ['feel', 'that', 'it', 's,', 'too', 'long', 'five', 'to', 'seven.']
# ['Second', 'in', 'a', 'speech.', 'but', 'that', 's,', 'exactly']
# ['what', 'you', 'should', 'do', 'it', 'will', 'decrease', 'the']
# ['distance', 'If', 'you', 'will', 'between', 'the', 'speaker.']
# ['and', 'audience,', 'make', 'sure', 'that', 'you', 'do']
# ['scan', 'back', 'and', 'forth', 'without', 'making', 'any']
# ['lasting', 'contact', 'on', 'member', 'of', 'your']
# ['audience,', 'also', 'make', 'sure', 'you', 'do', 'do', 'The']
# ['hunt', 'and', 'peck.', 'what', 'I', 'call', 'it']
# ['where', 'you', 'look', 'at', 'two', 'people', 'over', 'and']
# ['over,', 'and', 'ignore', 'the', 'rest', 'of', 'the', 'crowd.']
# ['Maybe', 'those', 'people', 'are', 'smiling', 'and']
# ['nodding,', 'but', 'you', 'need', 'to', 'make', 'an', 'effort']
# ['to', 'establish', 'eye', 'contact', 'with', 'all', 'part']
# ['of', 'the', 'room', 'by', 'all', 'mean', 'ignore', 'the']
# ['advice', 'you', 'might', 'have', 'received', 'at', 'some']
# ['point', 'where', 'someone', 'said', 'if', 'you']
# ['nervous', 'all', 'you', 'need', 'to', 'do', 'is', 'Just', 'stare']
# ['at', 'the', 'back', 'wall', 'of', 'the', 'room', 'and', 'it']
# ['be', 'the', 'easiest', 'speech', 'you', 'ever', 'gave', 'well.']
# ['also', 'be', 'the', 'worst', 'speech,', 'because']
# ['no', 'one', 'in', 'your', 'audience,', 'will', 'be', 'involved']
# ['and', 'engaged', 'because', 'you', 'be', 'making?']
# ['I', 'contact', 'with', 'him.', 'We', 'have', 'talked', 'about']
# ['today,', 'the', '5', 'is', 'they', 'are', 'stance.', 'sound']
# ['sound', 'sound', 'sound', 'sound', 'sound', 'sound', 'sound']
# ['sound', 'sound', 'sound', 'sound', 'sound', 'sound', 'sound']
# ['sound', 'sound', 'sound', 'sound', 'sound', 'sound', 'sound', 'sound']
# ['sound', 'sound', 'sound', 'sound', 'sound', 'sound']
# ['sound', 'sound']

# %%
for i in textWithPunc1:
    print(' '.join(i))
# Out:
# Presentation or talking to your bos in
# the elevator, there are five secret to
# being a confident speaker. First,
# your stance. Second, your sound third
# smile, fourth silence and fit your site.
# First, your stance. when you
# you need to have a nice firm stance. your
# foot should be about hip apart, not
# too wide and not too close. We want to
# have our foot firmly planted on the
# ground, no crossing of the leg,
# no swaying back and forth no dancing
# backwards and forward no pacing
# side
# and by all mean no popping of the hip
# Once we have that firm, stable stance, we
# need to then stand up nice and tall to
# have a length in our torso, but our
# shoulder relaxed to increase the
# distance between our shoulder and our
# ear and to imagine the top of our head
# ha a string going Right to the ceiling
# making? U stand taller than usual? What
# do we do with our arm? The question
# every new speaker ha keep them in a
# neutral position at your side do
# clasp in front or behind do do this
# defensive move and when at your
# side then you can use them freely to
# gesture and add impact to your speech. If
# standing behind a lectern be
# careful not to grasp onto the lectern
# for dear life,
# this can cause you to bend over,
# impacting your posture negatively
# prevent you from doing any gesture and
# you might tap on it or make other
# distracting noise. So if you do need to
# use the lectern for your note, make sure
# that you are not touching it and that
# you are gesturing. talked about
# your stance. now, talk about your
# sound when you are giving a speech. that
# great stance is the basis for phenomenal
# projection,
# it will allow you to speak from your
# diaphragm and fill the room with sound
# make sure that you really lower those
# shoulder, because when We get nervous
# which most of U are when We speak we
# tend to make those shoulder, go higher
# and higher and higher towards our ear
# our voice get higher and higher and
# faster and faster and it help
# our presentation relax those shoulder,
# lower that voice and make sure that you
# speak in a slow, understandable case when
# We working with sound also think
# about having variation. Add interest to
# your speech. with sound use up high tone
# in a low tone, speak slow, and really
# really fast yeah. These will Add a
# dynamic nature to your speech. making you
# look very confident. We talked about
# stance, and your sound now, we have to
# talk about your smile, this is an
# extension of your sound because people
# who are smiling sound, more pleasant,
# great to listen to you might
# think that you look cheesy and silly
# smiling through a speech. but you will
# not. You will look friendly.
# You will look confident. and you will
# look at ease a a speaker. even if you
# really nervous on the inside, no one ha
# to know put on a big smile. When you give
# a speech. So long a it is appropriate to
# your topic now into the fourth s,
# silence. How is silence. something that a
# confident speaker. doe in our culture we
# like to fill every single moment with
# sound We do like to pause between
# sentence. We add word like, and So the
# entire speech is one long run. We
# should prevent that and when We lose our
# train of thought or need to think of
# What we want to say next,
# we often fill that time with um. Ah, like
# you know other mouth sound, This doe
# make a slip, professional prepared or
# polished use silence. It is your best
# friend. Lastly, your sight, what I mean by
# sight, is what about when you looking
# out at the audience, making eye contact
# is an important part of being a great
# confident. speaker you need to hold that
# eye contact Just like you would, in a
# one conversation to establish
# rapport with your audience, You might
# feel that it s, too long five to seven.
# Second in a speech. but that s, exactly
# what you should do it will decrease the
# distance If you will between the speaker.
# and audience, make sure that you do
# scan back and forth without making any
# lasting contact on member of your
# audience, also make sure you do do The
# hunt and peck. what I call it
# where you look at two people over and
# over, and ignore the rest of the crowd.
# Maybe those people are smiling and
# nodding, but you need to make an effort
# to establish eye contact with all part
# of the room by all mean ignore the
# advice you might have received at some
# point where someone said if you
# nervous all you need to do is Just stare
# at the back wall of the room and it
# be the easiest speech you ever gave well.
# also be the worst speech, because
# no one in your audience, will be involved
# and engaged because you be making?
# I contact with him. We have talked about
# today, the 5 is they are stance. sound
# sound sound sound sound sound sound sound
# sound sound sound sound sound sound sound
# sound sound sound sound sound sound sound sound
# sound sound sound sound sound sound
# sound sound

# %%
import xlsxwriter
workbook = xlsxwriter.Workbook('7MWaeOHDBOg With Punctuation.xlsx')# save the puncutaed transcript to file with the same video ID
worksheet = workbook.add_worksheet('Text With Punct.')
row=1
col=0
for i in textWithPunc1:
    print(' '.join(i))
    
  
    worksheet.write(row,col,' '.join(i))
    row+=1
workbook.close()
# Out:
# Presentation or talking to your bos in
# the elevator, there are five secret to
# being a confident speaker. First,
# your stance. Second, your sound third
# smile, fourth silence and fit your site.
# First, your stance. when you
# you need to have a nice firm stance. your
# foot should be about hip apart, not
# too wide and not too close. We want to
# have our foot firmly planted on the
# ground, no crossing of the leg,
# no swaying back and forth no dancing
# backwards and forward no pacing
# side
# and by all mean no popping of the hip
# Once we have that firm, stable stance, we
# need to then stand up nice and tall to
# have a length in our torso, but our
# shoulder relaxed to increase the
# distance between our shoulder and our
# ear and to imagine the top of our head
# ha a string going Right to the ceiling
# making? U stand taller than usual? What
# do we do with our arm? The question
# every new speaker ha keep them in a
# neutral position at your side do
# clasp in front or behind do do this
# defensive move and when at your
# side then you can use them freely to
# gesture and add impact to your speech. If
# standing behind a lectern be
# careful not to grasp onto the lectern
# for dear life,
# this can cause you to bend over,
# impacting your posture negatively
# prevent you from doing any gesture and
# you might tap on it or make other
# distracting noise. So if you do need to
# use the lectern for your note, make sure
# that you are not touching it and that
# you are gesturing. talked about
# your stance. now, talk about your
# sound when you are giving a speech. that
# great stance is the basis for phenomenal
# projection,
# it will allow you to speak from your
# diaphragm and fill the room with sound
# make sure that you really lower those
# shoulder, because when We get nervous
# which most of U are when We speak we
# tend to make those shoulder, go higher
# and higher and higher towards our ear
# our voice get higher and higher and
# faster and faster and it help
# our presentation relax those shoulder,
# lower that voice and make sure that you
# speak in a slow, understandable case when
# We working with sound also think
# about having variation. Add interest to
# your speech. with sound use up high tone
# in a low tone, speak slow, and really
# really fast yeah. These will Add a
# dynamic nature to your speech. making you
# look very confident. We talked about
# stance, and your sound now, we have to
# talk about your smile, this is an
# extension of your sound because people
# who are smiling sound, more pleasant,
# great to listen to you might
# think that you look cheesy and silly
# smiling through a speech. but you will
# not. You will look friendly.
# You will look confident. and you will
# look at ease a a speaker. even if you
# really nervous on the inside, no one ha
# to know put on a big smile. When you give
# a speech. So long a it is appropriate to
# your topic now into the fourth s,
# silence. How is silence. something that a
# confident speaker. doe in our culture we
# like to fill every single moment with
# sound We do like to pause between
# sentence. We add word like, and So the
# entire speech is one long run. We
# should prevent that and when We lose our
# train of thought or need to think of
# What we want to say next,
# we often fill that time with um. Ah, like
# you know other mouth sound, This doe
# make a slip, professional prepared or
# polished use silence. It is your best
# friend. Lastly, your sight, what I mean by
# sight, is what about when you looking
# out at the audience, making eye contact
# is an important part of being a great
# confident. speaker you need to hold that
# eye contact Just like you would, in a
# one conversation to establish
# rapport with your audience, You might
# feel that it s, too long five to seven.
# Second in a speech. but that s, exactly
# what you should do it will decrease the
# distance If you will between the speaker.
# and audience, make sure that you do
# scan back and forth without making any
# lasting contact on member of your
# audience, also make sure you do do The
# hunt and peck. what I call it
# where you look at two people over and
# over, and ignore the rest of the crowd.
# Maybe those people are smiling and
# nodding, but you need to make an effort
# to establish eye contact with all part
# of the room by all mean ignore the
# advice you might have received at some
# point where someone said if you
# nervous all you need to do is Just stare
# at the back wall of the room and it
# be the easiest speech you ever gave well.
# also be the worst speech, because
# no one in your audience, will be involved
# and engaged because you be making?
# I contact with him. We have talked about
# today, the 5 is they are stance. sound
# sound sound sound sound sound sound sound
# sound sound sound sound sound sound sound
# sound sound sound sound sound sound sound sound
# sound sound sound sound sound sound
# sound sound
