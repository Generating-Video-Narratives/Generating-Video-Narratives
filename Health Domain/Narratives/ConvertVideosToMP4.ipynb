             "https://www.youtube.com/watch?v=WShT-I0wCO4",
            "https://www.youtube.com/watch?v=2utaepga5uk",
             "https://www.youtube.com/watch?v=pmuUnQ5Zi4Q",
            "https://www.youtube.com/watch?v=-u6I5UVahWg",
             "https://www.youtube.com/watch?v=dyRmGVgG7_8",
            "https://www.youtube.com/watch?v=aREqsWoX-EY",
             "https://www.youtube.com/watch?v=9nRhehMpODk",
            "https://www.youtube.com/watch?v=-Tyo2YsA0Y0",
             "https://www.youtube.com/watch?v=ZoEEgU6L-m8",
            "https://www.youtube.com/watch?v=FH7aHDHnkjU",
             "https://www.youtube.com/watch?v=cfyb39S_CZw",
            "https://www.youtube.com/watch?v=mSYXddFVvHo",
             "https://www.youtube.com/watch?v=323hkORG0OM",
            "https://www.youtube.com/watch?v=LYwQdM-2ok4",
             "https://www.youtube.com/watch?v=O5DOre3MFlw",
            "https://www.youtube.com/watch?v=bqkquNb5Z8A",
             "https://www.youtube.com/watch?v=qsAnlV8DUXo",
            "https://www.youtube.com/watch?v=2pzHkvmRSW8",
             "https://www.youtube.com/watch?v=_4ehrdRPEqE"]

# %%
# !pip install yt_dlp
from yt_dlp import YoutubeDL
# Out:
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\scam\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\scam\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\scam\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\scam\appdata\roaming\python\python37\site-packages)
# ...

# %%
videoID2=[]
for i in videoLinks1:
    
    video_url = i
    video_info = YoutubeDL().extract_info(url=video_url, download=True)
    options = {
        'format': 'bestaudio/best',
        'keepvideo': False,
        'outtmpl': '%(title)s.mp4',
        # 'playlist_items': '2'
    }
    videoID2.append(video_info)
    with YoutubeDL(options) as ydl:
        #out = ydl.download(video_info)
        out = ydl.download([video_info['webpage_url']])
    print('_____________________________________________')
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MxmrjLQvg7E
# [youtube] MxmrjLQvg7E: Downloading webpage
# [youtube] MxmrjLQvg7E: Downloading android player API JSON
# [info] MxmrjLQvg7E: Downloading 1 format(s): 22
# [download] Becca's lung cancer story [MxmrjLQvg7E].mp4 has already been downloaded
# [download] 100% of   37.20MiB
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MxmrjLQvg7E
# [youtube] MxmrjLQvg7E: Downloading webpage
# [youtube] MxmrjLQvg7E: Downloading android player API JSON
# [info] MxmrjLQvg7E: Downloading 1 format(s): 251
# [download] Becca's lung cancer story.mp4 has already been downloaded
# [download] 100% of    3.76MiB
# _____________________________________________
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rQutyErqBG0
# [youtube] rQutyErqBG0: Downloading webpage
# [youtube] rQutyErqBG0: Downloading android player API JSON
# [info] rQutyErqBG0: Downloading 1 format(s): 22
# ...
