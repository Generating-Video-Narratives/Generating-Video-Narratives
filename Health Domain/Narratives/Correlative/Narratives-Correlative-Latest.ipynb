# %%
import nltk
import codecs
#import pronto
import itertools

import numpy as np
from nltk.tokenize import PunktSentenceTokenizer,sent_tokenize, word_tokenize
from nltk.corpus import stopwords, wordnet

from nltk.stem import WordNetLemmatizer, PorterStemmer
import signal, ctypes
from pronto import Ontology
from pronto import *
import re
import pandas as pd
from pandas import DataFrame
import math
from difflib import SequenceMatcher
import sys
import collections
from collections import Counter
import statistics 
import ast
#aggregates=pd.read_excel("Videos Cleaned Aggregates For Narratives .xlsx",sheet_name ="Sheet1")
#aggregates=pd.read_excel("Videos Cleaned Aggregates For Narratives-with duration .xlsx",sheet_name ="Sheet1")

#aggregates=pd.read_excel("Videos Cleaned Aggregates For Narratives2 .xlsx",sheet_name ="Sheet1") 
aggregates=pd.read_excel("Patients Stories Aggregates For NarrativeswithDuration.xlsx",sheet_name ="Sheet1")  
print('With duration')
print()

for i in aggregates:
    print(i)
    print()

videoId=list(aggregates['VideoID'])

startTime=list(aggregates['Start'])
endTime=list(aggregates['End'])
# this is added here but not in the aggregation file in the aggregation folder
duration=list(aggregates['Duration'])
##################################################################
focusTopic=list(aggregates['Focus Topic'])+list(aggregates['Unnamed: 5'])+list(aggregates['Unnamed: 6'])+list(aggregates['Unnamed: 7'])

fC1=list(aggregates['Focus Concept'])
w1=list(aggregates['Focus Concept Weight'])
fC2=list(aggregates['Unnamed: 10'])
w2=list(aggregates['Unnamed: 11'])
fC3=list(aggregates['Unnamed: 12'])
w3=list(aggregates['Unnamed: 13'])
fC4=list(aggregates['Unnamed: 14'])
w4=list(aggregates['Unnamed: 15'])
fC5=list(aggregates['Unnamed: 16'])
w5=list(aggregates['Unnamed: 17'])

oC1=list(aggregates['Unnamed: 19'])
wOC1=list(aggregates['Unnamed: 20'])
oC2=list(aggregates['Unnamed: 21'])
wOC2=list(aggregates['Unnamed: 22'])
oC3=list(aggregates['Unnamed: 23'])
wOC3=list(aggregates['Unnamed: 24'])
oC4=list(aggregates['Unnamed: 25'])
wOC4=list(aggregates['Unnamed: 26'])







segCharacterisation=[]
for i in range(len(videoId)):
    segCharacterisation.append([videoId[i],startTime[i],endTime[i],int(duration[i]),[fC1[i],w1[i],fC2[i],w2[i],fC3[i],w3[i],fC4[i],
    w4[i],fC5[i],w5[i]],[oC1[i],wOC1[i],oC2[i],wOC2[i],oC3[i],wOC3[i],oC4[i],wOC4[i]]]) #oC17[i],wOC17[i],oC18[i],wOC18[i]]])

# I want to find the segments with oneFC. I think they will be good to start with in generating their narratives
# This could help in deciding which narratives to use for the evaluation

segWithOneFC=[]
segWithTwoFC=[]
segWithMoreFC=[]
otherCon=[]
for i in  segCharacterisation  :
    
    c=0
    j=0
    if i[4]:
        while j <= len(i[4])-2:
            if str(i[4][j]) != 'nan':
                c+=1
            j+=2
        
    if c==1:
        conc=[]
        otherCon=[]
        j=0
        while j <= len(i[4])-2:
            if str(i[4][j]) != 'nan':
                conc.append([i[4][j],i[4][j+1]])
            j+=2
        j=0
        if i[5]:
            while j <= len(i[5])-2:
                
                if str(i[5][j]) != 'nan':
                    otherCon.append([i[5][j],i[5][j+1]])
                j+=2
        segWithOneFC.append([i[0],i[1],i[2],i[3],conc,otherCon])
        conc=[]
        otherCon=[]
    if c==2:
        conc=[]
        otherCon=[]
        j=0
        while j <= len(i[4])-2:
            if str(i[4][j]) != 'nan':
                conc.append([i[4][j],i[4][j+1]])
            j+=2
        j=0
        if i[5]:
            while j <= len(i[5])-2:
                
                if str(i[5][j]) != 'nan':
                    otherCon.append([i[5][j],i[5][j+1]])
                j+=2
        segWithTwoFC.append([i[0],i[1],i[2],i[3],conc,otherCon])
        conc=[]
        otherCon=[]
    if c>=3:
        conc=[]
        otherCon=[]
        j=0
        while j <= len(i[4])-2:
            if str(i[4][j]) != 'nan':
                conc.append([i[4][j],i[4][j+1]])
            j+=2
        j=0
        if i[5]:
            while j <= len(i[5])-2:
                
                if str(i[5][j]) != 'nan':
                    otherCon.append([i[5][j],i[5][j+1]])
                j+=2
        segWithMoreFC.append([i[0],i[1],i[2],i[3],conc,otherCon])
        conc=[]
        otherCon=[]


print('# of segments with one FC= ',len(segWithOneFC))  
print()
print('# of segments with Two FC= ',len(segWithTwoFC))   
print()
print('# of segments with More FC= ',len(segWithMoreFC))   
print()
if  segWithOneFC:
    print('Seg with one FC')
    print('*******************************************************')
    print()
    for i in segWithOneFC:
        print(i)
        print()
if segWithTwoFC:
    print('Seg with Two FC')
    print('*******************************************************')
    print()
    for i in segWithTwoFC:
        print(i)
        print()
if segWithMoreFC:
    print('Seg with More than 3 FC')
    print('*******************************************************')
    for i in segWithMoreFC:
        print(i)
        print()
# Out:
# With duration
#
# VideoID
#
# Start
#
# End
#
# Duration
#
# Focus Topic
#
# Unnamed: 5
#
# Unnamed: 6
#
# Unnamed: 7
#
# Focus Concept
#
# Focus Concept Weight
#
# Unnamed: 10
#
# Unnamed: 11
#
# Unnamed: 12
#
# Unnamed: 13
#
# Unnamed: 14
#
# Unnamed: 15
#
# Unnamed: 16
#
# Unnamed: 17
#
# Other concepts
#
# Unnamed: 19
#
# Unnamed: 20
#
# Unnamed: 21
#
# Unnamed: 22
#
# Unnamed: 23
#
# Unnamed: 24
#
# Unnamed: 25
#
# Unnamed: 26
#
# Unnamed: 27
#
# Unnamed: 28
#
# Unnamed: 29
#
# Unnamed: 30
#
# Unnamed: 31
#
# Unnamed: 32
#
# Unnamed: 33
#
# Unnamed: 34
#
# Unnamed: 35
#
# Unnamed: 36
#
# # of segments with one FC=  202
#
# # of segments with Two FC=  70
#
# # of segments with More FC=  34
#
# Seg with one FC
# *******************************************************
#
# ['MxmrjLQvg7E7', 1.27, 2.32, 65, [['Mum', 2.0]], [['Mom', 1.0], ['Family', 1.0], ['Friend', 1.0]]]
#
# ['rQutyErqBG01', 0.04, 2.43, 159, [['LungCancer', 4.0]], [['Tumor', 4.0], ['Security', 1.0], ['Smoking', 1.0], ['Fear', 1.0]]]
#
# ['rQutyErqBG014', 4.03, 4.59, 55, [['LungCancer', 1.0]], []]
#
# ['rQutyErqBG017', 5.01, 5.43, 42, [['Insurance', 1.0]], []]
#
# ['hQQ5xQGZxdA9', 1.54, 3.14, 80, [['Pneumonia', 3.0]], [['Friend', 1.0], ['Thinking', 1.0], ['LungCancer', 1.0]]]
#
# ['hQQ5xQGZxdA15', 3.17, 4.39, 82, [['LungCancer', 2.0]], [['Tumor', 1.0], ['Thinking', 2.0]]]
#
# ['hQQ5xQGZxdA21', 4.41, 6.49, 128, [['Tumor', 6.0]], [['Memory', 1.0], ['Treatment', 1.0]]]
#
# ['hQQ5xQGZxdA31', 6.52, 7.28, 36, [['Wife', 1.0]], []]
#
# ['hQQ5xQGZxdA37', 8.1, 8.47, 37, [['Thinking', 1.0]], []]
#
# ['hQQ5xQGZxdA49', 10.48, 11.23, 35, [['Caregiver', 1.0]], []]
#
# ['hQQ5xQGZxdA55', 12.04, 12.38, 34, [['Caregiver', 1.0]], []]
#
# ['hQQ5xQGZxdA58', 12.39, 13.24, 45, [['Tumor', 1.0]], []]
#
# ['hQQ5xQGZxdA61', 13.25, 14.02, 37, [['Treatment', 1.0]], []]
#
# ['hQQ5xQGZxdA67', 14.45, 15.11, 26, [['Community', 1.0]], []]
#
# ['xY3B9nLm1u823', 5.53, 6.37, 44, [['Sleep', 1.0]], []]
#
# ['yV893Fx41lE1', 0.01, 2.19, 138, [['LungCancer', 3.0]], [['Training', 1.0], ['Soreness', 1.0], ['Pain', 2.0], ['Tumor', 1.0]]]
#
# ['wwiwjZw7d6o13', 3.14, 3.5, 36, [['Child', 2.0]], []]
#
# ['uJoY4oMLXEY1', 0.0, 0.42, 42, [['ShortnessOfBreath', 1.0]], []]
#
# ['uJoY4oMLXEY5', 1.38, 2.15, 37, [['Exercise', 1.0]], []]
#
# ['uJoY4oMLXEY9', 3.03, 3.19, 16, [['Copd', 1.0]], []]
#
# ['l9k9q6FHeX47', 1.24, 3.13, 109, [['ChestPain', 3.0]], [['Pain', 2.0], ['Learning', 1.0], ['Cough', 2.0], ['Bronchitis', 1.0]]]
#
# ['l9k9q6FHeX424', 5.11, 5.34, 22, [['Thinking', 1.0]], []]
#
# ['l9k9q6FHeX426', 5.35, 6.12, 37, [['Fear', 1.0]], []]
#
# ['l9k9q6FHeX450', 10.32, 11.09, 37, [['Pain', 1.0]], []]
#
# ['l9k9q6FHeX453', 11.1, 11.42, 32, [['Thinking', 1.0]], []]
#
# ['l9k9q6FHeX460', 12.34, 13.15, 41, [['LungCancer', 1.0]], []]
#
# ['l9k9q6FHeX463', 13.16, 13.51, 35, [['Thinking', 1.0]], []]
#
# ['l9k9q6FHeX469', 14.34, 15.14, 40, [['Treatment', 1.0]], []]
#
# ['l9k9q6FHeX481', 17.11, 17.49, 37, [['Friend', 1.0]], []]
#
# ['l9k9q6FHeX484', 17.52, 18.28, 36, [['Family', 1.0]], []]
#
# ['l9k9q6FHeX487', 18.31, 19.3, 59, [['Treatment', 2.0]], [['Friend', 1.0]]]
#
# ['j3t5nFnTULQ1', 0.05, 0.52, 47, [['ShortnessOfBreath', 1.0]], []]
#
# ['j3t5nFnTULQ7', 2.41, 3.31, 50, [['Hope', 1.0]], []]
#
# ['j3t5nFnTULQ9', 3.36, 4.22, 46, [['LungDisease', 1.0]], []]
#
# ['j3t5nFnTULQ11', 4.25, 4.43, 18, [['Family', 1.0]], []]
#
# ['tfxB32Vb5hE8', 1.43, 2.18, 35, [['Tumor', 1.0]], []]
#
# ['tfxB32Vb5hE10', 2.19, 2.49, 30, [['Hope', 1.0]], []]
#
# ['0fI_01yFmME1', 0.01, 0.49, 48, [['Friend', 1.0]], []]
#
# ['0fI_01yFmME3', 0.51, 1.4, 49, [['PulmonaryFibrosis', 1.0]], []]
#
# ['0fI_01yFmME7', 2.19, 3.17, 58, [['Husband', 1.0]], []]
#
# ['0fI_01yFmME11', 4.01, 4.23, 22, [['Caregiver', 1.0]], []]
#
# ['HBFn82ffSVE18', 4.25, 6.14, 108, [['Meditation', 3.0]], [['Anxiety', 1.0], ['Thinking', 1.0], ['LungCancer', 1.0], ['Dad', 1.0]]]
#
# ['HBFn82ffSVE30', 7.31, 7.51, 20, [['LungCancer', 1.0]], []]
#
# ['llk-qgIr9Nk4', 0.42, 1.13, 30, [['Tumor', 1.0]], []]
#
# ['llk-qgIr9Nk18', 4.08, 5.58, 110, [['Scared', 3.0]], [['Mom', 1.0], ['LungCancer', 1.0], ['Community', 1.0]]]
#
# ['llk-qgIr9Nk25', 6.0, 6.42, 42, [['Fear', 1.0]], []]
#
# ['llk-qgIr9Nk35', 8.18, 8.58, 40, [['Anxiety', 1.0]], []]
#
# ['llk-qgIr9Nk47', 11.01, 11.36, 35, [['Treatment', 1.0]], []]
#
# ['llk-qgIr9Nk53', 12.15, 13.01, 46, [['Family', 1.0]], []]
#
# ['llk-qgIr9Nk68', 16.06, 16.45, 39, [['Thinking', 1.0]], []]
#
# ['llk-qgIr9Nk74', 17.25, 18.0, 35, [['Sleep', 1.0]], []]
#
# ['llk-qgIr9Nk83', 19.23, 20.03, 40, [['Exercise', 1.0]], []]
#
# ['llk-qgIr9Nk86', 20.04, 20.41, 37, [['Husband', 1.0]], []]
#
# ['llk-qgIr9Nk95', 21.58, 22.38, 40, [['Exercise', 1.0]], []]
#
# ['llk-qgIr9Nk104', 24.08, 24.48, 40, [['Family', 1.0]], []]
#
# ['llk-qgIr9Nk128', 29.45, 30.26, 41, [['Mom', 1.0]], []]
#
# ['llk-qgIr9Nk137', 31.48, 32.26, 37, [['Exercise', 1.0]], []]
#
# ['llk-qgIr9Nk143', 33.06, 33.46, 39, [['Traffic', 1.0]], []]
#
# ['llk-qgIr9Nk155', 35.54, 36.32, 38, [['Treatment', 1.0]], []]
#
# ['llk-qgIr9Nk161', 37.21, 37.5, 29, [['LungCancer', 1.0]], []]
#
# ['llk-qgIr9Nk172', 39.48, 39.53, 5, [['LungCancer', 1.0]], []]
#
# ['3mcWSmPXFtM1', 0.0, 1.35, 95, [['Treatment', 2.0]], [['LungCancer', 2.0], ['Drug', 2.0]]]
#
# ['bmvlK4qhAnU15', 3.53, 4.33, 40, [['Husband', 1.0]], []]
#
# ['bmvlK4qhAnU30', 7.31, 8.13, 42, [['Sleep', 1.0]], []]
#
# ['bmvlK4qhAnU33', 8.19, 9.07, 48, [['Rest', 1.0]], []]
#
# ['bmvlK4qhAnU36', 9.09, 9.52, 43, [['Tumor', 1.0]], []]
#
# ['bmvlK4qhAnU42', 10.43, 11.27, 44, [['ShortnessOfBreath', 1.0]], []]
#
# ['bmvlK4qhAnU45', 11.29, 12.14, 45, [['Friend', 1.0]], []]
#
# ['bmvlK4qhAnU54', 13.45, 14.35, 50, [['Pain', 1.0]], []]
#
# ['bmvlK4qhAnU59', 15.14, 16.0, 46, [['LungCancer', 1.0]], []]
#
# ['bmvlK4qhAnU65', 16.5, 17.37, 47, [['Husband', 1.0]], []]
#
# ['bmvlK4qhAnU70', 18.16, 20.04, 108, [['LungCancer', 4.0]], [['Thinking', 1.0], ['Family', 1.0], ['Rest', 1.0]]]
#
# ['bmvlK4qhAnU77', 20.06, 21.28, 82, [['Friend', 2.0]], []]
#
# ['bmvlK4qhAnU87', 22.51, 23.19, 28, [['Rest', 1.0]], []]
#
# ['bmvlK4qhAnU92', 24.11, 25.03, 52, [['Treatment', 2.0]], [['Family', 1.0]]]
#
# ['wArV8Ho_C1A1', 0.13, 0.54, 41, [['Cough', 1.0]], []]
#
# ['wArV8Ho_C1A3', 0.55, 1.3, 34, [['Thinking', 1.0]], []]
#
# ['wArV8Ho_C1A8', 2.28, 3.01, 33, [['LungCancer', 1.0]], []]
#
# ['wArV8Ho_C1A10', 3.04, 3.51, 46, [['Husband', 1.0]], []]
#
# ['wArV8Ho_C1A12', 3.52, 4.22, 30, [['Family', 1.0]], []]
#
# ['ehh89UrZtZU12', 0.01, 4.07, 246, [['Copd', 8.0]], [['Smoking', 6.0], ['Cough', 1.0]]]
#
# ['VyGp12XbPzs1', 0.1, 0.54, 44, [['Pneumonia', 1.0]], []]
#
# ['VyGp12XbPzs4', 2.25, 3.23, 58, [['Hope', 2.0]], []]
#
# ['jZJTcp3d1q41', 0.11, 2.38, 147, [['Copd', 3.0]], [['DailyLiving', 1.0], ['Wife', 1.0], ['Exercise', 1.0]]]
#
# ['ZU_l9xCB-081', 0.04, 1.48, 104, [['Copd', 3.0]], [['Pneumonia', 1.0], ['Fear', 1.0], ['Mom', 1.0], ['Friend', 1.0]]]
#
# ['Nl55TpSjWp43', 0.42, 1.23, 41, [['Covid', 1.0]], []]
#
# ['Nl55TpSjWp45', 1.26, 2.19, 53, [['Husband', 1.0]], []]
#
# ['Nl55TpSjWp49', 3.0, 4.27, 86, [['Pneumonia', 2.0]], [['Rest', 1.0], ['Covid', 2.0], ['Copd', 1.0], ['LungDisease', 1.0]]]
#
# ['Nl55TpSjWp414', 4.3, 5.13, 43, [['Treatment', 1.0]], []]
#
# ['Nl55TpSjWp422', 7.11, 7.29, 17, [['Determination', 1.0]], []]
#
# ['6U7OpgFojaw3', 0.45, 1.41, 56, [['Cough', 1.0]], []]
#
# ['6U7OpgFojaw6', 1.43, 2.15, 32, [['Pneumonia', 1.0]], []]
#
# ['6U7OpgFojaw8', 2.16, 2.56, 40, [['Family', 1.0]], []]
#
# ['e0KVtXL-TjY1', 0.09, 0.5, 41, [['Christian', 1.0]], []]
#
# ['e0KVtXL-TjY7', 1.31, 2.09, 38, [['PulmonaryHypertension', 1.0]], []]
#
# ['aHAbRVZOxnk1', 0.06, 0.41, 35, [['Rest', 1.0]], []]
#
# ['aHAbRVZOxnk5', 1.19, 2.15, 56, [['Drug', 1.0]], []]
#
# ['aHAbRVZOxnk12', 3.43, 4.09, 26, [['Hope', 1.0]], []]
#
# ['im4bTtQ99SY1', 0.0, 2.03, 122, [['Vaping', 2.0]], [['Child', 2.0], ['Family', 1.0]]]
#
# ['GV3Rew061FA5', 1.31, 5.07, 216, [['Exercise', 7.0]], [['Glad', 1.0]]]
#
# ['Nxrz6_e_gwo1', 0.02, 2.34, 152, [['Copd', 5.0]], [['Rest', 1.0], ['Family', 2.0], ['Wheezing', 1.0], ['Exercise', 1.0]]]
#
# ['Nxrz6_e_gwo8', 2.39, 3.25, 46, [['Family', 1.0]], []]
#
# ['q9xteXsPy3c1', 0.0, 0.31, 31, [['Cough', 1.0]], []]
#
# ['q9xteXsPy3c2', 0.36, 1.09, 33, [['Guilt', 1.0]], []]
#
# ['q9xteXsPy3c3', 1.13, 1.44, 31, [['LungCancer', 1.0]], []]
#
# ['POskT8R_3t41', 0.0, 0.38, 38, [['PulmonaryHypertension', 1.0]], []]
#
# ['POskT8R_3t49', 2.57, 3.5, 53, [['Treatment', 1.0]], []]
#
# ['3Fker8Nmd5Y1', 0.05, 0.57, 51, [['LungDisease', 1.0]], []]
#
# ['OHeU3oj8nmc1', 0.0, 1.21, 81, [['Family', 2.0]], [['Gym', 1.0], ['Mum', 2.0], ['LungCancer', 1.0]]]
#
# ['OkHESl_I2O813', 4.39, 5.03, 24, [['Friend', 1.0]], []]
#
# ['r20Ak5ZxP_44', 0.54, 1.44, 50, [['Community', 1.0]], []]
#
# ['r20Ak5ZxP_47', 1.47, 2.29, 42, [['LungCancer', 1.0]], []]
#
# ['r20Ak5ZxP_443', 11.05, 11.52, 46, [['Treatment', 1.0]], []]
#
# ['r20Ak5ZxP_458', 11.55, 15.55, 240, [['Smoking', 7.0]], [['LungCancer', 3.0], ['Tension', 1.0], ['Family', 1.0], ['Education', 1.0]]]
#
# ['MjEJaR3zLjg4', 0.39, 1.2, 41, [['Husband', 1.0]], []]
#
# ['MjEJaR3zLjg7', 1.22, 1.59, 37, [['Treatment', 1.0]], []]
#
# ['MjEJaR3zLjg10', 2.01, 4.11, 130, [['Pneumonia', 2.0]], [['Asthma', 2.0], ['Mom', 1.0], ['LungCancer', 1.0], ['Tumor', 1.0]]]
#
# ['MjEJaR3zLjg19', 4.12, 4.51, 39, [['Family', 1.0]], []]
#
# ['MjEJaR3zLjg25', 5.34, 6.14, 39, [['Insurance', 1.0]], []]
#
# ['MjEJaR3zLjg33', 7.32, 8.12, 39, [['Anxiety', 1.0]], []]
#
# ['MjEJaR3zLjg39', 8.54, 10.0, 66, [['LungCancer', 2.0]], []]
#
# ['MjEJaR3zLjg52', 12.0, 12.38, 38, [['Family', 1.0]], []]
#
# ['MjEJaR3zLjg63', 14.48, 16.23, 95, [['Anxiety', 2.0]], [['Husband', 1.0], ['Pneumonia', 1.0], ['LungCancer', 1.0], ['Mom', 1.0]]]
#
# ['MjEJaR3zLjg71', 16.53, 18.54, 120, [['Tumor', 4.0]], [['LungCancer', 1.0], ['Treatment', 1.0]]]
#
# ['MjEJaR3zLjg80', 18.57, 19.2, 23, [['Family', 1.0]], []]
#
# ['MjEJaR3zLjg86', 20.12, 21.33, 80, [['Community', 2.0]], [['Mom', 1.0]]]
#
# ['MjEJaR3zLjg101', 23.36, 24.12, 36, [['LungCancer', 1.0]], []]
#
# ['MjEJaR3zLjg104', 24.14, 24.5, 36, [['Sleep', 1.0]], []]
#
# ['MjEJaR3zLjg107', 24.52, 27.31, 158, [['Family', 4.0]], [['Pneumonia', 1.0], ['Caregiver', 1.0], ['Child', 1.0]]]
#
# ['MjEJaR3zLjg121', 28.21, 28.32, 11, [['Treatment', 1.0]], []]
#
# ['KFBT8x3DPuM1', 0.0, 2.27, 147, [['Child', 4.0]], [['Community', 1.0], ['Family', 1.0], ['Grandchild', 1.0]]]
#
# ['HCgXqdpQGhc4', 0.47, 1.19, 32, [['Husband', 1.0]], []]
#
# ['HCgXqdpQGhc9', 2.06, 2.48, 42, [['LungCancer', 1.0]], []]
#
# ['HCgXqdpQGhc15', 3.36, 4.2, 44, [['Treatment', 1.0]], []]
#
# ['HCgXqdpQGhc27', 6.41, 8.28, 106, [['Husband', 2.0]], [['Exercise', 1.0], ['Thinking', 2.0]]]
#
# ['HCgXqdpQGhc35', 8.3, 9.18, 47, [['LungCancer', 1.0]], []]
#
# ['HCgXqdpQGhc39', 9.2, 10.0, 40, [['Anxiety', 1.0]], []]
#
# ['HCgXqdpQGhc45', 10.47, 11.35, 47, [['Drug', 1.0]], []]
#
# ['HCgXqdpQGhc54', 13.05, 13.41, 35, [['Pain', 1.0]], []]
#
# ['HCgXqdpQGhc57', 13.42, 14.27, 45, [['Husband', 1.0]], []]
#
# ['HCgXqdpQGhc60', 14.29, 15.07, 38, [['Friend', 1.0]], []]
#
# ['HCgXqdpQGhc77', 18.57, 19.46, 49, [['Husband', 1.0]], []]
#
# ['HCgXqdpQGhc80', 19.48, 22.04, 136, [['LungCancer', 2.0]], [['Pain', 1.0], ['Husband', 2.0], ['Family', 1.0], ['Treatment', 1.0]]]
#
# ['HCgXqdpQGhc90', 22.25, 23.52, 87, [['Treatment', 2.0]], []]
#
# ['E8nRS2LxFdw1', 0.0, 0.45, 45, [['Pain', 1.0]], []]
#
# ['E8nRS2LxFdw7', 1.3, 2.14, 44, [['Training', 1.0]], []]
#
# ['n7KHBGEC2Gg1', 0.0, 0.47, 47, [['Husband', 1.0]], []]
#
# ['n7KHBGEC2Gg10', 3.23, 4.17, 54, [['Wife', 1.0]], []]
#
# ['FHXbDHakK1w1', 0.01, 0.37, 36, [['LungCancer', 1.0]], []]
#
# ['FHXbDHakK1w6', 3.32, 4.12, 40, [['Rest', 1.0]], []]
#
# ['FHXbDHakK1w15', 10.13, 10.55, 42, [['LungCancer', 1.0]], []]
#
# ['FHXbDHakK1w16', 11.0, 11.39, 39, [['Community', 1.0]], []]
#
# ['FHXbDHakK1w20', 14.05, 14.42, 36, [['LungCancer', 1.0]], []]
#
# ['FHXbDHakK1w22', 15.3, 16.08, 37, [['LungCancer', 1.0]], []]
#
# ['FHXbDHakK1w23', 16.14, 16.5, 36, [['Gym', 1.0]], []]
#
# ['FHXbDHakK1w24', 16.56, 17.31, 34, [['Treatment', 1.0]], []]
#
# ['FHXbDHakK1w28', 19.5, 21.1, 80, [['Treatment', 2.0]], []]
#
# ['FHXbDHakK1w30', 21.15, 24.44, 209, [['Friend', 4.0]], [['Wife', 1.0], ['Rest', 1.0], ['Treatment', 1.0]]]
#
# ['FHXbDHakK1w39', 27.52, 28.27, 35, [['Scared', 1.0]], []]
#
# ['FHXbDHakK1w40', 28.32, 29.09, 37, [['LungCancer', 1.0]], []]
#
# ['WShT-I0wCO46', 1.27, 2.01, 33, [['LungCancer', 1.0]], []]
#
# ['WShT-I0wCO48', 2.04, 2.4, 36, [['Wife', 1.0]], []]
#
# ['WShT-I0wCO410', 2.44, 3.34, 50, [['Treatment', 1.0]], []]
#
# ['WShT-I0wCO420', 5.39, 6.29, 50, [['Treatment', 1.0]], []]
#
# ['2utaepga5uk1', 0.0, 0.38, 38, [['Pain', 1.0]], []]
#
# ['2utaepga5uk3', 0.47, 2.29, 102, [['Treatment', 2.0]], [['Friend', 1.0]]]
#
# ['2utaepga5uk11', 3.22, 4.09, 46, [['Thinking', 1.0]], []]
#
# ['2utaepga5uk18', 5.34, 5.43, 9, [['Thinking', 1.0]], []]
#
# ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, [['Energy', 1.0]], []]
#
# ['dyRmGVgG7_84', 0.47, 1.17, 30, [['Copd', 1.0]], []]
#
# ['aREqsWoX-EY8', 2.2, 3.04, 43, [['Family', 1.0]], []]
#
# ['9nRhehMpODk8', 2.11, 2.59, 48, [['Hope', 1.0]], []]
#
# ['Tyo2YsA0Y02', 0.43, 1.19, 36, [['Hope', 1.0]], []]
#
# ['ZoEEgU6L-m85', 1.47, 2.35, 48, [['Treatment', 1.0]], []]
#
# ['ZoEEgU6L-m87', 2.39, 3.29, 50, [['Exercise', 1.0]], []]
#
# ['FH7aHDHnkjU7', 1.36, 2.06, 30, [['Exercise', 1.0]], []]
#
# ['FH7aHDHnkjU9', 2.08, 2.57, 49, [['Wife', 1.0]], []]
#
# ['FH7aHDHnkjU14', 3.35, 4.22, 47, [['Exercise', 1.0]], []]
#
# ['323hkORG0OM1', 0.02, 0.37, 35, [['Smoking', 1.0]], []]
#
# ['323hkORG0OM3', 0.4, 1.57, 77, [['Tumor', 2.0]], []]
#
# ['LYwQdM-2ok41', 0.0, 2.27, 147, [['LungCancer', 5.0]], [['Treatment', 1.0], ['Tumor', 1.0], ['Mom', 1.0], ['Bronchitis', 1.0]]]
#
# ['LYwQdM-2ok411', 3.12, 3.26, 13, [['Insurance', 1.0]], []]
#
# ['O5DOre3MFlw8', 2.31, 3.12, 41, [['Rest', 1.0]], []]
#
# ['O5DOre3MFlw12', 4.0, 4.48, 48, [['Friend', 1.0]], []]
#
# ['O5DOre3MFlw22', 8.07, 8.57, 50, [['Family', 1.0]], []]
#
# ['O5DOre3MFlw24', 9.0, 9.44, 44, [['Exercise', 1.0]], []]
#
# ['O5DOre3MFlw26', 9.49, 10.39, 50, [['Friend', 1.0]], []]
#
# ['O5DOre3MFlw30', 11.37, 13.14, 97, [['Noise', 3.0]], []]
#
# ['O5DOre3MFlw35', 13.5, 14.26, 36, [['Noise', 1.0]], []]
#
# ['O5DOre3MFlw37', 14.33, 15.22, 49, [['Energy', 1.0]], []]
#
# ['O5DOre3MFlw39', 15.3, 16.18, 47, [['Friend', 1.0]], []]
#
# ['O5DOre3MFlw43', 17.04, 17.59, 55, [['Dad', 1.0]], []]
#
# ['O5DOre3MFlw49', 19.55, 20.35, 40, [['Friend', 1.0]], []]
#
# ['O5DOre3MFlw65', 25.45, 26.21, 36, [['Caregiver', 1.0]], []]
#
# ['O5DOre3MFlw69', 27.06, 27.5, 44, [['Scared', 1.0]], []]
#
# ['bqkquNb5Z8A1', 0.03, 0.41, 38, [['Pain', 1.0]], []]
#
# ['bqkquNb5Z8A10', 2.47, 3.31, 43, [['Drug', 1.0]], []]
#
# ['bqkquNb5Z8A13', 3.33, 4.04, 31, [['Pain', 1.0]], []]
#
# ['qsAnlV8DUXo1', 0.0, 0.42, 42, [['PulmonaryFibrosis', 1.0]], []]
#
# ['qsAnlV8DUXo4', 0.47, 1.31, 44, [['Family', 1.0]], []]
#
# ['2pzHkvmRSW86', 1.38, 2.24, 46, [['Friend', 1.0]], []]
#
# ['2pzHkvmRSW812', 3.19, 3.53, 33, [['LungDisease', 1.0]], []]
#
# Seg with Two FC
# *******************************************************
#
# ['MxmrjLQvg7E12', 2.34, 3.25, 51, [['LungCancer', 1.0], ['Energy', 1.0]], []]
#
# ['mWo-G3UQ-zU1', 0.0, 2.16, 136, [['Dad', 3.0], ['Temple', 2.0]], [['Family', 1.0], ['Energy', 1.0]]]
#
# ['mWo-G3UQ-zU6', 2.22, 2.31, 8, [['Dad', 1.0], ['Hope', 1.0]], []]
#
# ['hQQ5xQGZxdA46', 10.12, 10.47, 35, [['Friend', 1.0], ['LungCancer', 1.0]], []]
#
# ['hQQ5xQGZxdA64', 14.03, 14.43, 40, [['Pain', 1.0], ['Caregiver', 1.0]], []]
#
# ['xY3B9nLm1u81', 0.0, 1.13, 72, [['Sleep', 2.0], ['Pain', 2.0]], [['Wife', 1.0], ['LungCancer', 1.0]]]
#
# ['xY3B9nLm1u818', 4.37, 5.16, 39, [['Pain', 1.0], ['Hope', 1.0]], []]
#
# ['wwiwjZw7d6o1', 0.17, 1.12, 55, [['Mum', 2.0], ['Family', 2.0]], [['Learning', 1.0], ['Friend', 1.0], ['Hope', 1.0]]]
#
# ['wwiwjZw7d6o5', 1.14, 3.12, 118, [['Treatment', 2.0], ['Fear', 3.0]], [['Scared', 1.0], ['Child', 1.0], ['Hope', 1.0]]]
#
# ['uJoY4oMLXEY3', 0.46, 1.35, 49, [['Copd', 1.0], ['Pneumonia', 1.0]], []]
#
# ['l9k9q6FHeX415', 3.15, 5.1, 114, [['Pain', 3.0], ['Cough', 2.0]], [['ChestPain', 1.0], ['Bronchitis', 1.0]]]
#
# ['l9k9q6FHeX432', 6.51, 7.51, 60, [['Thinking', 2.0], ['Smoking', 1.0]], []]
#
# ['l9k9q6FHeX456', 11.45, 12.31, 46, [['Family', 1.0], ['Mom', 1.0]], []]
#
# ['l9k9q6FHeX475', 15.55, 16.31, 35, [['Treatment', 1.0], ['Family', 1.0]], []]
#
# ['l9k9q6FHeX487', 18.31, 19.17, 46, [['Friend', 1.0], ['Treatment', 1.0]], []]
#
# ['j3t5nFnTULQ3', 0.56, 1.46, 49, [['LungDisease', 1.0], ['Treatment', 1.0]], []]
#
# ['tfxB32Vb5hE1', 0.02, 1.39, 97, [['LungCancer', 3.0], ['Treatment', 2.0]], []]
#
# ['HBFn82ffSVE7', 1.38, 2.33, 55, [['LungCancer', 1.0], ['Tumor', 2.0]], []]
#
# ['HBFn82ffSVE25', 6.15, 6.4, 25, [['Pneumonia', 1.0], ['Rest', 1.0]], []]
#
# ['llk-qgIr9Nk1', 0.01, 0.39, 38, [['Family', 1.0], ['Treatment', 1.0]], []]
#
# ['llk-qgIr9Nk56', 13.03, 13.52, 49, [['LungCancer', 1.0], ['Treatment', 1.0]], []]
#
# ['llk-qgIr9Nk116', 26.54, 27.37, 43, [['Insurance', 1.0], ['LungCancer', 1.0]], []]
#
# ['llk-qgIr9Nk119', 27.39, 28.16, 37, [['Church', 1.0], ['Safety', 1.0]], []]
#
# ['llk-qgIr9Nk158', 36.33, 37.2, 47, [['Anxiety', 1.0], ['Sleep', 1.0]], []]
#
# ['bmvlK4qhAnU1', 0.0, 0.47, 47, [['Husband', 1.0], ['Tumor', 1.0]], []]
#
# ['bmvlK4qhAnU4', 0.5, 3.08, 138, [['LungCancer', 3.0], ['Hope', 3.0]], []]
#
# ['bmvlK4qhAnU84', 22.02, 22.48, 46, [['Husband', 1.0], ['Dad', 1.0]], []]
#
# ['bmvlK4qhAnU89', 23.24, 24.09, 45, [['Thinking', 1.0], ['Strength', 1.0]], []]
#
# ['bmvlK4qhAnU92', 24.11, 24.55, 44, [['Family', 1.0], ['Treatment', 1.0]], []]
#
# ['jZJTcp3d1q413', 3.57, 4.22, 25, [['Community', 1.0], ['Family', 2.0]], []]
#
# ['Nl55TpSjWp416', 5.17, 6.46, 89, [['Pneumonia', 3.0], ['Rest', 1.0]], []]
#
# ['e0KVtXL-TjY10', 2.11, 2.54, 43, [['Strength', 1.0], ['Child', 1.0]], []]
#
# ['aHAbRVZOxnk3', 0.43, 1.17, 34, [['PulmonaryFibrosis', 1.0], ['Pneumonia', 1.0]], []]
#
# ['aHAbRVZOxnk10', 2.58, 3.39, 41, [['Treatment', 1.0], ['Rehabilitation', 1.0]], []]
#
# ['im4bTtQ99SY9', 2.06, 2.47, 41, [['Drug', 1.0], ['Friend', 1.0]], []]
#
# ['GV3Rew061FA1', 0.02, 1.29, 87, [['Copd', 2.0], ['Smoking', 2.0]], [['Exercise', 1.0], ['Pneumonia', 1.0]]]
#
# ['Nxrz6_e_gwo10', 3.3, 4.16, 46, [['Copd', 1.0], ['Thinking', 1.0]], []]
#
# ['POskT8R_3t43', 0.42, 1.43, 61, [['Rest', 2.0], ['ShortnessOfBreath', 1.0]], []]
#
# ['3Fker8Nmd5Y8', 2.2, 2.54, 33, [['Family', 1.0], ['Child', 2.0]], []]
#
# ['OHeU3oj8nmc7', 1.23, 2.08, 45, [['Smoking', 1.0], ['Cough', 1.0]], []]
#
# ['OHeU3oj8nmc14', 2.52, 3.34, 42, [['Dad', 1.0], ['LungCancer', 1.0]], []]
#
# ['OkHESl_I2O83', 0.51, 1.26, 35, [['Family', 1.0], ['Friend', 1.0]], []]
#
# ['4AWZD3ClqW81', 0.08, 2.14, 126, [['EndOfLifeCare', 2.0], ['Friend', 2.0]], [['PulmonaryFibrosis', 1.0], ['Exercise', 1.0], ['Family', 1.0], ['Wife', 1.0]]]
#
# ['r20Ak5ZxP_41', 0.05, 0.52, 47, [['Hope', 1.0], ['Learning', 1.0]], []]
#
# ['r20Ak5ZxP_413', 3.19, 4.02, 42, [['Fatigue', 1.0], ['Scared', 2.0]], []]
#
# ['r20Ak5ZxP_419', 4.47, 5.3, 43, [['Pneumonia', 1.0], ['Cough', 1.0]], []]
#
# ['r20Ak5ZxP_430', 7.36, 8.21, 45, [['Anxiety', 1.0], ['Cough', 1.0]], []]
#
# ['MjEJaR3zLjg60', 14.03, 14.46, 43, [['Exercise', 1.0], ['Thinking', 1.0]], []]
#
# ['HCgXqdpQGhc1', 0.01, 0.44, 43, [['Hope', 1.0], ['LungCancer', 1.0]], []]
#
# ['HCgXqdpQGhc66', 15.55, 16.39, 43, [['Learning', 1.0], ['Caregiver', 1.0]], []]
#
# ['HCgXqdpQGhc98', 24.25, 26.04, 99, [['Drug', 2.0], ['Treatment', 3.0]], [['Hope', 1.0], ['Thinking', 1.0]]]
#
# ['FHXbDHakK1w7', 4.2, 7.07, 167, [['Wife', 2.0], ['Thinking', 2.0]], [['ShortnessOfBreath', 3.0]]]
#
# ['FHXbDHakK1w11', 7.12, 8.36, 84, [['Wheezing', 1.0], ['Bronchitis', 2.0]], []]
#
# ['FHXbDHakK1w26', 18.22, 19.0, 38, [['Family', 1.0], ['Strength', 1.0]], []]
#
# ['FHXbDHakK1w36', 25.34, 28.27, 173, [['Treatment', 2.0], ['LungCancer', 3.0]], [['Drug', 1.0], ['Scared', 1.0]]]
#
# ['WShT-I0wCO41', 0.0, 0.5, 50, [['Pain', 1.0], ['Drug', 1.0]], []]
#
# ['WShT-I0wCO418', 5.06, 5.37, 31, [['Concentration', 1.0], ['Strength', 1.0]], []]
#
# ['2utaepga5uk14', 4.11, 4.53, 41, [['Family', 1.0], ['Friend', 1.0]], []]
#
# ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, [['Husband', 2.0], ['LungCancer', 3.0]], [['Hope', 1.0], ['Energy', 1.0]]]
#
# ['dyRmGVgG7_86', 1.19, 2.17, 58, [['LungCancer', 1.0], ['Drug', 1.0]], []]
#
# ['aREqsWoX-EY1', 0.05, 1.0, 55, [['Wife', 1.0], ['LungCancer', 1.0]], []]
#
# ['Tyo2YsA0Y01', 0.05, 0.38, 33, [['Treatment', 1.0], ['LungCancer', 1.0]], []]
#
# ['Tyo2YsA0Y03', 1.25, 2.49, 84, [['Energy', 1.0], ['Treatment', 2.0]], []]
#
# ['ZoEEgU6L-m89', 3.31, 4.54, 83, [['Child', 2.0], ['Thinking', 1.0]], []]
#
# ['FH7aHDHnkjU17', 4.24, 4.45, 21, [['Family', 1.0], ['Rest', 1.0]], []]
#
# ['cfyb39S_CZw1', 0.06, 1.19, 73, [['LungCancer', 3.0], ['Smoking', 1.0]], []]
#
# ['cfyb39S_CZw7', 2.07, 2.4, 33, [['LungCancer', 1.0], ['Grandchild', 1.0]], []]
#
# ['mSYXddFVvHo4', 0.52, 1.28, 36, [['Belief', 1.0], ['Hope', 1.0]], []]
#
# ['323hkORG0OM9', 2.19, 2.31, 12, [['LungCancer', 1.0], ['Treatment', 1.0]], []]
#
# ['O5DOre3MFlw3', 0.36, 2.27, 111, [['Mom', 3.0], ['Child', 1.0]], []]
#
# Seg with More than 3 FC
# *******************************************************
# ['MxmrjLQvg7E1', 0.0, 0.4, 40, [['Thinking', 1.0], ['Mum', 2.0], ['Treatment', 1.0]], []]
#
# ['MxmrjLQvg7E4', 0.43, 1.24, 41, [['LungCancer', 1.0], ['Pain', 1.0], ['Training', 1.0]], []]
#
# ['rQutyErqBG012', 3.25, 4.01, 35, [['Treatment', 1.0], ['Pain', 1.0], ['Noise', 1.0], ['Child', 1.0]], []]
#
# ['hQQ5xQGZxdA1', 0.01, 1.23, 82, [['Caregiver', 2.0], ['LungCancer', 2.0], ['Treatment', 1.0]], []]
#
# ['hQQ5xQGZxdA40', 8.48, 10.1, 82, [['Wife', 1.0], ['Community', 2.0], ['Tumor', 1.0]], []]
#
# ['xY3B9nLm1u88', 1.54, 3.5, 116, [['Pain', 3.0], ['Sleep', 1.0], ['Thinking', 1.0]], []]
#
# ['l9k9q6FHeX44', 0.4, 1.22, 42, [['Child', 1.0], ['LungCancer', 1.0], ['Education', 1.0]], []]
#
# ['HBFn82ffSVE3', 0.35, 1.35, 60, [['Pneumonia', 2.0], ['Rest', 1.0], ['Thinking', 1.0]], []]
#
# ['llk-qgIr9Nk41', 9.36, 10.13, 37, [['Mom', 1.0], ['Sleep', 1.0], ['Exercise', 1.0]], []]
#
# ['llk-qgIr9Nk77', 18.02, 18.39, 37, [['Family', 1.0], ['Husband', 1.0], ['Insurance', 1.0]], []]
#
# ['bmvlK4qhAnU12', 3.1, 3.5, 40, [['Wife', 1.0], ['Mom', 1.0], ['Education', 1.0], ['Community', 1.0]], []]
#
# ['wArV8Ho_C1A5', 1.34, 2.26, 51, [['Mum', 1.0], ['Energy', 1.0], ['Sleep', 1.0]], []]
#
# ['VyGp12XbPzs2', 0.59, 2.2, 81, [['Exercise', 2.0], ['Strength', 1.0], ['Treatment', 1.0]], []]
#
# ['q9xteXsPy3c4', 1.5, 3.05, 74, [['Family', 2.0], ['Tumor', 1.0], ['Friend', 1.0], ['Training', 1.0]], []]
#
# ['q9xteXsPy3c6', 3.11, 4.1, 58, [['Mom', 1.0], ['Friend', 1.0], ['LungCancer', 1.0]], []]
#
# ['OHeU3oj8nmc20', 4.15, 4.49, 33, [['Gym', 1.0], ['Grandchild', 2.0], ['Thinking', 1.0]], []]
#
# ['4AWZD3ClqW85', 3.01, 3.44, 43, [['Exercise', 1.0], ['MentalHealth', 2.0], ['Family', 1.0]], []]
#
# ['r20Ak5ZxP_416', 4.03, 4.46, 42, [['Husband', 1.0], ['LungCancer', 1.0], ['Energy', 1.0]], []]
#
# ['MjEJaR3zLjg1', 0.01, 0.36, 35, [['Hope', 1.0], ['Glad', 1.0], ['Caregiver', 1.0], ['LungCancer', 1.0]], []]
#
# ['HCgXqdpQGhc105', 26.06, 26.49, 43, [['Caregiver', 1.0], ['Friend', 1.0], ['LungCancer', 1.0]], []]
#
# ['E8nRS2LxFdw4', 0.46, 1.29, 43, [['Alcohol', 1.0], ['Diet', 1.0], ['Treatment', 1.0]], []]
#
# ['FHXbDHakK1w4', 2.06, 3.26, 79, [['Wife', 1.0], ['Family', 2.0], ['Rest', 1.0]], []]
#
# ['FHXbDHakK1w13', 8.43, 10.08, 85, [['Insurance', 1.0], ['Pneumonia', 2.0], ['Anxiety', 1.0]], []]
#
# ['FHXbDHakK1w44', 31.33, 32.47, 74, [['Anxiety', 2.0], ['Wife', 1.0], ['Treatment', 1.0]], []]
#
# ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, [['LungCancer', 1.0], ['Mom', 1.0], ['Pain', 1.0]], []]
#
# ['dyRmGVgG7_89', 2.2, 3.02, 41, [['Gym', 1.0], ['Treatment', 1.0], ['Thinking', 1.0]], []]
#
# ['9nRhehMpODk3', 0.39, 1.3, 51, [['Hope', 1.0], ['Treatment', 1.0], ['Pain', 1.0]], []]
#
# ['Tyo2YsA0Y05', 2.52, 3.51, 58, [['LungCancer', 1.0], ['Family', 1.0], ['Fear', 1.0], ['Hope', 1.0]], []]
#
# ['ZoEEgU6L-m81', 0.11, 1.02, 51, [['Energy', 1.0], ['LungCancer', 1.0], ['Strength', 1.0]], []]
#
# ['FH7aHDHnkjU1', 0.03, 1.34, 91, [['PulmonaryFibrosis', 3.0], ['Mobility', 1.0], ['Cough', 1.0]], []]
#
# ['cfyb39S_CZw5', 1.2, 2.05, 44, [['Hope', 1.0], ['Scared', 1.0], ['Wife', 1.0]], []]
#
# ['mSYXddFVvHo1', 0.03, 0.5, 47, [['LungDisease', 1.0], ['Exercise', 1.0], ['Family', 1.0], ['Training', 2.0]], []]
#
# ['LYwQdM-2ok49', 2.32, 3.08, 36, [['Tumor', 1.0], ['Drug', 1.0], ['Pain', 1.0]], []]
#
# ['O5DOre3MFlw16', 5.44, 7.33, 108, [['Dad', 2.0], ['Mom', 1.0], ['Family', 1.0]], []]

# %%
from numpy import nan
conceptsPath=pd.read_excel("ontologyConcepts.xlsx",sheet_name ="Sheet1") 
cleanedParents2=[]
for i in conceptsPath:
    print(i)

con1=list(conceptsPath['Concept'])



con2=list(conceptsPath['Unnamed: 1'])

con3=list(conceptsPath['Unnamed: 2'])

con4=list(conceptsPath['Topic'])



for i in range(0,len(con1)):
    
    cleanedParents2.append([con1[i],con2[i],con3[i],con4[i]])

cleanedP=[]
for i in cleanedParents2:
    print(i)
    print([item for item in i if not(pd.isnull(item)) == True])
    print('*******************************************')
    cleanedP.append([item for item in i if not(pd.isnull(item)) == True])
cleanedParents2=cleanedP
for i in cleanedParents2:
    print(i)
    print()
# Out:
# Concept
# Unnamed: 1
# Unnamed: 2
# Topic
# ['AcquiringInformation', nan, nan, 'Environment']
# ['AcquiringInformation', 'Environment']
# *******************************************
# ['Behaviour', nan, nan, 'PhysicalHealth']
# ['Behaviour', 'PhysicalHealth']
# *******************************************
# ['BodyImage', nan, nan, 'PsychologicalHealth']
# ['BodyImage', 'PsychologicalHealth']
# *******************************************
# ['CognitiveFunction', nan, nan, 'PsychologicalHealth']
# ['CognitiveFunction', 'PsychologicalHealth']
# *******************************************
# ['DailyLiving', nan, nan, 'LevelOfIndependence']
# ['DailyLiving', 'LevelOfIndependence']
# *******************************************
# ['Diet', 'Behaviour', nan, 'PhysicalHealth']
# ['Diet', 'Behaviour', 'PhysicalHealth']
# *******************************************
# ['EconomicStatus', nan, nan, 'Environment']
# ['EconomicStatus', 'Environment']
# *******************************************
# ['Energy', nan, nan, 'PhysicalHealth']
# ['Energy', 'PhysicalHealth']
# *******************************************
# [nan, nan, nan, 'Environment']
# ['Environment']
# *******************************************
# ['FinancialIssue', nan, nan, 'LevelOfIndependence']
# ['FinancialIssue', 'LevelOfIndependence']
# *******************************************
# ['LegalIssue', nan, nan, 'LevelOfIndependence']
# ['LegalIssue', 'LevelOfIndependence']
# *******************************************
# [nan, nan, nan, 'LevelOfIndependence']
# ['LevelOfIndependence']
# *******************************************
# ['MedicalSelfCare', nan, nan, 'LevelOfIndependence']
# ['MedicalSelfCare', 'LevelOfIndependence']
# *******************************************
# ['Mobility', nan, nan, 'LevelOfIndependence']
# ['Mobility', 'LevelOfIndependence']
# *******************************************
# ['NegativeFeeling', nan, nan, 'PsychologicalHealth']
# ['NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['OtherSymptoms', 'PhysicalSymptoms', nan, 'PhysicalHealth']
# ['OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Pain', 'PhysicalSymptoms', nan, 'PhysicalHealth']
# ['Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['PersonalRelationship', nan, nan, 'SocialRelationship']
# ['PersonalRelationship', 'SocialRelationship']
# *******************************************
# [nan, nan, nan, 'PersonalValuesAndBeliefs']
# ['PersonalValuesAndBeliefs']
# *******************************************
# ['PhysicalEnvironment', nan, nan, 'Environment']
# ['PhysicalEnvironment', 'Environment']
# *******************************************
# [nan, nan, nan, 'PhysicalHealth']
# ['PhysicalHealth']
# *******************************************
# ['PhysicalSymptoms', nan, nan, 'PhysicalHealth']
# ['PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['PositiveFeeling', nan, nan, 'PsychologicalHealth']
# ['PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# [nan, nan, nan, 'PsychologicalHealth']
# ['PsychologicalHealth']
# *******************************************
# ['Rehabilitation', nan, nan, 'Environment']
# ['Rehabilitation', 'Environment']
# *******************************************
# ['Religion', nan, nan, 'PersonalValuesAndBeliefs']
# ['Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['RespiratoryIllness', nan, nan, 'PhysicalHealth']
# ['RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['RespiratoryIllnessSymptoms', 'PhysicalSymptoms', nan, 'PhysicalHealth']
# ['RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Rest', nan, nan, 'PhysicalHealth']
# ['Rest', 'PhysicalHealth']
# *******************************************
# ['SocialActivity', nan, nan, 'SocialRelationship']
# ['SocialActivity', 'SocialRelationship']
# *******************************************
# ['SocialCare', nan, nan, 'Environment']
# ['SocialCare', 'Environment']
# *******************************************
# [nan, nan, nan, 'SocialRelationship']
# ['SocialRelationship']
# *******************************************
# ['Spirituality', nan, nan, 'PersonalValuesAndBeliefs']
# ['Spirituality', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Treatment', nan, nan, 'LevelOfIndependence']
# ['Treatment', 'LevelOfIndependence']
# *******************************************
# ['WorkCapacity', nan, nan, 'LevelOfIndependence']
# ['WorkCapacity', 'LevelOfIndependence']
# *******************************************
# ['AccessToGreenSpace', 'PhysicalEnvironment', nan, 'Environment']
# ['AccessToGreenSpace', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['Accessibility', 'WorkCapacity', nan, 'LevelOfIndependence']
# ['Accessibility', 'WorkCapacity', 'LevelOfIndependence']
# *******************************************
# ['AccessibiltyOfSocial', 'SocialCare', nan, 'Environment']
# ['AccessibiltyOfSocial', 'SocialCare', 'Environment']
# *******************************************
# ['Aching', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Aching', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['AcutePain', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# ['AcutePain', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['AddressingMinorAilments', 'MedicalSelfCare', nan, 'LevelOfIndependence']
# ['AddressingMinorAilments', 'MedicalSelfCare', 'LevelOfIndependence']
# *******************************************
# ['Alcohol', 'Behaviour', nan, 'PhysicalHealth']
# ['Alcohol', 'Behaviour', 'PhysicalHealth']
# *******************************************
# ['Anger', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Anger', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Anxiety', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Anxiety', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Appearance', 'BodyImage', nan, 'PsychologicalHealth']
# ['Appearance', 'BodyImage', 'PsychologicalHealth']
# *******************************************
# ['AppetiteLoss', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['AppetiteLoss', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Apprehension', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Apprehension', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Asthma', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['Asthma', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['Bathing', 'DailyLiving', nan, 'LevelOfIndependence']
# ['Bathing', 'DailyLiving', 'LevelOfIndependence']
# *******************************************
# ['Belief', 'Spirituality', nan, 'PersonalValuesAndBeliefs']
# ['Belief', 'Spirituality', 'PersonalValuesAndBeliefs']
# *******************************************
# ['BowelIssues', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['BowelIssues', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Breathlessness', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Breathlessness', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Bronchitis', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['Bronchitis', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['Buddhism', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['Buddhism', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['CareInformation', 'AcquiringInformation', nan, 'Environment']
# ['CareInformation', 'AcquiringInformation', 'Environment']
# *******************************************
# ['CarePlan', 'LegalIssue', nan, 'LevelOfIndependence']
# ['CarePlan', 'LegalIssue', 'LevelOfIndependence']
# *******************************************
# ['Caregiver', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Caregiver', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['CaregiverAssistance', 'DailyLiving', nan, 'LevelOfIndependence']
# ['CaregiverAssistance', 'DailyLiving', 'LevelOfIndependence']
# *******************************************
# ['ChestPain', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['ChestPain', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['Child', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Child', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Christian', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['Christian', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['ChronicPain', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# ['ChronicPain', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Church', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['Church', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Climate', 'PhysicalEnvironment', nan, 'Environment']
# ['Climate', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['Community', 'SocialActivity', nan, 'SocialRelationship']
# ['Community', 'SocialActivity', 'SocialRelationship']
# *******************************************
# ['ComplexMedication', 'Treatment', nan, 'LevelOfIndependence']
# ['ComplexMedication', 'Treatment', 'LevelOfIndependence']
# *******************************************
# ['Concentration', 'CognitiveFunction', nan, 'PsychologicalHealth']
# ['Concentration', 'CognitiveFunction', 'PsychologicalHealth']
# *******************************************
# ['Copd', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['Copd', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['Cough', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Cough', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Covid', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['Covid', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['CulturalFactors', 'SocialActivity', nan, 'SocialRelationship']
# ['CulturalFactors', 'SocialActivity', 'SocialRelationship']
# *******************************************
# ['Dad', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Dad', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Depression', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Depression', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Determination', 'PositiveFeeling', nan, 'PsychologicalHealth']
# ['Determination', 'PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# ['Diarrhea', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Diarrhea', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Digestion', 'Diet', 'Behaviour', 'PhysicalHealth']
# ['Digestion', 'Diet', 'Behaviour', 'PhysicalHealth']
# *******************************************
# ['Dirt', 'PhysicalEnvironment', nan, 'Environment']
# ['Dirt', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['DisableAccess', 'Mobility', nan, 'LevelOfIndependence']
# ['DisableAccess', 'Mobility', 'LevelOfIndependence']
# *******************************************
# ['Discomfort', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Discomfort', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Drowsiness', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Drowsiness', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Drug', 'Behaviour', nan, 'PhysicalHealth']
# ['Drug', 'Behaviour', 'PhysicalHealth']
# *******************************************
# ['Dyspnea', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Dyspnea', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Education', 'EconomicStatus', nan, 'Environment']
# ['Education', 'EconomicStatus', 'Environment']
# *******************************************
# ['EndOfLifeCare', 'LegalIssue', nan, 'LevelOfIndependence']
# ['EndOfLifeCare', 'LegalIssue', 'LevelOfIndependence']
# *******************************************
# ['Endurance', 'Energy', nan, 'PhysicalHealth']
# ['Endurance', 'Energy', 'PhysicalHealth']
# *******************************************
# ['EquipmentCost', 'FinancialIssue', nan, 'LevelOfIndependence']
# ['EquipmentCost', 'FinancialIssue', 'LevelOfIndependence']
# *******************************************
# ['Excitement', 'PositiveFeeling', nan, 'PsychologicalHealth']
# ['Excitement', 'PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# ['Exercise', 'Rehabilitation', nan, 'Environment']
# ['Exercise', 'Rehabilitation', 'Environment']
# *******************************************
# ['Existentiality', 'Spirituality', nan, 'PersonalValuesAndBeliefs']
# ['Existentiality', 'Spirituality', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Family', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Family', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Fatigue', 'Energy', nan, 'PhysicalHealth']
# ['Fatigue', 'Energy', 'PhysicalHealth']
# *******************************************
# ['Fear', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Fear', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Fever', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Fever', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['FinancialSchemes', 'FinancialIssue', nan, 'LevelOfIndependence']
# ['FinancialSchemes', 'FinancialIssue', 'LevelOfIndependence']
# *******************************************
# ['Flexibility', 'Energy', nan, 'PhysicalHealth']
# ['Flexibility', 'Energy', 'PhysicalHealth']
# *******************************************
# ['FlexibleWorking', 'WorkCapacity', nan, 'LevelOfIndependence']
# ['FlexibleWorking', 'WorkCapacity', 'LevelOfIndependence']
# *******************************************
# ['FluidIntake', 'Diet', 'Behaviour', 'PhysicalHealth']
# ['FluidIntake', 'Diet', 'Behaviour', 'PhysicalHealth']
# *******************************************
# ['FoodPreparation', 'DailyLiving', nan, 'LevelOfIndependence']
# ['FoodPreparation', 'DailyLiving', 'LevelOfIndependence']
# *******************************************
# ['Friend', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Friend', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['FuneralPlan', 'LegalIssue', nan, 'LevelOfIndependence']
# ['FuneralPlan', 'LegalIssue', 'LevelOfIndependence']
# *******************************************
# ['Furious', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Furious', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Glad', 'PositiveFeeling', nan, 'PsychologicalHealth']
# ['Glad', 'PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# ['Grandchild', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Grandchild', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Grief', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Grief', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Guilt', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Guilt', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Gym', 'Rehabilitation', nan, 'Environment']
# ['Gym', 'Rehabilitation', 'Environment']
# *******************************************
# ['HeartBroken', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['HeartBroken', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Hinduism', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['Hinduism', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Hope', 'PositiveFeeling', nan, 'PsychologicalHealth']
# ['Hope', 'PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# ['Hopelessness', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Hopelessness', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Humorous', 'PositiveFeeling', nan, 'PsychologicalHealth']
# ['Humorous', 'PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# ['Husband', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Husband', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Hypochondriac', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Hypochondriac', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Income', 'EconomicStatus', nan, 'Environment']
# ['Income', 'EconomicStatus', 'Environment']
# *******************************************
# ['Inheritance', 'LegalIssue', nan, 'LevelOfIndependence']
# ['Inheritance', 'LegalIssue', 'LevelOfIndependence']
# *******************************************
# ['Injuries', 'MedicalSelfCare', nan, 'LevelOfIndependence']
# ['Injuries', 'MedicalSelfCare', 'LevelOfIndependence']
# *******************************************
# ['Insomnia', 'Rest', nan, 'PhysicalHealth']
# ['Insomnia', 'Rest', 'PhysicalHealth']
# *******************************************
# ['Insurance', 'LegalIssue', nan, 'LevelOfIndependence']
# ['Insurance', 'LegalIssue', 'LevelOfIndependence']
# *******************************************
# ['Irritability', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Irritability', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Jewish', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['Jewish', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['LanguageDifficulty', 'SocialActivity', nan, 'SocialRelationship']
# ['LanguageDifficulty', 'SocialActivity', 'SocialRelationship']
# *******************************************
# ['Learning', 'CognitiveFunction', nan, 'PsychologicalHealth']
# ['Learning', 'CognitiveFunction', 'PsychologicalHealth']
# *******************************************
# ['Leisure', 'Rehabilitation', nan, 'Environment']
# ['Leisure', 'Rehabilitation', 'Environment']
# *******************************************
# ['LossOfIncome', 'FinancialIssue', nan, 'LevelOfIndependence']
# ['LossOfIncome', 'FinancialIssue', 'LevelOfIndependence']
# *******************************************
# ['LossOfInterest', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['LossOfInterest', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['LossOfPleasure', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['LossOfPleasure', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Loving', 'PositiveFeeling', nan, 'PsychologicalHealth']
# ['Loving', 'PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# ['LoweringOfMood', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['LoweringOfMood', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['LungCancer', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['LungCancer', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['LungDisease', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['LungDisease', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['MedicalAid', 'Treatment', nan, 'LevelOfIndependence']
# ['MedicalAid', 'Treatment', 'LevelOfIndependence']
# *******************************************
# ['MedicalInformation', 'AcquiringInformation', nan, 'Environment']
# ['MedicalInformation', 'AcquiringInformation', 'Environment']
# *******************************************
# ['MedicineCost', 'FinancialIssue', nan, 'LevelOfIndependence']
# ['MedicineCost', 'FinancialIssue', 'LevelOfIndependence']
# *******************************************
# ['MedicineIntake', 'Treatment', nan, 'LevelOfIndependence']
# ['MedicineIntake', 'Treatment', 'LevelOfIndependence']
# *******************************************
# ['Meditation', 'Spirituality', nan, 'PersonalValuesAndBeliefs']
# ['Meditation', 'Spirituality', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Memory', 'CognitiveFunction', nan, 'PsychologicalHealth']
# ['Memory', 'CognitiveFunction', 'PsychologicalHealth']
# *******************************************
# ['MentalHealth', 'CognitiveFunction', nan, 'PsychologicalHealth']
# ['MentalHealth', 'CognitiveFunction', 'PsychologicalHealth']
# *******************************************
# ['Mindfulness', 'Spirituality', nan, 'PersonalValuesAndBeliefs']
# ['Mindfulness', 'Spirituality', 'PersonalValuesAndBeliefs']
# *******************************************
# ['MobilityAid', 'Mobility', nan, 'LevelOfIndependence']
# ['MobilityAid', 'Mobility', 'LevelOfIndependence']
# *******************************************
# ['Mom', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Mom', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Mosque', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['Mosque', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Mould', 'PhysicalEnvironment', nan, 'Environment']
# ['Mould', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['Mum', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Mum', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Muslim', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['Muslim', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Nausea', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Nausea', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Nervousness', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Nervousness', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Noise', 'PhysicalEnvironment', nan, 'Environment']
# ['Noise', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['NutrientIntake', 'Diet', 'Behaviour', 'PhysicalHealth']
# ['NutrientIntake', 'Diet', 'Behaviour', 'PhysicalHealth']
# *******************************************
# ['Occupation', 'EconomicStatus', nan, 'Environment']
# ['Occupation', 'EconomicStatus', 'Environment']
# *******************************************
# ['Oedema', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Oedema', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Optimisim', 'PositiveFeeling', nan, 'PsychologicalHealth']
# ['Optimisim', 'PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# ['OrganDonation', 'LegalIssue', nan, 'LevelOfIndependence']
# ['OrganDonation', 'LegalIssue', 'LevelOfIndependence']
# *******************************************
# ['Parents', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Parents', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Parks', 'PhysicalEnvironment', nan, 'Environment']
# ['Parks', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['PartTime', 'WorkCapacity', nan, 'LevelOfIndependence']
# ['PartTime', 'WorkCapacity', 'LevelOfIndependence']
# *******************************************
# ['PeriodicRest', 'Rest', nan, 'PhysicalHealth']
# ['PeriodicRest', 'Rest', 'PhysicalHealth']
# *******************************************
# ['Pleased', 'PositiveFeeling', nan, 'PsychologicalHealth']
# ['Pleased', 'PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# ['Pneumonia', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['Pneumonia', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['Pollution', 'PhysicalEnvironment', nan, 'Environment']
# ['Pollution', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['Pray', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['Pray', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['PulmonaryFibrosis', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['PulmonaryFibrosis', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['PulmonaryHypertension', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['PulmonaryHypertension', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['Pulmonary_Rehab', 'Treatment', nan, 'LevelOfIndependence']
# ['Pulmonary_Rehab', 'Treatment', 'LevelOfIndependence']
# *******************************************
# ['QualityOfSocialCare', 'SocialCare', nan, 'Environment']
# ['QualityOfSocialCare', 'SocialCare', 'Environment']
# *******************************************
# ['Recreation', 'Rehabilitation', nan, 'Environment']
# ['Recreation', 'Rehabilitation', 'Environment']
# *******************************************
# ['Redundancy', 'WorkCapacity', nan, 'LevelOfIndependence']
# ['Redundancy', 'WorkCapacity', 'LevelOfIndependence']
# *******************************************
# ['Relative', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Relative', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Relaxation', 'Rest', nan, 'PhysicalHealth']
# ['Relaxation', 'Rest', 'PhysicalHealth']
# *******************************************
# ['ReligiousCelebration', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['ReligiousCelebration', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Remembering', 'CognitiveFunction', nan, 'PsychologicalHealth']
# ['Remembering', 'CognitiveFunction', 'PsychologicalHealth']
# *******************************************
# ['RunnyNose', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['RunnyNose', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Sadness', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Sadness', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Safety', 'PhysicalEnvironment', nan, 'Environment']
# ['Safety', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['Satisfied', 'PositiveFeeling', nan, 'PsychologicalHealth']
# ['Satisfied', 'PositiveFeeling', 'PsychologicalHealth']
# *******************************************
# ['Scared', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Scared', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Security', 'PhysicalEnvironment', nan, 'Environment']
# ['Security', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['SeekingEmergencyCare', 'MedicalSelfCare', nan, 'LevelOfIndependence']
# ['SeekingEmergencyCare', 'MedicalSelfCare', 'LevelOfIndependence']
# *******************************************
# ['SelfEsteem', 'BodyImage', nan, 'PsychologicalHealth']
# ['SelfEsteem', 'BodyImage', 'PsychologicalHealth']
# *******************************************
# ['SenseOfIsolation', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['SenseOfIsolation', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['SexualActivity', 'SocialActivity', nan, 'SocialRelationship']
# ['SexualActivity', 'SocialActivity', 'SocialRelationship']
# *******************************************
# ['ShortnessOfBreath', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['ShortnessOfBreath', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Showering', 'DailyLiving', nan, 'LevelOfIndependence']
# ['Showering', 'DailyLiving', 'LevelOfIndependence']
# *******************************************
# ['Sleep', 'Rest', nan, 'PhysicalHealth']
# ['Sleep', 'Rest', 'PhysicalHealth']
# *******************************************
# ['Smoking', 'Behaviour', nan, 'PhysicalHealth']
# ['Smoking', 'Behaviour', 'PhysicalHealth']
# *******************************************
# ['Sneezing', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Sneezing', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['SocioEconomicallyDisadvantaged', 'FinancialIssue', nan, 'LevelOfIndependence']
# ['SocioEconomicallyDisadvantaged', 'FinancialIssue', 'LevelOfIndependence']
# *******************************************
# ['SoreThroat', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['SoreThroat', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Soreness', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Soreness', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['SpiritualResources', 'Spirituality', nan, 'PersonalValuesAndBeliefs']
# ['SpiritualResources', 'Spirituality', 'PersonalValuesAndBeliefs']
# *******************************************
# ['SpiritualServices', 'Spirituality', nan, 'PersonalValuesAndBeliefs']
# ['SpiritualServices', 'Spirituality', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Spouse', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Spouse', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Strength', 'Energy', nan, 'PhysicalHealth']
# ['Strength', 'Energy', 'PhysicalHealth']
# *******************************************
# ['SwellenLymphNodes', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['SwellenLymphNodes', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Tearfulness', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Tearfulness', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Temple', 'Religion', nan, 'PersonalValuesAndBeliefs']
# ['Temple', 'Religion', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Tension', 'NegativeFeeling', nan, 'PsychologicalHealth']
# ['Tension', 'NegativeFeeling', 'PsychologicalHealth']
# *******************************************
# ['Thinking', 'CognitiveFunction', nan, 'PsychologicalHealth']
# ['Thinking', 'CognitiveFunction', 'PsychologicalHealth']
# *******************************************
# ['TightChest', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['TightChest', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Toileting', 'DailyLiving', nan, 'LevelOfIndependence']
# ['Toileting', 'DailyLiving', 'LevelOfIndependence']
# *******************************************
# ['Toxine', 'PhysicalEnvironment', nan, 'Environment']
# ['Toxine', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['Traffic', 'PhysicalEnvironment', nan, 'Environment']
# ['Traffic', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['Training', 'AcquiringInformation', nan, 'Environment']
# ['Training', 'AcquiringInformation', 'Environment']
# *******************************************
# ['Transport', 'PhysicalEnvironment', nan, 'Environment']
# ['Transport', 'PhysicalEnvironment', 'Environment']
# *******************************************
# ['TravelExpenses', 'FinancialIssue', nan, 'LevelOfIndependence']
# ['TravelExpenses', 'FinancialIssue', 'LevelOfIndependence']
# *******************************************
# ['TreatmentCost', 'FinancialIssue', nan, 'LevelOfIndependence']
# ['TreatmentCost', 'FinancialIssue', 'LevelOfIndependence']
# *******************************************
# ['Tumor', 'RespiratoryIllness', nan, 'PhysicalHealth']
# ['Tumor', 'RespiratoryIllness', 'PhysicalHealth']
# *******************************************
# ['Value', 'Spirituality', nan, 'PersonalValuesAndBeliefs']
# ['Value', 'Spirituality', 'PersonalValuesAndBeliefs']
# *******************************************
# ['Vaping', 'Behaviour', nan, 'PhysicalHealth']
# ['Vaping', 'Behaviour', 'PhysicalHealth']
# *******************************************
# ['Wheezing', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# ['Wheezing', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
# *******************************************
# ['Wife', 'PersonalRelationship', nan, 'SocialRelationship']
# ['Wife', 'PersonalRelationship', 'SocialRelationship']
# *******************************************
# ['Will', 'LegalIssue', nan, 'LevelOfIndependence']
# ['Will', 'LegalIssue', 'LevelOfIndependence']
# *******************************************
# ['Workload', 'WorkCapacity', nan, 'LevelOfIndependence']
# ['Workload', 'WorkCapacity', 'LevelOfIndependence']
# *******************************************
# ['AcquiringInformation', 'Environment']
#
# ['Behaviour', 'PhysicalHealth']
#
# ['BodyImage', 'PsychologicalHealth']
#
# ['CognitiveFunction', 'PsychologicalHealth']
#
# ['DailyLiving', 'LevelOfIndependence']
#
# ['Diet', 'Behaviour', 'PhysicalHealth']
#
# ['EconomicStatus', 'Environment']
#
# ['Energy', 'PhysicalHealth']
#
# ['Environment']
#
# ['FinancialIssue', 'LevelOfIndependence']
#
# ['LegalIssue', 'LevelOfIndependence']
#
# ['LevelOfIndependence']
#
# ['MedicalSelfCare', 'LevelOfIndependence']
#
# ['Mobility', 'LevelOfIndependence']
#
# ['NegativeFeeling', 'PsychologicalHealth']
#
# ['OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Pain', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['PersonalRelationship', 'SocialRelationship']
#
# ['PersonalValuesAndBeliefs']
#
# ['PhysicalEnvironment', 'Environment']
#
# ['PhysicalHealth']
#
# ['PhysicalSymptoms', 'PhysicalHealth']
#
# ['PositiveFeeling', 'PsychologicalHealth']
#
# ['PsychologicalHealth']
#
# ['Rehabilitation', 'Environment']
#
# ['Religion', 'PersonalValuesAndBeliefs']
#
# ['RespiratoryIllness', 'PhysicalHealth']
#
# ['RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Rest', 'PhysicalHealth']
#
# ['SocialActivity', 'SocialRelationship']
#
# ['SocialCare', 'Environment']
#
# ['SocialRelationship']
#
# ['Spirituality', 'PersonalValuesAndBeliefs']
#
# ['Treatment', 'LevelOfIndependence']
#
# ['WorkCapacity', 'LevelOfIndependence']
#
# ['AccessToGreenSpace', 'PhysicalEnvironment', 'Environment']
#
# ['Accessibility', 'WorkCapacity', 'LevelOfIndependence']
#
# ['AccessibiltyOfSocial', 'SocialCare', 'Environment']
#
# ['Aching', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['AcutePain', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['AddressingMinorAilments', 'MedicalSelfCare', 'LevelOfIndependence']
#
# ['Alcohol', 'Behaviour', 'PhysicalHealth']
#
# ['Anger', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Anxiety', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Appearance', 'BodyImage', 'PsychologicalHealth']
#
# ['AppetiteLoss', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Apprehension', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Asthma', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['Bathing', 'DailyLiving', 'LevelOfIndependence']
#
# ['Belief', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# ['BowelIssues', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Breathlessness', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Bronchitis', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['Buddhism', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['CareInformation', 'AcquiringInformation', 'Environment']
#
# ['CarePlan', 'LegalIssue', 'LevelOfIndependence']
#
# ['Caregiver', 'PersonalRelationship', 'SocialRelationship']
#
# ['CaregiverAssistance', 'DailyLiving', 'LevelOfIndependence']
#
# ['ChestPain', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['Child', 'PersonalRelationship', 'SocialRelationship']
#
# ['Christian', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['ChronicPain', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Church', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['Climate', 'PhysicalEnvironment', 'Environment']
#
# ['Community', 'SocialActivity', 'SocialRelationship']
#
# ['ComplexMedication', 'Treatment', 'LevelOfIndependence']
#
# ['Concentration', 'CognitiveFunction', 'PsychologicalHealth']
#
# ['Copd', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['Cough', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Covid', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['CulturalFactors', 'SocialActivity', 'SocialRelationship']
#
# ['Dad', 'PersonalRelationship', 'SocialRelationship']
#
# ['Depression', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Determination', 'PositiveFeeling', 'PsychologicalHealth']
#
# ['Diarrhea', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Digestion', 'Diet', 'Behaviour', 'PhysicalHealth']
#
# ['Dirt', 'PhysicalEnvironment', 'Environment']
#
# ['DisableAccess', 'Mobility', 'LevelOfIndependence']
#
# ['Discomfort', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Drowsiness', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Drug', 'Behaviour', 'PhysicalHealth']
#
# ['Dyspnea', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Education', 'EconomicStatus', 'Environment']
#
# ['EndOfLifeCare', 'LegalIssue', 'LevelOfIndependence']
#
# ['Endurance', 'Energy', 'PhysicalHealth']
#
# ['EquipmentCost', 'FinancialIssue', 'LevelOfIndependence']
#
# ['Excitement', 'PositiveFeeling', 'PsychologicalHealth']
#
# ['Exercise', 'Rehabilitation', 'Environment']
#
# ['Existentiality', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# ['Family', 'PersonalRelationship', 'SocialRelationship']
#
# ['Fatigue', 'Energy', 'PhysicalHealth']
#
# ['Fear', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Fever', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['FinancialSchemes', 'FinancialIssue', 'LevelOfIndependence']
#
# ['Flexibility', 'Energy', 'PhysicalHealth']
#
# ['FlexibleWorking', 'WorkCapacity', 'LevelOfIndependence']
#
# ['FluidIntake', 'Diet', 'Behaviour', 'PhysicalHealth']
#
# ['FoodPreparation', 'DailyLiving', 'LevelOfIndependence']
#
# ['Friend', 'PersonalRelationship', 'SocialRelationship']
#
# ['FuneralPlan', 'LegalIssue', 'LevelOfIndependence']
#
# ['Furious', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Glad', 'PositiveFeeling', 'PsychologicalHealth']
#
# ['Grandchild', 'PersonalRelationship', 'SocialRelationship']
#
# ['Grief', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Guilt', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Gym', 'Rehabilitation', 'Environment']
#
# ['HeartBroken', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Hinduism', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['Hope', 'PositiveFeeling', 'PsychologicalHealth']
#
# ['Hopelessness', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Humorous', 'PositiveFeeling', 'PsychologicalHealth']
#
# ['Husband', 'PersonalRelationship', 'SocialRelationship']
#
# ['Hypochondriac', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Income', 'EconomicStatus', 'Environment']
#
# ['Inheritance', 'LegalIssue', 'LevelOfIndependence']
#
# ['Injuries', 'MedicalSelfCare', 'LevelOfIndependence']
#
# ['Insomnia', 'Rest', 'PhysicalHealth']
#
# ['Insurance', 'LegalIssue', 'LevelOfIndependence']
#
# ['Irritability', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Jewish', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['LanguageDifficulty', 'SocialActivity', 'SocialRelationship']
#
# ['Learning', 'CognitiveFunction', 'PsychologicalHealth']
#
# ['Leisure', 'Rehabilitation', 'Environment']
#
# ['LossOfIncome', 'FinancialIssue', 'LevelOfIndependence']
#
# ['LossOfInterest', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['LossOfPleasure', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Loving', 'PositiveFeeling', 'PsychologicalHealth']
#
# ['LoweringOfMood', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['LungCancer', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['LungDisease', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['MedicalAid', 'Treatment', 'LevelOfIndependence']
#
# ['MedicalInformation', 'AcquiringInformation', 'Environment']
#
# ['MedicineCost', 'FinancialIssue', 'LevelOfIndependence']
#
# ['MedicineIntake', 'Treatment', 'LevelOfIndependence']
#
# ['Meditation', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# ['Memory', 'CognitiveFunction', 'PsychologicalHealth']
#
# ['MentalHealth', 'CognitiveFunction', 'PsychologicalHealth']
#
# ['Mindfulness', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# ['MobilityAid', 'Mobility', 'LevelOfIndependence']
#
# ['Mom', 'PersonalRelationship', 'SocialRelationship']
#
# ['Mosque', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['Mould', 'PhysicalEnvironment', 'Environment']
#
# ['Mum', 'PersonalRelationship', 'SocialRelationship']
#
# ['Muslim', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['Nausea', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Nervousness', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Noise', 'PhysicalEnvironment', 'Environment']
#
# ['NutrientIntake', 'Diet', 'Behaviour', 'PhysicalHealth']
#
# ['Occupation', 'EconomicStatus', 'Environment']
#
# ['Oedema', 'OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Optimisim', 'PositiveFeeling', 'PsychologicalHealth']
#
# ['OrganDonation', 'LegalIssue', 'LevelOfIndependence']
#
# ['Parents', 'PersonalRelationship', 'SocialRelationship']
#
# ['Parks', 'PhysicalEnvironment', 'Environment']
#
# ['PartTime', 'WorkCapacity', 'LevelOfIndependence']
#
# ['PeriodicRest', 'Rest', 'PhysicalHealth']
#
# ['Pleased', 'PositiveFeeling', 'PsychologicalHealth']
#
# ['Pneumonia', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['Pollution', 'PhysicalEnvironment', 'Environment']
#
# ['Pray', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['PulmonaryFibrosis', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['PulmonaryHypertension', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['Pulmonary_Rehab', 'Treatment', 'LevelOfIndependence']
#
# ['QualityOfSocialCare', 'SocialCare', 'Environment']
#
# ['Recreation', 'Rehabilitation', 'Environment']
#
# ['Redundancy', 'WorkCapacity', 'LevelOfIndependence']
#
# ['Relative', 'PersonalRelationship', 'SocialRelationship']
#
# ['Relaxation', 'Rest', 'PhysicalHealth']
#
# ['ReligiousCelebration', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['Remembering', 'CognitiveFunction', 'PsychologicalHealth']
#
# ['RunnyNose', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Sadness', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Safety', 'PhysicalEnvironment', 'Environment']
#
# ['Satisfied', 'PositiveFeeling', 'PsychologicalHealth']
#
# ['Scared', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Security', 'PhysicalEnvironment', 'Environment']
#
# ['SeekingEmergencyCare', 'MedicalSelfCare', 'LevelOfIndependence']
#
# ['SelfEsteem', 'BodyImage', 'PsychologicalHealth']
#
# ['SenseOfIsolation', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['SexualActivity', 'SocialActivity', 'SocialRelationship']
#
# ['ShortnessOfBreath', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Showering', 'DailyLiving', 'LevelOfIndependence']
#
# ['Sleep', 'Rest', 'PhysicalHealth']
#
# ['Smoking', 'Behaviour', 'PhysicalHealth']
#
# ['Sneezing', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['SocioEconomicallyDisadvantaged', 'FinancialIssue', 'LevelOfIndependence']
#
# ['SoreThroat', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Soreness', 'Pain', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['SpiritualResources', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# ['SpiritualServices', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# ['Spouse', 'PersonalRelationship', 'SocialRelationship']
#
# ['Strength', 'Energy', 'PhysicalHealth']
#
# ['SwellenLymphNodes', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Tearfulness', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Temple', 'Religion', 'PersonalValuesAndBeliefs']
#
# ['Tension', 'NegativeFeeling', 'PsychologicalHealth']
#
# ['Thinking', 'CognitiveFunction', 'PsychologicalHealth']
#
# ['TightChest', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Toileting', 'DailyLiving', 'LevelOfIndependence']
#
# ['Toxine', 'PhysicalEnvironment', 'Environment']
#
# ['Traffic', 'PhysicalEnvironment', 'Environment']
#
# ['Training', 'AcquiringInformation', 'Environment']
#
# ['Transport', 'PhysicalEnvironment', 'Environment']
#
# ['TravelExpenses', 'FinancialIssue', 'LevelOfIndependence']
#
# ['TreatmentCost', 'FinancialIssue', 'LevelOfIndependence']
#
# ['Tumor', 'RespiratoryIllness', 'PhysicalHealth']
#
# ['Value', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# ['Vaping', 'Behaviour', 'PhysicalHealth']
#
# ['Wheezing', 'RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# ['Wife', 'PersonalRelationship', 'SocialRelationship']
#
# ['Will', 'LegalIssue', 'LevelOfIndependence']
#
# ['Workload', 'WorkCapacity', 'LevelOfIndependence']

# %%
# Remove nan values within the concepts in segCharacterisation and save the result into segCharacterisation1
segCharacterisation1=[]
tempCon1=[]
tempCon2=[]

for i in segCharacterisation  : 
    for j in i[4]:
        if str(j) != 'nan':
            tempCon1.append(j)
    for j in i[5]:
        if str(j) != 'nan':
            tempCon2.append(j)
    segCharacterisation1.append([i[0],i[1],i[2],i[3],tempCon1,tempCon2]) 
    tempCon1=[]
    tempCon2=[]
print()
print('# of segments  ',len(segCharacterisation1))
print()
for i in  segCharacterisation1:
    
    print(i)
    print()
    print('________________________')
# Out:
# # of segments   307
#
# ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]
#
# ________________________
# ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]
#
# ________________________
# ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]
#
# ________________________
# ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]
#
# ________________________
# ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]
#
# ________________________
# ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]
#
# ________________________
# ['rQutyErqBG014', 4.03, 4.59, 55, ['LungCancer', 1.0], []]
#
# ________________________
# ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]
#
# ________________________
# ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]
#
# ________________________
# ['mWo-G3UQ-zU6', 2.22, 2.31, 8, ['Dad', 1.0, 'Hope', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]
#
# ________________________
# ['hQQ5xQGZxdA15', 3.17, 4.39, 82, ['LungCancer', 2.0], ['Tumor', 1.0, 'Thinking', 2.0]]
#
# ________________________
# ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]
#
# ________________________
# ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA58', 12.39, 13.24, 45, ['Tumor', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA67', 14.45, 15.11, 26, ['Community', 1.0], []]
#
# ________________________
# ['xY3B9nLm1u81', 0.0, 1.13, 72, ['Sleep', 2.0, 'Pain', 2.0], ['Wife', 1.0, 'LungCancer', 1.0]]
#
# ________________________
# ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['xY3B9nLm1u818', 4.37, 5.16, 39, ['Pain', 1.0, 'Hope', 1.0], []]
#
# ________________________
# ['xY3B9nLm1u823', 5.53, 6.37, 44, ['Sleep', 1.0], []]
#
# ________________________
# ['yV893Fx41lE1', 0.01, 2.19, 138, ['LungCancer', 3.0], ['Training', 1.0, 'Soreness', 1.0, 'Pain', 2.0, 'Tumor', 1.0]]
#
# ________________________
# ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]
#
# ________________________
# ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]
#
# ________________________
# ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]
#
# ________________________
# ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]
#
# ________________________
# ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]
#
# ________________________
# ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]
#
# ________________________
# ['uJoY4oMLXEY9', 3.03, 3.19, 16, ['Copd', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX44', 0.4, 1.22, 42, ['Child', 1.0, 'LungCancer', 1.0, 'Education', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX47', 1.24, 3.13, 109, ['ChestPain', 3.0], ['Pain', 2.0, 'Learning', 1.0, 'Cough', 2.0, 'Bronchitis', 1.0]]
#
# ________________________
# ['l9k9q6FHeX415', 3.15, 5.1, 114, ['Pain', 3.0, 'Cough', 2.0], ['ChestPain', 1.0, 'Bronchitis', 1.0]]
#
# ________________________
# ['l9k9q6FHeX424', 5.11, 5.34, 22, ['Thinking', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX426', 5.35, 6.12, 37, ['Fear', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX432', 6.51, 7.51, 60, ['Thinking', 2.0, 'Smoking', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX450', 10.32, 11.09, 37, ['Pain', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX453', 11.1, 11.42, 32, ['Thinking', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX456', 11.45, 12.31, 46, ['Family', 1.0, 'Mom', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX460', 12.34, 13.15, 41, ['LungCancer', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX463', 13.16, 13.51, 35, ['Thinking', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX469', 14.34, 15.14, 40, ['Treatment', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX475', 15.55, 16.31, 35, ['Treatment', 1.0, 'Family', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX481', 17.11, 17.49, 37, ['Friend', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX484', 17.52, 18.28, 36, ['Family', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX487', 18.31, 19.17, 46, ['Friend', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX487', 18.31, 19.3, 59, ['Treatment', 2.0], ['Friend', 1.0]]
#
# ________________________
# ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]
#
# ________________________
# ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['j3t5nFnTULQ7', 2.41, 3.31, 50, ['Hope', 1.0], []]
#
# ________________________
# ['j3t5nFnTULQ9', 3.36, 4.22, 46, ['LungDisease', 1.0], []]
#
# ________________________
# ['j3t5nFnTULQ11', 4.25, 4.43, 18, ['Family', 1.0], []]
#
# ________________________
# ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]
#
# ________________________
# ['tfxB32Vb5hE8', 1.43, 2.18, 35, ['Tumor', 1.0], []]
#
# ________________________
# ['tfxB32Vb5hE10', 2.19, 2.49, 30, ['Hope', 1.0], []]
#
# ________________________
# ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]
#
# ________________________
# ['0fI_01yFmME3', 0.51, 1.4, 49, ['PulmonaryFibrosis', 1.0], []]
#
# ________________________
# ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]
#
# ________________________
# ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]
#
# ________________________
# ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]
#
# ________________________
# ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]
#
# ________________________
# ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]
#
# ________________________
# ['HBFn82ffSVE30', 7.31, 7.51, 20, ['LungCancer', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk1', 0.01, 0.39, 38, ['Family', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk4', 0.42, 1.13, 30, ['Tumor', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk18', 4.08, 5.58, 110, ['Scared', 3.0], ['Mom', 1.0, 'LungCancer', 1.0, 'Community', 1.0]]
#
# ________________________
# ['llk-qgIr9Nk25', 6.0, 6.42, 42, ['Fear', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk35', 8.18, 8.58, 40, ['Anxiety', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk41', 9.36, 10.13, 37, ['Mom', 1.0, 'Sleep', 1.0, 'Exercise', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk47', 11.01, 11.36, 35, ['Treatment', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk53', 12.15, 13.01, 46, ['Family', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk56', 13.03, 13.52, 49, ['LungCancer', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk68', 16.06, 16.45, 39, ['Thinking', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk74', 17.25, 18.0, 35, ['Sleep', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk77', 18.02, 18.39, 37, ['Family', 1.0, 'Husband', 1.0, 'Insurance', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk83', 19.23, 20.03, 40, ['Exercise', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk86', 20.04, 20.41, 37, ['Husband', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk95', 21.58, 22.38, 40, ['Exercise', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk104', 24.08, 24.48, 40, ['Family', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk116', 26.54, 27.37, 43, ['Insurance', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk119', 27.39, 28.16, 37, ['Church', 1.0, 'Safety', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk128', 29.45, 30.26, 41, ['Mom', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk137', 31.48, 32.26, 37, ['Exercise', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk143', 33.06, 33.46, 39, ['Traffic', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk155', 35.54, 36.32, 38, ['Treatment', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk158', 36.33, 37.2, 47, ['Anxiety', 1.0, 'Sleep', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk161', 37.21, 37.5, 29, ['LungCancer', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk172', 39.48, 39.53, 5, ['LungCancer', 1.0], []]
#
# ________________________
# ['3mcWSmPXFtM1', 0.0, 1.35, 95, ['Treatment', 2.0], ['LungCancer', 2.0, 'Drug', 2.0]]
#
# ________________________
# ['bmvlK4qhAnU1', 0.0, 0.47, 47, ['Husband', 1.0, 'Tumor', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU4', 0.5, 3.08, 138, ['LungCancer', 3.0, 'Hope', 3.0], []]
#
# ________________________
# ['bmvlK4qhAnU12', 3.1, 3.5, 40, ['Wife', 1.0, 'Mom', 1.0, 'Education', 1.0, 'Community', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU15', 3.53, 4.33, 40, ['Husband', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU30', 7.31, 8.13, 42, ['Sleep', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU33', 8.19, 9.07, 48, ['Rest', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU36', 9.09, 9.52, 43, ['Tumor', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU42', 10.43, 11.27, 44, ['ShortnessOfBreath', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU45', 11.29, 12.14, 45, ['Friend', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU54', 13.45, 14.35, 50, ['Pain', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU59', 15.14, 16.0, 46, ['LungCancer', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU65', 16.5, 17.37, 47, ['Husband', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU70', 18.16, 20.04, 108, ['LungCancer', 4.0], ['Thinking', 1.0, 'Family', 1.0, 'Rest', 1.0]]
#
# ________________________
# ['bmvlK4qhAnU77', 20.06, 21.28, 82, ['Friend', 2.0], []]
#
# ________________________
# ['bmvlK4qhAnU84', 22.02, 22.48, 46, ['Husband', 1.0, 'Dad', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU87', 22.51, 23.19, 28, ['Rest', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU89', 23.24, 24.09, 45, ['Thinking', 1.0, 'Strength', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU92', 24.11, 24.55, 44, ['Family', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU92', 24.11, 25.03, 52, ['Treatment', 2.0], ['Family', 1.0]]
#
# ________________________
# ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A8', 2.28, 3.01, 33, ['LungCancer', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]
#
# ________________________
# ['ehh89UrZtZU12', 0.01, 4.07, 246, ['Copd', 8.0], ['Smoking', 6.0, 'Cough', 1.0]]
#
# ________________________
# ['VyGp12XbPzs1', 0.1, 0.54, 44, ['Pneumonia', 1.0], []]
#
# ________________________
# ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['VyGp12XbPzs4', 2.25, 3.23, 58, ['Hope', 2.0], []]
#
# ________________________
# ['jZJTcp3d1q41', 0.11, 2.38, 147, ['Copd', 3.0], ['DailyLiving', 1.0, 'Wife', 1.0, 'Exercise', 1.0]]
#
# ________________________
# ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]
#
# ________________________
# ['ZU_l9xCB-081', 0.04, 1.48, 104, ['Copd', 3.0], ['Pneumonia', 1.0, 'Fear', 1.0, 'Mom', 1.0, 'Friend', 1.0]]
#
# ________________________
# ['Nl55TpSjWp43', 0.42, 1.23, 41, ['Covid', 1.0], []]
#
# ________________________
# ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]
#
# ________________________
# ['Nl55TpSjWp49', 3.0, 4.27, 86, ['Pneumonia', 2.0], ['Rest', 1.0, 'Covid', 2.0, 'Copd', 1.0, 'LungDisease', 1.0]]
#
# ________________________
# ['Nl55TpSjWp414', 4.3, 5.13, 43, ['Treatment', 1.0], []]
#
# ________________________
# ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]
#
# ________________________
# ['Nl55TpSjWp422', 7.11, 7.29, 17, ['Determination', 1.0], []]
#
# ________________________
# ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]
#
# ________________________
# ['6U7OpgFojaw6', 1.43, 2.15, 32, ['Pneumonia', 1.0], []]
#
# ________________________
# ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]
#
# ________________________
# ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]
#
# ________________________
# ['e0KVtXL-TjY7', 1.31, 2.09, 38, ['PulmonaryHypertension', 1.0], []]
#
# ________________________
# ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk10', 2.58, 3.39, 41, ['Treatment', 1.0, 'Rehabilitation', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk12', 3.43, 4.09, 26, ['Hope', 1.0], []]
#
# ________________________
# ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]
#
# ________________________
# ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]
#
# ________________________
# ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]
#
# ________________________
# ['GV3Rew061FA5', 1.31, 5.07, 216, ['Exercise', 7.0], ['Glad', 1.0]]
#
# ________________________
# ['Nxrz6_e_gwo1', 0.02, 2.34, 152, ['Copd', 5.0], ['Rest', 1.0, 'Family', 2.0, 'Wheezing', 1.0, 'Exercise', 1.0]]
#
# ________________________
# ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]
#
# ________________________
# ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c3', 1.13, 1.44, 31, ['LungCancer', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['POskT8R_3t41', 0.0, 0.38, 38, ['PulmonaryHypertension', 1.0], []]
#
# ________________________
# ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]
#
# ________________________
# ['POskT8R_3t49', 2.57, 3.5, 53, ['Treatment', 1.0], []]
#
# ________________________
# ['3Fker8Nmd5Y1', 0.05, 0.57, 51, ['LungDisease', 1.0], []]
#
# ________________________
# ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]
#
# ________________________
# ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]
#
# ________________________
# ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]
#
# ________________________
# ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]
#
# ________________________
# ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]
#
# ________________________
# ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]
#
# ________________________
# ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]
#
# ________________________
# ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_41', 0.05, 0.52, 47, ['Hope', 1.0, 'Learning', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_44', 0.54, 1.44, 50, ['Community', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_47', 1.47, 2.29, 42, ['LungCancer', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_413', 3.19, 4.02, 42, ['Fatigue', 1.0, 'Scared', 2.0], []]
#
# ________________________
# ['r20Ak5ZxP_416', 4.03, 4.46, 42, ['Husband', 1.0, 'LungCancer', 1.0, 'Energy', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_419', 4.47, 5.3, 43, ['Pneumonia', 1.0, 'Cough', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_430', 7.36, 8.21, 45, ['Anxiety', 1.0, 'Cough', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_443', 11.05, 11.52, 46, ['Treatment', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_458', 11.55, 15.55, 240, ['Smoking', 7.0], ['LungCancer', 3.0, 'Tension', 1.0, 'Family', 1.0, 'Education', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg1', 0.01, 0.36, 35, ['Hope', 1.0, 'Glad', 1.0, 'Caregiver', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg4', 0.39, 1.2, 41, ['Husband', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg7', 1.22, 1.59, 37, ['Treatment', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg10', 2.01, 4.11, 130, ['Pneumonia', 2.0], ['Asthma', 2.0, 'Mom', 1.0, 'LungCancer', 1.0, 'Tumor', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg19', 4.12, 4.51, 39, ['Family', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg25', 5.34, 6.14, 39, ['Insurance', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg33', 7.32, 8.12, 39, ['Anxiety', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg39', 8.54, 10.0, 66, ['LungCancer', 2.0], []]
#
# ________________________
# ['MjEJaR3zLjg52', 12.0, 12.38, 38, ['Family', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg60', 14.03, 14.46, 43, ['Exercise', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg63', 14.48, 16.23, 95, ['Anxiety', 2.0], ['Husband', 1.0, 'Pneumonia', 1.0, 'LungCancer', 1.0, 'Mom', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg71', 16.53, 18.54, 120, ['Tumor', 4.0], ['LungCancer', 1.0, 'Treatment', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg80', 18.57, 19.2, 23, ['Family', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg86', 20.12, 21.33, 80, ['Community', 2.0], ['Mom', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg101', 23.36, 24.12, 36, ['LungCancer', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg104', 24.14, 24.5, 36, ['Sleep', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg107', 24.52, 27.31, 158, ['Family', 4.0], ['Pneumonia', 1.0, 'Caregiver', 1.0, 'Child', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg121', 28.21, 28.32, 11, ['Treatment', 1.0], []]
#
# ________________________
# ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]
#
# ________________________
# ['HCgXqdpQGhc1', 0.01, 0.44, 43, ['Hope', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc4', 0.47, 1.19, 32, ['Husband', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc9', 2.06, 2.48, 42, ['LungCancer', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc15', 3.36, 4.2, 44, ['Treatment', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc27', 6.41, 8.28, 106, ['Husband', 2.0], ['Exercise', 1.0, 'Thinking', 2.0]]
#
# ________________________
# ['HCgXqdpQGhc35', 8.3, 9.18, 47, ['LungCancer', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc39', 9.2, 10.0, 40, ['Anxiety', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc45', 10.47, 11.35, 47, ['Drug', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc54', 13.05, 13.41, 35, ['Pain', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc57', 13.42, 14.27, 45, ['Husband', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc60', 14.29, 15.07, 38, ['Friend', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc66', 15.55, 16.39, 43, ['Learning', 1.0, 'Caregiver', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc77', 18.57, 19.46, 49, ['Husband', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc80', 19.48, 22.04, 136, ['LungCancer', 2.0], ['Pain', 1.0, 'Husband', 2.0, 'Family', 1.0, 'Treatment', 1.0]]
#
# ________________________
# ['HCgXqdpQGhc90', 22.25, 23.52, 87, ['Treatment', 2.0], []]
#
# ________________________
# ['HCgXqdpQGhc98', 24.25, 26.04, 99, ['Drug', 2.0, 'Treatment', 3.0], ['Hope', 1.0, 'Thinking', 1.0]]
#
# ________________________
# ['HCgXqdpQGhc105', 26.06, 26.49, 43, ['Caregiver', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['E8nRS2LxFdw1', 0.0, 0.45, 45, ['Pain', 1.0], []]
#
# ________________________
# ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['E8nRS2LxFdw7', 1.3, 2.14, 44, ['Training', 1.0], []]
#
# ________________________
# ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]
#
# ________________________
# ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w1', 0.01, 0.37, 36, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w4', 2.06, 3.26, 79, ['Wife', 1.0, 'Family', 2.0, 'Rest', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w6', 3.32, 4.12, 40, ['Rest', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w7', 4.2, 7.07, 167, ['Wife', 2.0, 'Thinking', 2.0], ['ShortnessOfBreath', 3.0]]
#
# ________________________
# ['FHXbDHakK1w11', 7.12, 8.36, 84, ['Wheezing', 1.0, 'Bronchitis', 2.0], []]
#
# ________________________
# ['FHXbDHakK1w13', 8.43, 10.08, 85, ['Insurance', 1.0, 'Pneumonia', 2.0, 'Anxiety', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w15', 10.13, 10.55, 42, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w16', 11.0, 11.39, 39, ['Community', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w20', 14.05, 14.42, 36, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w22', 15.3, 16.08, 37, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w23', 16.14, 16.5, 36, ['Gym', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w24', 16.56, 17.31, 34, ['Treatment', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w26', 18.22, 19.0, 38, ['Family', 1.0, 'Strength', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w28', 19.5, 21.1, 80, ['Treatment', 2.0], []]
#
# ________________________
# ['FHXbDHakK1w30', 21.15, 24.44, 209, ['Friend', 4.0], ['Wife', 1.0, 'Rest', 1.0, 'Treatment', 1.0]]
#
# ________________________
# ['FHXbDHakK1w36', 25.34, 28.27, 173, ['Treatment', 2.0, 'LungCancer', 3.0], ['Drug', 1.0, 'Scared', 1.0]]
#
# ________________________
# ['FHXbDHakK1w39', 27.52, 28.27, 35, ['Scared', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w40', 28.32, 29.09, 37, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w44', 31.33, 32.47, 74, ['Anxiety', 2.0, 'Wife', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['WShT-I0wCO41', 0.0, 0.5, 50, ['Pain', 1.0, 'Drug', 1.0], []]
#
# ________________________
# ['WShT-I0wCO46', 1.27, 2.01, 33, ['LungCancer', 1.0], []]
#
# ________________________
# ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]
#
# ________________________
# ['WShT-I0wCO410', 2.44, 3.34, 50, ['Treatment', 1.0], []]
#
# ________________________
# ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]
#
# ________________________
# ['WShT-I0wCO420', 5.39, 6.29, 50, ['Treatment', 1.0], []]
#
# ________________________
# ['2utaepga5uk1', 0.0, 0.38, 38, ['Pain', 1.0], []]
#
# ________________________
# ['2utaepga5uk3', 0.47, 2.29, 102, ['Treatment', 2.0], ['Friend', 1.0]]
#
# ________________________
# ['2utaepga5uk11', 3.22, 4.09, 46, ['Thinking', 1.0], []]
#
# ________________________
# ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]
#
# ________________________
# ['2utaepga5uk18', 5.34, 5.43, 9, ['Thinking', 1.0], []]
#
# ________________________
# ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]
#
# ________________________
# ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]
#
# ________________________
# ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]
#
# ________________________
# ['dyRmGVgG7_84', 0.47, 1.17, 30, ['Copd', 1.0], []]
#
# ________________________
# ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]
#
# ________________________
# ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]
#
# ________________________
# ['9nRhehMpODk3', 0.39, 1.3, 51, ['Hope', 1.0, 'Treatment', 1.0, 'Pain', 1.0], []]
#
# ________________________
# ['9nRhehMpODk8', 2.11, 2.59, 48, ['Hope', 1.0], []]
#
# ________________________
# ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatment', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['Tyo2YsA0Y02', 0.43, 1.19, 36, ['Hope', 1.0], []]
#
# ________________________
# ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]
#
# ________________________
# ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]
#
# ________________________
# ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]
#
# ________________________
# ['ZoEEgU6L-m85', 1.47, 2.35, 48, ['Treatment', 1.0], []]
#
# ________________________
# ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]
#
# ________________________
# ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU14', 3.35, 4.22, 47, ['Exercise', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]
#
# ________________________
# ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]
#
# ________________________
# ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]
#
# ________________________
# ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]
#
# ________________________
# ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]
#
# ________________________
# ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]
#
# ________________________
# ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]
#
# ________________________
# ['323hkORG0OM3', 0.4, 1.57, 77, ['Tumor', 2.0], []]
#
# ________________________
# ['323hkORG0OM9', 2.19, 2.31, 12, ['LungCancer', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['LYwQdM-2ok41', 0.0, 2.27, 147, ['LungCancer', 5.0], ['Treatment', 1.0, 'Tumor', 1.0, 'Mom', 1.0, 'Bronchitis', 1.0]]
#
# ________________________
# ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]
#
# ________________________
# ['LYwQdM-2ok411', 3.12, 3.26, 13, ['Insurance', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw3', 0.36, 2.27, 111, ['Mom', 3.0, 'Child', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw8', 2.31, 3.12, 41, ['Rest', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw12', 4.0, 4.48, 48, ['Friend', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw16', 5.44, 7.33, 108, ['Dad', 2.0, 'Mom', 1.0, 'Family', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw22', 8.07, 8.57, 50, ['Family', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw24', 9.0, 9.44, 44, ['Exercise', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw26', 9.49, 10.39, 50, ['Friend', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw30', 11.37, 13.14, 97, ['Noise', 3.0], []]
#
# ________________________
# ['O5DOre3MFlw35', 13.5, 14.26, 36, ['Noise', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw37', 14.33, 15.22, 49, ['Energy', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw39', 15.3, 16.18, 47, ['Friend', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw43', 17.04, 17.59, 55, ['Dad', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw49', 19.55, 20.35, 40, ['Friend', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw65', 25.45, 26.21, 36, ['Caregiver', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw69', 27.06, 27.5, 44, ['Scared', 1.0], []]
#
# ________________________
# ['bqkquNb5Z8A1', 0.03, 0.41, 38, ['Pain', 1.0], []]
#
# ________________________
# ['bqkquNb5Z8A10', 2.47, 3.31, 43, ['Drug', 1.0], []]
#
# ________________________
# ['bqkquNb5Z8A13', 3.33, 4.04, 31, ['Pain', 1.0], []]
#
# ________________________
# ['qsAnlV8DUXo1', 0.0, 0.42, 42, ['PulmonaryFibrosis', 1.0], []]
#
# ________________________
# ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]
#
# ________________________
# ['2pzHkvmRSW81', 0.08, 1.16, 68, [], ['Copd', 2.0, 'LungDisease', 2.0, 'Community', 1.0, 'Smoking', 2.0]]
#
# ________________________
# ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]
#
# ________________________
# ['2pzHkvmRSW812', 3.19, 3.53, 33, ['LungDisease', 1.0], []]
#
# ________________________

# %%
# Remove segments with duration <20 seconds
segCharacterisation2=[]
for i in  segCharacterisation1:
    if i[3] >=20:
        segCharacterisation2.append(i)
print('# of segments left after removing the segments with duration <20 sec ',len(segCharacterisation2))
print()
for i in segCharacterisation2:
    print(i)
    print()
    print('________________________')
temp=[]
foundUnwanted='False'
unwantedVideos=['bmvlK4qhAnU','l9k9q6FHeX4','llk-qgIr9Nk','FHXbDHakK1w','MjEJaR3zLjg','HCgXqdpQGhc','r20Ak5ZxP_4',
                'O5DOre3MFlw']

print('******  Temp *****************')
tempUn=[]
for i in segCharacterisation2:
    foundUnwanted='False'
    for u in unwantedVideos:
        if str(i[0])[:5] == str(u)[:5]:
            foundUnwanted='True'
            tempUn.append(i)
    if foundUnwanted=='False':
        temp.append(i)
for i in temp:
    print(i)
    print('*********************************************')
print('len(segCharacterisation2) = ',len(segCharacterisation2),'  len(temp)= ',len(temp),' len(tempUn) = ',len(tempUn))    
print()

for i in tempUn:
    print(i)
    print()
    
print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^')

segCharacterisation2=temp
# Out:
# # of segments left after removing the segments with duration <20 sec  298
#
# ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]
#
# ________________________
# ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]
#
# ________________________
# ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]
#
# ________________________
# ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]
#
# ________________________
# ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]
#
# ________________________
# ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]
#
# ________________________
# ['rQutyErqBG014', 4.03, 4.59, 55, ['LungCancer', 1.0], []]
#
# ________________________
# ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]
#
# ________________________
# ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]
#
# ________________________
# ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]
#
# ________________________
# ['hQQ5xQGZxdA15', 3.17, 4.39, 82, ['LungCancer', 2.0], ['Tumor', 1.0, 'Thinking', 2.0]]
#
# ________________________
# ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]
#
# ________________________
# ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA58', 12.39, 13.24, 45, ['Tumor', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]
#
# ________________________
# ['hQQ5xQGZxdA67', 14.45, 15.11, 26, ['Community', 1.0], []]
#
# ________________________
# ['xY3B9nLm1u81', 0.0, 1.13, 72, ['Sleep', 2.0, 'Pain', 2.0], ['Wife', 1.0, 'LungCancer', 1.0]]
#
# ________________________
# ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['xY3B9nLm1u818', 4.37, 5.16, 39, ['Pain', 1.0, 'Hope', 1.0], []]
#
# ________________________
# ['xY3B9nLm1u823', 5.53, 6.37, 44, ['Sleep', 1.0], []]
#
# ________________________
# ['yV893Fx41lE1', 0.01, 2.19, 138, ['LungCancer', 3.0], ['Training', 1.0, 'Soreness', 1.0, 'Pain', 2.0, 'Tumor', 1.0]]
#
# ________________________
# ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]
#
# ________________________
# ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]
#
# ________________________
# ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]
#
# ________________________
# ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]
#
# ________________________
# ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]
#
# ________________________
# ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX44', 0.4, 1.22, 42, ['Child', 1.0, 'LungCancer', 1.0, 'Education', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX47', 1.24, 3.13, 109, ['ChestPain', 3.0], ['Pain', 2.0, 'Learning', 1.0, 'Cough', 2.0, 'Bronchitis', 1.0]]
#
# ________________________
# ['l9k9q6FHeX415', 3.15, 5.1, 114, ['Pain', 3.0, 'Cough', 2.0], ['ChestPain', 1.0, 'Bronchitis', 1.0]]
#
# ________________________
# ['l9k9q6FHeX424', 5.11, 5.34, 22, ['Thinking', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX426', 5.35, 6.12, 37, ['Fear', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX432', 6.51, 7.51, 60, ['Thinking', 2.0, 'Smoking', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX450', 10.32, 11.09, 37, ['Pain', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX453', 11.1, 11.42, 32, ['Thinking', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX456', 11.45, 12.31, 46, ['Family', 1.0, 'Mom', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX460', 12.34, 13.15, 41, ['LungCancer', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX463', 13.16, 13.51, 35, ['Thinking', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX469', 14.34, 15.14, 40, ['Treatment', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX475', 15.55, 16.31, 35, ['Treatment', 1.0, 'Family', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX481', 17.11, 17.49, 37, ['Friend', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX484', 17.52, 18.28, 36, ['Family', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX487', 18.31, 19.17, 46, ['Friend', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['l9k9q6FHeX487', 18.31, 19.3, 59, ['Treatment', 2.0], ['Friend', 1.0]]
#
# ________________________
# ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]
#
# ________________________
# ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['j3t5nFnTULQ7', 2.41, 3.31, 50, ['Hope', 1.0], []]
#
# ________________________
# ['j3t5nFnTULQ9', 3.36, 4.22, 46, ['LungDisease', 1.0], []]
#
# ________________________
# ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]
#
# ________________________
# ['tfxB32Vb5hE8', 1.43, 2.18, 35, ['Tumor', 1.0], []]
#
# ________________________
# ['tfxB32Vb5hE10', 2.19, 2.49, 30, ['Hope', 1.0], []]
#
# ________________________
# ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]
#
# ________________________
# ['0fI_01yFmME3', 0.51, 1.4, 49, ['PulmonaryFibrosis', 1.0], []]
#
# ________________________
# ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]
#
# ________________________
# ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]
#
# ________________________
# ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]
#
# ________________________
# ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]
#
# ________________________
# ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]
#
# ________________________
# ['HBFn82ffSVE30', 7.31, 7.51, 20, ['LungCancer', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk1', 0.01, 0.39, 38, ['Family', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk4', 0.42, 1.13, 30, ['Tumor', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk18', 4.08, 5.58, 110, ['Scared', 3.0], ['Mom', 1.0, 'LungCancer', 1.0, 'Community', 1.0]]
#
# ________________________
# ['llk-qgIr9Nk25', 6.0, 6.42, 42, ['Fear', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk35', 8.18, 8.58, 40, ['Anxiety', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk41', 9.36, 10.13, 37, ['Mom', 1.0, 'Sleep', 1.0, 'Exercise', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk47', 11.01, 11.36, 35, ['Treatment', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk53', 12.15, 13.01, 46, ['Family', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk56', 13.03, 13.52, 49, ['LungCancer', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk68', 16.06, 16.45, 39, ['Thinking', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk74', 17.25, 18.0, 35, ['Sleep', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk77', 18.02, 18.39, 37, ['Family', 1.0, 'Husband', 1.0, 'Insurance', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk83', 19.23, 20.03, 40, ['Exercise', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk86', 20.04, 20.41, 37, ['Husband', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk95', 21.58, 22.38, 40, ['Exercise', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk104', 24.08, 24.48, 40, ['Family', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk116', 26.54, 27.37, 43, ['Insurance', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk119', 27.39, 28.16, 37, ['Church', 1.0, 'Safety', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk128', 29.45, 30.26, 41, ['Mom', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk137', 31.48, 32.26, 37, ['Exercise', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk143', 33.06, 33.46, 39, ['Traffic', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk155', 35.54, 36.32, 38, ['Treatment', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk158', 36.33, 37.2, 47, ['Anxiety', 1.0, 'Sleep', 1.0], []]
#
# ________________________
# ['llk-qgIr9Nk161', 37.21, 37.5, 29, ['LungCancer', 1.0], []]
#
# ________________________
# ['3mcWSmPXFtM1', 0.0, 1.35, 95, ['Treatment', 2.0], ['LungCancer', 2.0, 'Drug', 2.0]]
#
# ________________________
# ['bmvlK4qhAnU1', 0.0, 0.47, 47, ['Husband', 1.0, 'Tumor', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU4', 0.5, 3.08, 138, ['LungCancer', 3.0, 'Hope', 3.0], []]
#
# ________________________
# ['bmvlK4qhAnU12', 3.1, 3.5, 40, ['Wife', 1.0, 'Mom', 1.0, 'Education', 1.0, 'Community', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU15', 3.53, 4.33, 40, ['Husband', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU30', 7.31, 8.13, 42, ['Sleep', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU33', 8.19, 9.07, 48, ['Rest', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU36', 9.09, 9.52, 43, ['Tumor', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU42', 10.43, 11.27, 44, ['ShortnessOfBreath', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU45', 11.29, 12.14, 45, ['Friend', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU54', 13.45, 14.35, 50, ['Pain', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU59', 15.14, 16.0, 46, ['LungCancer', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU65', 16.5, 17.37, 47, ['Husband', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU70', 18.16, 20.04, 108, ['LungCancer', 4.0], ['Thinking', 1.0, 'Family', 1.0, 'Rest', 1.0]]
#
# ________________________
# ['bmvlK4qhAnU77', 20.06, 21.28, 82, ['Friend', 2.0], []]
#
# ________________________
# ['bmvlK4qhAnU84', 22.02, 22.48, 46, ['Husband', 1.0, 'Dad', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU87', 22.51, 23.19, 28, ['Rest', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU89', 23.24, 24.09, 45, ['Thinking', 1.0, 'Strength', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU92', 24.11, 24.55, 44, ['Family', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['bmvlK4qhAnU92', 24.11, 25.03, 52, ['Treatment', 2.0], ['Family', 1.0]]
#
# ________________________
# ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A8', 2.28, 3.01, 33, ['LungCancer', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]
#
# ________________________
# ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]
#
# ________________________
# ['ehh89UrZtZU12', 0.01, 4.07, 246, ['Copd', 8.0], ['Smoking', 6.0, 'Cough', 1.0]]
#
# ________________________
# ['VyGp12XbPzs1', 0.1, 0.54, 44, ['Pneumonia', 1.0], []]
#
# ________________________
# ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['VyGp12XbPzs4', 2.25, 3.23, 58, ['Hope', 2.0], []]
#
# ________________________
# ['jZJTcp3d1q41', 0.11, 2.38, 147, ['Copd', 3.0], ['DailyLiving', 1.0, 'Wife', 1.0, 'Exercise', 1.0]]
#
# ________________________
# ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]
#
# ________________________
# ['ZU_l9xCB-081', 0.04, 1.48, 104, ['Copd', 3.0], ['Pneumonia', 1.0, 'Fear', 1.0, 'Mom', 1.0, 'Friend', 1.0]]
#
# ________________________
# ['Nl55TpSjWp43', 0.42, 1.23, 41, ['Covid', 1.0], []]
#
# ________________________
# ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]
#
# ________________________
# ['Nl55TpSjWp49', 3.0, 4.27, 86, ['Pneumonia', 2.0], ['Rest', 1.0, 'Covid', 2.0, 'Copd', 1.0, 'LungDisease', 1.0]]
#
# ________________________
# ['Nl55TpSjWp414', 4.3, 5.13, 43, ['Treatment', 1.0], []]
#
# ________________________
# ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]
#
# ________________________
# ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]
#
# ________________________
# ['6U7OpgFojaw6', 1.43, 2.15, 32, ['Pneumonia', 1.0], []]
#
# ________________________
# ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]
#
# ________________________
# ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]
#
# ________________________
# ['e0KVtXL-TjY7', 1.31, 2.09, 38, ['PulmonaryHypertension', 1.0], []]
#
# ________________________
# ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk10', 2.58, 3.39, 41, ['Treatment', 1.0, 'Rehabilitation', 1.0], []]
#
# ________________________
# ['aHAbRVZOxnk12', 3.43, 4.09, 26, ['Hope', 1.0], []]
#
# ________________________
# ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]
#
# ________________________
# ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]
#
# ________________________
# ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]
#
# ________________________
# ['GV3Rew061FA5', 1.31, 5.07, 216, ['Exercise', 7.0], ['Glad', 1.0]]
#
# ________________________
# ['Nxrz6_e_gwo1', 0.02, 2.34, 152, ['Copd', 5.0], ['Rest', 1.0, 'Family', 2.0, 'Wheezing', 1.0, 'Exercise', 1.0]]
#
# ________________________
# ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]
#
# ________________________
# ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c3', 1.13, 1.44, 31, ['LungCancer', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]
#
# ________________________
# ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['POskT8R_3t41', 0.0, 0.38, 38, ['PulmonaryHypertension', 1.0], []]
#
# ________________________
# ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]
#
# ________________________
# ['POskT8R_3t49', 2.57, 3.5, 53, ['Treatment', 1.0], []]
#
# ________________________
# ['3Fker8Nmd5Y1', 0.05, 0.57, 51, ['LungDisease', 1.0], []]
#
# ________________________
# ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]
#
# ________________________
# ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]
#
# ________________________
# ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]
#
# ________________________
# ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]
#
# ________________________
# ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]
#
# ________________________
# ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]
#
# ________________________
# ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]
#
# ________________________
# ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_41', 0.05, 0.52, 47, ['Hope', 1.0, 'Learning', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_44', 0.54, 1.44, 50, ['Community', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_47', 1.47, 2.29, 42, ['LungCancer', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_413', 3.19, 4.02, 42, ['Fatigue', 1.0, 'Scared', 2.0], []]
#
# ________________________
# ['r20Ak5ZxP_416', 4.03, 4.46, 42, ['Husband', 1.0, 'LungCancer', 1.0, 'Energy', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_419', 4.47, 5.3, 43, ['Pneumonia', 1.0, 'Cough', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_430', 7.36, 8.21, 45, ['Anxiety', 1.0, 'Cough', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_443', 11.05, 11.52, 46, ['Treatment', 1.0], []]
#
# ________________________
# ['r20Ak5ZxP_458', 11.55, 15.55, 240, ['Smoking', 7.0], ['LungCancer', 3.0, 'Tension', 1.0, 'Family', 1.0, 'Education', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg1', 0.01, 0.36, 35, ['Hope', 1.0, 'Glad', 1.0, 'Caregiver', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg4', 0.39, 1.2, 41, ['Husband', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg7', 1.22, 1.59, 37, ['Treatment', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg10', 2.01, 4.11, 130, ['Pneumonia', 2.0], ['Asthma', 2.0, 'Mom', 1.0, 'LungCancer', 1.0, 'Tumor', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg19', 4.12, 4.51, 39, ['Family', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg25', 5.34, 6.14, 39, ['Insurance', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg33', 7.32, 8.12, 39, ['Anxiety', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg39', 8.54, 10.0, 66, ['LungCancer', 2.0], []]
#
# ________________________
# ['MjEJaR3zLjg52', 12.0, 12.38, 38, ['Family', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg60', 14.03, 14.46, 43, ['Exercise', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg63', 14.48, 16.23, 95, ['Anxiety', 2.0], ['Husband', 1.0, 'Pneumonia', 1.0, 'LungCancer', 1.0, 'Mom', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg71', 16.53, 18.54, 120, ['Tumor', 4.0], ['LungCancer', 1.0, 'Treatment', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg80', 18.57, 19.2, 23, ['Family', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg86', 20.12, 21.33, 80, ['Community', 2.0], ['Mom', 1.0]]
#
# ________________________
# ['MjEJaR3zLjg101', 23.36, 24.12, 36, ['LungCancer', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg104', 24.14, 24.5, 36, ['Sleep', 1.0], []]
#
# ________________________
# ['MjEJaR3zLjg107', 24.52, 27.31, 158, ['Family', 4.0], ['Pneumonia', 1.0, 'Caregiver', 1.0, 'Child', 1.0]]
#
# ________________________
# ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]
#
# ________________________
# ['HCgXqdpQGhc1', 0.01, 0.44, 43, ['Hope', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc4', 0.47, 1.19, 32, ['Husband', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc9', 2.06, 2.48, 42, ['LungCancer', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc15', 3.36, 4.2, 44, ['Treatment', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc27', 6.41, 8.28, 106, ['Husband', 2.0], ['Exercise', 1.0, 'Thinking', 2.0]]
#
# ________________________
# ['HCgXqdpQGhc35', 8.3, 9.18, 47, ['LungCancer', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc39', 9.2, 10.0, 40, ['Anxiety', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc45', 10.47, 11.35, 47, ['Drug', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc54', 13.05, 13.41, 35, ['Pain', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc57', 13.42, 14.27, 45, ['Husband', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc60', 14.29, 15.07, 38, ['Friend', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc66', 15.55, 16.39, 43, ['Learning', 1.0, 'Caregiver', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc77', 18.57, 19.46, 49, ['Husband', 1.0], []]
#
# ________________________
# ['HCgXqdpQGhc80', 19.48, 22.04, 136, ['LungCancer', 2.0], ['Pain', 1.0, 'Husband', 2.0, 'Family', 1.0, 'Treatment', 1.0]]
#
# ________________________
# ['HCgXqdpQGhc90', 22.25, 23.52, 87, ['Treatment', 2.0], []]
#
# ________________________
# ['HCgXqdpQGhc98', 24.25, 26.04, 99, ['Drug', 2.0, 'Treatment', 3.0], ['Hope', 1.0, 'Thinking', 1.0]]
#
# ________________________
# ['HCgXqdpQGhc105', 26.06, 26.49, 43, ['Caregiver', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['E8nRS2LxFdw1', 0.0, 0.45, 45, ['Pain', 1.0], []]
#
# ________________________
# ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['E8nRS2LxFdw7', 1.3, 2.14, 44, ['Training', 1.0], []]
#
# ________________________
# ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]
#
# ________________________
# ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w1', 0.01, 0.37, 36, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w4', 2.06, 3.26, 79, ['Wife', 1.0, 'Family', 2.0, 'Rest', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w6', 3.32, 4.12, 40, ['Rest', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w7', 4.2, 7.07, 167, ['Wife', 2.0, 'Thinking', 2.0], ['ShortnessOfBreath', 3.0]]
#
# ________________________
# ['FHXbDHakK1w11', 7.12, 8.36, 84, ['Wheezing', 1.0, 'Bronchitis', 2.0], []]
#
# ________________________
# ['FHXbDHakK1w13', 8.43, 10.08, 85, ['Insurance', 1.0, 'Pneumonia', 2.0, 'Anxiety', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w15', 10.13, 10.55, 42, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w16', 11.0, 11.39, 39, ['Community', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w20', 14.05, 14.42, 36, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w22', 15.3, 16.08, 37, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w23', 16.14, 16.5, 36, ['Gym', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w24', 16.56, 17.31, 34, ['Treatment', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w26', 18.22, 19.0, 38, ['Family', 1.0, 'Strength', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w28', 19.5, 21.1, 80, ['Treatment', 2.0], []]
#
# ________________________
# ['FHXbDHakK1w30', 21.15, 24.44, 209, ['Friend', 4.0], ['Wife', 1.0, 'Rest', 1.0, 'Treatment', 1.0]]
#
# ________________________
# ['FHXbDHakK1w36', 25.34, 28.27, 173, ['Treatment', 2.0, 'LungCancer', 3.0], ['Drug', 1.0, 'Scared', 1.0]]
#
# ________________________
# ['FHXbDHakK1w39', 27.52, 28.27, 35, ['Scared', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w40', 28.32, 29.09, 37, ['LungCancer', 1.0], []]
#
# ________________________
# ['FHXbDHakK1w44', 31.33, 32.47, 74, ['Anxiety', 2.0, 'Wife', 1.0, 'Treatment', 1.0], []]
#
# ________________________
# ['WShT-I0wCO41', 0.0, 0.5, 50, ['Pain', 1.0, 'Drug', 1.0], []]
#
# ________________________
# ['WShT-I0wCO46', 1.27, 2.01, 33, ['LungCancer', 1.0], []]
#
# ________________________
# ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]
#
# ________________________
# ['WShT-I0wCO410', 2.44, 3.34, 50, ['Treatment', 1.0], []]
#
# ________________________
# ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]
#
# ________________________
# ['WShT-I0wCO420', 5.39, 6.29, 50, ['Treatment', 1.0], []]
#
# ________________________
# ['2utaepga5uk1', 0.0, 0.38, 38, ['Pain', 1.0], []]
#
# ________________________
# ['2utaepga5uk3', 0.47, 2.29, 102, ['Treatment', 2.0], ['Friend', 1.0]]
#
# ________________________
# ['2utaepga5uk11', 3.22, 4.09, 46, ['Thinking', 1.0], []]
#
# ________________________
# ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]
#
# ________________________
# ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]
#
# ________________________
# ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]
#
# ________________________
# ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]
#
# ________________________
# ['dyRmGVgG7_84', 0.47, 1.17, 30, ['Copd', 1.0], []]
#
# ________________________
# ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]
#
# ________________________
# ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]
#
# ________________________
# ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]
#
# ________________________
# ['9nRhehMpODk3', 0.39, 1.3, 51, ['Hope', 1.0, 'Treatment', 1.0, 'Pain', 1.0], []]
#
# ________________________
# ['9nRhehMpODk8', 2.11, 2.59, 48, ['Hope', 1.0], []]
#
# ________________________
# ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatment', 1.0, 'LungCancer', 1.0], []]
#
# ________________________
# ['Tyo2YsA0Y02', 0.43, 1.19, 36, ['Hope', 1.0], []]
#
# ________________________
# ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]
#
# ________________________
# ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]
#
# ________________________
# ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]
#
# ________________________
# ['ZoEEgU6L-m85', 1.47, 2.35, 48, ['Treatment', 1.0], []]
#
# ________________________
# ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]
#
# ________________________
# ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU14', 3.35, 4.22, 47, ['Exercise', 1.0], []]
#
# ________________________
# ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]
#
# ________________________
# ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]
#
# ________________________
# ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]
#
# ________________________
# ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]
#
# ________________________
# ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]
#
# ________________________
# ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]
#
# ________________________
# ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]
#
# ________________________
# ['323hkORG0OM3', 0.4, 1.57, 77, ['Tumor', 2.0], []]
#
# ________________________
# ['LYwQdM-2ok41', 0.0, 2.27, 147, ['LungCancer', 5.0], ['Treatment', 1.0, 'Tumor', 1.0, 'Mom', 1.0, 'Bronchitis', 1.0]]
#
# ________________________
# ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw3', 0.36, 2.27, 111, ['Mom', 3.0, 'Child', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw8', 2.31, 3.12, 41, ['Rest', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw12', 4.0, 4.48, 48, ['Friend', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw16', 5.44, 7.33, 108, ['Dad', 2.0, 'Mom', 1.0, 'Family', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw22', 8.07, 8.57, 50, ['Family', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw24', 9.0, 9.44, 44, ['Exercise', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw26', 9.49, 10.39, 50, ['Friend', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw30', 11.37, 13.14, 97, ['Noise', 3.0], []]
#
# ________________________
# ['O5DOre3MFlw35', 13.5, 14.26, 36, ['Noise', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw37', 14.33, 15.22, 49, ['Energy', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw39', 15.3, 16.18, 47, ['Friend', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw43', 17.04, 17.59, 55, ['Dad', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw49', 19.55, 20.35, 40, ['Friend', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw65', 25.45, 26.21, 36, ['Caregiver', 1.0], []]
#
# ________________________
# ['O5DOre3MFlw69', 27.06, 27.5, 44, ['Scared', 1.0], []]
#
# ________________________
# ['bqkquNb5Z8A1', 0.03, 0.41, 38, ['Pain', 1.0], []]
#
# ________________________
# ['bqkquNb5Z8A10', 2.47, 3.31, 43, ['Drug', 1.0], []]
#
# ________________________
# ['bqkquNb5Z8A13', 3.33, 4.04, 31, ['Pain', 1.0], []]
#
# ________________________
# ['qsAnlV8DUXo1', 0.0, 0.42, 42, ['PulmonaryFibrosis', 1.0], []]
#
# ________________________
# ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]
#
# ________________________
# ['2pzHkvmRSW81', 0.08, 1.16, 68, [], ['Copd', 2.0, 'LungDisease', 2.0, 'Community', 1.0, 'Smoking', 2.0]]
#
# ________________________
# ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]
#
# ________________________
# ['2pzHkvmRSW812', 3.19, 3.53, 33, ['LungDisease', 1.0], []]
#
# ________________________
# ******  Temp *****************
# ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]
# *********************************************
# ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]
# *********************************************
# ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]
# *********************************************
# ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]
# *********************************************
# ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]
# *********************************************
# ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]
# *********************************************
# ['rQutyErqBG014', 4.03, 4.59, 55, ['LungCancer', 1.0], []]
# *********************************************
# ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]
# *********************************************
# ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]
# *********************************************
# ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]
# *********************************************
# ['hQQ5xQGZxdA15', 3.17, 4.39, 82, ['LungCancer', 2.0], ['Tumor', 1.0, 'Thinking', 2.0]]
# *********************************************
# ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]
# *********************************************
# ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA58', 12.39, 13.24, 45, ['Tumor', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]
# *********************************************
# ['hQQ5xQGZxdA67', 14.45, 15.11, 26, ['Community', 1.0], []]
# *********************************************
# ['xY3B9nLm1u81', 0.0, 1.13, 72, ['Sleep', 2.0, 'Pain', 2.0], ['Wife', 1.0, 'LungCancer', 1.0]]
# *********************************************
# ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]
# *********************************************
# ['xY3B9nLm1u818', 4.37, 5.16, 39, ['Pain', 1.0, 'Hope', 1.0], []]
# *********************************************
# ['xY3B9nLm1u823', 5.53, 6.37, 44, ['Sleep', 1.0], []]
# *********************************************
# ['yV893Fx41lE1', 0.01, 2.19, 138, ['LungCancer', 3.0], ['Training', 1.0, 'Soreness', 1.0, 'Pain', 2.0, 'Tumor', 1.0]]
# *********************************************
# ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]
# *********************************************
# ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]
# *********************************************
# ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]
# *********************************************
# ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]
# *********************************************
# ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]
# *********************************************
# ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]
# *********************************************
# ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]
# *********************************************
# ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]
# *********************************************
# ['j3t5nFnTULQ7', 2.41, 3.31, 50, ['Hope', 1.0], []]
# *********************************************
# ['j3t5nFnTULQ9', 3.36, 4.22, 46, ['LungDisease', 1.0], []]
# *********************************************
# ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]
# *********************************************
# ['tfxB32Vb5hE8', 1.43, 2.18, 35, ['Tumor', 1.0], []]
# *********************************************
# ['tfxB32Vb5hE10', 2.19, 2.49, 30, ['Hope', 1.0], []]
# *********************************************
# ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]
# *********************************************
# ['0fI_01yFmME3', 0.51, 1.4, 49, ['PulmonaryFibrosis', 1.0], []]
# *********************************************
# ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]
# *********************************************
# ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]
# *********************************************
# ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]
# *********************************************
# ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]
# *********************************************
# ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]
# *********************************************
# ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]
# *********************************************
# ['HBFn82ffSVE30', 7.31, 7.51, 20, ['LungCancer', 1.0], []]
# *********************************************
# ['3mcWSmPXFtM1', 0.0, 1.35, 95, ['Treatment', 2.0], ['LungCancer', 2.0, 'Drug', 2.0]]
# *********************************************
# ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]
# *********************************************
# ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]
# *********************************************
# ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]
# *********************************************
# ['wArV8Ho_C1A8', 2.28, 3.01, 33, ['LungCancer', 1.0], []]
# *********************************************
# ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]
# *********************************************
# ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]
# *********************************************
# ['ehh89UrZtZU12', 0.01, 4.07, 246, ['Copd', 8.0], ['Smoking', 6.0, 'Cough', 1.0]]
# *********************************************
# ['VyGp12XbPzs1', 0.1, 0.54, 44, ['Pneumonia', 1.0], []]
# *********************************************
# ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]
# *********************************************
# ['VyGp12XbPzs4', 2.25, 3.23, 58, ['Hope', 2.0], []]
# *********************************************
# ['jZJTcp3d1q41', 0.11, 2.38, 147, ['Copd', 3.0], ['DailyLiving', 1.0, 'Wife', 1.0, 'Exercise', 1.0]]
# *********************************************
# ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]
# *********************************************
# ['ZU_l9xCB-081', 0.04, 1.48, 104, ['Copd', 3.0], ['Pneumonia', 1.0, 'Fear', 1.0, 'Mom', 1.0, 'Friend', 1.0]]
# *********************************************
# ['Nl55TpSjWp43', 0.42, 1.23, 41, ['Covid', 1.0], []]
# *********************************************
# ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]
# *********************************************
# ['Nl55TpSjWp49', 3.0, 4.27, 86, ['Pneumonia', 2.0], ['Rest', 1.0, 'Covid', 2.0, 'Copd', 1.0, 'LungDisease', 1.0]]
# *********************************************
# ['Nl55TpSjWp414', 4.3, 5.13, 43, ['Treatment', 1.0], []]
# *********************************************
# ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]
# *********************************************
# ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]
# *********************************************
# ['6U7OpgFojaw6', 1.43, 2.15, 32, ['Pneumonia', 1.0], []]
# *********************************************
# ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]
# *********************************************
# ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]
# *********************************************
# ['e0KVtXL-TjY7', 1.31, 2.09, 38, ['PulmonaryHypertension', 1.0], []]
# *********************************************
# ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]
# *********************************************
# ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]
# *********************************************
# ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]
# *********************************************
# ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]
# *********************************************
# ['aHAbRVZOxnk10', 2.58, 3.39, 41, ['Treatment', 1.0, 'Rehabilitation', 1.0], []]
# *********************************************
# ['aHAbRVZOxnk12', 3.43, 4.09, 26, ['Hope', 1.0], []]
# *********************************************
# ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]
# *********************************************
# ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]
# *********************************************
# ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]
# *********************************************
# ['GV3Rew061FA5', 1.31, 5.07, 216, ['Exercise', 7.0], ['Glad', 1.0]]
# *********************************************
# ['Nxrz6_e_gwo1', 0.02, 2.34, 152, ['Copd', 5.0], ['Rest', 1.0, 'Family', 2.0, 'Wheezing', 1.0, 'Exercise', 1.0]]
# *********************************************
# ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]
# *********************************************
# ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]
# *********************************************
# ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]
# *********************************************
# ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]
# *********************************************
# ['q9xteXsPy3c3', 1.13, 1.44, 31, ['LungCancer', 1.0], []]
# *********************************************
# ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]
# *********************************************
# ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]
# *********************************************
# ['POskT8R_3t41', 0.0, 0.38, 38, ['PulmonaryHypertension', 1.0], []]
# *********************************************
# ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]
# *********************************************
# ['POskT8R_3t49', 2.57, 3.5, 53, ['Treatment', 1.0], []]
# *********************************************
# ['3Fker8Nmd5Y1', 0.05, 0.57, 51, ['LungDisease', 1.0], []]
# *********************************************
# ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]
# *********************************************
# ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]
# *********************************************
# ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]
# *********************************************
# ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]
# *********************************************
# ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]
# *********************************************
# ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]
# *********************************************
# ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]
# *********************************************
# ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]
# *********************************************
# ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]
# *********************************************
# ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]
# *********************************************
# ['E8nRS2LxFdw1', 0.0, 0.45, 45, ['Pain', 1.0], []]
# *********************************************
# ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]
# *********************************************
# ['E8nRS2LxFdw7', 1.3, 2.14, 44, ['Training', 1.0], []]
# *********************************************
# ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]
# *********************************************
# ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]
# *********************************************
# ['WShT-I0wCO41', 0.0, 0.5, 50, ['Pain', 1.0, 'Drug', 1.0], []]
# *********************************************
# ['WShT-I0wCO46', 1.27, 2.01, 33, ['LungCancer', 1.0], []]
# *********************************************
# ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]
# *********************************************
# ['WShT-I0wCO410', 2.44, 3.34, 50, ['Treatment', 1.0], []]
# *********************************************
# ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]
# *********************************************
# ['WShT-I0wCO420', 5.39, 6.29, 50, ['Treatment', 1.0], []]
# *********************************************
# ['2utaepga5uk1', 0.0, 0.38, 38, ['Pain', 1.0], []]
# *********************************************
# ['2utaepga5uk3', 0.47, 2.29, 102, ['Treatment', 2.0], ['Friend', 1.0]]
# *********************************************
# ['2utaepga5uk11', 3.22, 4.09, 46, ['Thinking', 1.0], []]
# *********************************************
# ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]
# *********************************************
# ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]
# *********************************************
# ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]
# *********************************************
# ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]
# *********************************************
# ['dyRmGVgG7_84', 0.47, 1.17, 30, ['Copd', 1.0], []]
# *********************************************
# ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]
# *********************************************
# ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]
# *********************************************
# ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]
# *********************************************
# ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]
# *********************************************
# ['9nRhehMpODk3', 0.39, 1.3, 51, ['Hope', 1.0, 'Treatment', 1.0, 'Pain', 1.0], []]
# *********************************************
# ['9nRhehMpODk8', 2.11, 2.59, 48, ['Hope', 1.0], []]
# *********************************************
# ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatment', 1.0, 'LungCancer', 1.0], []]
# *********************************************
# ['Tyo2YsA0Y02', 0.43, 1.19, 36, ['Hope', 1.0], []]
# *********************************************
# ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]
# *********************************************
# ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]
# *********************************************
# ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]
# *********************************************
# ['ZoEEgU6L-m85', 1.47, 2.35, 48, ['Treatment', 1.0], []]
# *********************************************
# ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]
# *********************************************
# ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]
# *********************************************
# ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]
# *********************************************
# ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]
# *********************************************
# ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]
# *********************************************
# ['FH7aHDHnkjU14', 3.35, 4.22, 47, ['Exercise', 1.0], []]
# *********************************************
# ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]
# *********************************************
# ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]
# *********************************************
# ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]
# *********************************************
# ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]
# *********************************************
# ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]
# *********************************************
# ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]
# *********************************************
# ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]
# *********************************************
# ['323hkORG0OM3', 0.4, 1.57, 77, ['Tumor', 2.0], []]
# *********************************************
# ['LYwQdM-2ok41', 0.0, 2.27, 147, ['LungCancer', 5.0], ['Treatment', 1.0, 'Tumor', 1.0, 'Mom', 1.0, 'Bronchitis', 1.0]]
# *********************************************
# ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]
# *********************************************
# ['bqkquNb5Z8A1', 0.03, 0.41, 38, ['Pain', 1.0], []]
# *********************************************
# ['bqkquNb5Z8A10', 2.47, 3.31, 43, ['Drug', 1.0], []]
# *********************************************
# ['bqkquNb5Z8A13', 3.33, 4.04, 31, ['Pain', 1.0], []]
# *********************************************
# ['qsAnlV8DUXo1', 0.0, 0.42, 42, ['PulmonaryFibrosis', 1.0], []]
# *********************************************
# ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]
# *********************************************
# ['2pzHkvmRSW81', 0.08, 1.16, 68, [], ['Copd', 2.0, 'LungDisease', 2.0, 'Community', 1.0, 'Smoking', 2.0]]
# *********************************************
# ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]
# *********************************************
# ['2pzHkvmRSW812', 3.19, 3.53, 33, ['LungDisease', 1.0], []]
# *********************************************
# len(segCharacterisation2) =  298   len(temp)=  161  len(tempUn) =  137
#
# ['l9k9q6FHeX44', 0.4, 1.22, 42, ['Child', 1.0, 'LungCancer', 1.0, 'Education', 1.0], []]
#
# ['l9k9q6FHeX47', 1.24, 3.13, 109, ['ChestPain', 3.0], ['Pain', 2.0, 'Learning', 1.0, 'Cough', 2.0, 'Bronchitis', 1.0]]
#
# ['l9k9q6FHeX415', 3.15, 5.1, 114, ['Pain', 3.0, 'Cough', 2.0], ['ChestPain', 1.0, 'Bronchitis', 1.0]]
#
# ['l9k9q6FHeX424', 5.11, 5.34, 22, ['Thinking', 1.0], []]
#
# ['l9k9q6FHeX426', 5.35, 6.12, 37, ['Fear', 1.0], []]
#
# ['l9k9q6FHeX432', 6.51, 7.51, 60, ['Thinking', 2.0, 'Smoking', 1.0], []]
#
# ['l9k9q6FHeX450', 10.32, 11.09, 37, ['Pain', 1.0], []]
#
# ['l9k9q6FHeX453', 11.1, 11.42, 32, ['Thinking', 1.0], []]
#
# ['l9k9q6FHeX456', 11.45, 12.31, 46, ['Family', 1.0, 'Mom', 1.0], []]
#
# ['l9k9q6FHeX460', 12.34, 13.15, 41, ['LungCancer', 1.0], []]
#
# ['l9k9q6FHeX463', 13.16, 13.51, 35, ['Thinking', 1.0], []]
#
# ['l9k9q6FHeX469', 14.34, 15.14, 40, ['Treatment', 1.0], []]
#
# ['l9k9q6FHeX475', 15.55, 16.31, 35, ['Treatment', 1.0, 'Family', 1.0], []]
#
# ['l9k9q6FHeX481', 17.11, 17.49, 37, ['Friend', 1.0], []]
#
# ['l9k9q6FHeX484', 17.52, 18.28, 36, ['Family', 1.0], []]
#
# ['l9k9q6FHeX487', 18.31, 19.17, 46, ['Friend', 1.0, 'Treatment', 1.0], []]
#
# ['l9k9q6FHeX487', 18.31, 19.3, 59, ['Treatment', 2.0], ['Friend', 1.0]]
#
# ['llk-qgIr9Nk1', 0.01, 0.39, 38, ['Family', 1.0, 'Treatment', 1.0], []]
#
# ['llk-qgIr9Nk4', 0.42, 1.13, 30, ['Tumor', 1.0], []]
#
# ['llk-qgIr9Nk18', 4.08, 5.58, 110, ['Scared', 3.0], ['Mom', 1.0, 'LungCancer', 1.0, 'Community', 1.0]]
#
# ['llk-qgIr9Nk25', 6.0, 6.42, 42, ['Fear', 1.0], []]
#
# ['llk-qgIr9Nk35', 8.18, 8.58, 40, ['Anxiety', 1.0], []]
#
# ['llk-qgIr9Nk41', 9.36, 10.13, 37, ['Mom', 1.0, 'Sleep', 1.0, 'Exercise', 1.0], []]
#
# ['llk-qgIr9Nk47', 11.01, 11.36, 35, ['Treatment', 1.0], []]
#
# ['llk-qgIr9Nk53', 12.15, 13.01, 46, ['Family', 1.0], []]
#
# ['llk-qgIr9Nk56', 13.03, 13.52, 49, ['LungCancer', 1.0, 'Treatment', 1.0], []]
#
# ['llk-qgIr9Nk68', 16.06, 16.45, 39, ['Thinking', 1.0], []]
#
# ['llk-qgIr9Nk74', 17.25, 18.0, 35, ['Sleep', 1.0], []]
#
# ['llk-qgIr9Nk77', 18.02, 18.39, 37, ['Family', 1.0, 'Husband', 1.0, 'Insurance', 1.0], []]
#
# ['llk-qgIr9Nk83', 19.23, 20.03, 40, ['Exercise', 1.0], []]
#
# ['llk-qgIr9Nk86', 20.04, 20.41, 37, ['Husband', 1.0], []]
#
# ['llk-qgIr9Nk95', 21.58, 22.38, 40, ['Exercise', 1.0], []]
#
# ['llk-qgIr9Nk104', 24.08, 24.48, 40, ['Family', 1.0], []]
#
# ['llk-qgIr9Nk116', 26.54, 27.37, 43, ['Insurance', 1.0, 'LungCancer', 1.0], []]
#
# ['llk-qgIr9Nk119', 27.39, 28.16, 37, ['Church', 1.0, 'Safety', 1.0], []]
#
# ['llk-qgIr9Nk128', 29.45, 30.26, 41, ['Mom', 1.0], []]
#
# ['llk-qgIr9Nk137', 31.48, 32.26, 37, ['Exercise', 1.0], []]
#
# ['llk-qgIr9Nk143', 33.06, 33.46, 39, ['Traffic', 1.0], []]
#
# ['llk-qgIr9Nk155', 35.54, 36.32, 38, ['Treatment', 1.0], []]
#
# ['llk-qgIr9Nk158', 36.33, 37.2, 47, ['Anxiety', 1.0, 'Sleep', 1.0], []]
#
# ['llk-qgIr9Nk161', 37.21, 37.5, 29, ['LungCancer', 1.0], []]
#
# ['bmvlK4qhAnU1', 0.0, 0.47, 47, ['Husband', 1.0, 'Tumor', 1.0], []]
#
# ['bmvlK4qhAnU4', 0.5, 3.08, 138, ['LungCancer', 3.0, 'Hope', 3.0], []]
#
# ['bmvlK4qhAnU12', 3.1, 3.5, 40, ['Wife', 1.0, 'Mom', 1.0, 'Education', 1.0, 'Community', 1.0], []]
#
# ['bmvlK4qhAnU15', 3.53, 4.33, 40, ['Husband', 1.0], []]
#
# ['bmvlK4qhAnU30', 7.31, 8.13, 42, ['Sleep', 1.0], []]
#
# ['bmvlK4qhAnU33', 8.19, 9.07, 48, ['Rest', 1.0], []]
#
# ['bmvlK4qhAnU36', 9.09, 9.52, 43, ['Tumor', 1.0], []]
#
# ['bmvlK4qhAnU42', 10.43, 11.27, 44, ['ShortnessOfBreath', 1.0], []]
#
# ['bmvlK4qhAnU45', 11.29, 12.14, 45, ['Friend', 1.0], []]
#
# ['bmvlK4qhAnU54', 13.45, 14.35, 50, ['Pain', 1.0], []]
#
# ['bmvlK4qhAnU59', 15.14, 16.0, 46, ['LungCancer', 1.0], []]
#
# ['bmvlK4qhAnU65', 16.5, 17.37, 47, ['Husband', 1.0], []]
#
# ['bmvlK4qhAnU70', 18.16, 20.04, 108, ['LungCancer', 4.0], ['Thinking', 1.0, 'Family', 1.0, 'Rest', 1.0]]
#
# ['bmvlK4qhAnU77', 20.06, 21.28, 82, ['Friend', 2.0], []]
#
# ['bmvlK4qhAnU84', 22.02, 22.48, 46, ['Husband', 1.0, 'Dad', 1.0], []]
#
# ['bmvlK4qhAnU87', 22.51, 23.19, 28, ['Rest', 1.0], []]
#
# ['bmvlK4qhAnU89', 23.24, 24.09, 45, ['Thinking', 1.0, 'Strength', 1.0], []]
#
# ['bmvlK4qhAnU92', 24.11, 24.55, 44, ['Family', 1.0, 'Treatment', 1.0], []]
#
# ['bmvlK4qhAnU92', 24.11, 25.03, 52, ['Treatment', 2.0], ['Family', 1.0]]
#
# ['r20Ak5ZxP_41', 0.05, 0.52, 47, ['Hope', 1.0, 'Learning', 1.0], []]
#
# ['r20Ak5ZxP_44', 0.54, 1.44, 50, ['Community', 1.0], []]
#
# ['r20Ak5ZxP_47', 1.47, 2.29, 42, ['LungCancer', 1.0], []]
#
# ['r20Ak5ZxP_413', 3.19, 4.02, 42, ['Fatigue', 1.0, 'Scared', 2.0], []]
#
# ['r20Ak5ZxP_416', 4.03, 4.46, 42, ['Husband', 1.0, 'LungCancer', 1.0, 'Energy', 1.0], []]
#
# ['r20Ak5ZxP_419', 4.47, 5.3, 43, ['Pneumonia', 1.0, 'Cough', 1.0], []]
#
# ['r20Ak5ZxP_430', 7.36, 8.21, 45, ['Anxiety', 1.0, 'Cough', 1.0], []]
#
# ['r20Ak5ZxP_443', 11.05, 11.52, 46, ['Treatment', 1.0], []]
#
# ['r20Ak5ZxP_458', 11.55, 15.55, 240, ['Smoking', 7.0], ['LungCancer', 3.0, 'Tension', 1.0, 'Family', 1.0, 'Education', 1.0]]
#
# ['MjEJaR3zLjg1', 0.01, 0.36, 35, ['Hope', 1.0, 'Glad', 1.0, 'Caregiver', 1.0, 'LungCancer', 1.0], []]
#
# ['MjEJaR3zLjg4', 0.39, 1.2, 41, ['Husband', 1.0], []]
#
# ['MjEJaR3zLjg7', 1.22, 1.59, 37, ['Treatment', 1.0], []]
#
# ['MjEJaR3zLjg10', 2.01, 4.11, 130, ['Pneumonia', 2.0], ['Asthma', 2.0, 'Mom', 1.0, 'LungCancer', 1.0, 'Tumor', 1.0]]
#
# ['MjEJaR3zLjg19', 4.12, 4.51, 39, ['Family', 1.0], []]
#
# ['MjEJaR3zLjg25', 5.34, 6.14, 39, ['Insurance', 1.0], []]
#
# ['MjEJaR3zLjg33', 7.32, 8.12, 39, ['Anxiety', 1.0], []]
#
# ['MjEJaR3zLjg39', 8.54, 10.0, 66, ['LungCancer', 2.0], []]
#
# ['MjEJaR3zLjg52', 12.0, 12.38, 38, ['Family', 1.0], []]
#
# ['MjEJaR3zLjg60', 14.03, 14.46, 43, ['Exercise', 1.0, 'Thinking', 1.0], []]
#
# ['MjEJaR3zLjg63', 14.48, 16.23, 95, ['Anxiety', 2.0], ['Husband', 1.0, 'Pneumonia', 1.0, 'LungCancer', 1.0, 'Mom', 1.0]]
#
# ['MjEJaR3zLjg71', 16.53, 18.54, 120, ['Tumor', 4.0], ['LungCancer', 1.0, 'Treatment', 1.0]]
#
# ['MjEJaR3zLjg80', 18.57, 19.2, 23, ['Family', 1.0], []]
#
# ['MjEJaR3zLjg86', 20.12, 21.33, 80, ['Community', 2.0], ['Mom', 1.0]]
#
# ['MjEJaR3zLjg101', 23.36, 24.12, 36, ['LungCancer', 1.0], []]
#
# ['MjEJaR3zLjg104', 24.14, 24.5, 36, ['Sleep', 1.0], []]
#
# ['MjEJaR3zLjg107', 24.52, 27.31, 158, ['Family', 4.0], ['Pneumonia', 1.0, 'Caregiver', 1.0, 'Child', 1.0]]
#
# ['HCgXqdpQGhc1', 0.01, 0.44, 43, ['Hope', 1.0, 'LungCancer', 1.0], []]
#
# ['HCgXqdpQGhc4', 0.47, 1.19, 32, ['Husband', 1.0], []]
#
# ['HCgXqdpQGhc9', 2.06, 2.48, 42, ['LungCancer', 1.0], []]
#
# ['HCgXqdpQGhc15', 3.36, 4.2, 44, ['Treatment', 1.0], []]
#
# ['HCgXqdpQGhc27', 6.41, 8.28, 106, ['Husband', 2.0], ['Exercise', 1.0, 'Thinking', 2.0]]
#
# ['HCgXqdpQGhc35', 8.3, 9.18, 47, ['LungCancer', 1.0], []]
#
# ['HCgXqdpQGhc39', 9.2, 10.0, 40, ['Anxiety', 1.0], []]
#
# ['HCgXqdpQGhc45', 10.47, 11.35, 47, ['Drug', 1.0], []]
#
# ['HCgXqdpQGhc54', 13.05, 13.41, 35, ['Pain', 1.0], []]
#
# ['HCgXqdpQGhc57', 13.42, 14.27, 45, ['Husband', 1.0], []]
#
# ['HCgXqdpQGhc60', 14.29, 15.07, 38, ['Friend', 1.0], []]
#
# ['HCgXqdpQGhc66', 15.55, 16.39, 43, ['Learning', 1.0, 'Caregiver', 1.0], []]
#
# ['HCgXqdpQGhc77', 18.57, 19.46, 49, ['Husband', 1.0], []]
#
# ['HCgXqdpQGhc80', 19.48, 22.04, 136, ['LungCancer', 2.0], ['Pain', 1.0, 'Husband', 2.0, 'Family', 1.0, 'Treatment', 1.0]]
#
# ['HCgXqdpQGhc90', 22.25, 23.52, 87, ['Treatment', 2.0], []]
#
# ['HCgXqdpQGhc98', 24.25, 26.04, 99, ['Drug', 2.0, 'Treatment', 3.0], ['Hope', 1.0, 'Thinking', 1.0]]
#
# ['HCgXqdpQGhc105', 26.06, 26.49, 43, ['Caregiver', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]
#
# ['FHXbDHakK1w1', 0.01, 0.37, 36, ['LungCancer', 1.0], []]
#
# ['FHXbDHakK1w4', 2.06, 3.26, 79, ['Wife', 1.0, 'Family', 2.0, 'Rest', 1.0], []]
#
# ['FHXbDHakK1w6', 3.32, 4.12, 40, ['Rest', 1.0], []]
#
# ['FHXbDHakK1w7', 4.2, 7.07, 167, ['Wife', 2.0, 'Thinking', 2.0], ['ShortnessOfBreath', 3.0]]
#
# ['FHXbDHakK1w11', 7.12, 8.36, 84, ['Wheezing', 1.0, 'Bronchitis', 2.0], []]
#
# ['FHXbDHakK1w13', 8.43, 10.08, 85, ['Insurance', 1.0, 'Pneumonia', 2.0, 'Anxiety', 1.0], []]
#
# ['FHXbDHakK1w15', 10.13, 10.55, 42, ['LungCancer', 1.0], []]
#
# ['FHXbDHakK1w16', 11.0, 11.39, 39, ['Community', 1.0], []]
#
# ['FHXbDHakK1w20', 14.05, 14.42, 36, ['LungCancer', 1.0], []]
#
# ['FHXbDHakK1w22', 15.3, 16.08, 37, ['LungCancer', 1.0], []]
#
# ['FHXbDHakK1w23', 16.14, 16.5, 36, ['Gym', 1.0], []]
#
# ['FHXbDHakK1w24', 16.56, 17.31, 34, ['Treatment', 1.0], []]
#
# ['FHXbDHakK1w26', 18.22, 19.0, 38, ['Family', 1.0, 'Strength', 1.0], []]
#
# ['FHXbDHakK1w28', 19.5, 21.1, 80, ['Treatment', 2.0], []]
#
# ['FHXbDHakK1w30', 21.15, 24.44, 209, ['Friend', 4.0], ['Wife', 1.0, 'Rest', 1.0, 'Treatment', 1.0]]
#
# ['FHXbDHakK1w36', 25.34, 28.27, 173, ['Treatment', 2.0, 'LungCancer', 3.0], ['Drug', 1.0, 'Scared', 1.0]]
#
# ['FHXbDHakK1w39', 27.52, 28.27, 35, ['Scared', 1.0], []]
#
# ['FHXbDHakK1w40', 28.32, 29.09, 37, ['LungCancer', 1.0], []]
#
# ['FHXbDHakK1w44', 31.33, 32.47, 74, ['Anxiety', 2.0, 'Wife', 1.0, 'Treatment', 1.0], []]
#
# ['O5DOre3MFlw3', 0.36, 2.27, 111, ['Mom', 3.0, 'Child', 1.0], []]
#
# ['O5DOre3MFlw8', 2.31, 3.12, 41, ['Rest', 1.0], []]
#
# ['O5DOre3MFlw12', 4.0, 4.48, 48, ['Friend', 1.0], []]
#
# ['O5DOre3MFlw16', 5.44, 7.33, 108, ['Dad', 2.0, 'Mom', 1.0, 'Family', 1.0], []]
#
# ['O5DOre3MFlw22', 8.07, 8.57, 50, ['Family', 1.0], []]
#
# ['O5DOre3MFlw24', 9.0, 9.44, 44, ['Exercise', 1.0], []]
#
# ['O5DOre3MFlw26', 9.49, 10.39, 50, ['Friend', 1.0], []]
#
# ['O5DOre3MFlw30', 11.37, 13.14, 97, ['Noise', 3.0], []]
#
# ['O5DOre3MFlw35', 13.5, 14.26, 36, ['Noise', 1.0], []]
#
# ['O5DOre3MFlw37', 14.33, 15.22, 49, ['Energy', 1.0], []]
#
# ['O5DOre3MFlw39', 15.3, 16.18, 47, ['Friend', 1.0], []]
#
# ['O5DOre3MFlw43', 17.04, 17.59, 55, ['Dad', 1.0], []]
#
# ['O5DOre3MFlw49', 19.55, 20.35, 40, ['Friend', 1.0], []]
#
# ['O5DOre3MFlw65', 25.45, 26.21, 36, ['Caregiver', 1.0], []]
#
# ['O5DOre3MFlw69', 27.06, 27.5, 44, ['Scared', 1.0], []]
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
#### Generate some analyatics for the thesis- just this piece of code
########################################################################
processedConcepts=[]
narrConditional=[]
for i in  segCharacterisation2:
    # 1 find the path of the required concept to help in deciding its siblings
    
    conceptPath=[]
    siblingConcepts=[]
    corrNarrativeChild=[] 
    conceptSeg=[]
    if len(i[4])>1:
        
        for co in i[4][::2]:
            conceptPath=[]
            siblingConcepts=[]
            corrNarrativeChild=[] 
            if co not in processedConcepts:
                
                processedConcepts.append(co)
            
                for j in cleanedParents2:

                    if len(j)>1:
                        if j[0]==co :
                            #print('j in cleaned parents has match with i ',j,'    i ',co)
                            conceptPath=j
                #print('conceptPath ',conceptPath)    
                #print()

                # 2 Find concept's siblings from the ontology
                for j in cleanedParents2:
                    if len(j)>1:
                        if len(conceptPath)>1:
                            if conceptPath[1] == j[1] and conceptPath[0] != j[0]:
                                siblingConcepts.append(j)
                            
                            #elif conceptPath[1] == j[1] and conceptPath[0] != j[0]:
                            #    concept

                

                # 3 find the siblings in the characterised segments by comparing the segments with the list of possible siblings from the ontology    



                #print('i= ',i)
                #print()
                conceptSeg=[]
                for s in segCharacterisation2:
                    for j in s[4][::2]: # move two step not one by one to avoid comapring text with numbers as each element in i[4]=[concept,number of mentions]
                        for c in siblingConcepts:
                            if j==c[0]:
                                corrNarrativeChild.append([j,s])
                            elif j==co:
                                conceptSeg.append([j,s])



                # Add the rest of the conditions
                temp=[]
                temp2=[]

                notInList=[]
                duration=0
                numbOfSeg=0
                match=False
                noConSeg=0
                
                # if there are segments about the concept its self, then half of the segment will be for the narratives and 
                # the other half for the concept. Depend on how many segments for each group we have
                
               
                    
                        
                
                    
                for j in corrNarrativeChild:
                    
                    match=False

                    if temp:
                        for x in temp:
                            if x[1] == j[1]:
                                #print()
                                #print('Match')
                                #print()
                                #print('x[1]= ',x[1])
                                #print()
                                #print('i[1]= ',i[1])
                                #print()
                                match=True
                        if not match:
                            #print('not match so add it')
                            #print()
                            temp.append(j)
                            
                    else:
                        temp.append(j)

                       
                if conceptSeg:
                                
                    for j in conceptSeg:
                        
                        match=False

                        if temp2:
                            for x in temp2:
                                if x[1] == j[1]:
                                    
                                    match=True
                            if not match:
                               
                                temp2.append(j)
                                
                        else:
                            temp2.append(j)

                            
                        
               
                if temp2:
                   
                    narrConditional.append([co,temp,temp2])
                else:
                    narrConditional.append([co,temp])
                    
                temp=[]
                temp2=[]
                notInList=[]
               
                match=False
                
                
tempDuration=0
narrativesDuration=[]
print('len(narrConditional) ',len(narrConditional))
for i in narrConditional:
    if i[1]:
        print('*********  i[1]  *******************')
        for j in i[1]:
            tempDuration+=j[1][3]
            print(j)
            print()
        if i[2]:
            print('*********  i[2]  *******************')
            for j in i[2]:
                tempDuration+=j[1][3]
                print(j)
                print()
            
    narrativesDuration.append(tempDuration)
    tempDuration=0
    print('_________________________________________________')
    print()

print('Duration average= ',round(np.average(narrativesDuration),0))
print()
print('Duration STDV= ',round(np.std(narrativesDuration),0))
# Out:
# len(narrConditional)  51
# *********  i[1]  *******************
# ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]
#
# *********  i[2]  *******************
# ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# ['Thinking', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['2utaepga5uk11', 3.22, 4.09, 46, ['Thinking', 1.0], []]]
#
# ['Thinking', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]]
#
# ['Family', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]]
#
# ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]]
#
# ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]]
#
# ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]]
#
# ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]]
#
# ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]]
#
# ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]]
#
# ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]]
#
# ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]]
#
# ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]]
#
# ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]]
#
# ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]]
#
# ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]]
#
# ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]]
#
# ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]]
#
# ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]]
#
# ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]]
#
# ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]]
#
# ['Family', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Child', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# ['Wife', ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]]
#
# ['Family', ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]]
#
# ['Wife', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ['Grandchild', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# ['Family', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['Family', ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]]
#
# ['Friend', ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]]
#
# *********  i[2]  *******************
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]]
#
# ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# *********  i[2]  *******************
# ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# ['Treatment', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]]
#
# ['Treatment', ['3mcWSmPXFtM1', 0.0, 1.35, 95, ['Treatment', 2.0], ['LungCancer', 2.0, 'Drug', 2.0]]]
#
# ['Treatment', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['Nl55TpSjWp414', 4.3, 5.13, 43, ['Treatment', 1.0], []]]
#
# ['Treatment', ['aHAbRVZOxnk10', 2.58, 3.39, 41, ['Treatment', 1.0, 'Rehabilitation', 1.0], []]]
#
# ['Treatment', ['POskT8R_3t49', 2.57, 3.5, 53, ['Treatment', 1.0], []]]
#
# ['Treatment', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['WShT-I0wCO410', 2.44, 3.34, 50, ['Treatment', 1.0], []]]
#
# ['Treatment', ['WShT-I0wCO420', 5.39, 6.29, 50, ['Treatment', 1.0], []]]
#
# ['Treatment', ['2utaepga5uk3', 0.47, 2.29, 102, ['Treatment', 2.0], ['Friend', 1.0]]]
#
# ['Treatment', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# ['Treatment', ['9nRhehMpODk3', 0.39, 1.3, 51, ['Hope', 1.0, 'Treatment', 1.0, 'Pain', 1.0], []]]
#
# ['Treatment', ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatment', 1.0, 'LungCancer', 1.0], []]]
#
# ['Treatment', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]]
#
# ['Treatment', ['ZoEEgU6L-m85', 1.47, 2.35, 48, ['Treatment', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]]
#
# ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]]
#
# ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['Tumor', ['hQQ5xQGZxdA58', 12.39, 13.24, 45, ['Tumor', 1.0], []]]
#
# ['Copd', ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]]
#
# ['LungDisease', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# ['LungDisease', ['j3t5nFnTULQ9', 3.36, 4.22, 46, ['LungDisease', 1.0], []]]
#
# ['Tumor', ['tfxB32Vb5hE8', 1.43, 2.18, 35, ['Tumor', 1.0], []]]
#
# ['PulmonaryFibrosis', ['0fI_01yFmME3', 0.51, 1.4, 49, ['PulmonaryFibrosis', 1.0], []]]
#
# ['Pneumonia', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Tumor', ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]]
#
# ['Pneumonia', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# ['Copd', ['ehh89UrZtZU12', 0.01, 4.07, 246, ['Copd', 8.0], ['Smoking', 6.0, 'Cough', 1.0]]]
#
# ['Pneumonia', ['VyGp12XbPzs1', 0.1, 0.54, 44, ['Pneumonia', 1.0], []]]
#
# ['Copd', ['jZJTcp3d1q41', 0.11, 2.38, 147, ['Copd', 3.0], ['DailyLiving', 1.0, 'Wife', 1.0, 'Exercise', 1.0]]]
#
# ['Copd', ['ZU_l9xCB-081', 0.04, 1.48, 104, ['Copd', 3.0], ['Pneumonia', 1.0, 'Fear', 1.0, 'Mom', 1.0, 'Friend', 1.0]]]
#
# ['Covid', ['Nl55TpSjWp43', 0.42, 1.23, 41, ['Covid', 1.0], []]]
#
# ['Pneumonia', ['Nl55TpSjWp49', 3.0, 4.27, 86, ['Pneumonia', 2.0], ['Rest', 1.0, 'Covid', 2.0, 'Copd', 1.0, 'LungDisease', 1.0]]]
#
# ['Pneumonia', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# ['Pneumonia', ['6U7OpgFojaw6', 1.43, 2.15, 32, ['Pneumonia', 1.0], []]]
#
# ['PulmonaryHypertension', ['e0KVtXL-TjY7', 1.31, 2.09, 38, ['PulmonaryHypertension', 1.0], []]]
#
# ['PulmonaryFibrosis', ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]]
#
# ['Copd', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# ['Copd', ['Nxrz6_e_gwo1', 0.02, 2.34, 152, ['Copd', 5.0], ['Rest', 1.0, 'Family', 2.0, 'Wheezing', 1.0, 'Exercise', 1.0]]]
#
# ['Copd', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]]
#
# ['Tumor', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]]
#
# ['PulmonaryHypertension', ['POskT8R_3t41', 0.0, 0.38, 38, ['PulmonaryHypertension', 1.0], []]]
#
# ['LungDisease', ['3Fker8Nmd5Y1', 0.05, 0.57, 51, ['LungDisease', 1.0], []]]
#
# ['Copd', ['dyRmGVgG7_84', 0.47, 1.17, 30, ['Copd', 1.0], []]]
#
# ['PulmonaryFibrosis', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# ['LungDisease', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['Tumor', ['323hkORG0OM3', 0.4, 1.57, 77, ['Tumor', 2.0], []]]
#
# ['Tumor', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# ['PulmonaryFibrosis', ['qsAnlV8DUXo1', 0.0, 0.42, 42, ['PulmonaryFibrosis', 1.0], []]]
#
# ['LungDisease', ['2pzHkvmRSW812', 3.19, 3.53, 33, ['LungDisease', 1.0], []]]
#
# *********  i[2]  *******************
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['rQutyErqBG014', 4.03, 4.59, 55, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['LungCancer', ['hQQ5xQGZxdA15', 3.17, 4.39, 82, ['LungCancer', 2.0], ['Tumor', 1.0, 'Thinking', 2.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['yV893Fx41lE1', 0.01, 2.19, 138, ['LungCancer', 3.0], ['Training', 1.0, 'Soreness', 1.0, 'Pain', 2.0, 'Tumor', 1.0]]]
#
# ['LungCancer', ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]]
#
# ['LungCancer', ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]]
#
# ['LungCancer', ['HBFn82ffSVE30', 7.31, 7.51, 20, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['wArV8Ho_C1A8', 2.28, 3.01, 33, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['q9xteXsPy3c3', 1.13, 1.44, 31, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['WShT-I0wCO46', 1.27, 2.01, 33, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# ['LungCancer', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['LungCancer', ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]]
#
# ['LungCancer', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatment', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['LungCancer', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# ['LungCancer', ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]]
#
# ['LungCancer', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# ['LungCancer', ['LYwQdM-2ok41', 0.0, 2.27, 147, ['LungCancer', 5.0], ['Treatment', 1.0, 'Tumor', 1.0, 'Mom', 1.0, 'Bronchitis', 1.0]]]
#
# _________________________________________________
#
# _________________________________________________
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Rest', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Rest', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# ['Rest', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# ['Rest', ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]]
#
# ['Rest', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# ['Rest', ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]]
#
# *********  i[2]  *******************
# ['Energy', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['Energy', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# ['Energy', ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]]
#
# ['Energy', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]]
#
# ['Energy', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# _________________________________________________
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]]
#
# ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]]
#
# ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]]
#
# ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]]
#
# ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]]
#
# ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]]
#
# ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]]
#
# ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]]
#
# ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]]
#
# ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]]
#
# ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]]
#
# ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]]
#
# ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]]
#
# ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]]
#
# ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]]
#
# ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]]
#
# ['Family', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Wife', ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]]
#
# ['Family', ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]]
#
# ['Wife', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ['Grandchild', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# ['Family', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['Family', ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]]
#
# ['Friend', ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]]
#
# *********  i[2]  *******************
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]]
#
# ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]]
#
# ['Child', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]]
#
# ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]]
#
# ['Child', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# *********  i[2]  *******************
# ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]]
#
# ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]]
#
# ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]]
#
# ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]]
#
# ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]]
#
# ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]]
#
# ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]]
#
# ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]]
#
# ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]]
#
# ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]]
#
# ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]]
#
# ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]]
#
# ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]]
#
# ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]]
#
# ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]]
#
# ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]]
#
# ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]]
#
# ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]]
#
# ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]]
#
# ['Family', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Child', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# ['Wife', ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]]
#
# ['Family', ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]]
#
# ['Wife', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ['Grandchild', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# ['Family', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['Family', ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]]
#
# ['Friend', ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]]
#
# *********  i[2]  *******************
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# *********  i[2]  *******************
# ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]]
#
# ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]]
#
# ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]]
#
# ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]]
#
# ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]]
#
# ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]]
#
# ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]]
#
# ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]]
#
# ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]]
#
# ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]]
#
# ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]]
#
# ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]]
#
# ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]]
#
# ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]]
#
# ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]]
#
# ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]]
#
# ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]]
#
# ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]]
#
# ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]]
#
# ['Family', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Child', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# ['Wife', ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]]
#
# ['Family', ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]]
#
# ['Wife', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ['Grandchild', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# ['Family', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['Family', ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]]
#
# ['Friend', ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]]
#
# *********  i[2]  *******************
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['rQutyErqBG014', 4.03, 4.59, 55, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['LungCancer', ['hQQ5xQGZxdA15', 3.17, 4.39, 82, ['LungCancer', 2.0], ['Tumor', 1.0, 'Thinking', 2.0]]]
#
# ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]]
#
# ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Tumor', ['hQQ5xQGZxdA58', 12.39, 13.24, 45, ['Tumor', 1.0], []]]
#
# ['LungCancer', ['yV893Fx41lE1', 0.01, 2.19, 138, ['LungCancer', 3.0], ['Training', 1.0, 'Soreness', 1.0, 'Pain', 2.0, 'Tumor', 1.0]]]
#
# ['Copd', ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]]
#
# ['LungDisease', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# ['LungDisease', ['j3t5nFnTULQ9', 3.36, 4.22, 46, ['LungDisease', 1.0], []]]
#
# ['LungCancer', ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]]
#
# ['Tumor', ['tfxB32Vb5hE8', 1.43, 2.18, 35, ['Tumor', 1.0], []]]
#
# ['PulmonaryFibrosis', ['0fI_01yFmME3', 0.51, 1.4, 49, ['PulmonaryFibrosis', 1.0], []]]
#
# ['LungCancer', ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]]
#
# ['LungCancer', ['HBFn82ffSVE30', 7.31, 7.51, 20, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['wArV8Ho_C1A8', 2.28, 3.01, 33, ['LungCancer', 1.0], []]]
#
# ['Copd', ['ehh89UrZtZU12', 0.01, 4.07, 246, ['Copd', 8.0], ['Smoking', 6.0, 'Cough', 1.0]]]
#
# ['Copd', ['jZJTcp3d1q41', 0.11, 2.38, 147, ['Copd', 3.0], ['DailyLiving', 1.0, 'Wife', 1.0, 'Exercise', 1.0]]]
#
# ['Copd', ['ZU_l9xCB-081', 0.04, 1.48, 104, ['Copd', 3.0], ['Pneumonia', 1.0, 'Fear', 1.0, 'Mom', 1.0, 'Friend', 1.0]]]
#
# ['Covid', ['Nl55TpSjWp43', 0.42, 1.23, 41, ['Covid', 1.0], []]]
#
# ['PulmonaryHypertension', ['e0KVtXL-TjY7', 1.31, 2.09, 38, ['PulmonaryHypertension', 1.0], []]]
#
# ['PulmonaryFibrosis', ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]]
#
# ['Copd', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# ['Copd', ['Nxrz6_e_gwo1', 0.02, 2.34, 152, ['Copd', 5.0], ['Rest', 1.0, 'Family', 2.0, 'Wheezing', 1.0, 'Exercise', 1.0]]]
#
# ['Copd', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]]
#
# ['LungCancer', ['q9xteXsPy3c3', 1.13, 1.44, 31, ['LungCancer', 1.0], []]]
#
# ['Tumor', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['PulmonaryHypertension', ['POskT8R_3t41', 0.0, 0.38, 38, ['PulmonaryHypertension', 1.0], []]]
#
# ['LungDisease', ['3Fker8Nmd5Y1', 0.05, 0.57, 51, ['LungDisease', 1.0], []]]
#
# ['LungCancer', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['WShT-I0wCO46', 1.27, 2.01, 33, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# ['LungCancer', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['Copd', ['dyRmGVgG7_84', 0.47, 1.17, 30, ['Copd', 1.0], []]]
#
# ['LungCancer', ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]]
#
# ['LungCancer', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatment', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['LungCancer', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# ['PulmonaryFibrosis', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# ['LungCancer', ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]]
#
# ['LungCancer', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# ['LungDisease', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['Tumor', ['323hkORG0OM3', 0.4, 1.57, 77, ['Tumor', 2.0], []]]
#
# ['LungCancer', ['LYwQdM-2ok41', 0.0, 2.27, 147, ['LungCancer', 5.0], ['Treatment', 1.0, 'Tumor', 1.0, 'Mom', 1.0, 'Bronchitis', 1.0]]]
#
# ['Tumor', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# ['PulmonaryFibrosis', ['qsAnlV8DUXo1', 0.0, 0.42, 42, ['PulmonaryFibrosis', 1.0], []]]
#
# ['LungDisease', ['2pzHkvmRSW812', 3.19, 3.53, 33, ['LungDisease', 1.0], []]]
#
# *********  i[2]  *******************
# ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]]
#
# ['Pneumonia', ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]]
#
# ['Pneumonia', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Pneumonia', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# ['Pneumonia', ['VyGp12XbPzs1', 0.1, 0.54, 44, ['Pneumonia', 1.0], []]]
#
# ['Pneumonia', ['Nl55TpSjWp49', 3.0, 4.27, 86, ['Pneumonia', 2.0], ['Rest', 1.0, 'Covid', 2.0, 'Copd', 1.0, 'LungDisease', 1.0]]]
#
# ['Pneumonia', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# ['Pneumonia', ['6U7OpgFojaw6', 1.43, 2.15, 32, ['Pneumonia', 1.0], []]]
#
# ['Pneumonia', ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['rQutyErqBG014', 4.03, 4.59, 55, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA15', 3.17, 4.39, 82, ['LungCancer', 2.0], ['Tumor', 1.0, 'Thinking', 2.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['yV893Fx41lE1', 0.01, 2.19, 138, ['LungCancer', 3.0], ['Training', 1.0, 'Soreness', 1.0, 'Pain', 2.0, 'Tumor', 1.0]]]
#
# ['Copd', ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]]
#
# ['LungDisease', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# ['LungDisease', ['j3t5nFnTULQ9', 3.36, 4.22, 46, ['LungDisease', 1.0], []]]
#
# ['LungCancer', ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]]
#
# ['PulmonaryFibrosis', ['0fI_01yFmME3', 0.51, 1.4, 49, ['PulmonaryFibrosis', 1.0], []]]
#
# ['Pneumonia', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['LungCancer', ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]]
#
# ['Pneumonia', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# ['LungCancer', ['HBFn82ffSVE30', 7.31, 7.51, 20, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['wArV8Ho_C1A8', 2.28, 3.01, 33, ['LungCancer', 1.0], []]]
#
# ['Copd', ['ehh89UrZtZU12', 0.01, 4.07, 246, ['Copd', 8.0], ['Smoking', 6.0, 'Cough', 1.0]]]
#
# ['Pneumonia', ['VyGp12XbPzs1', 0.1, 0.54, 44, ['Pneumonia', 1.0], []]]
#
# ['Copd', ['jZJTcp3d1q41', 0.11, 2.38, 147, ['Copd', 3.0], ['DailyLiving', 1.0, 'Wife', 1.0, 'Exercise', 1.0]]]
#
# ['Copd', ['ZU_l9xCB-081', 0.04, 1.48, 104, ['Copd', 3.0], ['Pneumonia', 1.0, 'Fear', 1.0, 'Mom', 1.0, 'Friend', 1.0]]]
#
# ['Covid', ['Nl55TpSjWp43', 0.42, 1.23, 41, ['Covid', 1.0], []]]
#
# ['Pneumonia', ['Nl55TpSjWp49', 3.0, 4.27, 86, ['Pneumonia', 2.0], ['Rest', 1.0, 'Covid', 2.0, 'Copd', 1.0, 'LungDisease', 1.0]]]
#
# ['Pneumonia', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# ['Pneumonia', ['6U7OpgFojaw6', 1.43, 2.15, 32, ['Pneumonia', 1.0], []]]
#
# ['PulmonaryHypertension', ['e0KVtXL-TjY7', 1.31, 2.09, 38, ['PulmonaryHypertension', 1.0], []]]
#
# ['PulmonaryFibrosis', ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]]
#
# ['Copd', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# ['Copd', ['Nxrz6_e_gwo1', 0.02, 2.34, 152, ['Copd', 5.0], ['Rest', 1.0, 'Family', 2.0, 'Wheezing', 1.0, 'Exercise', 1.0]]]
#
# ['Copd', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]]
#
# ['LungCancer', ['q9xteXsPy3c3', 1.13, 1.44, 31, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['PulmonaryHypertension', ['POskT8R_3t41', 0.0, 0.38, 38, ['PulmonaryHypertension', 1.0], []]]
#
# ['LungDisease', ['3Fker8Nmd5Y1', 0.05, 0.57, 51, ['LungDisease', 1.0], []]]
#
# ['LungCancer', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['WShT-I0wCO46', 1.27, 2.01, 33, ['LungCancer', 1.0], []]]
#
# ['LungCancer', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# ['LungCancer', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['Copd', ['dyRmGVgG7_84', 0.47, 1.17, 30, ['Copd', 1.0], []]]
#
# ['LungCancer', ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]]
#
# ['LungCancer', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatment', 1.0, 'LungCancer', 1.0], []]]
#
# ['LungCancer', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['LungCancer', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# ['PulmonaryFibrosis', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# ['LungCancer', ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]]
#
# ['LungCancer', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# ['LungDisease', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['LungCancer', ['LYwQdM-2ok41', 0.0, 2.27, 147, ['LungCancer', 5.0], ['Treatment', 1.0, 'Tumor', 1.0, 'Mom', 1.0, 'Bronchitis', 1.0]]]
#
# ['PulmonaryFibrosis', ['qsAnlV8DUXo1', 0.0, 0.42, 42, ['PulmonaryFibrosis', 1.0], []]]
#
# ['LungDisease', ['2pzHkvmRSW812', 3.19, 3.53, 33, ['LungDisease', 1.0], []]]
#
# *********  i[2]  *******************
# ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]]
#
# ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['Tumor', ['hQQ5xQGZxdA58', 12.39, 13.24, 45, ['Tumor', 1.0], []]]
#
# ['Tumor', ['tfxB32Vb5hE8', 1.43, 2.18, 35, ['Tumor', 1.0], []]]
#
# ['Tumor', ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]]
#
# ['Tumor', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]]
#
# ['Tumor', ['323hkORG0OM3', 0.4, 1.57, 77, ['Tumor', 2.0], []]]
#
# ['Tumor', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]]
#
# ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]]
#
# ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]]
#
# ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]]
#
# ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]]
#
# ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]]
#
# ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]]
#
# ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]]
#
# ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]]
#
# ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]]
#
# ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]]
#
# ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]]
#
# ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]]
#
# ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]]
#
# ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]]
#
# ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]]
#
# ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]]
#
# ['Family', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Child', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# ['Family', ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]]
#
# ['Grandchild', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# ['Family', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['Family', ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]]
#
# ['Friend', ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]]
#
# *********  i[2]  *******************
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]]
#
# ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]]
#
# ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['Wife', ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]]
#
# ['Wife', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# _________________________________________________
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]]
#
# ...
#
# ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]]
#
# ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]]
#
# ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]]
#
# ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]]
#
# ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]]
#
# ['Family', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Child', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# ['Wife', ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]]
#
# ['Family', ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]]
#
# ['Wife', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ['Grandchild', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# ['Family', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['Family', ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]]
#
# ['Friend', ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]]
#
# *********  i[2]  *******************
# ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# ['Exercise', ['GV3Rew061FA5', 1.31, 5.07, 216, ['Exercise', 7.0], ['Glad', 1.0]]]
#
# ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# ['Exercise', ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]]
#
# ['Exercise', ['FH7aHDHnkjU14', 3.35, 4.22, 47, ['Exercise', 1.0], []]]
#
# ['Exercise', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# *********  i[2]  *******************
# ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Gym', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]]
#
# ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]]
#
# ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]]
#
# ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]]
#
# ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]]
#
# ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]]
#
# ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]]
#
# ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]]
#
# ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]]
#
# ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]]
#
# ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]]
#
# ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]]
#
# ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]]
#
# ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]]
#
# ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]]
#
# ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]]
#
# ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]]
#
# ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]]
#
# ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]]
#
# ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]]
#
# ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]]
#
# ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]]
#
# ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]]
#
# ['Family', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Child', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# ['Wife', ['FH7aHDHnkjU9', 2.08, 2.57, 49, ['Wife', 1.0], []]]
#
# ['Family', ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]]
#
# ['Wife', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ['Family', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]
#
# ['Family', ['qsAnlV8DUXo4', 0.47, 1.31, 44, ['Family', 1.0], []]]
#
# ['Friend', ['2pzHkvmRSW86', 1.38, 2.24, 46, ['Friend', 1.0], []]]
#
# *********  i[2]  *******************
# ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Grandchild', ['cfyb39S_CZw7', 2.07, 2.4, 33, ['LungCancer', 1.0, 'Grandchild', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# *********  i[2]  *******************
# ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# ['Thinking', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]
#
# ['Thinking', ['2utaepga5uk11', 3.22, 4.09, 46, ['Thinking', 1.0], []]]
#
# ['Thinking', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# *********  i[2]  *******************
# ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Diet', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ['Drug', ['WShT-I0wCO41', 0.0, 0.5, 50, ['Pain', 1.0, 'Drug', 1.0], []]]
#
# ['Drug', ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]]
#
# ['Smoking', ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]]
#
# ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# ['Drug', ['bqkquNb5Z8A10', 2.47, 3.31, 43, ['Drug', 1.0], []]]
#
# *********  i[2]  *******************
# ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ['Drug', ['WShT-I0wCO41', 0.0, 0.5, 50, ['Pain', 1.0, 'Drug', 1.0], []]]
#
# ['Drug', ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]]
#
# ['Smoking', ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]]
#
# ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# ['Drug', ['bqkquNb5Z8A10', 2.47, 3.31, 43, ['Drug', 1.0], []]]
#
# *********  i[2]  *******************
# ['Diet', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# ['Thinking', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Thinking', ['2utaepga5uk11', 3.22, 4.09, 46, ['Thinking', 1.0], []]]
#
# ['Thinking', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]
#
# *********  i[2]  *******************
# ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# ['Treatment', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]]
#
# ['Treatment', ['3mcWSmPXFtM1', 0.0, 1.35, 95, ['Treatment', 2.0], ['LungCancer', 2.0, 'Drug', 2.0]]]
#
# ['Treatment', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['Nl55TpSjWp414', 4.3, 5.13, 43, ['Treatment', 1.0], []]]
#
# ['Treatment', ['aHAbRVZOxnk10', 2.58, 3.39, 41, ['Treatment', 1.0, 'Rehabilitation', 1.0], []]]
#
# ['Treatment', ['POskT8R_3t49', 2.57, 3.5, 53, ['Treatment', 1.0], []]]
#
# ['Treatment', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['WShT-I0wCO410', 2.44, 3.34, 50, ['Treatment', 1.0], []]]
#
# ['Treatment', ['WShT-I0wCO420', 5.39, 6.29, 50, ['Treatment', 1.0], []]]
#
# ['Treatment', ['2utaepga5uk3', 0.47, 2.29, 102, ['Treatment', 2.0], ['Friend', 1.0]]]
#
# ['Treatment', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# ['Treatment', ['9nRhehMpODk3', 0.39, 1.3, 51, ['Hope', 1.0, 'Treatment', 1.0, 'Pain', 1.0], []]]
#
# ['Treatment', ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatment', 1.0, 'LungCancer', 1.0], []]]
#
# ['Treatment', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]]
#
# ['Treatment', ['ZoEEgU6L-m85', 1.47, 2.35, 48, ['Treatment', 1.0], []]]
#
# *********  i[2]  *******************
# ['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# *********  i[2]  *******************
# ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# _________________________________________________
#
# *********  i[1]  *******************
# ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# *********  i[2]  *******************
# ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# _________________________________________________
#
# Duration average=  1423.0
#
# Duration STDV=  1465.0

# %%
segMin=2
segMax=10
durMin=180
durMax=300
siblingConcepts=[]
corrNarrativeChild=[]   
narrConditional=[]
processedConcepts=[]
for i in  segCharacterisation2:
    # 1 find the path of the required concept to help in deciding its siblings
    #print('i= ',i)
    #print()
    #print('i[0]= ',i[0])
    #print()
    conceptPath=[]
    siblingConcepts=[]
    corrNarrativeChild=[] 
    conceptSeg=[]
    if len(i[4])>1:
        
        for co in i[4][::2]:
            conceptPath=[]
            siblingConcepts=[]
            corrNarrativeChild=[] 
            if co not in processedConcepts:
                print('co= ',co)
                print()
                processedConcepts.append(co)
            
                for j in cleanedParents2:

                    if len(j)>1:
                        if j[0]==co :
                            #print('j in cleaned parents has match with i ',j,'    i ',co)
                            conceptPath=j
                #print('conceptPath ',conceptPath)    
                #print()

                # 2 Find concept's siblings from the ontology
                for j in cleanedParents2:
                    if len(j)>1:
                        if len(conceptPath)>1:
                            if conceptPath[1] == j[1] and conceptPath[0] != j[0]:
                                siblingConcepts.append(j)
                            
                            #elif conceptPath[1] == j[1] and conceptPath[0] != j[0]:
                            #    concept

                if siblingConcepts:
                    for j in siblingConcepts:
                        print('sibling = ',j)
                        print()
                else:
                    print('No siblings')
                    print()

                # 3 find the siblings in the characterised segments by comparing the segments with the list of possible siblings from the ontology    



                #print('i= ',i)
                #print()
                conceptSeg=[]
                for s in segCharacterisation2:
                    for j in s[4][::2]: # move two step not one by one to avoid comapring text with numbers as each element in i[4]=[concept,number of mentions]
                        for c in siblingConcepts:
                            if j==c[0]:
                                corrNarrativeChild.append([j,s])
                            elif j==co:
                                conceptSeg.append([j,s])



                # Add the rest of the conditions
                temp=[]
                temp2=[]

                notInList=[]
                duration=0
                numbOfSeg=0
                match=False
                noConSeg=0
                print('corrNarrativeChild ',corrNarrativeChild)
                print()
                # if there are segments about the concept its self, then half of the segment will be for the narratives and 
                # the other half for the concept. Depend on how many segments for each group we have
                
                if conceptSeg:
                    if len(conceptSeg)>=int(segMax/2):
                        noConSeg=int(segMax/2)
                    else:
                        noConSeg=segMax-len(conceptSeg)
                else:
                    noConSeg=segMax
                    
                        
                
                    
                for j in corrNarrativeChild:
                    if  (duration+j[1][3]) <= durMax and (numbOfSeg+1) <=noConSeg:
                        match=False

                        if temp:
                            for x in temp:
                                if x[1] == j[1]:
                                    #print()
                                    #print('Match')
                                    #print()
                                    #print('x[1]= ',x[1])
                                    #print()
                                    #print('i[1]= ',i[1])
                                    #print()
                                    match=True
                            if not match:
                                #print('not match so add it')
                                #print()
                                temp.append(j)
                                duration+=j[1][3]
                                numbOfSeg+=1

                        else:
                            temp.append(j)

                            duration+=j[1][3]
                            numbOfSeg+=1
                if conceptSeg:
                                
                    for j in conceptSeg:
                        if  (duration+j[1][3]) <= durMax and (numbOfSeg+1) <=segMax:
                            match=False

                            if temp2:
                                for x in temp2:
                                    if x[1] == j[1]:
                                        #print()
                                        #print('Match')
                                        #print()
                                        #print('x[1]= ',x[1])
                                        #print()
                                        #print('i[1]= ',i[1])
                                        #print()
                                        match=True
                                if not match:
                                    #print('not match so add it')
                                    #print()
                                    temp2.append(j)
                                    duration+=j[1][3]
                                    numbOfSeg+=1

                            else:
                                temp2.append(j)

                                duration+=j[1][3]
                                numbOfSeg+=1
                     
                        
               
                if temp2:
                    print('temp ',temp)
                    print()
                    print('temp2= ',temp2)
                    narrConditional.append([co,temp,temp2])
                else:
                    narrConditional.append([co,temp])
                    
                temp=[]
                temp2=[]
                notInList=[]
                duration=0
                numbOfSeg=0
                match=False
                noConSeg=0
# Out:
# co=  Thinking
#
# sibling =  ['Concentration', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Learning', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Memory', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['MentalHealth', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Remembering', 'CognitiveFunction', 'PsychologicalHealth']
#
# corrNarrativeChild  [['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]]
#
# temp  [['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]]
#
# temp2=  [['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]], ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]]
# co=  Mum
#
# sibling =  ['Caregiver', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Child', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Dad', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Family', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Friend', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Grandchild', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Husband', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mom', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Parents', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Relative', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Spouse', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Wife', 'PersonalRelationship', 'SocialRelationship']
#
# corrNarrativeChild  [['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]], ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]], ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]], ['Family', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]], ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]], ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]], ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]], ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]], ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]], ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]], ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]], ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]], ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]], ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Friend', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Friend', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Child', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]], ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]], ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]], ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]], ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]], ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]], ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]], ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]], ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]], ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]], ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]], ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]], ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family ...
#
# co=  Treatment
#
# sibling =  ['DailyLiving', 'LevelOfIndependence']
#
# sibling =  ['FinancialIssue', 'LevelOfIndependence']
#
# sibling =  ['LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['MedicalSelfCare', 'LevelOfIndependence']
#
# sibling =  ['Mobility', 'LevelOfIndependence']
#
# sibling =  ['WorkCapacity', 'LevelOfIndependence']
#
# corrNarrativeChild  [['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]]
#
# temp  [['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]]
#
# temp2=  [['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]]
# co=  LungCancer
#
# sibling =  ['Asthma', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Bronchitis', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['ChestPain', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Copd', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Covid', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['LungDisease', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Pneumonia', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['PulmonaryFibrosis', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['PulmonaryHypertension', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Tumor', 'RespiratoryIllness', 'PhysicalHealth']
#
# corrNarrativeChild  [['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]], ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]], ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]], ['Tumor', ['hQQ5xQGZxdA58', 12.39, 13.24, 45, ['Tumor', 1.0], []]], ['Copd', ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]], ['Pneumonia', ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]], ['LungDisease', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]], ['LungDisease', ['j3t5nFnTULQ9', 3.36, 4.22, 46, ['LungDisease', 1.0], []]], ['Tumor', ['tfxB32Vb5hE8', 1.43, 2.18, 35, ['Tumor', 1.0], []]], ['PulmonaryFibrosis', ['0fI_01yFmME3', 0.51, 1.4, 49, ['PulmonaryFibrosis', 1.0], []]], ['Pneumonia', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]], ['Tumor', ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]], ['Pneumonia', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]], ['Copd', ['ehh89UrZtZU12', 0.01, 4.07, 246, ['Copd', 8.0], ['Smoking', 6.0, 'Cough', 1.0]]], ['Pneumonia', ['VyGp12XbPzs1', 0.1, 0.54, 44, ['Pneumonia', 1.0], []]], ['Copd', ['jZJTcp3d1q41', 0.11, 2.38, 147, ['Copd', 3.0], ['DailyLiving', 1.0, 'Wife', 1.0, 'Exercise', 1.0]]], ['Copd', ['ZU_l9xCB-081', 0.04, 1.48, 104, ['Copd', 3.0], ['Pneumonia', 1.0, 'Fear', 1.0, 'Mom', 1.0, 'Friend', 1.0]]], ['Covid', ['Nl55TpSjWp43', 0.42, 1.23, 41, ['Covid', 1.0], []]], ['Pneumonia', ['Nl55TpSjWp49', 3.0, 4.27, 86, ['Pneumonia', 2.0], ['Rest', 1.0, 'Covid', 2.0, 'Copd', 1.0, 'LungDisease', 1.0]]], ['Pneumonia', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]], ['Pneumonia', ['6U7OpgFojaw6', 1.43, 2.15, 32, ['Pneumonia', 1.0], []]], ['PulmonaryHypertension', ['e0KVtXL-TjY7', 1.31, 2.09, 38, ['PulmonaryHypertension', 1.0], []]], ['PulmonaryFibrosis', ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]], ['Pneumonia', ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]], ['Copd', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]], ['Copd', ['Nxrz6_e_gwo1', 0.02, 2.34, 152, ['Copd', 5.0], ['Rest', 1.0, 'Family', 2.0, 'Wheezing', 1.0, 'Exercise', 1.0]]], ['Copd', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]], ['Tumor', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['PulmonaryHypertension', ['POskT8R_3t41', 0.0, 0.38, 38, ['PulmonaryHypertension', 1.0], []]], ['LungDisease', ['3Fker8Nmd5Y1', 0.05, 0.57, 51, ['LungDisease', 1.0], []]], ['Copd', ['dyRmGVgG7_84', 0.47, 1.17, 30, ['Copd', 1.0], []]], ['PulmonaryFibrosis', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]], ['LungDisease', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]], ['Tumor', ['323hkORG0OM3', 0.4, 1.57, 77, ['Tumor', 2.0], []]], ['Tumor', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]], ['PulmonaryFibrosis', ['qsAnlV8DUXo1', 0.0, 0.42, 42, ['PulmonaryFibrosis', 1.0], []]], ['LungDisease', ['2pzHkvmRSW812', 3.19, 3.53, 33, ['LungDisease', 1.0], []]]]
#
# co=  Pain
#
# sibling =  ['OtherSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# sibling =  ['RespiratoryIllnessSymptoms', 'PhysicalSymptoms', 'PhysicalHealth']
#
# corrNarrativeChild  []
#
# temp  []
#
# temp2=  [['Pain', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['Pain', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Pain', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]], ['Pain', ['xY3B9nLm1u81', 0.0, 1.13, 72, ['Sleep', 2.0, 'Pain', 2.0], ['Wife', 1.0, 'LungCancer', 1.0]]], ['Pain', ['xY3B9nLm1u818', 4.37, 5.16, 39, ['Pain', 1.0, 'Hope', 1.0], []]], ['Pain', ['E8nRS2LxFdw1', 0.0, 0.45, 45, ['Pain', 1.0], []]]]
# co=  Training
#
# sibling =  ['CareInformation', 'AcquiringInformation', 'Environment']
#
# sibling =  ['MedicalInformation', 'AcquiringInformation', 'Environment']
#
# corrNarrativeChild  []
#
# temp  []
#
# temp2=  [['Training', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['Training', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Training', ['E8nRS2LxFdw7', 1.3, 2.14, 44, ['Training', 1.0], []]], ['Training', ['mSYXddFVvHo1', 0.03, 0.5, 47, ['LungDisease', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Training', 2.0], []]]]
# co=  Energy
#
# sibling =  ['Behaviour', 'PhysicalHealth']
#
# sibling =  ['PhysicalSymptoms', 'PhysicalHealth']
#
# sibling =  ['RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Rest', 'PhysicalHealth']
#
# corrNarrativeChild  [['Rest', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]], ['Rest', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]], ['Rest', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]], ['Rest', ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]], ['Rest', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]], ['Rest', ['FH7aHDHnkjU17', 4.24, 4.45, 21, ['Family', 1.0, 'Rest', 1.0], []]]]
#
# co=  Noise
#
# sibling =  ['AccessToGreenSpace', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Climate', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Dirt', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Mould', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Parks', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Pollution', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Safety', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Security', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Toxine', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Traffic', 'PhysicalEnvironment', 'Environment']
#
# sibling =  ['Transport', 'PhysicalEnvironment', 'Environment']
#
# corrNarrativeChild  []
#
# temp  []
#
# temp2=  [['Noise', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]]
# co=  Child
#
# sibling =  ['Caregiver', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Dad', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Family', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Friend', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Grandchild', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Husband', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mom', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mum', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Parents', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Relative', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Spouse', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Wife', 'PersonalRelationship', 'SocialRelationship']
#
# corrNarrativeChild  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]], ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]], ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]], ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Family', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]], ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]], ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]], ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]], ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]], ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]], ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]], ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]], ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]], ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Friend', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Friend', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]], ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]], ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]], ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]], ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]], ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]], ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]], ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]], ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]], ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]], ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]], ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]], ['Family', ['Tyo2YsA0Y05', 2.52, 3 ...
#
# co=  Insurance
#
# sibling =  ['CarePlan', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['EndOfLifeCare', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['FuneralPlan', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['Inheritance', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['OrganDonation', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['Will', 'LegalIssue', 'LevelOfIndependence']
#
# corrNarrativeChild  [['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]]
#
# temp  [['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]]
#
# temp2=  [['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]]
# co=  Dad
#
# sibling =  ['Caregiver', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Child', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Family', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Friend', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Grandchild', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Husband', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mom', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mum', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Parents', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Relative', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Spouse', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Wife', 'PersonalRelationship', 'SocialRelationship']
#
# corrNarrativeChild  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]], ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]], ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]], ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Family', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]], ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]], ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]], ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]], ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]], ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]], ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]], ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]], ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]], ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]], ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]], ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Friend', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Friend', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Child', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]], ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]], ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]], ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]], ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]], ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]], ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]], ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]], ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]], ['Husband', ['pmuUnQ5Zi4Q7' ...
#
# temp  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]]
#
# temp2=  [['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]]
# co=  Temple
#
# sibling =  ['Buddhism', 'Religion', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Christian', 'Religion', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Church', 'Religion', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Hinduism', 'Religion', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Jewish', 'Religion', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Mosque', 'Religion', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Muslim', 'Religion', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Pray', 'Religion', 'PersonalValuesAndBeliefs']
#
# sibling =  ['ReligiousCelebration', 'Religion', 'PersonalValuesAndBeliefs']
#
# corrNarrativeChild  [['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]]
#
# temp  [['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]]
#
# temp2=  [['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]]
# co=  Caregiver
#
# sibling =  ['Child', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Dad', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Family', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Friend', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Grandchild', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Husband', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mom', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mum', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Parents', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Relative', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Spouse', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Wife', 'PersonalRelationship', 'SocialRelationship']
#
# corrNarrativeChild  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]], ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]], ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]], ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Family', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]], ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]], ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]], ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]], ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]], ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]], ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]], ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]], ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]], ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]], ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]], ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Friend', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Friend', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Child', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]], ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]], ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]], ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]], ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]], ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]], ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]], ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]], ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]], ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]], ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]], ['Wife', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]], ['Family', ['aREqsWoX-EY8', 2.2, 3.04, 43, ['Family', 1.0], []]], ['Fami ...
#
# co=  Pneumonia
#
# sibling =  ['Asthma', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Bronchitis', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['ChestPain', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Copd', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Covid', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['LungCancer', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['LungDisease', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['PulmonaryFibrosis', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['PulmonaryHypertension', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Tumor', 'RespiratoryIllness', 'PhysicalHealth']
#
# corrNarrativeChild  [['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]], ['LungCancer', ['rQutyErqBG014', 4.03, 4.59, 55, ['LungCancer', 1.0], []]], ['LungCancer', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['LungCancer', ['hQQ5xQGZxdA15', 3.17, 4.39, 82, ['LungCancer', 2.0], ['Tumor', 1.0, 'Thinking', 2.0]]], ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]], ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]], ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]], ['Tumor', ['hQQ5xQGZxdA58', 12.39, 13.24, 45, ['Tumor', 1.0], []]], ['LungCancer', ['yV893Fx41lE1', 0.01, 2.19, 138, ['LungCancer', 3.0], ['Training', 1.0, 'Soreness', 1.0, 'Pain', 2.0, 'Tumor', 1.0]]], ['Copd', ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]], ['LungDisease', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]], ['LungDisease', ['j3t5nFnTULQ9', 3.36, 4.22, 46, ['LungDisease', 1.0], []]], ['LungCancer', ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]], ['Tumor', ['tfxB32Vb5hE8', 1.43, 2.18, 35, ['Tumor', 1.0], []]], ['PulmonaryFibrosis', ['0fI_01yFmME3', 0.51, 1.4, 49, ['PulmonaryFibrosis', 1.0], []]], ['LungCancer', ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]], ['Tumor', ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]], ['LungCancer', ['HBFn82ffSVE30', 7.31, 7.51, 20, ['LungCancer', 1.0], []]], ['LungCancer', ['wArV8Ho_C1A8', 2.28, 3.01, 33, ['LungCancer', 1.0], []]], ['Copd', ['ehh89UrZtZU12', 0.01, 4.07, 246, ['Copd', 8.0], ['Smoking', 6.0, 'Cough', 1.0]]], ['Copd', ['jZJTcp3d1q41', 0.11, 2.38, 147, ['Copd', 3.0], ['DailyLiving', 1.0, 'Wife', 1.0, 'Exercise', 1.0]]], ['Copd', ['ZU_l9xCB-081', 0.04, 1.48, 104, ['Copd', 3.0], ['Pneumonia', 1.0, 'Fear', 1.0, 'Mom', 1.0, 'Friend', 1.0]]], ['Covid', ['Nl55TpSjWp43', 0.42, 1.23, 41, ['Covid', 1.0], []]], ['PulmonaryHypertension', ['e0KVtXL-TjY7', 1.31, 2.09, 38, ['PulmonaryHypertension', 1.0], []]], ['PulmonaryFibrosis', ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]], ['Copd', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]], ['Copd', ['Nxrz6_e_gwo1', 0.02, 2.34, 152, ['Copd', 5.0], ['Rest', 1.0, 'Family', 2.0, 'Wheezing', 1.0, 'Exercise', 1.0]]], ['Copd', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]], ['LungCancer', ['q9xteXsPy3c3', 1.13, 1.44, 31, ['LungCancer', 1.0], []]], ['Tumor', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['LungCancer', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['PulmonaryHypertension', ['POskT8R_3t41', 0.0, 0.38, 38, ['PulmonaryHypertension', 1.0], []]], ['LungDisease', ['3Fker8Nmd5Y1', 0.05, 0.57, 51, ['LungDisease', 1.0], []]], ['LungCancer', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]], ['LungCancer', ['WShT-I0wCO46', 1.27, 2.01, 33, ['LungCancer', 1.0], []]], ['LungCancer', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]], ['LungCancer', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]], ['Copd', ['dyRmGVgG7_84', 0.47, 1.17, 30, ['Copd', 1.0], []]], ['LungCancer', ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]], ['LungCancer', ['aREqsWoX-EY1', 0.05, 1.0, 55, ['Wife', 1.0, 'LungCancer', 1.0], []]], ['LungCancer', ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatm ...
#
# co=  Tumor
#
# sibling =  ['Asthma', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Bronchitis', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['ChestPain', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Copd', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Covid', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['LungCancer', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['LungDisease', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['Pneumonia', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['PulmonaryFibrosis', 'RespiratoryIllness', 'PhysicalHealth']
#
# sibling =  ['PulmonaryHypertension', 'RespiratoryIllness', 'PhysicalHealth']
#
# corrNarrativeChild  [['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]], ['LungCancer', ['rQutyErqBG014', 4.03, 4.59, 55, ['LungCancer', 1.0], []]], ['LungCancer', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]], ['LungCancer', ['hQQ5xQGZxdA15', 3.17, 4.39, 82, ['LungCancer', 2.0], ['Tumor', 1.0, 'Thinking', 2.0]]], ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]], ['LungCancer', ['yV893Fx41lE1', 0.01, 2.19, 138, ['LungCancer', 3.0], ['Training', 1.0, 'Soreness', 1.0, 'Pain', 2.0, 'Tumor', 1.0]]], ['Copd', ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]], ['Pneumonia', ['uJoY4oMLXEY3', 0.46, 1.35, 49, ['Copd', 1.0, 'Pneumonia', 1.0], []]], ['LungDisease', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]], ['LungDisease', ['j3t5nFnTULQ9', 3.36, 4.22, 46, ['LungDisease', 1.0], []]], ['LungCancer', ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]], ['PulmonaryFibrosis', ['0fI_01yFmME3', 0.51, 1.4, 49, ['PulmonaryFibrosis', 1.0], []]], ['Pneumonia', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]], ['LungCancer', ['HBFn82ffSVE7', 1.38, 2.33, 55, ['LungCancer', 1.0, 'Tumor', 2.0], []]], ['Pneumonia', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]], ['LungCancer', ['HBFn82ffSVE30', 7.31, 7.51, 20, ['LungCancer', 1.0], []]], ['LungCancer', ['wArV8Ho_C1A8', 2.28, 3.01, 33, ['LungCancer', 1.0], []]], ['Copd', ['ehh89UrZtZU12', 0.01, 4.07, 246, ['Copd', 8.0], ['Smoking', 6.0, 'Cough', 1.0]]], ['Pneumonia', ['VyGp12XbPzs1', 0.1, 0.54, 44, ['Pneumonia', 1.0], []]], ['Copd', ['jZJTcp3d1q41', 0.11, 2.38, 147, ['Copd', 3.0], ['DailyLiving', 1.0, 'Wife', 1.0, 'Exercise', 1.0]]], ['Copd', ['ZU_l9xCB-081', 0.04, 1.48, 104, ['Copd', 3.0], ['Pneumonia', 1.0, 'Fear', 1.0, 'Mom', 1.0, 'Friend', 1.0]]], ['Covid', ['Nl55TpSjWp43', 0.42, 1.23, 41, ['Covid', 1.0], []]], ['Pneumonia', ['Nl55TpSjWp49', 3.0, 4.27, 86, ['Pneumonia', 2.0], ['Rest', 1.0, 'Covid', 2.0, 'Copd', 1.0, 'LungDisease', 1.0]]], ['Pneumonia', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]], ['Pneumonia', ['6U7OpgFojaw6', 1.43, 2.15, 32, ['Pneumonia', 1.0], []]], ['PulmonaryHypertension', ['e0KVtXL-TjY7', 1.31, 2.09, 38, ['PulmonaryHypertension', 1.0], []]], ['PulmonaryFibrosis', ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]], ['Pneumonia', ['aHAbRVZOxnk3', 0.43, 1.17, 34, ['PulmonaryFibrosis', 1.0, 'Pneumonia', 1.0], []]], ['Copd', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]], ['Copd', ['Nxrz6_e_gwo1', 0.02, 2.34, 152, ['Copd', 5.0], ['Rest', 1.0, 'Family', 2.0, 'Wheezing', 1.0, 'Exercise', 1.0]]], ['Copd', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]], ['LungCancer', ['q9xteXsPy3c3', 1.13, 1.44, 31, ['LungCancer', 1.0], []]], ['LungCancer', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['PulmonaryHypertension', ['POskT8R_3t41', 0.0, 0.38, 38, ['PulmonaryHypertension', 1.0], []]], ['LungDisease', ['3Fker8Nmd5Y1', 0.05, 0.57, 51, ['LungDisease', 1.0], []]], ['LungCancer', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]], ['LungCancer', ['WShT-I0wCO46', 1.27, 2.01, 33, ['LungCancer', 1.0], []]], ['LungCancer', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]], ['LungCancer', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCance ...
#
# co=  Wife
#
# sibling =  ['Caregiver', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Child', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Dad', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Family', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Friend', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Grandchild', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Husband', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mom', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mum', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Parents', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Relative', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Spouse', 'PersonalRelationship', 'SocialRelationship']
#
# corrNarrativeChild  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]], ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Family', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]], ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]], ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]], ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]], ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]], ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]], ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]], ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]], ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]], ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]], ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]], ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Friend', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Friend', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Child', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]], ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]], ['Grandchild', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]], ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]], ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]], ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]], ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]], ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ['LungCancer', 1.0, 'Mom', 1.0, 'Pain', 1.0], []]], ['Husband', ['pmuUnQ5Zi4Q7', 1.56, 2.51, 54, ['Husband', 2.0, 'LungCancer', 3.0], ['Hope', 1.0, 'Energy', 1.0]]], ['Family', ['a ...
#
# co=  Community
#
# sibling =  ['CulturalFactors', 'SocialActivity', 'SocialRelationship']
#
# sibling =  ['LanguageDifficulty', 'SocialActivity', 'SocialRelationship']
#
# sibling =  ['SexualActivity', 'SocialActivity', 'SocialRelationship']
#
# corrNarrativeChild  []
#
# temp  []
#
# temp2=  [['Community', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]], ['Community', ['hQQ5xQGZxdA67', 14.45, 15.11, 26, ['Community', 1.0], []]], ['Community', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]]]
# co=  Friend
#
# sibling =  ['Caregiver', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Child', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Dad', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Family', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Grandchild', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Husband', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mom', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mum', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Parents', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Relative', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Spouse', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Wife', 'PersonalRelationship', 'SocialRelationship']
#
# ...
#
# sibling =  ['Dad', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Family', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Friend', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Husband', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mom', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Mum', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Parents', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Relative', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Spouse', 'PersonalRelationship', 'SocialRelationship']
#
# sibling =  ['Wife', 'PersonalRelationship', 'SocialRelationship']
#
# corrNarrativeChild  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]], ['Wife', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]], ['Friend', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA49', 10.48, 11.23, 35, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA55', 12.04, 12.38, 34, ['Caregiver', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA64', 14.03, 14.43, 40, ['Pain', 1.0, 'Caregiver', 1.0], []]], ['Mum', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Family', ['wwiwjZw7d6o1', 0.17, 1.12, 55, ['Mum', 2.0, 'Family', 2.0], ['Learning', 1.0, 'Friend', 1.0, 'Hope', 1.0]]], ['Child', ['wwiwjZw7d6o13', 3.14, 3.5, 36, ['Child', 2.0], []]], ['Friend', ['0fI_01yFmME1', 0.01, 0.49, 48, ['Friend', 1.0], []]], ['Husband', ['0fI_01yFmME7', 2.19, 3.17, 58, ['Husband', 1.0], []]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]], ['Mum', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]], ['Husband', ['wArV8Ho_C1A10', 3.04, 3.51, 46, ['Husband', 1.0], []]], ['Family', ['wArV8Ho_C1A12', 3.52, 4.22, 30, ['Family', 1.0], []]], ['Family', ['jZJTcp3d1q413', 3.57, 4.22, 25, ['Community', 1.0, 'Family', 2.0], []]], ['Husband', ['Nl55TpSjWp45', 1.26, 2.19, 53, ['Husband', 1.0], []]], ['Family', ['6U7OpgFojaw8', 2.16, 2.56, 40, ['Family', 1.0], []]], ['Child', ['e0KVtXL-TjY10', 2.11, 2.54, 43, ['Strength', 1.0, 'Child', 1.0], []]], ['Friend', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Family', ['Nxrz6_e_gwo8', 2.39, 3.25, 46, ['Family', 1.0], []]], ['Family', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Friend', ['q9xteXsPy3c4', 1.5, 3.05, 74, ['Family', 2.0, 'Tumor', 1.0, 'Friend', 1.0, 'Training', 1.0], []]], ['Mom', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Friend', ['q9xteXsPy3c6', 3.11, 4.1, 58, ['Mom', 1.0, 'Friend', 1.0, 'LungCancer', 1.0], []]], ['Family', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Child', ['3Fker8Nmd5Y8', 2.2, 2.54, 33, ['Family', 1.0, 'Child', 2.0], []]], ['Family', ['OHeU3oj8nmc1', 0.0, 1.21, 81, ['Family', 2.0], ['Gym', 1.0, 'Mum', 2.0, 'LungCancer', 1.0]]], ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]], ['Family', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O83', 0.51, 1.26, 35, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]], ['Friend', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]], ['Family', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Child', ['KFBT8x3DPuM1', 0.0, 2.27, 147, ['Child', 4.0], ['Community', 1.0, 'Family', 1.0, 'Grandchild', 1.0]]], ['Husband', ['n7KHBGEC2Gg1', 0.0, 0.47, 47, ['Husband', 1.0], []]], ['Wife', ['n7KHBGEC2Gg10', 3.23, 4.17, 54, ['Wife', 1.0], []]], ['Wife', ['WShT-I0wCO48', 2.04, 2.4, 36, ['Wife', 1.0], []]], ['Family', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Friend', ['2utaepga5uk14', 4.11, 4.53, 41, ['Family', 1.0, 'Friend', 1.0], []]], ['Mom', ['pmuUnQ5Zi4Q1', 0.05, 0.57, 51, ...
#
# co=  EndOfLifeCare
#
# sibling =  ['CarePlan', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['FuneralPlan', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['Inheritance', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['Insurance', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['OrganDonation', 'LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['Will', 'LegalIssue', 'LevelOfIndependence']
#
# corrNarrativeChild  [['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]]
#
# temp  [['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]]
#
# temp2=  [['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]]
# co=  MentalHealth
#
# sibling =  ['Concentration', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Learning', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Memory', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Remembering', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Thinking', 'CognitiveFunction', 'PsychologicalHealth']
#
# corrNarrativeChild  [['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]], ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]], ['Thinking', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]], ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]], ['Thinking', ['2utaepga5uk11', 3.22, 4.09, 46, ['Thinking', 1.0], []]], ['Thinking', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]]
#
# co=  Alcohol
#
# sibling =  ['Diet', 'Behaviour', 'PhysicalHealth']
#
# sibling =  ['Drug', 'Behaviour', 'PhysicalHealth']
#
# sibling =  ['Smoking', 'Behaviour', 'PhysicalHealth']
#
# sibling =  ['Vaping', 'Behaviour', 'PhysicalHealth']
#
# corrNarrativeChild  [['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]], ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]], ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]], ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]], ['Diet', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]], ['Drug', ['WShT-I0wCO41', 0.0, 0.5, 50, ['Pain', 1.0, 'Drug', 1.0], []]], ['Drug', ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]], ['Smoking', ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]], ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]], ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]], ['Drug', ['bqkquNb5Z8A10', 2.47, 3.31, 43, ['Drug', 1.0], []]]]
#
# co=  Diet
#
# sibling =  ['Alcohol', 'Behaviour', 'PhysicalHealth']
#
# sibling =  ['Drug', 'Behaviour', 'PhysicalHealth']
#
# sibling =  ['Smoking', 'Behaviour', 'PhysicalHealth']
#
# sibling =  ['Vaping', 'Behaviour', 'PhysicalHealth']
#
# corrNarrativeChild  [['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]], ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]], ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]], ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]], ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]], ['Drug', ['WShT-I0wCO41', 0.0, 0.5, 50, ['Pain', 1.0, 'Drug', 1.0], []]], ['Drug', ['dyRmGVgG7_86', 1.19, 2.17, 58, ['LungCancer', 1.0, 'Drug', 1.0], []]], ['Smoking', ['cfyb39S_CZw1', 0.06, 1.19, 73, ['LungCancer', 3.0, 'Smoking', 1.0], []]], ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]], ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]], ['Drug', ['bqkquNb5Z8A10', 2.47, 3.31, 43, ['Drug', 1.0], []]]]
#
# co=  Concentration
#
# sibling =  ['Learning', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Memory', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['MentalHealth', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Remembering', 'CognitiveFunction', 'PsychologicalHealth']
#
# sibling =  ['Thinking', 'CognitiveFunction', 'PsychologicalHealth']
#
# corrNarrativeChild  [['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]], ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]], ['Thinking', ['Nxrz6_e_gwo10', 3.3, 4.16, 46, ['Copd', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]], ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Thinking', ['2utaepga5uk11', 3.22, 4.09, 46, ['Thinking', 1.0], []]], ['Thinking', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['ZoEEgU6L-m89', 3.31, 4.54, 83, ['Child', 2.0, 'Thinking', 1.0], []]]]
#
# co=  Mobility
#
# sibling =  ['DailyLiving', 'LevelOfIndependence']
#
# sibling =  ['FinancialIssue', 'LevelOfIndependence']
#
# sibling =  ['LegalIssue', 'LevelOfIndependence']
#
# sibling =  ['MedicalSelfCare', 'LevelOfIndependence']
#
# sibling =  ['Treatment', 'LevelOfIndependence']
#
# sibling =  ['WorkCapacity', 'LevelOfIndependence']
#
# corrNarrativeChild  [['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]], ['Treatment', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]], ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]], ['Treatment', ['tfxB32Vb5hE1', 0.02, 1.39, 97, ['LungCancer', 3.0, 'Treatment', 2.0], []]], ['Treatment', ['3mcWSmPXFtM1', 0.0, 1.35, 95, ['Treatment', 2.0], ['LungCancer', 2.0, 'Drug', 2.0]]], ['Treatment', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]], ['Treatment', ['Nl55TpSjWp414', 4.3, 5.13, 43, ['Treatment', 1.0], []]], ['Treatment', ['aHAbRVZOxnk10', 2.58, 3.39, 41, ['Treatment', 1.0, 'Rehabilitation', 1.0], []]], ['Treatment', ['POskT8R_3t49', 2.57, 3.5, 53, ['Treatment', 1.0], []]], ['Treatment', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]], ['Treatment', ['WShT-I0wCO410', 2.44, 3.34, 50, ['Treatment', 1.0], []]], ['Treatment', ['WShT-I0wCO420', 5.39, 6.29, 50, ['Treatment', 1.0], []]], ['Treatment', ['2utaepga5uk3', 0.47, 2.29, 102, ['Treatment', 2.0], ['Friend', 1.0]]], ['Treatment', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]], ['Treatment', ['9nRhehMpODk3', 0.39, 1.3, 51, ['Hope', 1.0, 'Treatment', 1.0, 'Pain', 1.0], []]], ['Treatment', ['Tyo2YsA0Y01', 0.05, 0.38, 33, ['Treatment', 1.0, 'LungCancer', 1.0], []]], ['Treatment', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]], ['Treatment', ['ZoEEgU6L-m85', 1.47, 2.35, 48, ['Treatment', 1.0], []]]]
#
# co=  Scared
#
# sibling =  ['Anger', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Anxiety', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Apprehension', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Depression', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Fear', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Furious', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Grief', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Guilt', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['HeartBroken', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Hopelessness', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Hypochondriac', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Irritability', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['LossOfInterest', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['LossOfPleasure', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['LoweringOfMood', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Nervousness', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Sadness', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['SenseOfIsolation', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Tearfulness', 'NegativeFeeling', 'PsychologicalHealth']
#
# sibling =  ['Tension', 'NegativeFeeling', 'PsychologicalHealth']
#
# corrNarrativeChild  [['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]], ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]], ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]]
#
# temp  [['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]], ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]], ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]]
#
# temp2=  [['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]]
# co=  Belief
#
# sibling =  ['Existentiality', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Meditation', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Mindfulness', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# sibling =  ['SpiritualResources', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# sibling =  ['SpiritualServices', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# sibling =  ['Value', 'Spirituality', 'PersonalValuesAndBeliefs']
#
# corrNarrativeChild  [['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]]
#
# temp  [['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]]
#
# temp2=  [['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]]

# %%
narrConditional2=[]
for i in narrConditional:
    for c in cleanedParents2:
        if c[0]==i[0]:
            topic=c[-1]
    if i[1]:
        narrConditional2.append([topic,i])
print('# of correlatives narratives = ',len(narrConditional2))
length=[]
tempDuration=0
narrativesDuration=[]
for i in narrConditional2:
    

    print(i[0])
    print()
    if len(i[1])==2:
        print('length is 2')
        print()
        print(i[1][0])
        for j in i[1][1]:
            tempDuration+=j[1][3]
            print(j)
            print()

    elif len(i[1])==3:
        print('length is 3')
        print()
        print(i[1][0])
        for j in i[1][1]:
            tempDuration+=j[1][3]
            print(j)
            print()
        for j in i[1][2]:
            tempDuration+=j[1][3]
            print(j)
            print()
        
    
    narrativesDuration.append(tempDuration)
    tempDuration=0
    print('___________________________________')
    
print('Duration average= ',round(np.average(narrativesDuration),0))
print()
print('Duration STDV= ',round(np.std(narrativesDuration),0))
# Out:
# # of correlatives narratives =  43
# PsychologicalHealth
#
# length is 3
#
# Thinking
# ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]
#
# ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 2
#
# Mum
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ___________________________________
# LevelOfIndependence
#
# length is 3
#
# Treatment
# ['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# LungCancer
# ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]]
#
# ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]]
#
# ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Energy
# ['Rest', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Rest', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# ['Rest', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# ['Rest', ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]]
#
# ['Rest', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 2
#
# Child
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# LevelOfIndependence
#
# length is 3
#
# Insurance
# ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# Dad
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PersonalValuesAndBeliefs
#
# length is 3
#
# Temple
# ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ___________________________________
# SocialRelationship
#
# length is 2
#
# Caregiver
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Pneumonia
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Tumor
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 2
#
# Wife
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 2
#
# Friend
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 2
#
# Family
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 3
#
# Fear
# ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# ShortnessOfBreath
# ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# ['Cough', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Cough', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Copd
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# Environment
#
# length is 3
#
# Exercise
# ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Gym', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# LungDisease
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# PulmonaryFibrosis
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 2
#
# Husband
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Rest
# ['Energy', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['Energy', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# ['Energy', ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]]
#
# ['Energy', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]]
#
# ['Energy', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# ___________________________________
# PersonalValuesAndBeliefs
#
# length is 3
#
# Meditation
# ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# Cough
# ['ShortnessOfBreath', ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]]
#
# ['ShortnessOfBreath', ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]]
#
# ['ShortnessOfBreath', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Covid
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PersonalValuesAndBeliefs
#
# length is 3
#
# Christian
# ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# PulmonaryHypertension
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Drug
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Vaping
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Smoking
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 3
#
# Guilt
# ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 2
#
# Mom
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# Environment
#
# length is 3
#
# Gym
# ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# ['Exercise', ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]]
#
# ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 2
#
# Grandchild
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# LevelOfIndependence
#
# length is 3
#
# EndOfLifeCare
# ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 2
#
# MentalHealth
# ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Alcohol
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 2
#
# Diet
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 2
#
# Concentration
# ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# ___________________________________
# LevelOfIndependence
#
# length is 2
#
# Mobility
# ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 3
#
# Scared
# ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ___________________________________
# PersonalValuesAndBeliefs
#
# length is 3
#
# Belief
# ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# ___________________________________
# Duration average=  268.0
#
# Duration STDV=  45.0

# %%
narrative3=[]
temp=[]
temp2=[]
temp3=[]
#listUnwanted=['V8eLdbKXGzk','i68a6M5FFBc&t','Yl_FJAOcFgQ']
for i in narrConditional2:
   
    if len(i[1])==2:
        for j in i[1][1]:

            #if j[1][0] not in listUnwanted:
            temp2.append(j)
    elif len(i[1])==3:
    
        for j in i[1][1]:

            #if j[1][0] not in listUnwanted:
            temp2.append(j)
        for j2 in i[1][2]:
            
            #if j2[1][0] not in listUnwanted:
            temp3.append(j2)
    
    #print('i[0]= ',i[0])
    #print('i[1][0] ',i[1][0])
    #print('temp2 ',temp2)
    #print()
    #print('temp3= ',temp3)
    #print()
    temp=[i[1][0],temp2,temp3]
    narrative3.append([i[0],temp])
    temp2=[]
    temp3=[]
for i in  narrative3:
    print('i[0] ',i[0])
    print('i[1][0] ',i[1][0])
    print()
    for j in i[1][1]:
        print('j ',j)
        print()
    if i[1][2]:
        for j2 in i[1][2]:
            print('j2= ',j2)
            print()
    else:
        print('i[1][2] is empty ',i[1][2])
        print()
    
    
    print('_________________________')
narrConditional2=narrative3
# Out:
# i[0]  PsychologicalHealth
# i[1][0]  Thinking
#
# j  ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j  ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]
#
# j2=  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j2=  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j2=  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j2=  ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Mum
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  LevelOfIndependence
# i[1][0]  Treatment
#
# j  ['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# j2=  ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j2=  ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j2=  ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j2=  ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  LungCancer
#
# j  ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]]
#
# j  ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]]
#
# j  ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Energy
#
# j  ['Rest', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Rest', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# j  ['Rest', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# j  ['Rest', ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]]
#
# j  ['Rest', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Child
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  LevelOfIndependence
# i[1][0]  Insurance
#
# j  ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# j2=  ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Dad
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# j2=  ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Temple
#
# j  ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# j2=  ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Caregiver
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Pneumonia
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Tumor
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Wife
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Friend
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Family
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  Fear
#
# j  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# j  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# j2=  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j2=  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  ShortnessOfBreath
#
# j  ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# j  ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# j  ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# j  ['Cough', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Cough', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Copd
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  Environment
# i[1][0]  Exercise
#
# j  ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# j  ['Gym', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# j2=  ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# j2=  ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# j2=  ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j2=  ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  LungDisease
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  PulmonaryFibrosis
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Husband
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Rest
#
# j  ['Energy', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['Energy', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# j  ['Energy', ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]]
#
# j  ['Energy', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]]
#
# j  ['Energy', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Meditation
#
# j  ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# j2=  ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Cough
#
# j  ['ShortnessOfBreath', ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]]
#
# j  ['ShortnessOfBreath', ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]]
#
# j  ['ShortnessOfBreath', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# j2=  ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# j2=  ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# j2=  ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Covid
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Christian
#
# j  ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j2=  ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  PulmonaryHypertension
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Drug
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Vaping
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Smoking
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# j  ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  Guilt
#
# j  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# j  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# j2=  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Mom
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  Environment
# i[1][0]  Gym
#
# j  ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# j  ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# j  ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j  ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# j  ['Exercise', ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]]
#
# j2=  ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Grandchild
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  LevelOfIndependence
# i[1][0]  EndOfLifeCare
#
# j  ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# j2=  ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  MentalHealth
#
# j  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Alcohol
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Diet
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  Concentration
#
# j  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  LevelOfIndependence
# i[1][0]  Mobility
#
# j  ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# j  ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# i[1][2] is empty  []
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  Scared
#
# j  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# j  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# j2=  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# _________________________
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Belief
#
# j  ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# j2=  ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# _________________________

# %%
narrative3=[]
temp=[]
temp2=[]
seg_alreadyTaken=[]
for i in  narrConditional2:
    print('i[0] ',i[0])
    print('i[1][0] ',i[1][0])
    print()
    for j in i[1][1]:
        print('j ',j)
        print()
        if j[1] not in seg_alreadyTaken:
            seg_alreadyTaken.append(j[1])
            temp.append(j)
    if i[1][2]:
        for j in i[1][2]:
            print('j= ',j)
            print()
            if j[1] not in seg_alreadyTaken:
                seg_alreadyTaken.append(j[1])
                temp2.append(j)
    narrative3.append([i[0],[i[1][0],temp,temp2]])
    temp=[]
    temp2=[]
    seg_alreadyTaken=[]
    
    print('_________________________')
print('*****************************************************')
for i in narrative3:
    print('i[0] ',i[0])
    print('i[1][0] ',i[1][0])
    print()
    for j in i[1][1]:
        print('j ',j)
        print()
        
    if i[1][2]:
        for j in i[1][2]:
            print('j= ',j)
            print()
    print('**************************')
           
narrConditional2= narrative3
# Out:
# i[0]  PsychologicalHealth
# i[1][0]  Thinking
#
# j  ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j  ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]
#
# j=  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j=  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j=  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j=  ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Mum
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# _________________________
# i[0]  LevelOfIndependence
# i[1][0]  Treatment
#
# j  ['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# j=  ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j=  ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j=  ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j=  ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  LungCancer
#
# j  ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]]
#
# j  ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]]
#
# j  ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Energy
#
# j  ['Rest', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Rest', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# j  ['Rest', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# j  ['Rest', ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]]
#
# j  ['Rest', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Child
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# _________________________
# i[0]  LevelOfIndependence
# i[1][0]  Insurance
#
# j  ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# j=  ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Dad
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# j=  ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Temple
#
# j  ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# j=  ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Caregiver
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Pneumonia
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Tumor
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Wife
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Friend
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Family
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  Fear
#
# j  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# j  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# j=  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j=  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  ShortnessOfBreath
#
# j  ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# j  ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# j  ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# j  ['Cough', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Cough', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Copd
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________
# i[0]  Environment
# i[1][0]  Exercise
#
# j  ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# j  ['Gym', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# j=  ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# j=  ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# j=  ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j=  ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  LungDisease
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  PulmonaryFibrosis
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Husband
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Rest
#
# j  ['Energy', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['Energy', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# j  ['Energy', ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]]
#
# j  ['Energy', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]]
#
# j  ['Energy', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# _________________________
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Meditation
#
# j  ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# j=  ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Cough
#
# j  ['ShortnessOfBreath', ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]]
#
# j  ['ShortnessOfBreath', ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]]
#
# j  ['ShortnessOfBreath', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# j=  ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# j=  ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# j=  ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Covid
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Christian
#
# j  ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j=  ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  PulmonaryHypertension
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Drug
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Vaping
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Smoking
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# j  ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  Guilt
#
# j  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# j  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# j=  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Mom
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# _________________________
# i[0]  Environment
# i[1][0]  Gym
#
# j  ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# j  ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# j  ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j  ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# j  ['Exercise', ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]]
#
# j=  ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# _________________________
# i[0]  SocialRelationship
# i[1][0]  Grandchild
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# _________________________
# i[0]  LevelOfIndependence
# i[1][0]  EndOfLifeCare
#
# j  ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# j=  ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  MentalHealth
#
# j  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Alcohol
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# _________________________
# i[0]  PhysicalHealth
# i[1][0]  Diet
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  Concentration
#
# j  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# _________________________
# i[0]  LevelOfIndependence
# i[1][0]  Mobility
#
# j  ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# j  ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# _________________________
# i[0]  PsychologicalHealth
# i[1][0]  Scared
#
# j  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# j  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# j=  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# _________________________
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Belief
#
# j  ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# j=  ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# _________________________
# *****************************************************
# i[0]  PsychologicalHealth
# i[1][0]  Thinking
#
# j  ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j  ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]
#
# j=  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j=  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j=  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j=  ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Mum
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# **************************
# i[0]  LevelOfIndependence
# i[1][0]  Treatment
#
# j  ['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# j=  ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j=  ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j=  ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j=  ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  LungCancer
#
# j  ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]]
#
# j  ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]]
#
# j  ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Energy
#
# j  ['Rest', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Rest', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# j  ['Rest', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# j  ['Rest', ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]]
#
# j  ['Rest', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Child
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# **************************
# i[0]  LevelOfIndependence
# i[1][0]  Insurance
#
# j  ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# j=  ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Dad
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# j=  ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# **************************
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Temple
#
# j  ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# j=  ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Caregiver
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Pneumonia
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Tumor
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Wife
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Friend
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Family
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# **************************
# i[0]  PsychologicalHealth
# i[1][0]  Fear
#
# j  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# j  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# j=  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j=  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  ShortnessOfBreath
#
# j  ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# j  ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# j  ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# j  ['Cough', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Cough', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Copd
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# **************************
# i[0]  Environment
# i[1][0]  Exercise
#
# j  ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# j  ['Gym', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# j=  ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# j=  ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# j=  ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j=  ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  LungDisease
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  PulmonaryFibrosis
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Husband
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Rest
#
# j  ['Energy', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['Energy', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# j  ['Energy', ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]]
#
# j  ['Energy', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]]
#
# j  ['Energy', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# **************************
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Meditation
#
# j  ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# j=  ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Cough
#
# j  ['ShortnessOfBreath', ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]]
#
# j  ['ShortnessOfBreath', ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]]
#
# j  ['ShortnessOfBreath', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# j=  ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# j=  ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# j=  ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Covid
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# **************************
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Christian
#
# j  ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j=  ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  PulmonaryHypertension
#
# j  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Drug
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Vaping
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Smoking
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# j  ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# **************************
# i[0]  PsychologicalHealth
# i[1][0]  Guilt
#
# j  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# j  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# j=  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Mom
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# **************************
# i[0]  Environment
# i[1][0]  Gym
#
# j  ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# j  ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# j  ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j  ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# j  ['Exercise', ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]]
#
# j=  ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# **************************
# i[0]  SocialRelationship
# i[1][0]  Grandchild
#
# j  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# **************************
# i[0]  LevelOfIndependence
# i[1][0]  EndOfLifeCare
#
# j  ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# j=  ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# **************************
# i[0]  PsychologicalHealth
# i[1][0]  MentalHealth
#
# j  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Alcohol
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# **************************
# i[0]  PhysicalHealth
# i[1][0]  Diet
#
# j  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j  ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# **************************
# i[0]  PsychologicalHealth
# i[1][0]  Concentration
#
# j  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j  ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# **************************
# i[0]  LevelOfIndependence
# i[1][0]  Mobility
#
# j  ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j  ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j  ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# j  ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# **************************
# i[0]  PsychologicalHealth
# i[1][0]  Scared
#
# j  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# j  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# j=  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# **************************
# i[0]  PersonalValuesAndBeliefs
# i[1][0]  Belief
#
# j  ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# j=  ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# **************************

# %%
# write the result to excel sheet
import xlsxwriter
workbook = xlsxwriter.Workbook('Correlative Narratives2.xlsx')# save the puncutaed transcript to file with the same video ID
worksheet = workbook.add_worksheet('correlative')
row=1
col=0
worksheet.write('A1', 'Focus Topic ')
worksheet.write('B1', 'Focus Concept')
worksheet.write('C1', 'Narrative Intro')
worksheet.write('D1', 'Narrative Seg Opening/closing')
worksheet.write('E1', 'Focus Concept Parent')
worksheet.write('F1', 'Concept')
worksheet.write('G1', 'VideoID')
worksheet.write('H1','Start Time' )
worksheet.write('I1','End Time' )
worksheet.write('J1', 'Duration')
worksheet.write('K1','Concepts within the segment' )


concIntro=''
videoClosing=''
videoOpen=''
segOpening=''
counter=0

for i in narrConditional2:
    col=0
    counter=0
    tempCol=0
    print(i[0])
    # topic
    videoOpen='This video is about the topic '+str(i[0]).upper()+' which relates to presentation skills.'
    worksheet.write(row,col,str(i[0]).upper())
    
    # Concept
    worksheet.write(row,col+1,str(i[1][0]).upper())#concept
    worksheet.write(row,col+2,videoOpen)
    ## video Intro
    ##### in case no segments are there for the FC but for the other correlatived concepts
    subCon=''
    processedCon=[]
    c=0
    #if len(i[1])==2:
    for j in i[1][1]:
        if j[0] not in processedCon:
            processedCon.append(j[0])# to write each concept one time. aVoid repeating the same concept in the text
            c+=1# to decide to write the word sequence or a video episode only
            subCon+=str(j[0]).upper()+', '# write the sequence of concepts
    if c >1:# to write either several episodes if the length >1 or an episode if the length==1
        concIntro='From the topic '+ str(i[0] ).upper()+', you will learn about '+str(i[1][0]).upper()+ '. '+subCon+' are similar to '+ str(i[1][0]).upper()+'. Hence, this video will present several episodes that mention '+ subCon+'. '
        partOfvideoClosing=' this video presented you with several video episodes that mention ' 
    else:

        concIntro='From the topic '+ str(i[0] ).upper()+', you will learn about '+str(i[1][0]).upper()+ '. '+subCon[:len(subCon)-2]+' is similar to '+  str(i[1][0]).upper()+'. Hence, this video will present several episodes that mention '+ subCon[:len(subCon)-2]+'. '
        partOfvideoClosing=' this video presented you with a video episode that mentions ' 
    worksheet.write(row,col+3,concIntro) 
    # opening seg / closing seg and opena another one
    tempCol=col+4 
    
    if len(i[1])==2:
        #concept
        #worksheet.write(row,col+3,j[1][0])
        #tempCol=col+4
        counter=0
        for j in i[1][1]:
            if counter==0:
                segOpening='You will now watch a video episode that mentions ' + str(j[0] ).upper()+'. It is taken from a YouTube video with ID= '+str(j[1][0])+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
                previousCon=j[0]
                counter+=1
            else:
                segOpening='Now you will watch a video episode that mentions ' + str(j[0] ).upper()+'. It is taken from a YouTube video with ID= '+str(j[1][0])+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
                previousCon=j[0]
                counter+=1
            worksheet.write(row,tempCol,segOpening)
            tempCol+=1
            worksheet.write(row,tempCol,j[0])
            tempCol+=1
            for k in j[1][0:4]:
                worksheet.write(row,tempCol,k)
                tempCol+=1
            
            #tempCol+=1    
            for k in j[1][4]:
                worksheet.write(row,tempCol,k)
                tempCol+=1

            #tempCol+=1
            if j[1][5]:
                for k in j[1][5]:
                    
                    worksheet.write(row,tempCol,k)
                    tempCol+=1
            row+=1
            col=1
            tempCol=col+3
        if c >1:# to write either several episodes if the length >1 or an episode if the length==1
            videoClosing='To learn about the concept '+str(i[1][0]).upper()+', this video included several episodes that mention '+subCon+' which are similar to '+ str(i[1][0]).upper() +'.'

        else:
        
            videoClosing='To learn about the concept '+str(i[1][0]).upper() +' this video included video episode that mentions '+subCon[:len(subCon)-2]+' which is similar to '+ str(i[1][0]).upper() +'.'
        worksheet.write(row,col+2,videoClosing)  

    
    elif len(i[1])==3:
        counter=0
        for j in i[1][1]:
            if counter==0:
                segOpening='You will now watch a video episode that mentions ' + str(j[0] ).upper()+'. It is taken from a YouTube video with ID= '+str(j[1][0])+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
                previousCon=j[0]
                counter+=1
            else:
                segOpening='Now you will watch a video episode that mentions ' + str(j[0] ).upper()+'. It is taken from a YouTube video with ID= '+str(j[1][0])+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
                previousCon=j[0]
                counter+=1
            worksheet.write(row,tempCol,segOpening)
            tempCol+=1
            worksheet.write(row,tempCol,j[0])
            tempCol+=1
            for k in j[1][0:4]:
                worksheet.write(row,tempCol,k)
                tempCol+=1
            
            #tempCol+=1    
            for k in j[1][4]:
                worksheet.write(row,tempCol,k)
                tempCol+=1

            
            if j[1][5]:
                #tempCol+=1
                for k in j[1][5]:
                    
                    worksheet.write(row,tempCol,k)
                    tempCol+=1
            row+=1
            col=1
            tempCol=col+3
        processedCon2=[]
        c2=0
        row+=1
        col=1
        tempCol=col+3
        for j in i[1][2]:
            if j[0] not in processedCon2:
                processedCon.append(j[0])# to write each concept one time. aVoid repeating the same concept in the text
                c2+=1# to decide to write the word sequence or a video episode only
                #subCon+=', '+str(j[0])# write the sequence of concepts
        if c >1:# to write either several episodes if the length >1 or an episode if the length==1
            videoClosing='To learn about the concept '+str(i[1][0]).upper()+', this video included several episodes that mention '+str(i[1][0]).upper() +'.'

        else:
        
            videoClosing='To learn about the concept '+str(i[1][0]).upper() +' this video included video episode that mentions '+ str(i[1][0]).upper() +'.'
        worksheet.write(row,col+2,videoClosing)  
        partOfvideoClosing=' You can now watch a video episode that mentions '+str(i[1][0]).upper()+'.'
        #else:
        #    partOfvideoClosing=' You can now watch several video episodes that mention '+i[1][0]+'.' 
        #worksheet.write(row,tempCol, videoClosing) 
        #tempCol+=1
   
        for j in i[1][2]:
            #if counter==0:
            #    segOpening='You will now watch a video episode that mentions ' + str(j[0] )+'. '
            #    previousCon=j[0]
            #    counter+=1
            #else:
            #    segOpening='You have watched a video episode that mentions ' + previousCon+'.  Now you will watch a video episode that mentions ' + str(j[0] )+'. '
            #    previousCon=j[0]
            #    counter+=1
            partOfvideoClosing=' You can now watch a video episode that mentions '+str(i[1][0]).upper()+'. It is taken from a YouTube video with ID= '+str(j[1][0])+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
            worksheet.write(row,tempCol, partOfvideoClosing)
            tempCol+=1
            worksheet.write(row,tempCol,j[0])
            tempCol+=1
            for k in j[1][0:4]:
                worksheet.write(row,tempCol,k)
                tempCol+=1
            
            #tempCol+=1    
            for k in j[1][4]:
                worksheet.write(row,tempCol,k)
                tempCol+=1


            if j[1][5]:
                #tempCol+=1
                for k in j[1][5]:
                    
                    worksheet.write(row,tempCol,k)
                    tempCol+=1
            row+=1
            col=1
            tempCol=col+3
    row+=1

workbook.close()
# Out:
# PsychologicalHealth
# SocialRelationship
# LevelOfIndependence
# PhysicalHealth
# PhysicalHealth
# SocialRelationship
# LevelOfIndependence
# SocialRelationship
# PersonalValuesAndBeliefs
# SocialRelationship
# PhysicalHealth
# PhysicalHealth
# SocialRelationship
# SocialRelationship
# SocialRelationship
# PsychologicalHealth
# PhysicalHealth
# PhysicalHealth
# Environment
# PhysicalHealth
# PhysicalHealth
# SocialRelationship
# PhysicalHealth
# PersonalValuesAndBeliefs
# PhysicalHealth
# PhysicalHealth
# PersonalValuesAndBeliefs
# PhysicalHealth
# PhysicalHealth
# PhysicalHealth
# PhysicalHealth
# PsychologicalHealth
# SocialRelationship
# Environment
# SocialRelationship
# LevelOfIndependence
# PsychologicalHealth
# PhysicalHealth
# PhysicalHealth
# PsychologicalHealth
# LevelOfIndependence
# PsychologicalHealth
# PersonalValuesAndBeliefs

# %%
import statistics
length=[]
for i in narrConditional2:
    if len(i[1]) not in length:
        length.append(len(i[1]))


    print('topic = ',i[0])# topic
    print()
    print('concept ',i[1][0])
    print()
    if len(i[1])==2:
        print('len(i[1])==2')
        print()
        print(i[1][0])
        print()
        for j in i[1][1]:
            print(j)
            print()
    if len(i[1])==3:
        print('len(i[1])==3')
        print()
        print(i[1][0])
        print()
        for j in i[1][1]:
            print(j)
            print()
        print('second half')
        print()
        for j in i[1][2]:
            print(j)
            print()
    
        
    print('________________________________________________')
print('length= ',length)


uniqueDurationOFNarrative=[]
allNarrativesDur=[]
durationOfNarratives=0
numberOfNarratives=0
for i in narrConditional2:
    numberOfNarratives+=1

    print(i[0])
    print()
    if len(i[1])==2:
        print('length is 2')
        print()
        print('i[1][0]= ',i[1][0])
        for j in i[1][1]:
            print('j of i[1][1] ',j)
            if j[1][3] not in uniqueDurationOFNarrative:
                uniqueDurationOFNarrative.append(j[1][3])
            durationOfNarratives+=j[1][3]
            print()

    elif len(i[1])==3:
        print('length is 3')
        print()
        print('i[1][0]= ',i[1][0])
        for j in i[1][1]:
            print('j of i[1][1] ',j)
            print()
            if j[1][3] not in uniqueDurationOFNarrative:
                uniqueDurationOFNarrative.append(j[1][3])
            durationOfNarratives+=j[1][3]
        for j in i[1][2]:
            print('j of i[1][2] ',j)
            print()
            if j[1][3] not in uniqueDurationOFNarrative:
                uniqueDurationOFNarrative.append(j[1][3])
            durationOfNarratives+=j[1][3]
    allNarrativesDur.append([i[0],i[1][0],durationOfNarratives])
    durationOfNarratives=0
        
    
    
    print('___________________________________')
print('uniqueDurationOFNarrative = ',uniqueDurationOFNarrative)
sumDur=0
for i in uniqueDurationOFNarrative:
    sumDur+=i
print('AvgDuration of a segment  = ',round((sumDur/len(uniqueDurationOFNarrative)),2))
print()
print('Number of narratives= ',numberOfNarratives)
print()

durationOfAllNarratives=0
listOfNarrDuration=[]
listOfNarrAbove3Duration=[]
numOfNarrativeAbove3Min=0
numOfNarrativeBelow3Min=0
numOfNarrativeAbove2Min=0
numOfNarrativeBelow2Min=0

durOfNarrativeAbove3Min=0

for i in allNarrativesDur:
    print(i)
    durationOfAllNarratives+=i[2]
    listOfNarrDuration.append(i[2])
    if i[2]>=180:
        numOfNarrativeAbove3Min+=1
        durOfNarrativeAbove3Min+=i[2]
        listOfNarrAbove3Duration.append(i[2])
    if i[2]>=120:
        numOfNarrativeAbove2Min+=1
    if i[2]<180:
        numOfNarrativeBelow3Min+=1
    if i[2]<120:
        numOfNarrativeBelow2Min+=1
        
    print()
print('duration of all Correlatives = ',durationOfAllNarratives)
print()
print('Average of narrative duration = ', round((durationOfAllNarratives/len(allNarrativesDur)),0))
print('Minimum narrative duration = ',min(listOfNarrDuration))
print('maximum of narrative duration= ',max(listOfNarrDuration))
print()
print('STDV of narrative duration =',round(statistics.stdev(listOfNarrDuration),0))
print()
print('# of narratives above 3 minutes = ',numOfNarrativeAbove3Min)
print()
print('duration of narratives above 3 minutes = ',durOfNarrativeAbove3Min)
print()
print('Average of narratives above 3 duration = ', round((durOfNarrativeAbove3Min/numOfNarrativeAbove3Min),0))
print('Minimum narratives above 3 duration = ',min(listOfNarrAbove3Duration))
print('maximum of narratives above 3 duration= ',max(listOfNarrAbove3Duration))
print()
print('STDV of narratives above 3 duration =',round(statistics.stdev(listOfNarrAbove3Duration),0))
print()
print('number of narratives per evaluater= ',round(numOfNarrativeAbove3Min/5,0))
print()
print('# of narratives below 3 minutes = ',numOfNarrativeBelow3Min)
print()
print('# of narratives above 2 minutes = ',numOfNarrativeAbove2Min)
print()
print('# of narratives below 2 minutes = ',numOfNarrativeBelow2Min)
print()
# Out:
# topic =  PsychologicalHealth
#
# concept  Thinking
#
# len(i[1])==3
#
# Thinking
#
# ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]
#
# second half
#
# ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Mum
#
# len(i[1])==3
#
# Mum
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  LevelOfIndependence
#
# concept  Treatment
#
# len(i[1])==3
#
# Treatment
#
# ['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# second half
#
# ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  LungCancer
#
# len(i[1])==3
#
# LungCancer
#
# ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]]
#
# ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]]
#
# ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Energy
#
# len(i[1])==3
#
# Energy
#
# ['Rest', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Rest', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# ['Rest', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# ['Rest', ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]]
#
# ['Rest', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Child
#
# len(i[1])==3
#
# Child
#
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  LevelOfIndependence
#
# concept  Insurance
#
# len(i[1])==3
#
# Insurance
#
# ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# second half
#
# ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Dad
#
# len(i[1])==3
#
# Dad
#
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# second half
#
# ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ________________________________________________
# topic =  PersonalValuesAndBeliefs
#
# concept  Temple
#
# len(i[1])==3
#
# Temple
#
# ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# second half
#
# ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Caregiver
#
# len(i[1])==3
#
# Caregiver
#
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Pneumonia
#
# len(i[1])==3
#
# Pneumonia
#
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Tumor
#
# len(i[1])==3
#
# Tumor
#
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Wife
#
# len(i[1])==3
#
# Wife
#
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Friend
#
# len(i[1])==3
#
# Friend
#
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Family
#
# len(i[1])==3
#
# Family
#
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PsychologicalHealth
#
# concept  Fear
#
# len(i[1])==3
#
# Fear
#
# ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# second half
#
# ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  ShortnessOfBreath
#
# len(i[1])==3
#
# ShortnessOfBreath
#
# ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# ['Cough', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Cough', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Copd
#
# len(i[1])==3
#
# Copd
#
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  Environment
#
# concept  Exercise
#
# len(i[1])==3
#
# Exercise
#
# ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ['Gym', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# second half
#
# ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  LungDisease
#
# len(i[1])==3
#
# LungDisease
#
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  PulmonaryFibrosis
#
# len(i[1])==3
#
# PulmonaryFibrosis
#
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Husband
#
# len(i[1])==3
#
# Husband
#
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Rest
#
# len(i[1])==3
#
# Rest
#
# ['Energy', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['Energy', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# ['Energy', ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]]
#
# ['Energy', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]]
#
# ['Energy', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PersonalValuesAndBeliefs
#
# concept  Meditation
#
# len(i[1])==3
#
# Meditation
#
# ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# second half
#
# ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Cough
#
# len(i[1])==3
#
# Cough
#
# ['ShortnessOfBreath', ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]]
#
# ['ShortnessOfBreath', ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]]
#
# ['ShortnessOfBreath', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# second half
#
# ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Covid
#
# len(i[1])==3
#
# Covid
#
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PersonalValuesAndBeliefs
#
# concept  Christian
#
# len(i[1])==3
#
# Christian
#
# ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# second half
#
# ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  PulmonaryHypertension
#
# len(i[1])==3
#
# PulmonaryHypertension
#
# ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Drug
#
# len(i[1])==3
#
# Drug
#
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Vaping
#
# len(i[1])==3
#
# Vaping
#
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Smoking
#
# len(i[1])==3
#
# Smoking
#
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PsychologicalHealth
#
# concept  Guilt
#
# len(i[1])==3
#
# Guilt
#
# ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# second half
#
# ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Mom
#
# len(i[1])==3
#
# Mom
#
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  Environment
#
# concept  Gym
#
# len(i[1])==3
#
# Gym
#
# ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# ['Exercise', ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]]
#
# second half
#
# ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ________________________________________________
# topic =  SocialRelationship
#
# concept  Grandchild
#
# len(i[1])==3
#
# Grandchild
#
# ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  LevelOfIndependence
#
# concept  EndOfLifeCare
#
# len(i[1])==3
#
# EndOfLifeCare
#
# ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# second half
#
# ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ________________________________________________
# topic =  PsychologicalHealth
#
# concept  MentalHealth
#
# len(i[1])==3
#
# MentalHealth
#
# ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Alcohol
#
# len(i[1])==3
#
# Alcohol
#
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PhysicalHealth
#
# concept  Diet
#
# len(i[1])==3
#
# Diet
#
# ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PsychologicalHealth
#
# concept  Concentration
#
# len(i[1])==3
#
# Concentration
#
# ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  LevelOfIndependence
#
# concept  Mobility
#
# len(i[1])==3
#
# Mobility
#
# ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# second half
#
# ________________________________________________
# topic =  PsychologicalHealth
#
# concept  Scared
#
# len(i[1])==3
#
# Scared
#
# ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# second half
#
# ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ________________________________________________
# topic =  PersonalValuesAndBeliefs
#
# concept  Belief
#
# len(i[1])==3
#
# Belief
#
# ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# second half
#
# ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# ________________________________________________
# length=  [3]
# PsychologicalHealth
#
# length is 3
#
# i[1][0]=  Thinking
# j of i[1][1]  ['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j of i[1][1]  ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]
#
# j of i[1][2]  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][2]  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j of i[1][2]  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j of i[1][2]  ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Mum
# j of i[1][1]  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][1]  ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# ___________________________________
# LevelOfIndependence
#
# length is 3
#
# i[1][0]=  Treatment
# j of i[1][1]  ['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# j of i[1][2]  ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][2]  ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][2]  ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][2]  ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  LungCancer
# j of i[1][1]  ['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]]
#
# j of i[1][1]  ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]]
#
# j of i[1][1]  ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Energy
# j of i[1][1]  ['Rest', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j of i[1][1]  ['Rest', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]]
#
# j of i[1][1]  ['Rest', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]]
#
# j of i[1][1]  ['Rest', ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]]
#
# j of i[1][1]  ['Rest', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Child
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j of i[1][1]  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][1]  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# j of i[1][1]  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# LevelOfIndependence
#
# length is 3
#
# i[1][0]=  Insurance
# j of i[1][1]  ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# j of i[1][2]  ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Dad
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j of i[1][1]  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]
#
# j of i[1][2]  ['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PersonalValuesAndBeliefs
#
# length is 3
#
# i[1][0]=  Temple
# j of i[1][1]  ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# j of i[1][2]  ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Caregiver
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j of i[1][1]  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][1]  ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Pneumonia
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j of i[1][1]  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Tumor
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j of i[1][1]  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Wife
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j of i[1][1]  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][1]  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Friend
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j of i[1][1]  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][1]  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Family
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j of i[1][1]  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][1]  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 3
#
# i[1][0]=  Fear
# j of i[1][1]  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# j of i[1][1]  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# j of i[1][2]  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j of i[1][2]  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  ShortnessOfBreath
# j of i[1][1]  ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# j of i[1][1]  ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# j of i[1][1]  ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# j of i[1][1]  ['Cough', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j of i[1][1]  ['Cough', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Copd
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j of i[1][1]  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# Environment
#
# length is 3
#
# i[1][0]=  Exercise
# j of i[1][1]  ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# j of i[1][1]  ['Gym', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]
#
# j of i[1][2]  ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# j of i[1][2]  ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# j of i[1][2]  ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j of i[1][2]  ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  LungDisease
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j of i[1][1]  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  PulmonaryFibrosis
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j of i[1][1]  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Husband
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j of i[1][1]  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][1]  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Rest
# j of i[1][1]  ['Energy', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j of i[1][1]  ['Energy', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]]
#
# j of i[1][1]  ['Energy', ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]]
#
# j of i[1][1]  ['Energy', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]]
#
# j of i[1][1]  ['Energy', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]
#
# ___________________________________
# PersonalValuesAndBeliefs
#
# length is 3
#
# i[1][0]=  Meditation
# j of i[1][1]  ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# j of i[1][2]  ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Cough
# j of i[1][1]  ['ShortnessOfBreath', ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]]
#
# j of i[1][1]  ['ShortnessOfBreath', ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]]
#
# j of i[1][1]  ['ShortnessOfBreath', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]
#
# j of i[1][2]  ['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]]
#
# j of i[1][2]  ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]]
#
# j of i[1][2]  ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Covid
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j of i[1][1]  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PersonalValuesAndBeliefs
#
# length is 3
#
# i[1][0]=  Christian
# j of i[1][1]  ['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][2]  ['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  PulmonaryHypertension
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]]
#
# j of i[1][1]  ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]]
#
# j of i[1][1]  ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Drug
# j of i[1][1]  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j of i[1][1]  ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# j of i[1][1]  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j of i[1][1]  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Vaping
# j of i[1][1]  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j of i[1][1]  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j of i[1][1]  ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]]
#
# j of i[1][1]  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j of i[1][1]  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Smoking
# j of i[1][1]  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j of i[1][1]  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j of i[1][1]  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j of i[1][1]  ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 3
#
# i[1][0]=  Guilt
# j of i[1][1]  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j of i[1][1]  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# j of i[1][1]  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# j of i[1][2]  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Mom
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j of i[1][1]  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][1]  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# Environment
#
# length is 3
#
# i[1][0]=  Gym
# j of i[1][1]  ['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]]
#
# j of i[1][1]  ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]]
#
# j of i[1][1]  ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]
#
# j of i[1][1]  ['Exercise', ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]]
#
# j of i[1][2]  ['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]
#
# ___________________________________
# SocialRelationship
#
# length is 3
#
# i[1][0]=  Grandchild
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]]
#
# j of i[1][1]  ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]
#
# j of i[1][1]  ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]
#
# ___________________________________
# LevelOfIndependence
#
# length is 3
#
# i[1][0]=  EndOfLifeCare
# j of i[1][1]  ['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]
#
# j of i[1][2]  ['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 3
#
# i[1][0]=  MentalHealth
# j of i[1][1]  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j of i[1][1]  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j of i[1][1]  ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j of i[1][1]  ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Alcohol
# j of i[1][1]  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j of i[1][1]  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j of i[1][1]  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j of i[1][1]  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j of i[1][1]  ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# ___________________________________
# PhysicalHealth
#
# length is 3
#
# i[1][0]=  Diet
# j of i[1][1]  ['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]]
#
# j of i[1][1]  ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]]
#
# j of i[1][1]  ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]]
#
# j of i[1][1]  ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]]
#
# j of i[1][1]  ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 3
#
# i[1][0]=  Concentration
# j of i[1][1]  ['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]]
#
# j of i[1][1]  ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]]
#
# j of i[1][1]  ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]]
#
# j of i[1][1]  ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]
#
# ___________________________________
# LevelOfIndependence
#
# length is 3
#
# i[1][0]=  Mobility
# j of i[1][1]  ['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]]
#
# j of i[1][1]  ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]]
#
# j of i[1][1]  ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]
#
# j of i[1][1]  ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]
#
# ___________________________________
# PsychologicalHealth
#
# length is 3
#
# i[1][0]=  Scared
# j of i[1][1]  ['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]]
#
# j of i[1][1]  ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]
#
# j of i[1][1]  ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]
#
# j of i[1][2]  ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]
#
# ___________________________________
# PersonalValuesAndBeliefs
#
# length is 3
#
# i[1][0]=  Belief
# j of i[1][1]  ['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]
#
# j of i[1][2]  ['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]
#
# ___________________________________
# uniqueDurationOFNarrative =  [43, 31, 40, 37, 116, 33, 35, 136, 82, 36, 91, 80, 128, 60, 25, 89, 61, 65, 22, 126, 42, 41, 24, 51, 159, 44, 118, 58, 56, 45, 81, 50, 52, 84, 108, 47, 122, 87, 30, 34, 49]
# AvgDuration of a segment  =  66.29
#
# Number of narratives=  43
#
# ['PsychologicalHealth', 'Thinking', 300]
#
# ['SocialRelationship', 'Mum', 289]
#
# ['LevelOfIndependence', 'Treatment', 285]
#
# ['PhysicalHealth', 'LungCancer', 290]
#
# ['PhysicalHealth', 'Energy', 270]
#
# ['SocialRelationship', 'Child', 299]
#
# ['LevelOfIndependence', 'Insurance', 168]
#
# ['SocialRelationship', 'Dad', 300]
#
# ['PersonalValuesAndBeliefs', 'Temple', 177]
#
# ['SocialRelationship', 'Caregiver', 300]
#
# ['PhysicalHealth', 'Pneumonia', 286]
#
# ['PhysicalHealth', 'Tumor', 286]
#
# ['SocialRelationship', 'Wife', 298]
#
# ['SocialRelationship', 'Friend', 298]
#
# ['SocialRelationship', 'Family', 298]
#
# ['PsychologicalHealth', 'Fear', 253]
#
# ['PhysicalHealth', 'ShortnessOfBreath', 264]
#
# ['PhysicalHealth', 'Copd', 286]
#
# ['Environment', 'Exercise', 285]
#
# ['PhysicalHealth', 'LungDisease', 286]
#
# ['PhysicalHealth', 'PulmonaryFibrosis', 286]
#
# ['SocialRelationship', 'Husband', 298]
#
# ['PhysicalHealth', 'Rest', 289]
#
# ['PersonalValuesAndBeliefs', 'Meditation', 144]
#
# ['PhysicalHealth', 'Cough', 278]
#
# ['PhysicalHealth', 'Covid', 286]
#
# ['PersonalValuesAndBeliefs', 'Christian', 177]
#
# ['PhysicalHealth', 'PulmonaryHypertension', 286]
#
# ['PhysicalHealth', 'Drug', 297]
#
# ['PhysicalHealth', 'Vaping', 272]
#
# ['PhysicalHealth', 'Smoking', 298]
#
# ['PsychologicalHealth', 'Guilt', 253]
#
# ['SocialRelationship', 'Mom', 298]
#
# ['Environment', 'Gym', 274]
#
# ['SocialRelationship', 'Grandchild', 298]
#
# ['LevelOfIndependence', 'EndOfLifeCare', 168]
#
# ['PsychologicalHealth', 'MentalHealth', 287]
#
# ['PhysicalHealth', 'Alcohol', 299]
#
# ['PhysicalHealth', 'Diet', 299]
#
# ['PsychologicalHealth', 'Concentration', 287]
#
# ['LevelOfIndependence', 'Mobility', 243]
#
# ['PsychologicalHealth', 'Scared', 253]
#
# ['PersonalValuesAndBeliefs', 'Belief', 144]
#
# duration of all Correlatives =  11532
#
# Average of narrative duration =  268.0
# Minimum narrative duration =  144
# maximum of narrative duration=  300
#
# STDV of narrative duration = 45.0
#
# # of narratives above 3 minutes =  37
#
# duration of narratives above 3 minutes =  10554
#
# Average of narratives above 3 duration =  285.0
# Minimum narratives above 3 duration =  243
# maximum of narratives above 3 duration=  300
#
# STDV of narratives above 3 duration = 15.0
#
# number of narratives per evaluater=  7.0
#
# # of narratives below 3 minutes =  6
#
# # of narratives above 2 minutes =  43
#
# # of narratives below 2 minutes =  0

# %%
length=[]
length1=[]
for i in narrConditional2:
    if len(i) not in length:
        length.append(len(i))
    if len(i[1]) not in length1:
        length1.append(len(i[1]))
print('length= ',length, ' length1 ',length1)
print()
for i in narrConditional2:        
    
    
    
    print('i[0] ',i[0])
    if len(i[1])==2:
        print('leni[1] is 2')
        print()
    elif len(i[1])==3:
        print('leni[1] = 3')
        print()
    for j in i[1]:
        
        print('j ',j)
        print()
    print('________________________________________')
# Out:
# length=  [2]  length1  [3]
#
# i[0]  PsychologicalHealth
# leni[1] = 3
#
# j  Thinking
#
# j  [['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]]
#
# j  [['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]], ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]]
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Mum
#
# j  [['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  LevelOfIndependence
# leni[1] = 3
#
# j  Treatment
#
# j  [['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]]
#
# j  [['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]]
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  LungCancer
#
# j  [['Pneumonia', ['hQQ5xQGZxdA9', 1.54, 3.14, 80, ['Pneumonia', 3.0], ['Friend', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0]]], ['Tumor', ['hQQ5xQGZxdA21', 4.41, 6.49, 128, ['Tumor', 6.0], ['Memory', 1.0, 'Treatment', 1.0]]], ['Tumor', ['hQQ5xQGZxdA40', 8.48, 10.1, 82, ['Wife', 1.0, 'Community', 2.0, 'Tumor', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Energy
#
# j  [['Rest', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]], ['Rest', ['HBFn82ffSVE25', 6.15, 6.4, 25, ['Pneumonia', 1.0, 'Rest', 1.0], []]], ['Rest', ['Nl55TpSjWp416', 5.17, 6.46, 89, ['Pneumonia', 3.0, 'Rest', 1.0], []]], ['Rest', ['aHAbRVZOxnk1', 0.06, 0.41, 35, ['Rest', 1.0], []]], ['Rest', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Child
#
# j  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  LevelOfIndependence
# leni[1] = 3
#
# j  Insurance
#
# j  [['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]]
#
# j  [['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]]
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Dad
#
# j  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]]
#
# j  [['Dad', ['OHeU3oj8nmc14', 2.52, 3.34, 42, ['Dad', 1.0, 'LungCancer', 1.0], []]]]
#
# ________________________________________
# i[0]  PersonalValuesAndBeliefs
# leni[1] = 3
#
# j  Temple
#
# j  [['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]]
#
# j  [['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]]
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Caregiver
#
# j  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Friend', ['OkHESl_I2O813', 4.39, 5.03, 24, ['Friend', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Pneumonia
#
# j  [['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]], ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Tumor
#
# j  [['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]], ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Wife
#
# j  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Friend
#
# j  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Family
#
# j  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PsychologicalHealth
# leni[1] = 3
#
# j  Fear
#
# j  [['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]], ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]]
#
# j  [['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]], ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]]
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  ShortnessOfBreath
#
# j  [['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]], ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]], ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]], ['Cough', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]], ['Cough', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Copd
#
# j  [['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]], ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  Environment
# leni[1] = 3
#
# j  Exercise
#
# j  [['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]], ['Gym', ['dyRmGVgG7_89', 2.2, 3.02, 41, ['Gym', 1.0, 'Treatment', 1.0, 'Thinking', 1.0], []]]]
#
# j  [['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]], ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]], ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]]]
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  LungDisease
#
# j  [['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]], ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  PulmonaryFibrosis
#
# j  [['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]], ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Husband
#
# j  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Rest
#
# j  [['Energy', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['Energy', ['wArV8Ho_C1A5', 1.34, 2.26, 51, ['Mum', 1.0, 'Energy', 1.0, 'Sleep', 1.0], []]], ['Energy', ['pmuUnQ5Zi4Q4', 1.0, 1.52, 52, ['Energy', 1.0], []]], ['Energy', ['Tyo2YsA0Y03', 1.25, 2.49, 84, ['Energy', 1.0, 'Treatment', 2.0], []]], ['Energy', ['ZoEEgU6L-m81', 0.11, 1.02, 51, ['Energy', 1.0, 'LungCancer', 1.0, 'Strength', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PersonalValuesAndBeliefs
# leni[1] = 3
#
# j  Meditation
#
# j  [['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]]
#
# j  [['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]]
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Cough
#
# j  [['ShortnessOfBreath', ['uJoY4oMLXEY1', 0.0, 0.42, 42, ['ShortnessOfBreath', 1.0], []]], ['ShortnessOfBreath', ['j3t5nFnTULQ1', 0.05, 0.52, 47, ['ShortnessOfBreath', 1.0], []]], ['ShortnessOfBreath', ['POskT8R_3t43', 0.42, 1.43, 61, ['Rest', 2.0, 'ShortnessOfBreath', 1.0], []]]]
#
# j  [['Cough', ['wArV8Ho_C1A1', 0.13, 0.54, 41, ['Cough', 1.0], []]], ['Cough', ['6U7OpgFojaw3', 0.45, 1.41, 56, ['Cough', 1.0], []]], ['Cough', ['q9xteXsPy3c1', 0.0, 0.31, 31, ['Cough', 1.0], []]]]
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Covid
#
# j  [['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]], ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PersonalValuesAndBeliefs
# leni[1] = 3
#
# j  Christian
#
# j  [['Temple', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]]]
#
# j  [['Christian', ['e0KVtXL-TjY1', 0.09, 0.5, 41, ['Christian', 1.0], []]]]
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  PulmonaryHypertension
#
# j  [['LungCancer', ['MxmrjLQvg7E4', 0.43, 1.24, 41, ['LungCancer', 1.0, 'Pain', 1.0, 'Training', 1.0], []]], ['LungCancer', ['MxmrjLQvg7E12', 2.34, 3.25, 51, ['LungCancer', 1.0, 'Energy', 1.0], []]], ['LungCancer', ['rQutyErqBG01', 0.04, 2.43, 159, ['LungCancer', 4.0], ['Tumor', 4.0, 'Security', 1.0, 'Smoking', 1.0, 'Fear', 1.0]]], ['LungCancer', ['hQQ5xQGZxdA46', 10.12, 10.47, 35, ['Friend', 1.0, 'LungCancer', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Drug
#
# j  [['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]], ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]], ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]], ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Vaping
#
# j  [['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]], ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Smoking', ['GV3Rew061FA1', 0.02, 1.29, 87, ['Copd', 2.0, 'Smoking', 2.0], ['Exercise', 1.0, 'Pneumonia', 1.0]]], ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]], ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Smoking
#
# j  [['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]], ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]], ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Alcohol', ['E8nRS2LxFdw4', 0.46, 1.29, 43, ['Alcohol', 1.0, 'Diet', 1.0, 'Treatment', 1.0], []]], ['Drug', ['LYwQdM-2ok49', 2.32, 3.08, 36, ['Tumor', 1.0, 'Drug', 1.0, 'Pain', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PsychologicalHealth
# leni[1] = 3
#
# j  Guilt
#
# j  [['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]], ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]], ['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]]
#
# j  [['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]]]
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Mom
#
# j  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  Environment
# leni[1] = 3
#
# j  Gym
#
# j  [['Exercise', ['uJoY4oMLXEY5', 1.38, 2.15, 37, ['Exercise', 1.0], []]], ['Exercise', ['VyGp12XbPzs2', 0.59, 2.2, 81, ['Exercise', 2.0, 'Strength', 1.0, 'Treatment', 1.0], []]], ['Exercise', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Exercise', ['ZoEEgU6L-m87', 2.39, 3.29, 50, ['Exercise', 1.0], []]], ['Exercise', ['FH7aHDHnkjU7', 1.36, 2.06, 30, ['Exercise', 1.0], []]]]
#
# j  [['Gym', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]]
#
# ________________________________________
# i[0]  SocialRelationship
# leni[1] = 3
#
# j  Grandchild
#
# j  [['Mum', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Mum', ['MxmrjLQvg7E7', 1.27, 2.32, 65, ['Mum', 2.0], ['Mom', 1.0, 'Family', 1.0, 'Friend', 1.0]]], ['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['0fI_01yFmME11', 4.01, 4.23, 22, ['Caregiver', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  LevelOfIndependence
# leni[1] = 3
#
# j  EndOfLifeCare
#
# j  [['Insurance', ['rQutyErqBG017', 5.01, 5.43, 42, ['Insurance', 1.0], []]]]
#
# j  [['EndOfLifeCare', ['4AWZD3ClqW81', 0.08, 2.14, 126, ['EndOfLifeCare', 2.0, 'Friend', 2.0], ['PulmonaryFibrosis', 1.0, 'Exercise', 1.0, 'Family', 1.0, 'Wife', 1.0]]]]
#
# ________________________________________
# i[0]  PsychologicalHealth
# leni[1] = 3
#
# j  MentalHealth
#
# j  [['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]], ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Alcohol
#
# j  [['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]], ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]], ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]], ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PhysicalHealth
# leni[1] = 3
#
# j  Diet
#
# j  [['Drug', ['aHAbRVZOxnk5', 1.19, 2.15, 56, ['Drug', 1.0], []]], ['Vaping', ['im4bTtQ99SY1', 0.0, 2.03, 122, ['Vaping', 2.0], ['Child', 2.0, 'Family', 1.0]]], ['Drug', ['im4bTtQ99SY9', 2.06, 2.47, 41, ['Drug', 1.0, 'Friend', 1.0], []]], ['Smoking', ['OHeU3oj8nmc7', 1.23, 2.08, 45, ['Smoking', 1.0, 'Cough', 1.0], []]], ['Smoking', ['323hkORG0OM1', 0.02, 0.37, 35, ['Smoking', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PsychologicalHealth
# leni[1] = 3
#
# j  Concentration
#
# j  [['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]], ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['HBFn82ffSVE3', 0.35, 1.35, 60, ['Pneumonia', 2.0, 'Rest', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['wArV8Ho_C1A3', 0.55, 1.3, 34, ['Thinking', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  LevelOfIndependence
# leni[1] = 3
#
# j  Mobility
#
# j  [['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]], ['Treatment', ['j3t5nFnTULQ3', 0.56, 1.46, 49, ['LungDisease', 1.0, 'Treatment', 1.0], []]]]
#
# j  []
#
# ________________________________________
# i[0]  PsychologicalHealth
# leni[1] = 3
#
# j  Scared
#
# j  [['Fear', ['wwiwjZw7d6o5', 1.14, 3.12, 118, ['Treatment', 2.0, 'Fear', 3.0], ['Scared', 1.0, 'Child', 1.0, 'Hope', 1.0]]], ['Guilt', ['q9xteXsPy3c2', 0.36, 1.09, 33, ['Guilt', 1.0], []]], ['Fear', ['Tyo2YsA0Y05', 2.52, 3.51, 58, ['LungCancer', 1.0, 'Family', 1.0, 'Fear', 1.0, 'Hope', 1.0], []]]]
#
# j  [['Scared', ['cfyb39S_CZw5', 1.2, 2.05, 44, ['Hope', 1.0, 'Scared', 1.0, 'Wife', 1.0], []]]]
#
# ________________________________________
# i[0]  PersonalValuesAndBeliefs
# leni[1] = 3
#
# j  Belief
#
# j  [['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]]
#
# j  [['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]]
#
# ________________________________________

# %%
import codecs
from bs4 import BeautifulSoup as Soup
def inSecTime(t):
    intPart=int(t)
    floatPart=int(round(float(t)-int(t),2)*100)

    inSec=(intPart*60)+floatPart
    return inSec

videoIDs=[['MxmrjLQvg7E',"Becca lung cancer story"],
          ['rQutyErqBG0',"Lung Cancer Patient Stories"],
          ['mWo-G3UQ-zU',"Ralph Patient Story"],
          ['hQQ5xQGZxdA',"Lung Cancer Survivor Story Dave"],
          ['xY3B9nLm1u8',"Nick lung cancer story"],
          ['yV893Fx41lE',"Non Smoking Lung Cancer Quintano Story"],
          ['wwiwjZw7d6o',"Young women can get lung cancer Joanna story"],
          ['uJoY4oMLXEY',"Chronic Respiratory Disease Patient Stories"],
          ['l9k9q6FHeX4',"Cancer Survivor Story How I Got Diagnosed with Lung Cancer Montessa Lee"],
          ['j3t5nFnTULQ',"Lung Disease and Double Lung Transplantation at Stanford Jen Julian story"],
          ['tfxB32Vb5hE',"Paige Lung Cancer Story Levine Cancer Institute"],
          ['0fI_01yFmME',"Lung Transplant after Pulmonary Fibrosis David Story"],
          ['HBFn82ffSVE',"Peter lung cancer story"],
          ['llk-qgIr9Nk',"Lung Cancer Patient Story Terri Path to No Evidence of Disease After Recurrences"],
          ["3mcWSmPXFtM","Lung Cancer Treatment Cait Story Cancer Research UK"],
          ['bmvlK4qhAnU',"Cancer Survivor Story How Got Diagnosed with Lung Cancer Ashley R"],
          ['wArV8Ho_C1A',"How am I going to die"],
          ['ehh89UrZtZU',"Struggle to Breathe COPD Chronic Obstructive Pulmonary Dise"],
          ['VyGp12XbPzs',"How I became active again  Jude story of living with bronchiectasis"],
          ['jZJTcp3d1q4',"COPD affects every part of my daily life Chris story"],
          ['ZU_l9xCB-08',"COPD exacerbations real stories"],
          ['Nl55TpSjWp4',"Stephen Story Celebrating Life After Severe Illness "],
          ['6U7OpgFojaw',"Sarcoidosis Patient Story"],
          ['e0KVtXL-TjY',"ECMO Patient Story Nichele Calhoun"],
          ['aHAbRVZOxnk',"MRCP PACES Respiratory Station Case presentation"],
          ['im4bTtQ99SY',"Doctors believe teen lung failure due to vaping  ABC News"],
          ['GV3Rew061FA',"02 Patient Testimonials with Respiratory illness of ITS"],
          ['Nxrz6_e_gwo',"Faces of Work related COPD COPD and Quality of Life "],
          ['q9xteXsPy3c',"It Turned Out To Be Lung Cancer  Lung Cancer Survivor Story Missy Spease"],
          ['POskT8R_3t4',"Laura Story Mayo Clinic Pulmonary Hypertension Vascular Disease Center"],
          ['3Fker8Nmd5Y',"Bilateral Lung Transplant Ben Story"],
          ['OHeU3oj8nmc',"Jeff lung cancer story"],
          ['OkHESl_I2O8',"Life After Lung Transplantation One Man Story"],
          ['4AWZD3ClqW8',"Facing Pulmonary Fibrosis Steve story"],
          ["r20Ak5ZxP_4","Getting Diagnosed with Stage  Lung Cancer Shyreece Story"],
          ["MjEJaR3zLjg","Patient Story Terri Shares How She Got Diagnosed Stage 3A Lung Cancer"],
          ["KFBT8x3DPuM","Pediatrician Don Schuessler Shares His Patient Story of Having RSV"],
          ["HCgXqdpQGhc","Ivy Patient Story How  Got Diagnosed with Stage 4  Lung Cancer"],
          ["E8nRS2LxFdw","Zoe experience with pulmonary embolism"],
          ["n7KHBGEC2Gg","Zara Story Unlikely Cause for Collapsed Lung"],
          ["FHXbDHakK1w","Lung Cancer Survivor Story Stephen Shares How He Got Diagnosed"],
          ["WShT-I0wCO4","John lung cancer story"],
          ["2utaepga5uk","Lung Transplant Patient Story Lynn Carey"],
          ["pmuUnQ5Zi4Q","If You Have Lungs You Can Get Lung Cancer Teri Story"],
          ["-u6I5UVahWg","Lung Cancer Patient John Story"],
          ["dyRmGVgG7_8","Fighting Lung Cancer Oswald Immunotherapy Story"],
          ["aREqsWoX-EY","Christopher Story Lung Cancer Survivor"],
          ["9nRhehMpODk","Barbara Story A Lung Cancer Patient"],
          ["-Tyo2YsA0Y0","A patient experience with lung cancer and treatment"],
          ["ZoEEgU6L-m8","Lung cancer survivor shares his story"],
          ["FH7aHDHnkjU","Pulmonary Fibrosis  Double Lung Transplant Andy Story"],
          ["cfyb39S_CZw","Lung Cancer Screening Patient Story"],
          ["mSYXddFVvHo","Lorcan Lucey Double Lung Transplant Patient Story"],
          ["323hkORG0OM","Lung Cancer Screening and Surgery A Patient Story"],
          ["LYwQdM-2ok4","Lung Cancer Survivor Story Molly Golbon Stage The Patient Story"],
          ["O5DOre3MFlw","The Man in an Iron Lung A Polio Survivor Story"],
          ["bqkquNb5Z8A","Pulmonary Hypertension Tara Story"],
          ["qsAnlV8DUXo","Lorenzo lung transplant success story"],
          ["2pzHkvmRSW8","Hillrom Respiratory Health Brian Story COPD and the Life2000 Ventilation System"],
          ["_4ehrdRPEqE","AleshaStory Research Nurse and Lung Cancer Patient"]]

concIntro=''
videoClosing=''
videoOpen=''
segOpening=''
counter=0
no=1
videoTitle=[]
openingList=[]
row=0
for i in narrConditional2:
    print('i = ',i)
    print()
    col=0
    counter=0
    tempCol=0
    print(i[0])
    
    videoTitle=[]
    openingList=[]
    vidID=''
    
    temp="""
        <html>
        <body>
        more words y y y 
          <tr>
              <th> </th>
          </tr>
          
          

       </body>
       </html>


    """
   
    similCon=''
    maincon=''
    conTaken=[]
    if len(i[1])==2:
        #print('len(i[1])==2')
        #print()
        maincon=str(i[1][0]).upper()
        #print(i[1][0])
        #print()
        for j in i[1][1]:
            if j[0] not in conTaken:
                conTaken.append(j[0])
                similCon+=((str(j[0]).upper())+' , ')
            print(j)
            #print()
    if len(i[1])==3:
        #print('len(i[1])==3')
        #print()
        maincon=str(i[1][0]).upper()
        #print(i[1][0])
        #print()
        for j in i[1][1]:
            if j[0] not in conTaken:
                conTaken.append(j[0])
                similCon+=((str(j[0]).upper())+' , ')
            #print(j)
            #print()
        #print('second half')
        #print()
        #for j in i[1][2]:
        #    print(j)
        #    print()
    print('maincon ',maincon,'   similCon ',similCon)
    print()
    
    
    
    # topic
    
    
    # Make the topic names more readable with spaces
    #######Topic1
    
    


    print('*******************************************')
    print('i[0]= ',i[0])
    
    '''
    if i[0]=='PHYSICAL HEALTH':
        i[0]='PHYSICAL HEALTH'
        
    elif i[0]=='SOCIAL RELATIONSHIP':
        i[0]='SOCIAL RELATIONSHIP' 
        
    elif i[0]=='PSYCHOLOGICAL HEALTH':
        i[0]='PSYCHOLOGICAL HEALTH' 
        
    elif i[0]=='LEVEL OF INDEPENDENCE':
        i[0]='LEVEL OF INDEPENDENCE' 
        
    elif str(i[0])=='PERSONALVALUESANDBELIEFS':
        i[0]='PERSONAL VALUES AND BELIEFS'
    
    else:
        i[0]=str(i[0]).upper()
        
    '''
    
    temp2 = re.findall('[A-Z][^A-Z]*', i[0] )#.split()
    

    topic = ' '.join(temp2)  
    
    #topic2=str(topic2).upper()
    #topic2=i[2][0][1] 
    
    
   
    similCon=similCon.rstrip(' , ')
    videoInto_1='<center><h1> Health-related Quality of Life Needs of Patients with Long-term Respiratory Illnesses</h1></center><br />'
    videoInto_1_1_1_2='<center><h2> This is a collection of video segments from YouTube videos with patient stories. </h2></center><br />'
    videoInto_1_1_1_3='<center><h2> They have been automatically segmented, characterised and linked to domain concepts. </h2></center><br />'
    
    videoInto_1_1_2='<center><h2>The videos in this page have been linked via "Correlative Linking" which means:  </h2></center><br />'
    videoInto_1_1_3='<center><h2> To become aware of a specific concept (Green oval) from a topic T, you will explore videos about a similar concept (Orange oval).</h2></center><br />'
    videoInto_1_1_4='<p style="text-align:center;"><img src="CorrelativeImageForForm.png" alt="Correlative Linking Definition" width="300" height="200"></p>'

            
    
    videoInto_1_2='<center><h2>Become aware of the concepts similar to '+maincon + ' from topic ' +topic.upper()+'.</h2></center><br />' 
    
    #if len(i[1])==2:
    #    if len(conTaken)>1:
    #        videoInto_1_3=similCon+' are similar to '+maincon+'. You are given a collection of video segments about '+similCon+' related to '+topic+'. <br /><br />'
    #    else:
    #        videoInto_1_3=similCon+' is similar to '+maincon+'. You are given a collection of video segments about '+similCon+' related to '+topic+'. <br /><br />'

            
    #elif len(i[1])==3:
    #    if len(conTaken)>1:
    #        videoInto_1_3=similCon+' are similar to '+maincon+'. You are given a collection of video segments about '+similCon+' , '+maincon+'  related to '+topic+'. <br /><br />'
            
    #    else:
    #        videoInto_1_3=similCon+' is similar to '+maincon+'. You are given a collection of video segments about '+similCon+' , '+maincon+'  related to '+topic+'. <br /><br />'

            

        
        
    #video_meta_1='These video segments have been extracted automatically from popular YouTube videos related to the Health-related Quality of Life Needs of Patients with Long-term Respiratory Illnesses.<br /><br />'
    video_meta_2='Each segment will start from a time point in the video and will stop when the corresponding concepts are covered.<br /><br />' 
    video_meta_3='You can re-watch the segment or watch other parts of the video, if you wish so.<br /><br />'
    
    
    #videoOpen='This video is about the topic '+str(i[0]).upper()+' which relates to presentation skills.'
    
    ## video Intro
    ##### in case no segments are there for the FC but for the other correlatived concepts
    subCon=''
    processedCon=[]
    c=0
    #if len(i[1])==2:
    for j in i[1][1]:
        print('j[1][0] ',j[1][0])
        if str(j[1][0])[:5]=='Tyo2YsA0Y01'[:5]:
            j[1][0]='-Tyo2YsA0Y0'

        #if str(j[1][0])[:5]=='l9k9q6FHeX4'[:5]:
        #    vidID='bmvlK4qhAnU'
            
        if j[0] not in processedCon:
            processedCon.append(j[0])# to write each concept one time. aVoid repeating the same concept in the text
            c+=1# to decide to write the word sequence or a video episode only
            subCon+=str(j[0]).upper()+', '# write the sequence of concepts
    '''      
    if c >1:# to write either several episodes if the length >1 or an episode if the length==1
        
        concIntro='From the topic '+ str(i[0] ).upper()+', you will learn about '+str(i[1][0]).upper()+ '. '+subCon+' are similar to '+ str(i[1][0]).upper()+'. Hence, this video will present several episodes that mention '+ subCon+'. '
        partOfvideoClosing=' this video presented you with several video episodes that mention ' 
    else:

        concIntro='From the topic '+ str(i[0] ).upper()+', you will learn about '+str(i[1][0]).upper()+ '. '+subCon[:len(subCon)-2]+' is similar to '+  str(i[1][0]).upper()+'. Hence, this video will present several episodes that mention '+ subCon[:len(subCon)-2]+'. '
        partOfvideoClosing=' this video presented you with a video episode that mentions ' 
    
    # opening seg / closing seg and opena another one
    '''  
    
    if len(i[1])==2:
        #concept
        #worksheet.write(row,col+3,j[1][0])
        #tempCol=col+4
        counter=0
        for j in i[1][1]:
            
            
            for v in videoIDs:
                #print('v[0]= ',v[0])
                
                if str(j[1][0])[:5]=='Tyo2YsA0Y01'[:5]:
                    j[1][0]='-Tyo2YsA0Y0'

                
                    
                    #print('j[1][0] ',j[1][0])
                    #print('str(v[0])[1:5] ',str(v[0])[1:5],'  str(j[1][0])[0:5] ',str(j[1][0])[0:5])
                    #print()

                if str(v[0])[1:5]==str(j[1][0])[0:5]:
                    st=inSecTime(j[1][1])
                    print('st= ',st)
                    #if str(st)=='0':
                    #    st='00'
                    en=inSecTime(j[1][2])
                    videoTitle.append((str(str(v[1])+'.mp4#t='+str(st)+','+str(en))))
                    #if str(j[1][0])[:5]=='l9k9q6FHeX4'[:5]:
                    #    vidID='bmvlK4qhAnU'
                    #else:
                    vidID=v[0]
                    print('video is addedd= ',str(v[1])+'.#t='+str(st)+','+str(en))
                    #print()
                else:
                    print('str(v[0])[0:5] ',str(v[0])[0:5],'  str(j[1][0])[0:5] ',str(j[1][0])[0:5])
                    print()
                    if str(v[0])[0:5]==str(j[1][0])[0:5]:
                        st=inSecTime(j[1][1])
                        print('st= ',st)
                        #if str(st)=='0':
                        #    st='00'
                        en=inSecTime(j[1][2])
                        videoTitle.append((str(str(v[1])+'.mp4#t='+str(st)+','+str(en))))
                        #if str(j[1][0])[:5]=='l9k9q6FHeX4'[:5]:
                        #    vidID='bmvlK4qhAnU'
                        #else:
                        vidID=v[0]
                        
                        print('video is added= ',str(v[1])+'.mp4#t='+str(st)+','+str(en))
                        #print()
                        
            if counter==0:
                segOpening='The next video segment mentions ' + str(j[0] ).upper()+' (related to '+topic+'). The segment is taken from a YouTube video with ID= '+vidID+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
                previousCon=j[0]
                counter+=1
                
            else:
                segOpening='The next video segment mentions ' + str(j[0] ).upper()+' (related to '+topic+'). the segment is taken from a YouTube video with ID= '+vidID+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
                previousCon=j[0]
                counter+=1
                
                    
            openingList.append(segOpening)


            
        if c >1:# to write either several episodes if the length >1 or an episode if the length==1
            videoClosing='You watched video segments about '+similCon+ ' which is similar to '+str(i[1][0]).upper()+' These concepts are related to '+topic.upper()+'. <br\> <br\>'

        else:
        
            videoClosing='You watched a video segment about '+similCon+ ' which is similar to '+str(i[1][0]).upper()+' These concepts are related to '+topic.upper()+'. <br\> <br\>'
        
    
    elif len(i[1])==3:
        counter=0
        for j in i[1][1]:
            
            
            for v in videoIDs:
                #print('v[0]= ',v[0])
                
                if str(j[1][0])[:5]=='Tyo2YsA0Y01'[:5]:
                    j[1][0]='-Tyo2YsA0Y0'

                
                    
                    #print('j[1][0] ',j[1][0])
                    #print('str(v[0])[1:5] ',str(v[0])[1:5],'  str(j[1][0])[0:5] ',str(j[1][0])[0:5])
                    #print()

                if str(v[0])[1:5]==str(j[1][0])[0:5]:
                    st=inSecTime(j[1][1])
                    print('st= ',st)
                    #if str(st)=='0':
                    #    st='00'
                    en=inSecTime(j[1][2])
                    videoTitle.append((str(str(v[1])+'.mp4#t='+str(st)+','+str(en))))
                    #if str(j[1][0])[:5]=='l9k9q6FHeX4'[:5]:
                    #    vidID='bmvlK4qhAnU'
                    #else:
                    vidID=v[0]
                    print('video is addedd= ',str(v[1])+'.#t='+str(st)+','+str(en))
                    #print()
                else:
                    print('str(v[0])[0:5] ',str(v[0])[0:5],'  str(j[1][0])[0:5] ',str(j[1][0])[0:5])
                    print()
                    if str(v[0])[0:5]==str(j[1][0])[0:5]:
                        st=inSecTime(j[1][1])
                        print('st= ',st)
                        #if str(st)=='0':
                        #    st='00'
                        en=inSecTime(j[1][2])
                        videoTitle.append((str(str(v[1])+'.mp4#t='+str(st)+','+str(en))))
                        
                        #if str(j[1][0])[:5]=='l9k9q6FHeX4'[:5]:
                        #    vidID='bmvlK4qhAnU'
                        #else:
                        vidID=v[0]
                        print('video is added= ',str(v[1])+'.mp4#t='+str(st)+','+str(en))
                        #print()
                        
            if counter==0:
                segOpening='The next video segment mentions  ' + str(j[0] ).upper()+' ( related to '+topic.upper()+'). The segment is taken from a YouTube video with ID= '+vidID+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
                previousCon=j[0]
                counter+=1
                
            else:
                segOpening='The next video segment mentions  ' + str(j[0] ).upper()+' ( related to '+topic.upper()+'). The segment is taken from a YouTube video with ID= '+vidID+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
                previousCon=j[0]
                counter+=1
                
            openingList.append(segOpening)
            
                    
        processedCon2=[]
        c2=0
        row+=1
        col=1
        tempCol=col+3
        for j in i[1][2]:
            if j[0] not in processedCon2:
                processedCon.append(j[0])# to write each concept one time. aVoid repeating the same concept in the text
                c2+=1# to decide to write the word sequence or a video episode only
                #subCon+=', '+str(j[0])# write the sequence of concepts
        if c >1:# to write either several episodes if the length >1 or an episode if the length==1
            videoClosing='<h2>You watched several video segments about ('+similCon+ ') which are similar to ('+str(i[1][0]).upper()+') related to '+topic.upper()+'.</h2> <br\> <br\>'

        else:
        
            videoClosing='<h2>You watched a video segment about ('+similCon+ ') which is similar to ('+str(i[1][0]).upper()+') related to '+topic.upper()+'.</h2> <br\> <br\>'
         
        
        
        
        #partOfvideoClosing=' The next videom episode mentions '+str(i[1][0]).upper()+' (which relates to '+str(i[0]).upper()+').<br\>'
        
        for j in i[1][2]:
           
            
            
            for v in videoIDs:
                #print('v[0]= ',v[0])
                
                if str(j[1][0])[:5]=='Tyo2YsA0Y01'[:5]:
                    j[1][0]='-Tyo2YsA0Y0'

                
                    #print('j[1][0] ',j[1][0])
                    #print('str(v[0])[1:5] ',str(v[0])[1:5],'  str(j[1][0])[0:5] ',str(j[1][0])[0:5])
                    #print()

                if str(v[0])[1:5]==str(j[1][0])[0:5]:
                    st=inSecTime(j[1][1])
                    print('st= ',st)
                    #if str(st)=='0':
                    #    st='00'
                    en=inSecTime(j[1][2])
                    videoTitle.append((str(str(v[1])+'.mp4#t='+str(st)+','+str(en))))

                    #if str(j[1][0])[:5]=='l9k9q6FHeX4'[:5]:
                    #    vidID='bmvlK4qhAnU'
                    #else:
                    vidID=v[0]
                    print('video is addedd= ',str(v[1])+'.#t='+str(st)+','+str(en))
                    #print()
                else:
                    print('str(v[0])[0:5] ',str(v[0])[0:5],'  str(j[1][0])[0:5] ',str(j[1][0])[0:5])
                    print()
                    if str(v[0])[0:5]==str(j[1][0])[0:5]:
                        st=inSecTime(j[1][1])
                        print('st= ',st)
                        #if str(st)=='0':
                        #    st='00'
                        en=inSecTime(j[1][2])
                        videoTitle.append((str(str(v[1])+'.mp4#t='+str(st)+','+str(en))))
                        
                        #if str(j[1][0])[:5]=='l9k9q6FHeX4'[:5]:
                        #    vidID='bmvlK4qhAnU'
                        #else:
                        vidID=v[0]
                        print('video is added= ',str(v[1])+'.mp4#t='+str(st)+','+str(en))
                        #print()
                        
            partOfvideoClosing=' The next video segment mentions '+str(i[1][0]).upper()+' ( related to '+topic.upper()+'). The segment is taken from a YouTube video with ID= '+vidID+' , and starts at '+str(j[1][1])+' with a duration of '+str(j[1][3])+' seconds.'
            openingList.append(partOfvideoClosing)
                    
    additionalText=''
    print('len(openingList) ',len(openingList),'   len(videoTitle) ',len(videoTitle))
    print()
    for s in range(0,len(openingList)):
        additionalText+='<p>'
        #additionalText+='/n'
        additionalText+='<br />'
        additionalText+=str(openingList[s])
        #additionalText+='/n'
        additionalText+='<br />'
        additionalText+='</p>'
        additionalText+='<br />'
        #additionalText+='/n'
        #additionalText+='<p>'
        #additionalText+='/n'
        additionalText+="<video  width='400' height='200' class='demoVideo' controls>"
        #additionalText+='/n'
        additionalText+='<source src= "'+str(videoTitle[s])+' " type="video/mp4">'
        #additionalText+='/n'
        additionalText+="</video>" 
        additionalText+='<br />'
        additionalText+='<br />'
        #additionalText+='/n'
        #additionalText+='</p>'
        #additionalText+='/n'
    #additionalText+='"""'
    print('additional text')
    
    print(additionalText)
    print()
    meta_closing_1='The segments were automatically extracted from popular YouTube videos related to the Health-related Quality of Life Needs of Patients with Long-term Respiratory Illnesses, using algorithms for segmentation, characterisation and linking based on a theory for concept learning.<br/><br/> '    
    meta_closing_2='We hope you found the collection of video segments helpful. <br/><br/>'
    
    #videoClose='You have watched a video to learn about using the two topics ' +i[2][0][0]+', '+i[2][0][1]+' relevant to presentation skills.'
    elements = temp.split("more words y y y ")
    fileName='CorrelativeNarrativeWebPage'+str(no)+'.html'
    no+=1
    newFile=elements[0]+videoInto_1+videoInto_1_1_1_2+videoInto_1_1_1_3+videoInto_1_1_2+videoInto_1_1_3+videoInto_1_1_4+videoInto_1_2+video_meta_2+video_meta_3+ additionalText +videoClosing+meta_closing_1+meta_closing_2+elements[1]
    f = open(fileName, 'w', encoding="utf-8")
    
    
    f.write(newFile)

    f.close()
# Out:
# i =  ['PsychologicalHealth', ['Thinking', [['MentalHealth', ['4AWZD3ClqW85', 3.01, 3.44, 43, ['Exercise', 1.0, 'MentalHealth', 2.0, 'Family', 1.0], []]], ['Concentration', ['WShT-I0wCO418', 5.06, 5.37, 31, ['Concentration', 1.0, 'Strength', 1.0], []]]], [['Thinking', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Thinking', ['hQQ5xQGZxdA37', 8.1, 8.47, 37, ['Thinking', 1.0], []]], ['Thinking', ['xY3B9nLm1u88', 1.54, 3.5, 116, ['Pain', 3.0, 'Sleep', 1.0, 'Thinking', 1.0], []]], ['Thinking', ['OHeU3oj8nmc20', 4.15, 4.49, 33, ['Gym', 1.0, 'Grandchild', 2.0, 'Thinking', 1.0], []]]]]]
#
# PsychologicalHealth
# maincon  THINKING    similCon  MENTALHEALTH , CONCENTRATION ,
#
# *******************************************
# i[0]=  PsychologicalHealth
# j[1][0]  4AWZD3ClqW85
# j[1][0]  WShT-I0wCO418
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  4AWZD
#
# st=  181
# video is added=  Facing Pulmonary Fibrosis Steve story.mp4#t=181,224
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  4AWZD
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  WShT-
#
# st=  306
# video is added=  John lung cancer story.mp4#t=306,337
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  WShT-
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  Mxmrj
#
# st=  0
# video is added=  Becca lung cancer story.mp4#t=0,40
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  hQQ5x
#
# st=  490
# video is added=  Lung Cancer Survivor Story Dave.mp4#t=490,527
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  xY3B9
#
# st=  114
# video is added=  Nick lung cancer story.mp4#t=114,230
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  xY3B9
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  OHeU3
#
# st=  255
# video is added=  Jeff lung cancer story.mp4#t=255,289
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  OHeU3
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  OHeU3
#
# len(openingList)  6    len(videoTitle)  6
#
# additional text
# <p><br />The next video segment mentions  MENTALHEALTH ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= 4AWZD3ClqW8 , and starts at 3.01 with a duration of 43 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Facing Pulmonary Fibrosis Steve story.mp4#t=181,224 " type="video/mp4"></video><br /><br /><p><br />The next video segment mentions  CONCENTRATION ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= WShT-I0wCO4 , and starts at 5.06 with a duration of 31 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "John lung cancer story.mp4#t=306,337 " type="video/mp4"></video><br /><br /><p><br /> The next video segment mentions THINKING ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= MxmrjLQvg7E , and starts at 0.0 with a duration of 40 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Becca lung cancer story.mp4#t=0,40 " type="video/mp4"></video><br /><br /><p><br /> The next video segment mentions THINKING ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= hQQ5xQGZxdA , and starts at 8.1 with a duration of 37 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Lung Cancer Survivor Story Dave.mp4#t=490,527 " type="video/mp4"></video><br /><br /><p><br /> The next video segment mentions THINKING ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= xY3B9nLm1u8 , and starts at 1.54 with a duration of 116 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Nick lung cancer story.mp4#t=114,230 " type="video/mp4"></video><br /><br /><p><br /> The next video segment mentions THINKING ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= OHeU3oj8nmc , and starts at 4.15 with a duration of 33 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Jeff lung cancer story.mp4#t=255,289 " type="video/mp4"></video><br /><br />
#
# i =  ['SocialRelationship', ['Mum', [['Child', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Dad', ['mWo-G3UQ-zU1', 0.0, 2.16, 136, ['Dad', 3.0, 'Temple', 2.0], ['Family', 1.0, 'Energy', 1.0]]], ['Caregiver', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Wife', ['hQQ5xQGZxdA31', 6.52, 7.28, 36, ['Wife', 1.0], []]]], []]]
#
# SocialRelationship
# maincon  MUM    similCon  CHILD , DAD , CAREGIVER , WIFE ,
#
# *******************************************
# i[0]=  SocialRelationship
# j[1][0]  rQutyErqBG012
# j[1][0]  mWo-G3UQ-zU1
# j[1][0]  hQQ5xQGZxdA1
# j[1][0]  hQQ5xQGZxdA31
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  rQuty
#
# st=  205
# video is added=  Lung Cancer Patient Stories.mp4#t=205,241
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  mWo-G
#
# st=  0
# video is added=  Ralph Patient Story.mp4#t=0,136
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  mWo-G
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  hQQ5x
#
# st=  1
# video is added=  Lung Cancer Survivor Story Dave.mp4#t=1,83
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  hQQ5x
#
# st=  412
# video is added=  Lung Cancer Survivor Story Dave.mp4#t=412,448
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  hQQ5x
#
# len(openingList)  4    len(videoTitle)  4
#
# additional text
# <p><br />The next video segment mentions  CHILD ( related to SOCIAL RELATIONSHIP). The segment is taken from a YouTube video with ID= rQutyErqBG0 , and starts at 3.25 with a duration of 35 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Lung Cancer Patient Stories.mp4#t=205,241 " type="video/mp4"></video><br /><br /><p><br />The next video segment mentions  DAD ( related to SOCIAL RELATIONSHIP). The segment is taken from a YouTube video with ID= mWo-G3UQ-zU , and starts at 0.0 with a duration of 136 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Ralph Patient Story.mp4#t=0,136 " type="video/mp4"></video><br /><br /><p><br />The next video segment mentions  CAREGIVER ( related to SOCIAL RELATIONSHIP). The segment is taken from a YouTube video with ID= hQQ5xQGZxdA , and starts at 0.01 with a duration of 82 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Lung Cancer Survivor Story Dave.mp4#t=1,83 " type="video/mp4"></video><br /><br /><p><br />The next video segment mentions  WIFE ( related to SOCIAL RELATIONSHIP). The segment is taken from a YouTube video with ID= hQQ5xQGZxdA , and starts at 6.52 with a duration of 36 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Lung Cancer Survivor Story Dave.mp4#t=412,448 " type="video/mp4"></video><br /><br />
#
# i =  ['LevelOfIndependence', ['Treatment', [['Mobility', ['FH7aHDHnkjU1', 0.03, 1.34, 91, ['PulmonaryFibrosis', 3.0, 'Mobility', 1.0, 'Cough', 1.0], []]]], [['Treatment', ['MxmrjLQvg7E1', 0.0, 0.4, 40, ['Thinking', 1.0, 'Mum', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['rQutyErqBG012', 3.25, 4.01, 35, ['Treatment', 1.0, 'Pain', 1.0, 'Noise', 1.0, 'Child', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA1', 0.01, 1.23, 82, ['Caregiver', 2.0, 'LungCancer', 2.0, 'Treatment', 1.0], []]], ['Treatment', ['hQQ5xQGZxdA61', 13.25, 14.02, 37, ['Treatment', 1.0], []]]]]]
#
# LevelOfIndependence
# maincon  TREATMENT    similCon  MOBILITY ,
#
# *******************************************
# i[0]=  LevelOfIndependence
# j[1][0]  FH7aHDHnkjU1
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  FH7aH
#
# st=  3
# video is added=  Pulmonary Fibrosis  Double Lung Transplant Andy Story.mp4#t=3,94
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  FH7aH
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  Mxmrj
#
# st=  0
# video is added=  Becca lung cancer story.mp4#t=0,40
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  Mxmrj
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  rQuty
#
# st=  205
# video is added=  Lung Cancer Patient Stories.mp4#t=205,241
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  rQuty
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  hQQ5x
#
# st=  1
# video is added=  Lung Cancer Survivor Story Dave.mp4#t=1,83
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  hQQ5x
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  hQQ5x
#
# ...
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  q9xte
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  -Tyo2
#
# st=  172
# video is added=  A patient experience with lung cancer and treatment.mp4#t=172,231
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  -Tyo2
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  cfyb3
#
# st=  80
# video is added=  Lung Cancer Screening Patient Story.mp4#t=80,125
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  cfyb3
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  cfyb3
#
# len(openingList)  4    len(videoTitle)  4
#
# additional text
# <p><br />The next video segment mentions  FEAR ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= wwiwjZw7d6o , and starts at 1.14 with a duration of 118 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Young women can get lung cancer Joanna story.mp4#t=74,192 " type="video/mp4"></video><br /><br /><p><br />The next video segment mentions  GUILT ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= q9xteXsPy3c , and starts at 0.36 with a duration of 33 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "It Turned Out To Be Lung Cancer  Lung Cancer Survivor Story Missy Spease.mp4#t=36,69 " type="video/mp4"></video><br /><br /><p><br />The next video segment mentions  FEAR ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= -Tyo2YsA0Y0 , and starts at 2.52 with a duration of 58 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "A patient experience with lung cancer and treatment.mp4#t=172,231 " type="video/mp4"></video><br /><br /><p><br /> The next video segment mentions SCARED ( related to PSYCHOLOGICAL HEALTH). The segment is taken from a YouTube video with ID= cfyb39S_CZw , and starts at 1.2 with a duration of 44 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Lung Cancer Screening Patient Story.mp4#t=80,125 " type="video/mp4"></video><br /><br />
#
# i =  ['PersonalValuesAndBeliefs', ['Belief', [['Meditation', ['HBFn82ffSVE18', 4.25, 6.14, 108, ['Meditation', 3.0], ['Anxiety', 1.0, 'Thinking', 1.0, 'LungCancer', 1.0, 'Dad', 1.0]]]], [['Belief', ['mSYXddFVvHo4', 0.52, 1.28, 36, ['Belief', 1.0, 'Hope', 1.0], []]]]]]
#
# PersonalValuesAndBeliefs
# maincon  BELIEF    similCon  MEDITATION ,
#
# *******************************************
# i[0]=  PersonalValuesAndBeliefs
# j[1][0]  HBFn82ffSVE18
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  HBFn8
#
# st=  265
# video is added=  Peter lung cancer story.mp4#t=265,374
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  HBFn8
#
# str(v[0])[0:5]  Mxmrj   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  rQuty   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  mWo-G   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  hQQ5x   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  xY3B9   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  yV893   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  wwiwj   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  uJoY4   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  l9k9q   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  j3t5n   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  tfxB3   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  0fI_0   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  HBFn8   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  llk-q   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  3mcWS   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  bmvlK   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  wArV8   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  ehh89   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  VyGp1   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  jZJTc   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  ZU_l9   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  Nl55T   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  6U7Op   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  e0KVt   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  aHAbR   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  im4bT   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  GV3Re   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  Nxrz6   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  q9xte   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  POskT   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  3Fker   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  OHeU3   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  OkHES   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  4AWZD   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  r20Ak   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  MjEJa   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  KFBT8   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  HCgXq   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  E8nRS   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  n7KHB   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  FHXbD   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  WShT-   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  2utae   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  pmuUn   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  -u6I5   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  dyRmG   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  aREqs   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  9nRhe   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  -Tyo2   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  ZoEEg   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  FH7aH   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  cfyb3   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  mSYXd   str(j[1][0])[0:5]  mSYXd
#
# st=  52
# video is added=  Lorcan Lucey Double Lung Transplant Patient Story.mp4#t=52,88
# str(v[0])[0:5]  323hk   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  LYwQd   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  O5DOr   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  bqkqu   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  qsAnl   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  2pzHk   str(j[1][0])[0:5]  mSYXd
#
# str(v[0])[0:5]  _4ehr   str(j[1][0])[0:5]  mSYXd
#
# len(openingList)  2    len(videoTitle)  2
#
# additional text
# <p><br />The next video segment mentions  MEDITATION ( related to PERSONAL VALUES AND BELIEFS). The segment is taken from a YouTube video with ID= HBFn82ffSVE , and starts at 4.25 with a duration of 108 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Peter lung cancer story.mp4#t=265,374 " type="video/mp4"></video><br /><br /><p><br /> The next video segment mentions BELIEF ( related to PERSONAL VALUES AND BELIEFS). The segment is taken from a YouTube video with ID= mSYXddFVvHo , and starts at 0.52 with a duration of 36 seconds.<br /></p><br /><video  width='400' height='200' class='demoVideo' controls><source src= "Lorcan Lucey Double Lung Transplant Patient Story.mp4#t=52,88 " type="video/mp4"></video><br /><br />
